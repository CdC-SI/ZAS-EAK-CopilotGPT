# %% [markdown]
# # AI usecase decision tree optimization

# %% [markdown]
# ## Processing

# %% [markdown]
# ### Process the answers

# %% [markdown]
# #### Group identical nodes

# %%
def group_identical_answer_nodes(tree):
    grouped_answers = {}
    replace_by = []
    to_modify = set()
    new_tree = []

    for item in tree:
        if item['type'] == 'answer':
            output = item['content']
            for source in item['source']:
                output += ", " + source

            if output not in grouped_answers:
                grouped_answers[output] = []
            grouped_answers[output].append(item)

    for sources, items in grouped_answers.items():
        first_item = items[0]
        deleted_nodes = [item['id'] for item in items[1:]]

        in_values = []
        for item in items:
            if 'in' in item:
                in_values.extend(item['in'] if isinstance(item['in'], list) else [item['in']])
        to_modify.update(in_values)

        first_item['in'] = in_values

        replace_by.append({
            "id": first_item['id'],
            "deleted_nodes": deleted_nodes
        })

        new_tree.append(first_item)

    # Add untouched nodes
    for item in tree:
        if item['type'] != 'answer':
            new_tree.append(item)

    return new_tree, replace_by, list(to_modify)

# %% [markdown]
# #### Update parent nodes

# %%
def update_question_nodes(tree, replace_by, to_modify):
    updated_tree = []

    for item in tree:
        if item['type'] == 'question':
            if item['id'] in to_modify:
                updated_item = item.copy()

                for mapping in replace_by:
                    if updated_item['yes'] in mapping['deleted_nodes']:
                        updated_item['yes'] = mapping['id']
                        break

                for mapping in replace_by:
                    if updated_item['no'] in mapping['deleted_nodes']:
                        updated_item['no'] = mapping['id']
                        break

                updated_tree.append(updated_item)
            else:
                updated_tree.append(item)
        else:
            updated_tree.append(item)

    return updated_tree

# %% [markdown]
# ### Process the question nodes

# %% [markdown]
# #### Group identical nodes

# %%
def group_identical_question_nodes(tree, to_modify):
    grouped_questions = {}
    question_replace_by = []
    question_to_modify = set()
    updated_tree = []
    processed = []

    # Collect question nodes from new_tree
    question_nodes = [node for node in tree if node['type'] == 'question' and node['id'] in to_modify]

    # Group question nodes by (content, yes, no)
    for item in question_nodes:
        key = (item['content'], item['yes'], item['no'])
        if key not in grouped_questions:
            grouped_questions[key] = []
        grouped_questions[key].append(item)

    # Process groups
    for key, items in grouped_questions.items():
        if len(items) > 1:
            first_item = items[0]
            deleted_nodes = [item['id'] for item in items[1:]]

            # Merge 'in' values
            in_values = []
            for item in items:
                if 'in' in item:
                    in_values.extend(item['in'] if isinstance(item['in'], list) else [item['in']])

            question_to_modify.update(in_values)

            # Update 'in' of surviving node
            first_item['in'] = in_values
            
            # Add to question_replace_by mapping
            question_replace_by.append({
                "id": first_item['id'],
                "deleted_nodes": deleted_nodes
            })

            updated_tree.append(first_item)
        # else:
        #     updated_tree.append(items[0])

    # # Add untouched question nodes
    # for item in tree:
    #     if item['type'] == 'question' and item['id'] not in [q['id'] for group in grouped_questions.values() for q in group]:
    #         updated_tree.append(item)

    # # Add answer nodes
    # for item in tree:
    #     if item['type'] == 'answer':
    #         updated_tree.append(item)

    # processed = []
    for q in question_replace_by:
        processed.append(q['id'])
        processed.extend(q['deleted_nodes'])

    return updated_tree, question_replace_by, list(question_to_modify), processed

# %% [markdown]
# #### Update parent nodes

# %%
def update_remaining_question_nodes(tree, new_tree, question_replace_by, question_to_modify, processed):
    updated_tree = new_tree

    for item in tree:

        # Check if this question node's id is in question_to_modify
        if item['id'] in question_to_modify:
            updated_item = item.copy()

            # Update 'yes' value if needed
            for mapping in question_replace_by:
                if updated_item['yes'] in mapping['deleted_nodes']:
                    updated_item['yes'] = mapping['id']
                    break

            # Update 'no' value if needed
            for mapping in question_replace_by:
                if updated_item['no'] in mapping['deleted_nodes']:
                    updated_item['no'] = mapping['id']
                    break

            # Add updated question node
            updated_tree.append(updated_item)
        # Node is not affected, just copy
        elif item['id'] not in processed:
            updated_tree.append(item)

    return updated_tree

# %% [markdown]
# ### Iteration over the tree

# %%
def reduce_tree(tree):
    print("Starting reduction...")    
    print("current node count: ", len(tree))

    # Step 1: Merge identical answers and update parents
    new_tree, replace_by, to_modify = group_identical_answer_nodes(tree)
    new_tree = update_question_nodes(new_tree, replace_by, to_modify)

    # Save original tree
    tree = new_tree

    while True:
        print("current node count: ", len(tree))

        # Step 2: Merge identical questions layer by layer
        new_tree, question_replace_by, question_to_modify, processed = group_identical_question_nodes(new_tree, to_modify)
        new_tree = update_remaining_question_nodes(tree, new_tree, question_replace_by, question_to_modify, processed)

        if len(new_tree) == len(tree):
            break  # No further reduction
        else:
            # Move to next row
            to_modify = question_to_modify 
            tree = new_tree

    print("Reduction complete.")
    return new_tree

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Load the data

# %%
import json

# Load the PDF paths from the JSON file
with open('data/sources/tree.json', 'r') as file:
    tree = json.load(file)

# %% [markdown]
# ### Process the data

# %%
final_tree = reduce_tree(tree)
# Out:
# Starting reduction...
# current node count:  95
# current node count:  65
# current node count:  61
# Reduction complete.

# %% [markdown]
# ### Save the new tree

# %%
# Save the new_tree structure to a JSON file
with open('data/output/final_tree.json', 'w') as json_file:
    json.dump(final_tree, json_file, ensure_ascii=False)

print(f"Data saved to data/output/final_tree.json")
# Out:
# Data saved to data/output/final_tree.json

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### Load the trees

# %%
with open('data/output/final_tree.json', 'r') as file:
    optimized_tree = json.load(file)

with open('data/sources/tree.json', 'r') as file:
    original_tree = json.load(file)

# %%
# Preprocess the tree: {id: node}
opti_dict = {node['id']: node for node in optimized_tree}
og_dict = {node['id']: node for node in original_tree}

# %% [markdown]
# ### Find the root

# %%
root = tree[0]
for node in tree:
    if node['in'] == []:
        root = node
        break
root['id']
# Out:
# 'b26'

# %% [markdown]
# ### Exploring functions

# %% [markdown]
# #### Explore a specific path

# %%
def explore_custom_path(start_id, tree_dict, path_choices):
    current_id = start_id
    path = []
    choice_index = 0

    while True:
        node = tree_dict.get(current_id)

        if not node:
            print(f"Node with id {current_id} not found!")
            break

        path.append(node)

        if node['type'] == 'answer':
            print(f"Reached answer node: {node['id']}")
            break

        # Determine which branch to follow
        if choice_index >= len(path_choices):
            print(f"No more choices left, stopping at node {node['id']}")
            break

        choice = path_choices[choice_index]
        if choice not in ["yes", "no"]:
            print(f"Invalid choice '{choice}' at step {choice_index}, stopping.")
            break

        current_id = node[choice]
        choice_index += 1

    return path

# %% [markdown]
# #### Explore all possible paths

# %%
def explore_all_paths(start_id, tree_dict):
    all_paths = []

    def dfs(current_id, current_path):
        node = tree_dict.get(current_id)
        if not node:
            print(f"Node with id {current_id} not found!")
            return

        # Add current node to the path
        current_path.append(node)

        # If answer node, record path
        if node['type'] == 'answer':
            all_paths.append(list(current_path))  # Copy of current_path
        else:
            # Recurse on "yes" branch
            dfs(node['yes'], list(current_path))  # Copy to avoid mutation

            # Recurse on "no" branch
            dfs(node['no'], list(current_path))

    dfs(start_id, [])
    return all_paths

# %% [markdown]
# #### Display a path

# %%
def display_path(path):
    print("Explored Path:")
    for node in path:
        if node['type'] == 'question':
            print(f"Node ID: {node['id']}, Content: {node['content']}")
        if node['type'] == 'answer':
            print(f"Node ID: {node['id']}, Content: {node['content']}, Sources: {node['source']}")

# %% [markdown]
# ### Explore the optimized tree

# %% [markdown]
# #### Specific path

# %%
custom_path = ["yes", "no", "yes", "yes"]
opti_test_path = explore_custom_path(root['id'], opti_dict, custom_path)

display_path(opti_test_path)
# Out:
# Reached answer node: g2
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: g2, Content: Rente par pallier, Sources: ['Lettre c des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)']

# %% [markdown]
# #### All paths

# %%
opti_all_paths = explore_all_paths(root['id'], opti_dict)

print(len(opti_all_paths), "Possible Paths")
# Out:
# 48 Possible Paths

# %%
all_paths_reduced = []

for path in opti_all_paths:
    reduced_path = {'path': [], 'answer': ''}
    for i, node in enumerate(path):
        if node['type'] == 'question':
            if node['yes'] == path[i+1]['id']:
                reduced_path['path'].append('yes')
            else:
                reduced_path['path'].append('no')
        else:
            reduced_path['answer'] = f"Décision: {node['content']}, Sources: {node['source']}"
    all_paths_reduced.append(reduced_path)

# Save the new_tree structure to a JSON file
with open('data/output/all_paths.json', 'w') as json_file:
    json.dump(all_paths_reduced, json_file, ensure_ascii=False)

print(f"Data saved to data/output/all_paths.json")
# Out:
# Data saved to data/output/all_paths.json

# %% [markdown]
# ### Explore the original tree

# %% [markdown]
# #### All paths

# %%
og_all_paths = explore_all_paths(root['id'], og_dict)

print(len(og_all_paths), "Possible Paths")
# Out:
# 48 Possible Paths

# %% [markdown]
# ### Compare outcomes

# %%
similarity_ratio = 0

for i, path in enumerate(og_all_paths):
    print(f"Path {i}:")

    print(f"\nOriginal")
    display_path(path)

    print(f"\nOptimized")
    display_path(opti_all_paths[i])
    print(path[-1])

    og_outcome = f"{path[-1]['content']}, source: {path[-1]['source']}"
    opti_outcome = f"{opti_all_paths[i][-1]['content']}, source: {opti_all_paths[i][-1]['source']}"

    if og_outcome == opti_outcome:
        print(f"\nSame outcome:")
        print(f"Outcome: {og_outcome}")
        similarity_ratio += 1
        
    else:
        print(f"\nDifferent outcomes:")
        print(f"Optimized outcome: {opti_outcome}")
        print(f"Original outcome: {og_outcome}")

    print("\n----------------------------------------\n")

print(f"Similarity Ratio: {similarity_ratio / len(og_all_paths) * 100}%")
# Out:
# Path 0:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k30, Content: Est-il augmentÃ© ?
# Node ID: n30, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t30, Content: Rente linÃ©aire, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k30, Content: Est-il augmentÃ© ?
# Node ID: r44, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t45, Content: Rente linÃ©aire, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 't30', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'n30'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 1:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k30, Content: Est-il augmentÃ© ?
# Node ID: n30, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t31, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k30, Content: Est-il augmentÃ© ?
# Node ID: r44, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j21, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 't31', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'n30'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 2:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k30, Content: Est-il augmentÃ© ?
# Node ID: n32, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t32, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k30, Content: Est-il augmentÃ© ?
# Node ID: n32, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j21, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 't32', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'n32'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 3:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k30, Content: Est-il augmentÃ© ?
# Node ID: n32, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t33, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)', 'Art. 88bis al. 2 RAI']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k30, Content: Est-il augmentÃ© ?
# Node ID: n32, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t33, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)', 'Art. 88bis al. 2 RAI']
# {'id': 't33', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)', 'Art. 88bis al. 2 RAI'], 'in': 'n32'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)', 'Art. 88bis al. 2 RAI']
#
# ----------------------------------------
#
# Path 4:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k28, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m28, Content: Rente linÃ©aire, Sources: ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k28, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m29, Content: Rente linÃ©aire, Sources: ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'm28', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'k28'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 5:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k28, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m29, Content: Rente linÃ©aire, Sources: ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h28, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k28, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m29, Content: Rente linÃ©aire, Sources: ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'm29', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'k28'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 6:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h26, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j26, Content: Rente linÃ©aire, Sources: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e18, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: g18, Content: Rente linÃ©aire, Sources: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'j26', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'h26'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 7:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h26, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j27, Content: Rente linÃ©aire, Sources: ['Ch. 9102 CIRAI', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e26, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e18, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: g19, Content: Rente linÃ©aire, Sources: ['Ch. 9102 CIRAI', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'j27', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Ch. 9102 CIRAI', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'h26'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Ch. 9102 CIRAI', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 8:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: j34, Content: Rente par pallier, Sources: ['Lettre c des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: g2, Content: Rente par pallier, Sources: ['Lettre c des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)']
# {'id': 'j34', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Lettre c des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)'], 'in': 'h34'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Lettre c des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)']
#
# ----------------------------------------
#
# Path 9:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r36, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: u37, Content: Le taux d'invaliditÃ© est-il d'au-moins 70% ?
# Node ID: w37, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r36, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: u37, Content: Le taux d'invaliditÃ© est-il d'au-moins 70% ?
# Node ID: j21, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'w37', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'u37'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 10:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r36, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: u37, Content: Le taux d'invaliditÃ© est-il d'au-moins 70% ?
# Node ID: w38, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r36, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: u37, Content: Le taux d'invaliditÃ© est-il d'au-moins 70% ?
# Node ID: m22, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'w38', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'u37'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 11:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r36, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t36, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r36, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m22, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 't36', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'r36'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 12:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r39, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t40, Content: Rente linÃ©aire, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r44, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t45, Content: Rente linÃ©aire, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 't40', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'r39'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 13:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r39, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t39, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p36, Content: Le montant de la rente est-il diminuÃ© ?
# Node ID: r44, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j21, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 't39', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'r39'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 14:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r41, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: u42, Content: Le taux d'invaliditÃ© est-il d'au-moins 50% ?
# Node ID: w42, Content: Rente par pallier, Sources: ['Ch. 9212 CIRAI', 'Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r41, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: u42, Content: Le taux d'invaliditÃ© est-il d'au-moins 50% ?
# Node ID: w42, Content: Rente par pallier, Sources: ['Ch. 9212 CIRAI', 'Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'w42', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Ch. 9212 CIRAI', 'Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'u42'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Ch. 9212 CIRAI', 'Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 15:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r41, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: u42, Content: Le taux d'invaliditÃ© est-il d'au-moins 50% ?
# Node ID: w43, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r41, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: u42, Content: Le taux d'invaliditÃ© est-il d'au-moins 50% ?
# Node ID: m22, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'w43', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'u42'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 16:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r41, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t41, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r41, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m22, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 't41', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'r41'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 17:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r44, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t45, Content: Rente linÃ©aire, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r44, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t45, Content: Rente linÃ©aire, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 't45', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'r44'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 18:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r44, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: t44, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n36, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: p41, Content: Le montant de la rente est-il augmentÃ© ?
# Node ID: r44, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j21, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 't44', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'r44'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 19:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: m35, Content: Rente par pallier, Sources: ['Art 17 al. 1 let. b LPGA']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h34, Content: L'Ã¢ge de lâ€™assurÃ©, au 01.01.2022, est-il Ã©gal ou supÃ©rieur (=>) Ã  55 ans ?
# Node ID: k35, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: j3, Content: Rente par pallier, Sources: ['Art 17 al. 1 let. b LPGA']
# {'id': 'm35', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Art 17 al. 1 let. b LPGA'], 'in': 'k35'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Art 17 al. 1 let. b LPGA']
#
# ----------------------------------------
#
# Path 20:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h46, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: k47, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: m47, Content: Rente linÃ©aire, Sources: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)', 'Ch. 9102 CIRAI']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h46, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: k47, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: m47, Content: Rente linÃ©aire, Sources: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)', 'Ch. 9102 CIRAI']
# {'id': 'm47', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)', 'Ch. 9102 CIRAI'], 'in': 'k47'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)', 'Ch. 9102 CIRAI']
#
# ----------------------------------------
#
# Path 21:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h46, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: k47, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n48, Content: Changement de palier selon l'ancien systÃ¨me?
# Node ID: t48, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Ch. 9212 CIRAI']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h46, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: k47, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k16, Content: Changement de palier selon l'ancien systÃ¨me?
# Node ID: t16, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Ch. 9212 CIRAI']
# {'id': 't48', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Ch. 9212 CIRAI'], 'in': 'n48'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Ch. 9212 CIRAI']
#
# ----------------------------------------
#
# Path 22:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h46, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: k47, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: n48, Content: Changement de palier selon l'ancien systÃ¨me?
# Node ID: t49, Content: Rente par pallier, Sources: ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Ch. 9211 CIRAI']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: c26, Content: Droit ouvert dans le systÃ¨me linÃ©aire ?
# Node ID: e34, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: h46, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: k47, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: k16, Content: Changement de palier selon l'ancien systÃ¨me?
# Node ID: t17, Content: Rente par pallier, Sources: ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Ch. 9211 CIRAI']
# {'id': 't49', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Lettre b point 1 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Ch. 9211 CIRAI'], 'in': 'n48'}
#
# Same outcome:
# ...
# {'id': 'g14', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Art 17 al. 1 let. b LPGA', 'Art. 87 RAI', 'Ch. 5101 CIRAI'], 'in': 'e14'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Art 17 al. 1 let. b LPGA', 'Art. 87 RAI', 'Ch. 5101 CIRAI']
#
# ----------------------------------------
#
# Path 40:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h22, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: k22, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m22, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h22, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: k22, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m22, Content: Rente par pallier, Sources: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'm22', 'type': 'answer', 'content': 'Rente par pallier', 'source': ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'k22'}
#
# Same outcome:
# Outcome: Rente par pallier, source: ['Lettre b points 1 et 2 des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 41:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h22, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: k22, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m23, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h22, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: k22, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j21, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'm23', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'k22'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 42:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h22, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: k24, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m24, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h22, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: k24, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j21, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'm24', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'k24'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 43:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h22, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: k24, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m25, Content: Rente linÃ©aire, Sources: ['Art. 88bis al. 2 RAI', 'Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h22, Content: Le degrÃ© dâ€™invaliditÃ© est-il augmentÃ© ?
# Node ID: k24, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: m25, Content: Rente linÃ©aire, Sources: ['Art. 88bis al. 2 RAI', 'Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'm25', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art. 88bis al. 2 RAI', 'Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'k24'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art. 88bis al. 2 RAI', 'Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 44:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h20, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j20, Content: Rente linÃ©aire, Sources: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h20, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: g18, Content: Rente linÃ©aire, Sources: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'j20', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'h20'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 45:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h20, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j21, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e20, Content: Le degrÃ© dâ€™invaliditÃ© sâ€™est-il modifiÃ© dâ€™au-moins 5% ?
# Node ID: h20, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: j21, Content: Rente linÃ©aire, Sources: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'j21', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'h20'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Art 17 al. 1 let. b LPGA', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 46:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e18, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: g18, Content: Rente linÃ©aire, Sources: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e18, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: g18, Content: Rente linÃ©aire, Sources: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'g18', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'e18'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Path 47:
#
# Original
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e18, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: g19, Content: Rente linÃ©aire, Sources: ['Ch. 9102 CIRAI', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# Optimized
# Explored Path:
# Node ID: b26, Content: S'agit-il d'une rÃ©vision sur demande ou d'une rÃ©vision d'office?
# Node ID: b2, Content: S'agit-il d'une 1Ã¨re demande RER ou demande subsÃ©quente dÃ©pÃ´sÃ©e avant le 01.07.2021 et Ã©chÃ©ance dÃ©lai de carence avant le 01.01.2022?
# Node ID: c18, Content: Y a-t-il eu une modification des faits entre le 01.01.2022 et le 31.12.2023 ?
# Node ID: e18, Content: Y a-t-il eu une augmentation du taux depuis le 01.01.2024 ?
# Node ID: g19, Content: Rente linÃ©aire, Sources: ['Ch. 9102 CIRAI', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
# {'id': 'g19', 'type': 'answer', 'content': 'Rente linÃ©aire', 'source': ['Ch. 9102 CIRAI', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)'], 'in': 'e18'}
#
# Same outcome:
# Outcome: Rente linÃ©aire, source: ['Ch. 9102 CIRAI', 'Lettre 1 des dispositions transitoires relatives Ã\xa0 la modification du 18 octobre 2023 (RAI)']
#
# ----------------------------------------
#
# Similarity Ratio: 100.0%

# %%
def check_path(path):
    found = False
    for p in all_paths_reduced:
        if path == p['path']:
            print(p['answer'])
            found = True
            break
    if not found:
        print("No matching path found.")

# %%
check_path(["yes", "no", "yes", "yes"])
# Out:
# Décision: Rente par pallier, Sources: ['Lettre c des dispositions transitoires de la modification du 19 juin 2020 (DÃ©veloppement continu de lâ€™AI)']
