# %%
import os
import re
import glob
import subprocess
import requests
import ast
import webvtt
import json
from dotenv import load_dotenv
from openai import OpenAI
from ast import literal_eval

# %%
load_dotenv()
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY", None)

# %%
llm_client = OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ### Download init files (video + audio)

# %%
url = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/init-f3-v1.mp4"

with open(os.path.join('video', 'init-f3-v1.mp4'), 'wb') as out_file:
    response = requests.get(url)
    out_file.write(response.content)

url = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/init-f1-a1.mp4"

with open(os.path.join('video', 'init-f1-a1.mp4'), 'wb') as out_file:
    response = requests.get(url)
    out_file.write(response.content)

# %% [markdown]
# ### Download all m4s video segments

# %%
BASE_URL = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/"
for i in range(1, 233):
    filename = f"seg-{i}-f3-v1.m4s"
    url = os.path.join(BASE_URL, filename)
    response = requests.get(url)
    with open(os.path.join('video/video_segments', filename), 'wb') as out_file:
        out_file.write(response.content)

# %% [markdown]
# ### Download all m4s audio segments

# %%
BASE_URL = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/"
for i in range(1, 233):
    filename = f"seg-{i}-f1-a1.m4s"
    url = os.path.join(BASE_URL, filename)
    response = requests.get(url)
    with open(os.path.join('video/audio_segments', filename), 'wb') as out_file:
        out_file.write(response.content)

# %% [markdown]
# ### Generate mp4 with audio

# %%
# run bash script 'create_clips.sh' in examples/video/video_segments
# add audio segments to /video folder

# %%
ffmpeg -i "concat:../init-f3-v1.mp4|seg-1-f3-v1.m4s" -i "concat:../init-f1-a1.mp4|../seg-1-f1-a1.m4s" -c copy -map 0:v -map 1:a ../output_segment1_with_audio.mp4

# %% [markdown]
# ### Download subtitles

# %%
BASE_URL = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/"
for i in range(1, 233):
    filename = f"seg-{i}-f6.vtt"
    url = os.path.join(BASE_URL, filename)
    response = requests.get(url)
    with open(os.path.join('video/subtitle_segments', filename), 'wb') as out_file:
        out_file.write(response.content)

# %% [markdown]
# # ---> MAKE CODE PARALLEL + ASYNCIO

# %% [markdown]
# # Parse subtitles to find relevant topic passages

# %%
transcript = []
subtitle_segments = []
video_segments = []
audio_segments = []
seen = set()
for i in range(1, 233):
    filename = f'./video/subtitle_segments/seg-{i}-f6.vtt'
    
    captions = webvtt.read(filename)
    
    for caption in captions:
        print("START: ", caption.start)
        print("END: ", caption.end)
        print("TEXT: ", caption.text)
        print("----------")
        if caption.text not in seen and not seen.add(caption.text):
            transcript.append(caption)
            subtitle_segments.append(filename)
            video_segments.append(f'./video/video_segments/seg-{i}-f3-v1.m4s')
            audio_segments.append(f'./video/subtitle_segments/seg-{i}-f1-a1.m4s')
# Out:
# START:  00:00:00.000
# END:  00:00:13.948
# TEXT:  ...
# ----------
# START:  00:00:00.000
# END:  00:00:13.948
# TEXT:  ...
# ----------
# START:  00:00:00.000
# END:  00:00:13.948
# TEXT:  ...
# ----------
# START:  00:00:00.000
# END:  00:00:13.948
# TEXT:  ...
# ----------
# START:  00:00:00.000
# END:  00:00:13.948
# TEXT:  ...
# ----------
# START:  00:00:14.228
# END:  00:00:16.428
# TEXT:  -Mesdames, Messieurs,
# bonsoir et bienvenue.
# ----------
# START:  00:00:14.228
# END:  00:00:16.428
# TEXT:  -Mesdames, Messieurs,
# bonsoir et bienvenue.
# ----------
# START:  00:00:16.508
# END:  00:00:18.868
# TEXT:  Insultes, menaces et intimidation,
# ----------
# START:  00:00:18.948
# END:  00:00:22.228
# TEXT:  c'est ce que vivent
# les étudiants de l'EPLF
# ----------
# START:  00:00:22.308
# END:  00:00:25.348
# TEXT:  qui émettent un avis contraire
# au mouvement propalestinien.
# ----------
# START:  00:00:22.308
# END:  00:00:25.348
# TEXT:  qui émettent un avis contraire
# au mouvement propalestinien.
# ----------
# START:  00:00:25.428
# END:  00:00:31.388
# TEXT:  Le président de l'EPFL,
# Martin Vetterli, est avec nous.
# ----------
# START:  00:00:32.148
# END:  00:00:34.788
# TEXT:  Une manifestation spectaculaire
# ----------
# START:  00:00:34.868
# END:  00:00:37.549
# TEXT:  contre la géothermie
# dans la commune de Haute-Sorne (JU).
# ----------
# START:  00:00:37.589
# END:  00:00:41.189
# TEXT:  Des militants en colère
# et des dégâts considérables.
# ----------
# START:  00:00:37.589
# END:  00:00:41.189
# TEXT:  Des militants en colère
# et des dégâts considérables.
# ----------
# START:  00:00:41.989
# END:  00:00:44.469
# TEXT:  A deux semaines
# des élections européennes,
# ----------
# START:  00:00:44.549
# END:  00:00:47.189
# TEXT:  alors qu'on parle
# d'un excellent score tout à droite,
# ----------
# START:  00:00:47.269
# END:  00:00:51.389
# TEXT:  l'AfD a été exclu de son groupe
# parlementaire à Bruxelles.
# ----------
# START:  00:00:47.269
# END:  00:00:51.389
# TEXT:  l'AfD a été exclu de son groupe
# parlementaire à Bruxelles.
# ----------
# START:  00:00:51.469
# END:  00:00:54.949
# TEXT:  Sa tête de liste
# enchaîne les dérapages.
# ----------
# START:  00:00:56.589
# END:  00:01:01.269
# TEXT:  Nous percerons un des mystères
# qui entourent les pyramides.
# ----------
# START:  00:01:01.349
# END:  00:01:03.870
# TEXT:  Comment ont-elles été construites ?
# ----------
# START:  00:01:03.910
# END:  00:01:06.390
# TEXT:  Il y a une réponse récente.
# ----------
# START:  00:01:03.910
# END:  00:01:06.390
# TEXT:  Il y a une réponse récente.
# ----------
# START:  00:01:07.550
# END:  00:01:09.390
# TEXT:  60 ans et toujours aussi glamour.
# ----------
# START:  00:01:09.470
# END:  00:01:12.670
# TEXT:  L'icône du rock Lenny Kravitz
# sort un nouvel album.
# ----------
# START:  00:01:09.470
# END:  00:01:12.670
# TEXT:  L'icône du rock Lenny Kravitz
# sort un nouvel album.
# ----------
# START:  00:01:16.150
# END:  00:01:20.630
# TEXT:  Le climat est délétère à l'EPFL
# ----------
# START:  00:01:16.150
# END:  00:01:20.630
# TEXT:  Le climat est délétère à l'EPFL
# ----------
# START:  00:01:20.710
# END:  00:01:22.990
# TEXT:  sur fond de guerre
# entre Israël et le Hamas.
# ----------
# START:  00:01:23.070
# END:  00:01:25.190
# TEXT:  Les étudiants qui émettent
# un avis contraire
# ----------
# START:  00:01:25.270
# END:  00:01:27.590
# TEXT:  au mouvement propalestinien
# sont menacés.
# ----------
# START:  00:01:27.670
# END:  00:01:37.271
# TEXT:  Des jeunes ont peur
# d'aller sur le campus.
# ----------
# START:  00:01:27.670
# END:  00:01:37.271
# TEXT:  Des jeunes ont peur
# d'aller sur le campus.
# ----------
# START:  00:01:27.670
# END:  00:01:37.271
# TEXT:  Des jeunes ont peur
# d'aller sur le campus.
# ----------
# START:  00:01:39.671
# END:  00:01:42.431
# TEXT:  -Si ce groupe de discussion
# sur la guerre au Moyen-Orient
# ----------
# START:  00:01:42.471
# END:  00:01:45.911
# TEXT:  par des étudiants de l'EPFL
# a été depuis supprimé,
# ----------
# START:  00:01:42.471
# END:  00:01:45.911
# TEXT:  par des étudiants de l'EPFL
# a été depuis supprimé,
# ----------
# START:  00:01:45.991
# END:  00:01:48.911
# TEXT:  il en subsiste
# ces captures d'écran.
# ----------
# START:  00:01:51.511
# END:  00:01:53.711
# TEXT:  Des menaces de mort dirigées
# contre des étudiants
# ----------
# START:  00:01:51.511
# END:  00:01:53.711
# TEXT:  Des menaces de mort dirigées
# contre des étudiants
# ----------
# START:  00:01:53.791
# END:  00:01:55.712
# TEXT:  qui souhaitaient apaiser
# des tensions.
# ----------
# START:  00:01:57.552
# END:  00:01:59.792
# TEXT:  Des menaces de mort dirigées
# contre des étudiants
# ----------
# START:  00:01:59.872
# END:  00:02:01.672
# TEXT:  qui souhaitaient apaiser
# des tensions.
# ----------
# START:  00:01:59.872
# END:  00:02:01.672
# TEXT:  qui souhaitaient apaiser
# des tensions.
# ----------
# START:  00:02:01.752
# END:  00:02:03.432
# TEXT:  Ces révélations du journal Le Temps
# ----------
# START:  00:02:03.512
# END:  00:02:05.912
# TEXT:  décrivent une radicalisation
# sur le campus de l'EPFL.
# ----------
# START:  00:02:05.992
# END:  00:02:10.632
# TEXT:  Cet étudiant visé ne s'affole pas,
# mais avoue être sur ses gardes.
# ----------
# START:  00:02:05.992
# END:  00:02:10.632
# TEXT:  Cet étudiant visé ne s'affole pas,
# mais avoue être sur ses gardes.
# ----------
# START:  00:02:12.272
# END:  00:02:13.712
# TEXT:  -Une limite a été franchie
# ----------
# START:  00:02:13.792
# END:  00:02:17.072
# TEXT:  parce que c'est un événement
# qui n'a jamais été vu sur le campus.
# ----------
# START:  00:02:13.792
# END:  00:02:17.072
# TEXT:  parce que c'est un événement
# qui n'a jamais été vu sur le campus.
# ----------
# START:  00:02:17.152
# END:  00:02:25.393
# TEXT:  On a peur,
# on regarde un peu derrière nous.
# ----------
# START:  00:02:17.152
# END:  00:02:25.393
# TEXT:  On a peur,
# on regarde un peu derrière nous.
# ----------
# START:  00:02:25.873
# END:  00:02:28.473
# TEXT:  -La direction de l'EPFL
# organisait cet après-midi
# ----------
# START:  00:02:28.553
# END:  00:02:30.993
# TEXT:  une discussion
# pour éviter toute escalade.
# ----------
# START:  00:02:31.073
# END:  00:02:34.913
# TEXT:  Si la démarche a été saluée,
# certains en ont profité
# ----------
# START:  00:02:31.073
# END:  00:02:34.913
# TEXT:  Si la démarche a été saluée,
# certains en ont profité
# ----------
# START:  00:02:35.033
# END:  00:02:38.593
# TEXT:  pour remettre en doute
# le témoignage des étudiants menacés.
# ----------
# START:  00:02:38.873
# END:  00:02:42.913
# TEXT:  -La première réaction dans
# l'auditoire, c'est "ils mentent".
# ----------
# START:  00:02:38.873
# END:  00:02:42.913
# TEXT:  -La première réaction dans
# l'auditoire, c'est "ils mentent".
# ----------
# START:  00:02:42.993
# END:  00:02:52.074
# TEXT:  Ils parlent de menaces de mort,
# donc forcément ils mentent.
# ----------
# START:  00:02:42.993
# END:  00:02:52.074
# TEXT:  Ils parlent de menaces de mort,
# donc forcément ils mentent.
# ----------
# START:  00:02:52.514
# END:  00:02:55.554
# TEXT:  -Du côté
# des manifestants propalestiniens,
# ----------
# START:  00:02:55.594
# END:  00:02:58.394
# TEXT:  on condamne fermement
# toutes attitudes discriminatoires.
# ----------
# START:  00:02:55.594
# END:  00:02:58.394
# TEXT:  on condamne fermement
# toutes attitudes discriminatoires.
# ----------
# START:  00:02:58.634
# END:  00:03:01.554
# TEXT:  -Menacer de mort pour des idées
# politiques,
# ----------
# START:  00:03:01.634
# END:  00:03:04.834
# TEXT:  ce n'est pas acceptable,
# surtout pas dans notre école.
# ----------
# START:  00:03:01.634
# END:  00:03:04.834
# TEXT:  ce n'est pas acceptable,
# surtout pas dans notre école.
# ----------
# START:  00:03:04.914
# END:  00:03:15.915
# TEXT:  Ca ne reflète pas
# la majorité des étudiants.
# ----------
# START:  00:03:04.914
# END:  00:03:15.915
# TEXT:  Ca ne reflète pas
# la majorité des étudiants.
# ----------
# START:  00:03:16.595
# END:  00:03:19.035
# TEXT:  -Le groupe propalestinien considère
# ----------
# START:  00:03:19.115
# END:  00:03:21.915
# TEXT:  que la direction porte
# une part de responsabilité
# ----------
# START:  00:03:19.115
# END:  00:03:21.915
# TEXT:  que la direction porte
# une part de responsabilité
# ----------
# START:  00:03:21.995
# END:  00:03:24.475
# TEXT:  en limitant la liberté d'expression.
# ----------
# START:  00:03:24.555
# END:  00:03:31.395
# TEXT:  La direction de l'EPFL doit faire
# la lumière sur ces événements.
# ----------
# START:  00:03:24.555
# END:  00:03:31.395
# TEXT:  La direction de l'EPFL doit faire
# la lumière sur ces événements.
# ----------
# START:  00:03:32.995
# END:  00:03:35.115
# TEXT:  -Martin Vetterli, bonsoir.
# ----------
# START:  00:03:35.195
# END:  00:03:41.916
# TEXT:  Le Temps révèle que des étudiants
# de votre établissement
# ----------
# START:  00:03:35.195
# END:  00:03:41.916
# TEXT:  Le Temps révèle que des étudiants
# de votre établissement
# ----------
# START:  00:03:41.996
# END:  00:03:47.236
# TEXT:  sont harcelés car ils pensent
# différemment, et parlent de paix.
# ----------
# START:  00:03:41.996
# END:  00:03:47.236
# TEXT:  sont harcelés car ils pensent
# différemment, et parlent de paix.
# ----------
# START:  00:03:47.316
# END:  00:03:54.396
# TEXT:  Un étudiant est menacé de mort
# sur les réseaux sociaux:
# ----------
# START:  00:03:47.316
# END:  00:03:54.396
# TEXT:  Un étudiant est menacé de mort
# sur les réseaux sociaux:
# ----------
# START:  00:03:54.476
# END:  00:03:57.196
# TEXT:  "il faut tuer Nicolas et son gang".
# ----------
# START:  00:03:57.276
# END:  00:04:01.556
# TEXT:  Une autre est intimidée:
# "on a vu où tu étais assise".
# ----------
# START:  00:03:57.276
# END:  00:04:01.556
# TEXT:  Une autre est intimidée:
# "on a vu où tu étais assise".
# ----------
# START:  00:04:01.636
# END:  00:04:04.437
# TEXT:  Quelle est votre réaction ?
# ----------
# START:  00:04:04.437
# END:  00:04:06.477
# TEXT:  - Je suis très triste
# ----------
# START:  00:04:06.477
# END:  00:04:10.477
# TEXT:  qu'il y a une telle tension
# sur le campus.
# ----------
# START:  00:04:06.477
# END:  00:04:10.477
# TEXT:  qu'il y a une telle tension
# sur le campus.
# ----------
# START:  00:04:10.477
# END:  00:04:14.077
# TEXT:  Ce sont les excès
# des réseaux sociaux.
# ----------
# START:  00:04:14.237
# END:  00:04:18.317
# TEXT:  Si on n'est pas dans le cadre légal,
# ----------
# START:  00:04:14.237
# END:  00:04:18.317
# TEXT:  Si on n'est pas dans le cadre légal,
# ----------
# START:  00:04:18.477
# END:  00:04:21.117
# TEXT:  par rapport aux lois
# sur le racisme et l'antisémitisme,
# ----------
# START:  00:04:21.117
# END:  00:04:25.357
# TEXT:  on donne
# le support à notre communauté.
# ----------
# START:  00:04:21.117
# END:  00:04:25.357
# TEXT:  on donne
# le support à notre communauté.
# ----------
# START:  00:04:25.357
# END:  00:04:32.918
# TEXT:  Nos étudiants ont des canaux où ils
# peuvent venir chercher de l'aide.
# ----------
# START:  00:04:25.357
# END:  00:04:32.918
# TEXT:  Nos étudiants ont des canaux où ils
# peuvent venir chercher de l'aide.
# ----------
# START:  00:04:32.918
# END:  00:04:37.038
# TEXT:  Et on prendra
# les mesures nécessaires.
# ----------
# START:  00:04:38.798
# END:  00:04:41.838
# TEXT:  Des plaintes pourront être portées.
# ----------
# START:  00:04:38.798
# END:  00:04:41.838
# TEXT:  Des plaintes pourront être portées.
# ----------
# START:  00:04:41.998
# END:  00:04:45.798
# TEXT:  -On entend des étudiants juifs
# ----------
# START:  00:04:45.798
# END:  00:04:50.518
# TEXT:  qui ont peur de venir sur le campus.
# ----------
# START:  00:04:45.798
# END:  00:04:50.518
# TEXT:  qui ont peur de venir sur le campus.
# ----------
# START:  00:04:50.678
# END:  00:04:52.878
# TEXT:  Leur sécurité est garantie ?
# ----------
# START:  00:04:52.878
# END:  00:04:56.079
# TEXT:  -C'est notre première priorité.
# ----------
# START:  00:04:52.878
# END:  00:04:56.079
# TEXT:  -C'est notre première priorité.
# ----------
# START:  00:04:56.079
# END:  00:04:59.599
# TEXT:  La sécurité de tous sur le campus.
# ----------
# START:  00:04:59.599
# END:  00:05:04.359
# TEXT:  On a parlé avec ces gens,
# ils se sont exprimés.
# ----------
# START:  00:04:59.599
# END:  00:05:04.359
# TEXT:  On a parlé avec ces gens,
# ils se sont exprimés.
# ----------
# START:  00:05:04.519
# END:  00:05:08.039
# TEXT:  Ils ont besoin d'être protégés,
# comme tout le monde.
# ----------
# START:  00:05:08.039
# END:  00:05:10.679
# TEXT:  -Vous reconnaissez
# qu'il y a une dérive
# ----------
# START:  00:05:10.679
# END:  00:05:14.359
# TEXT:  de certains membres
# des militants propalestiniens ?
# ----------
# START:  00:05:10.679
# END:  00:05:14.359
# TEXT:  de certains membres
# des militants propalestiniens ?
# ----------
# START:  00:05:14.519
# END:  00:05:17.919
# TEXT:  -Il y a toujours des dérives.
# ----------
# START:  00:05:17.919
# END:  00:05:23.440
# TEXT:  Il y a un large spectre
# d'opinions sur le campus.
# ----------
# START:  00:05:17.919
# END:  00:05:23.440
# TEXT:  Il y a un large spectre
# d'opinions sur le campus.
# ----------
# START:  00:05:23.440
# END:  00:05:27.760
# TEXT:  Notre mission
# est de garder une unité.
# ----------
# START:  00:05:27.760
# END:  00:05:30.120
# TEXT:  -Comment on en est arrivé là ?
# ----------
# START:  00:05:27.760
# END:  00:05:30.120
# TEXT:  -Comment on en est arrivé là ?
# ----------
# START:  00:05:30.120
# END:  00:05:35.000
# TEXT:  Y a-t-il aussi une responsabilité
# de la part des grandes écoles
# ----------
# START:  00:05:35.000
# END:  00:05:39.600
# TEXT:  de laisser entrer ces discussions
# politiques sur le campus ?
# ----------
# START:  00:05:35.000
# END:  00:05:39.600
# TEXT:  de laisser entrer ces discussions
# politiques sur le campus ?
# ----------
# START:  00:05:39.600
# END:  00:05:43.800
# TEXT:  L'université ne doit-elle
# pas être totalement neutre ?
# ----------
# START:  00:05:43.960
# END:  00:05:47.641
# TEXT:  -L'université en tant qu'institution
# doit rester neutre
# ----------
# START:  00:05:43.960
# END:  00:05:47.641
# TEXT:  -L'université en tant qu'institution
# doit rester neutre
# ----------
# START:  00:05:47.641
# END:  00:05:49.281
# TEXT:  pour permettre un débat.
# ----------
# START:  00:05:49.281
# END:  00:05:53.441
# TEXT:  Mais chacun est un être humain
# qui peut s'exprimer en son nom.
# ----------
# START:  00:05:49.281
# END:  00:05:53.441
# TEXT:  Mais chacun est un être humain
# qui peut s'exprimer en son nom.
# ----------
# START:  00:05:53.441
# END:  00:05:55.921
# TEXT:  Il ne faut pas
# qu'il y ait de dérive.
# ----------
# START:  00:05:56.081
# END:  00:06:01.921
# TEXT:  Il ne faut pas qu'il y ait le genre
# d'excès dont vous avez parlé.
# ----------
# START:  00:05:56.081
# END:  00:06:01.921
# TEXT:  Il ne faut pas qu'il y ait le genre
# d'excès dont vous avez parlé.
# ----------
# START:  00:06:02.841
# END:  00:06:06.601
# TEXT:  -On a atteint
# à ce niveau-là du rouge.
# ----------
# START:  00:06:06.601
# END:  00:06:12.322
# TEXT:  Qu'est-ce que vous allez faire
# pour remettre de l'ordre ?
# ----------
# START:  00:06:06.601
# END:  00:06:12.322
# TEXT:  Qu'est-ce que vous allez faire
# pour remettre de l'ordre ?
# ----------
# START:  00:06:12.322
# END:  00:06:15.482
# TEXT:  -On n'est pas dans le désordre.
# ----------
# START:  00:06:15.482
# END:  00:06:18.722
# TEXT:  Sur le campus, ça se passe bien.
# ----------
# START:  00:06:15.482
# END:  00:06:18.722
# TEXT:  Sur le campus, ça se passe bien.
# ----------
# START:  00:06:19.882
# END:  00:06:24.042
# TEXT:  Plusieurs centaines de participants
# représentant les étudiants,
# ----------
# START:  00:06:19.882
# END:  00:06:24.042
# TEXT:  Plusieurs centaines de participants
# représentant les étudiants,
# ----------
# START:  00:06:24.042
# END:  00:06:27.922
# TEXT:  les employés et les profs ont parlé
# et ça s'est bien passé.
# ----------
# START:  00:06:27.922
# END:  00:06:33.162
# TEXT:  Tous nos canaux de soutien sont
# à disposition de toute la communauté.
# ----------
# START:  00:06:27.922
# END:  00:06:33.162
# TEXT:  Tous nos canaux de soutien sont
# à disposition de toute la communauté.
# ----------
# START:  00:06:33.162
# END:  00:06:38.043
# TEXT:  -Vous appelez les étudiants
# à s'adresser à vos canaux de soutien
# ----------
# START:  00:06:38.203
# END:  00:06:42.203
# TEXT:  si quelque chose se passe.
# ----------
# START:  00:06:38.203
# END:  00:06:42.203
# TEXT:  si quelque chose se passe.
# ----------
# START:  00:06:42.363
# END:  00:06:46.243
# TEXT:  -On a créé
# une commission spécifique.
# ----------
# START:  00:06:46.403
# END:  00:06:49.443
# TEXT:  On va regarder
# ces différentes dimensions.
# ----------
# START:  00:06:46.403
# END:  00:06:49.443
# TEXT:  On va regarder
# ces différentes dimensions.
# ----------
# START:  00:06:49.603
# END:  00:06:55.723
# TEXT:  Cette commission
# est dirigée par ma collègue.
# ----------
# START:  00:06:55.723
# END:  00:07:00.003
# TEXT:  -Ce matin,
# dans la commune de Haute-Sorne,
# ----------
# START:  00:06:55.723
# END:  00:07:00.003
# TEXT:  -Ce matin,
# dans la commune de Haute-Sorne,
# ----------
# START:  00:07:00.003
# END:  00:07:04.844
# TEXT:  ils étaient une centaine
# à exprimer leur colère
# ----------
# START:  00:07:00.003
# END:  00:07:04.844
# TEXT:  ils étaient une centaine
# à exprimer leur colère
# ----------
# START:  00:07:04.844
# END:  00:07:08.924
# TEXT:  contre le projet
# de géothermie profonde.
# ----------
# START:  00:07:08.924
# END:  00:07:11.644
# TEXT:  La police a dû intervenir.
# ----------
# START:  00:07:13.484
# END:  00:07:15.964
# TEXT:  -Un puissant
# jet de lisier annonce la couleur.
# ----------
# START:  00:07:16.044
# END:  00:07:19.524
# TEXT:  La manifestation
# contre la géothermie profonde
# ----------
# START:  00:07:19.604
# END:  00:07:23.524
# TEXT:  à Haute-Sorne (JU) a largement
# dépassé le cadre pacifiste.
# ----------
# START:  00:07:19.604
# END:  00:07:23.524
# TEXT:  à Haute-Sorne (JU) a largement
# dépassé le cadre pacifiste.
# ----------
# START:  00:07:23.604
# END:  00:07:25.564
# TEXT:  Une centaine de personnes a mis
# ----------
# START:  00:07:25.644
# END:  00:07:28.325
# TEXT:  les services de sécurité
# à l'épreuve ce vendredi matin
# ----------
# START:  00:07:25.644
# END:  00:07:28.325
# TEXT:  les services de sécurité
# à l'épreuve ce vendredi matin
# ----------
# START:  00:07:28.405
# END:  00:07:31.165
# TEXT:  avec cette intrusion
# sur le site de forage.
# ----------
# START:  00:07:33.805
# END:  00:07:38.085
# TEXT:  Le rassemblement a démarré
# dans une humeur festive
# ----------
# START:  00:07:33.805
# END:  00:07:38.085
# TEXT:  Le rassemblement a démarré
# dans une humeur festive
# ----------
# START:  00:07:38.165
# END:  00:07:40.925
# TEXT:  avant de dégénérer.
# ----------
# START:  00:07:42.965
# END:  00:07:45.005
# TEXT:  -Si je n'ai pas les fenêtres fermées,
# ----------
# START:  00:07:42.965
# END:  00:07:45.005
# TEXT:  -Si je n'ai pas les fenêtres fermées,
# ----------
# START:  00:07:45.085
# END:  00:07:47.605
# TEXT:  j'ai une vibration dans le corps.
# ----------
# START:  00:07:47.685
# END:  00:07:49.045
# TEXT:  C'est nuit et jour.
# ----------
# START:  00:07:49.125
# END:  00:07:51.285
# TEXT:  Ce qu'ils font est hyper violent.
# ----------
# START:  00:07:51.365
# END:  00:07:53.966
# TEXT:  Aujourd'hui,
# il y a eu des actes de violence,
# ----------
# START:  00:07:51.365
# END:  00:07:53.966
# TEXT:  Aujourd'hui,
# il y a eu des actes de violence,
# ----------
# START:  00:07:54.046
# END:  00:07:59.126
# TEXT:  mais je ne regrette pas
# que ça se soit passé.
# ----------
# START:  00:07:59.566
# END:  00:08:02.366
# TEXT:  -L'objet de la discorde
# est cette tour de forage,
# ----------
# START:  00:07:59.566
# END:  00:08:02.366
# TEXT:  -L'objet de la discorde
# est cette tour de forage,
# ----------
# START:  00:08:02.446
# END:  00:08:04.406
# TEXT:  en activité
# depuis mardi dernier.
# ----------
# START:  00:08:04.486
# END:  00:08:09.846
# TEXT:  Le gouvernement jurassien
# déplore l'escalade de la violence.
# ----------
# START:  00:08:04.486
# END:  00:08:09.846
# TEXT:  Le gouvernement jurassien
# déplore l'escalade de la violence.
# ----------
# START:  00:08:10.566
# END:  00:08:12.326
# TEXT:  -Le gouvernement estime
# ----------
# START:  00:08:12.406
# END:  00:08:14.486
# TEXT:  qu'on peut être opposé au projet.
# ----------
# START:  00:08:14.566
# END:  00:08:16.046
# TEXT:  On peut manifester.
# ----------
# START:  00:08:14.566
# END:  00:08:16.046
# TEXT:  On peut manifester.
# ----------
# START:  00:08:16.126
# END:  00:08:18.087
# TEXT:  Aujourd'hui,
# des limites ont été franchies.
# ----------
# START:  00:08:18.167
# END:  00:08:22.207
# TEXT:  Il y a des questions
# de sécurité et de propriété privée.
# ----------
# START:  00:08:22.287
# END:  00:08:24.967
# TEXT:  On a peut-être franchi une étape.
# ----------
# START:  00:08:22.287
# END:  00:08:24.967
# TEXT:  On a peut-être franchi une étape.
# ----------
# START:  00:08:26.367
# END:  00:08:30.927
# TEXT:  -Une trentaine de policiers est
# intervenue pour disperser la foule.
# ----------
# START:  00:08:31.007
# END:  00:08:35.727
# TEXT:  Une nouvelle manifestation
# est déjà annoncée mercredi prochain.
# ----------
# START:  00:08:31.007
# END:  00:08:35.727
# TEXT:  Une nouvelle manifestation
# est déjà annoncée mercredi prochain.
# ----------
# START:  00:08:37.207
# END:  00:08:39.287
# TEXT:  -Lausanne et sa lutte
# contre la drogue.
# ----------
# START:  00:08:39.367
# END:  00:08:42.967
# TEXT:  La ville ouvre un deuxième local
# d'injection à la place de la Riponne,
# ----------
# START:  00:08:39.367
# END:  00:08:42.967
# TEXT:  La ville ouvre un deuxième local
# d'injection à la place de la Riponne,
# ----------
# START:  00:08:43.047
# END:  00:08:45.648
# TEXT:  connue pour la présence
# de toxicomanes.
# ----------
# START:  00:08:45.728
# END:  00:08:48.928
# TEXT:  Cet espace est présenté
# comme une alternative
# ----------
# START:  00:08:45.728
# END:  00:08:48.928
# TEXT:  Cet espace est présenté
# comme une alternative
# ----------
# START:  00:08:49.008
# END:  00:08:52.488
# TEXT:  à la consommation
# dans l'espace public.
# ----------
# START:  00:08:54.168
# END:  00:08:56.008
# TEXT:  -C’est un local tout neuf.
# ----------
# START:  00:08:54.168
# END:  00:08:56.008
# TEXT:  -C’est un local tout neuf.
# ----------
# START:  00:08:56.088
# END:  00:09:03.408
# TEXT:  Des box pour l’inhalation
# et l'injection, une salle de repos.
# ----------
# START:  00:09:03.488
# END:  00:09:07.688
# TEXT:  A partir de lundi, les consommateurs
# de cocaïne, héroïne et autres
# ----------
# START:  00:09:03.488
# END:  00:09:07.688
# TEXT:  A partir de lundi, les consommateurs
# de cocaïne, héroïne et autres
# ----------
# START:  00:09:07.768
# END:  00:09:12.369
# TEXT:  pourront en bénéficier
# en plein centre-ville de Lausanne.
# ----------
# START:  00:09:07.768
# END:  00:09:12.369
# TEXT:  pourront en bénéficier
# en plein centre-ville de Lausanne.
# ----------
# START:  00:09:13.049
# END:  00:09:15.569
# TEXT:  -On vise des personnes
# très désinsérées
# ----------
# START:  00:09:15.649
# END:  00:09:18.329
# TEXT:  qui consomment dans l’espace public,
# ----------
# START:  00:09:18.409
# END:  00:09:22.329
# TEXT:  ça crée des inquiétudes
# ----------
# START:  00:09:18.409
# END:  00:09:22.329
# TEXT:  ça crée des inquiétudes
# ----------
# START:  00:09:22.409
# END:  00:09:24.889
# TEXT:  et des nuisances pour le voisinage,
# ----------
# START:  00:09:24.969
# END:  00:09:27.889
# TEXT:  et des risques pour la santé
# de ceux qui consomment.
# ----------
# START:  00:09:28.729
# END:  00:09:32.169
# TEXT:  -Pas de distribution de drogue sur
# place, mais du matériel stérile.
# ----------
# START:  00:09:32.249
# END:  00:09:34.770
# TEXT:  Et la possibilité d’un suivi social.
# ----------
# START:  00:09:34.810
# END:  00:09:38.970
# TEXT:  Le deuxième espace de consommation
# sécurisée de la capitale vaudoise.
# ----------
# START:  00:09:34.810
# END:  00:09:38.970
# TEXT:  Le deuxième espace de consommation
# sécurisée de la capitale vaudoise.
# ----------
# START:  00:09:39.050
# END:  00:09:43.570
# TEXT:  Un premier local a été ouvert
# il y a 6 ans à 500 m de là.
# ----------
# START:  00:09:43.650
# END:  00:09:48.450
# TEXT:  L'équipe y enregistre en moyenne
# 95 prises de drogues par jour.
# ----------
# START:  00:09:43.650
# END:  00:09:48.450
# TEXT:  L'équipe y enregistre en moyenne
# 95 prises de drogues par jour.
# ----------
# START:  00:09:49.770
# END:  00:09:51.530
# TEXT:  -On a des temps d’attente
# ----------
# START:  00:09:51.610
# END:  00:09:53.650
# TEXT:  pouvant aller jusqu'à une demi-heure.
# ----------
# START:  00:09:51.610
# END:  00:09:53.650
# TEXT:  pouvant aller jusqu'à une demi-heure.
# ----------
# START:  00:09:53.730
# END:  00:09:56.890
# TEXT:  On sait que les personnes
# dans l’urgence de la consommation
# ----------
# START:  00:09:56.930
# END:  00:09:59.210
# TEXT:  peinent à attendre
# plus que 10-15 min.
# ----------
# START:  00:09:59.290
# END:  00:10:04.411
# TEXT:  On arrive
# aux limites du projet actuel.
# ----------
# START:  00:09:59.290
# END:  00:10:04.411
# TEXT:  On arrive
# aux limites du projet actuel.
# ----------
# START:  00:10:04.971
# END:  00:10:07.891
# TEXT:  -Le local tout juste inauguré
# est à quelques mètres
# ----------
# START:  00:10:07.971
# END:  00:10:10.851
# TEXT:  du lieu de rassemblement habituel
# des personnes toxicomanes,
# ----------
# START:  00:10:07.971
# END:  00:10:10.851
# TEXT:  du lieu de rassemblement habituel
# des personnes toxicomanes,
# ----------
# START:  00:10:10.931
# END:  00:10:12.611
# TEXT:  sur la place de la Riponne.
# ----------
# START:  00:10:13.011
# END:  00:10:14.371
# TEXT:  -C’est très bien.
# ----------
# START:  00:10:14.451
# END:  00:10:15.931
# TEXT:  On aura une salle de repos,
# ----------
# START:  00:10:16.011
# END:  00:10:21.371
# TEXT:  on pourra se poser,
# ils pourront nous surveiller.
# ----------
# START:  00:10:21.651
# END:  00:10:24.651
# TEXT:  -Les gens qui consomment
# seront en sécurité
# ----------
# START:  00:10:21.651
# END:  00:10:24.651
# TEXT:  -Les gens qui consomment
# seront en sécurité
# ----------
# START:  00:10:24.731
# END:  00:10:28.172
# TEXT:  et ne font pas ça
# dans la rue devant des enfants.
# ----------
# START:  00:10:28.452
# END:  00:10:30.932
# TEXT:  -Les deux espaces
# de consommation sécurisée
# ----------
# START:  00:10:31.012
# END:  00:10:33.492
# TEXT:  sont financés
# par la Ville et le Canton.
# ----------
# START:  00:10:31.012
# END:  00:10:33.492
# TEXT:  sont financés
# par la Ville et le Canton.
# ----------
# START:  00:10:37.092
# END:  00:10:40.532
# TEXT:  Ils complètent une série
# de mesures prises l'été 2023.
# ----------
# START:  00:10:37.092
# END:  00:10:40.532
# TEXT:  Ils complètent une série
# de mesures prises l'été 2023.
# ----------
# START:  00:10:46.572
# END:  00:10:49.732
# TEXT:  La nouvelle antenne de la Riponne
# est un projet pilote.
# ----------
# START:  00:10:46.572
# END:  00:10:49.732
# TEXT:  La nouvelle antenne de la Riponne
# est un projet pilote.
# ----------
# START:  00:10:49.812
# END:  00:10:52.973
# TEXT:  Son efficacité
# sera évaluée dans une année.
# ----------
# START:  00:10:54.493
# END:  00:10:56.453
# TEXT:  -Le personnel de Vetropack
# ----------
# START:  00:10:54.493
# END:  00:10:56.453
# TEXT:  -Le personnel de Vetropack
# ----------
# START:  00:10:56.533
# END:  00:10:58.693
# TEXT:  entame une grève
# à durée indéterminée.
# ----------
# START:  00:10:58.773
# END:  00:11:00.933
# TEXT:  La majorité des employés
# de Saint-Prex (VD)
# ----------
# START:  00:11:01.013
# END:  00:11:04.133
# TEXT:  a arrêté de travailler.
# ----------
# START:  00:11:01.013
# END:  00:11:04.133
# TEXT:  a arrêté de travailler.
# ----------
# START:  00:11:05.853
# END:  00:11:07.613
# TEXT:  Yoan Rithner, vous êtes sur place.
# ----------
# START:  00:11:07.693
# END:  00:11:10.093
# TEXT:  Pas de licenciement
# sans plan social,
# ----------
# START:  00:11:10.173
# END:  00:11:15.373
# TEXT:  c'est le coeur des revendications.
# ----------
# START:  00:11:10.173
# END:  00:11:15.373
# TEXT:  c'est le coeur des revendications.
# ----------
# START:  00:11:15.373
# END:  00:11:17.214
# TEXT:  -Exactement.
# ----------
# START:  00:11:17.374
# END:  00:11:19.614
# TEXT:  Un plan social digne de ce nom.
# ----------
# START:  00:11:19.614
# END:  00:11:23.534
# TEXT:  C'est actuellement loin d'être
# le cas pour les employés
# ----------
# START:  00:11:19.614
# END:  00:11:23.534
# TEXT:  C'est actuellement loin d'être
# le cas pour les employés
# ----------
# START:  00:11:23.534
# END:  00:11:27.894
# TEXT:  qui ont décidé
# de débrayer en fin de matinée.
# ----------
# START:  00:11:27.894
# END:  00:11:32.054
# TEXT:  La production
# des bouteilles est à l'arrêt.
# ----------
# START:  00:11:27.894
# END:  00:11:32.054
# TEXT:  La production
# des bouteilles est à l'arrêt.
# ----------
# START:  00:11:32.054
# END:  00:11:37.214
# TEXT:  Les palettes ne sont plus livrées.
# ----------
# START:  00:11:32.054
# END:  00:11:37.214
# TEXT:  Les palettes ne sont plus livrées.
# ----------
# START:  00:11:37.214
# END:  00:11:41.294
# TEXT:  "On n'a plus rien à perdre"
# ----------
# START:  00:11:41.294
# END:  00:11:52.775
# TEXT:  a dit un des employés depuis
# l'annonce de la fermeture de l'usine.
# ----------
# START:  00:11:41.294
# END:  00:11:52.775
# TEXT:  a dit un des employés depuis
# l'annonce de la fermeture de l'usine.
# ----------
# START:  00:11:41.294
# END:  00:11:52.775
# TEXT:  a dit un des employés depuis
# l'annonce de la fermeture de l'usine.
# ----------
# START:  00:11:52.935
# END:  00:11:55.615
# TEXT:  Pour l'instant, la direction refuse
# ----------
# START:  00:11:55.615
# END:  00:11:58.735
# TEXT:  d'entrer dans des véritables
# négociations.
# ----------
# START:  00:11:58.735
# END:  00:12:01.375
# TEXT:  Il y a une cinquantaine d'employés
# ----------
# START:  00:11:58.735
# END:  00:12:01.375
# TEXT:  Il y a une cinquantaine d'employés
# ----------
# START:  00:12:01.375
# END:  00:12:04.415
# TEXT:  qui n'auraient droit
# à aucune indemnité.
# ----------
# START:  00:12:04.415
# END:  00:12:08.976
# TEXT:  Une trentaine d'autres
# n'aurait droit qu'à un demi-salaire.
# ----------
# START:  00:12:04.415
# END:  00:12:08.976
# TEXT:  Une trentaine d'autres
# n'aurait droit qu'à un demi-salaire.
# ----------
# START:  00:12:09.136
# END:  00:12:12.736
# TEXT:  La direction a réagi
# en fin d'après-midi.
# ----------
# START:  00:12:12.736
# END:  00:12:17.856
# TEXT:  Elle a dit
# ne pas comprendre la grève.
# ----------
# START:  00:12:12.736
# END:  00:12:17.856
# TEXT:  Elle a dit
# ne pas comprendre la grève.
# ----------
# START:  00:12:17.856
# END:  00:12:21.056
# TEXT:  Les discussions
# sont encore en cours.
# ----------
# START:  00:12:21.056
# END:  00:12:26.176
# TEXT:  Elle demande un arrêt de la grève
# sinon elle risque de retarder
# ----------
# START:  00:12:21.056
# END:  00:12:26.176
# TEXT:  Elle demande un arrêt de la grève
# sinon elle risque de retarder
# ----------
# START:  00:12:26.176
# END:  00:12:30.896
# TEXT:  le versement des indemnités
# pour les personnes licenciées.
# ----------
# START:  00:12:30.896
# END:  00:12:34.977
# TEXT:  Les premiers licenciements
# devraient être annoncés
# ----------
# START:  00:12:30.896
# END:  00:12:34.977
# TEXT:  Les premiers licenciements
# devraient être annoncés
# ----------
# START:  00:12:34.977
# END:  00:12:42.097
# TEXT:  au courant
# de la semaine prochaine.
# ----------
# START:  00:12:34.977
# END:  00:12:42.097
# TEXT:  au courant
# de la semaine prochaine.
# ----------
# START:  00:12:42.097
# END:  00:12:43.577
# TEXT:  -De la prison ferme
# ----------
# START:  00:12:43.577
# END:  00:12:47.457
# TEXT:  pour l'ex-entraîneur de foot
# et avocat à Neuchâtel.
# ----------
# START:  00:12:47.457
# END:  00:12:50.617
# TEXT:  Il passera une année
# derrière les barreaux
# ----------
# START:  00:12:47.457
# END:  00:12:50.617
# TEXT:  Il passera une année
# derrière les barreaux
# ----------
# START:  00:12:50.697
# END:  00:12:52.297
# TEXT:  pour des actes sexuels sur mineurs.
# ----------
# START:  00:12:52.377
# END:  00:12:53.857
# TEXT:  Une peine alourdie en appel.
# ----------
# START:  00:12:55.497
# END:  00:12:58.137
# TEXT:  -34 mois de prison dont 12 fermes
# et une interdiction à vie
# ----------
# START:  00:12:55.497
# END:  00:12:58.137
# TEXT:  -34 mois de prison dont 12 fermes
# et une interdiction à vie
# ----------
# START:  00:12:58.217
# END:  00:13:00.138
# TEXT:  d'exercer toute activité
# auprès de mineurs.
# ----------
# START:  00:13:00.218
# END:  00:13:03.378
# TEXT:  Cet avocat et ex-entraîneur de foot
# condamné pour contrainte sexuelle
# ----------
# START:  00:13:03.458
# END:  00:13:06.618
# TEXT:  et actes d'ordre sexuel
# avec des enfants.
# ----------
# START:  00:13:03.458
# END:  00:13:06.618
# TEXT:  et actes d'ordre sexuel
# avec des enfants.
# ----------
# START:  00:13:06.698
# END:  00:13:09.818
# TEXT:  Les faits datent de 2017 à 2020.
# ----------
# START:  00:13:09.898
# END:  00:13:11.898
# TEXT:  L'entraîneur rencontre
# des adolescents
# ----------
# START:  00:13:11.978
# END:  00:13:14.058
# TEXT:  dans le cadre du football
# à La Chaux-de-Fonds.
# ----------
# START:  00:13:11.978
# END:  00:13:14.058
# TEXT:  dans le cadre du football
# à La Chaux-de-Fonds.
# ----------
# START:  00:13:14.138
# END:  00:13:16.658
# TEXT:  Les jeunes sont en difficulté
# scolaire ou familiale,
# ----------
# START:  00:13:16.738
# END:  00:13:20.058
# TEXT:  il les engage dans son étude
# comme stagiaires ou apprentis.
# ----------
# START:  00:13:16.738
# END:  00:13:20.058
# TEXT:  il les engage dans son étude
# comme stagiaires ou apprentis.
# ----------
# START:  00:13:20.138
# END:  00:13:22.098
# TEXT:  Il leur offre des cadeaux.
# ----------
# START:  00:13:22.178
# END:  00:13:26.219
# TEXT:  Parfois, les jeunes dorment
# chez l'avocat qui leur demande
# ----------
# START:  00:13:26.339
# END:  00:13:29.019
# TEXT:  de se déshabiller
# ou se doucher devant lui.
# ----------
# START:  00:13:26.339
# END:  00:13:29.019
# TEXT:  de se déshabiller
# ou se doucher devant lui.
# ----------
# START:  00:13:29.099
# END:  00:13:32.779
# TEXT:  Ils ont parfois reçu des claques
# ou des fessées,
# ----------
# START:  00:13:32.819
# END:  00:13:36.379
# TEXT:  à plusieurs reprises, l'accusé
# a touché leurs parties intimes.
# ----------
# START:  00:13:32.819
# END:  00:13:36.379
# TEXT:  à plusieurs reprises, l'accusé
# a touché leurs parties intimes.
# ----------
# START:  00:13:36.459
# END:  00:13:41.659
# TEXT:  La Cour d'appel a revu à la hausse
# la peine du premier procès.
# ----------
# START:  00:13:41.739
# END:  00:13:46.259
# TEXT:  Soulagement des plaignants
# et de la procureure.
# ----------
# START:  00:13:41.739
# END:  00:13:46.259
# TEXT:  Soulagement des plaignants
# et de la procureure.
# ----------
# START:  00:13:46.699
# END:  00:13:48.179
# TEXT:  -Le Ministère public
# ----------
# START:  00:13:48.259
# END:  00:13:50.099
# TEXT:  est satisfait du jugement.
# ----------
# START:  00:13:50.179
# END:  00:13:52.500
# TEXT:  Il a obtenu ce qu'il avait requis,
# ----------
# START:  00:13:50.179
# END:  00:13:52.500
# TEXT:  Il a obtenu ce qu'il avait requis,
# ----------
# START:  00:13:52.580
# END:  00:13:55.740
# TEXT:  notamment sur la contrainte sexuelle.
# ----------
# START:  00:13:55.820
# END:  00:14:00.700
# TEXT:  C'était ce qui n'avait pas été retenu
# en première instance.
# ----------
# START:  00:13:55.820
# END:  00:14:00.700
# TEXT:  C'était ce qui n'avait pas été retenu
# en première instance.
# ----------
# START:  00:14:00.980
# END:  00:14:04.980
# TEXT:  -Du côté de la défense,
# on dénonce un procès émotionnel
# ----------
# START:  00:14:05.060
# END:  00:14:08.300
# TEXT:  et trop de poids accordé
# aux témoignages des plaignants.
# ----------
# START:  00:14:05.060
# END:  00:14:08.300
# TEXT:  et trop de poids accordé
# aux témoignages des plaignants.
# ----------
# START:  00:14:08.580
# END:  00:14:10.220
# TEXT:  -Très sévère,
# ----------
# START:  00:14:10.300
# END:  00:14:12.020
# TEXT:  j'ai le sentiment
# ----------
# START:  00:14:12.100
# END:  00:14:16.901
# TEXT:  qu'on se focalise
# sur la parole des plaignants,
# ----------
# START:  00:14:12.100
# END:  00:14:16.901
# TEXT:  qu'on se focalise
# sur la parole des plaignants,
# ----------
# START:  00:14:16.981
# END:  00:14:23.061
# TEXT:  qui est importante,
# mais qu'on occulte la défense.
# ----------
# START:  00:14:23.541
# END:  00:14:27.781
# TEXT:  -La défense a annoncé faire recours
# auprès du Tribunal fédéral.
# ----------
# START:  00:14:23.541
# END:  00:14:27.781
# TEXT:  -La défense a annoncé faire recours
# auprès du Tribunal fédéral.
# ----------
# START:  00:14:29.061
# END:  00:14:31.861
# TEXT:  -La Cour internationale de justice
# ordonne à Israël
# ----------
# START:  00:14:31.941
# END:  00:14:35.181
# TEXT:  d'arrêter immédiatement
# son offensive militaire à Rafah.
# ----------
# START:  00:14:31.941
# END:  00:14:35.181
# TEXT:  d'arrêter immédiatement
# son offensive militaire à Rafah.
# ----------
# START:  00:14:35.261
# END:  00:14:38.461
# TEXT:  Une ordonnance juridiquement
# contraignante,
# ----------
# START:  00:14:38.541
# END:  00:14:48.302
# TEXT:  mais que la Cour n'a aucun moyen
# de faire respecter.
# ----------
# START:  00:14:38.541
# END:  00:14:48.302
# TEXT:  mais que la Cour n'a aucun moyen
# de faire respecter.
# ----------
# START:  00:14:38.541
# END:  00:14:48.302
# TEXT:  mais que la Cour n'a aucun moyen
# de faire respecter.
# ----------
# START:  00:14:50.582
# END:  00:14:52.702
# TEXT:  Près des élections européennes,
# ----------
# START:  00:14:52.782
# END:  00:14:56.702
# TEXT:  le parti allemand AfD
# mis sur la touche à Bruxelles.
# ----------
# START:  00:14:52.782
# END:  00:14:56.702
# TEXT:  le parti allemand AfD
# mis sur la touche à Bruxelles.
# ----------
# START:  00:14:56.782
# END:  00:15:00.262
# TEXT:  Sa tête de liste
# cumule les dérapages,
# ----------
# START:  00:15:00.342
# END:  00:15:05.582
# TEXT:  comme estimer qu'un nazi n'est
# pas automatiquement un criminel.
# ----------
# START:  00:15:00.342
# END:  00:15:05.582
# TEXT:  comme estimer qu'un nazi n'est
# pas automatiquement un criminel.
# ----------
# START:  00:15:05.662
# END:  00:15:12.663
# TEXT:  L'extrême droite italienne
# et française a condamné ces propos.
# ----------
# START:  00:15:05.662
# END:  00:15:12.663
# TEXT:  L'extrême droite italienne
# et française a condamné ces propos.
# ----------
# START:  00:15:14.383
# END:  00:15:17.023
# TEXT:  -Maximilian Krah est l'acteur
# du dernier épisode
# ----------
# START:  00:15:17.103
# END:  00:15:18.663
# TEXT:  d'une série de scandales,
# ----------
# START:  00:15:18.743
# END:  00:15:23.343
# TEXT:  eurodéputé et candidat du parti
# d'extrême droite allemand (AfD)
# ----------
# START:  00:15:18.743
# END:  00:15:23.343
# TEXT:  eurodéputé et candidat du parti
# d'extrême droite allemand (AfD)
# ----------
# START:  00:15:23.423
# END:  00:15:26.103
# TEXT:  aux élections européennes
# le mois prochain.
# ----------
# START:  00:15:26.183
# END:  00:15:31.023
# TEXT:  Dans une interview récente,
# ses propos ont choqué.
# ----------
# START:  00:15:26.183
# END:  00:15:31.023
# TEXT:  Dans une interview récente,
# ses propos ont choqué.
# ----------
# START:  00:15:39.144
# END:  00:15:40.544
# TEXT:  Des propos inadmissibles
# ----------
# START:  00:15:40.624
# END:  00:15:42.984
# TEXT:  même pour le Rassemblement
# National et la Lega,
# ----------
# START:  00:15:43.064
# END:  00:15:45.624
# TEXT:  les partis d'extrême droite
# français et italien.
# ----------
# START:  00:15:43.064
# END:  00:15:45.624
# TEXT:  les partis d'extrême droite
# français et italien.
# ----------
# START:  00:15:45.704
# END:  00:15:48.504
# TEXT:  Ils ont annoncé
# leur rupture avec l'AfD.
# ----------
# START:  00:15:48.584
# END:  00:15:51.584
# TEXT:  Hier, le groupe qui les fédérait
# au Parlement européen,
# ----------
# START:  00:15:51.664
# END:  00:15:59.545
# TEXT:  annonce l'exclusion
# de M.Krah et de ses 8 collègues.
# ----------
# START:  00:15:51.664
# END:  00:15:59.545
# TEXT:  annonce l'exclusion
# de M.Krah et de ses 8 collègues.
# ----------
# START:  00:15:59.945
# END:  00:16:05.665
# TEXT:  -Nous allons maintenant
# ----------
# START:  00:15:59.945
# END:  00:16:05.665
# TEXT:  -Nous allons maintenant
# ----------
# START:  00:16:05.705
# END:  00:16:07.625
# TEXT:  mener une campagne intensive
# ----------
# START:  00:16:07.705
# END:  00:16:10.465
# TEXT:  pendant deux semaines
# et nous veillerons à regagner
# ----------
# START:  00:16:07.705
# END:  00:16:10.465
# TEXT:  pendant deux semaines
# et nous veillerons à regagner
# ----------
# START:  00:16:10.545
# END:  00:16:12.745
# TEXT:  la confiance
# de nos partenaires internationaux.
# ----------
# START:  00:16:12.825
# END:  00:16:15.705
# TEXT:  Et nous serons
# à nouveau membres du groupe.
# ----------
# START:  00:16:16.145
# END:  00:16:18.745
# TEXT:  -C'est tout le parti
# qui crée le malaise.
# ----------
# START:  00:16:18.825
# END:  00:16:20.625
# TEXT:  En janvier,
# la presse révélait
# ----------
# START:  00:16:20.705
# END:  00:16:24.266
# TEXT:  une réunion secrète
# de partis identitaires, dont l'AfD.
# ----------
# START:  00:16:20.705
# END:  00:16:24.266
# TEXT:  une réunion secrète
# de partis identitaires, dont l'AfD.
# ----------
# START:  00:16:24.346
# END:  00:16:27.186
# TEXT:  L'un des thèmes abordés:
# ----------
# START:  00:16:27.266
# END:  00:16:29.906
# TEXT:  un projet
# d'expulsion massive d'Allemagne
# ----------
# START:  00:16:29.986
# END:  00:16:32.626
# TEXT:  de personnes étrangères
# ou d'origine étrangère.
# ----------
# START:  00:16:29.986
# END:  00:16:32.626
# TEXT:  de personnes étrangères
# ou d'origine étrangère.
# ----------
# START:  00:16:32.706
# END:  00:16:36.626
# TEXT:  A l'époque, le Rassemblement
# National avait pris ses distances.
# ----------
# START:  00:16:37.026
# END:  00:16:38.626
# TEXT:  -Je considère que nous avons
# ----------
# START:  00:16:38.746
# END:  00:16:40.866
# TEXT:  une opposition flagrante avec l'AfD
# ----------
# START:  00:16:38.746
# END:  00:16:40.866
# TEXT:  une opposition flagrante avec l'AfD
# ----------
# START:  00:16:40.946
# END:  00:16:50.307
# TEXT:  et nous serons amenés à discuter
# de divergences aussi importantes.
# ----------
# START:  00:16:40.946
# END:  00:16:50.307
# TEXT:  et nous serons amenés à discuter
# de divergences aussi importantes.
# ----------
# START:  00:16:50.907
# END:  00:16:57.227
# TEXT:  -M.Krah est soupçonné d'avoir touché
# des financements russes et chinois.
# ----------
# START:  00:16:50.907
# END:  00:16:57.227
# TEXT:  -M.Krah est soupçonné d'avoir touché
# des financements russes et chinois.
# ----------
# START:  00:16:57.307
# END:  00:16:59.747
# TEXT:  L'un de ses assistants a été arrêté,
# ----------
# START:  00:16:59.827
# END:  00:17:02.827
# TEXT:  accusé d'avoir espionné
# pour le compte de Pékin.
# ----------
# START:  00:17:04.427
# END:  00:17:07.107
# TEXT:  -Les élections européennes
# sont dans deux semaines.
# ----------
# START:  00:17:07.187
# END:  00:17:09.787
# TEXT:  On parle beaucoup
# de la montée de l'extrême droite.
# ----------
# START:  00:17:09.867
# END:  00:17:10.987
# TEXT:  Isabelle Ory,
# ----------
# START:  00:17:11.067
# END:  00:17:18.708
# TEXT:  Maximilian Krah est-il en train
# de faire exploser l'extrême droite ?
# ----------
# START:  00:17:11.067
# END:  00:17:18.708
# TEXT:  Maximilian Krah est-il en train
# de faire exploser l'extrême droite ?
# ----------
# START:  00:17:18.708
# END:  00:17:21.428
# TEXT:  -Cette crise entre l'AfD
# ----------
# START:  00:17:18.708
# END:  00:17:21.428
# TEXT:  -Cette crise entre l'AfD
# ----------
# START:  00:17:21.588
# END:  00:17:25.108
# TEXT:  et ses
# deux grands partenaires européens,
# ----------
# START:  00:17:25.108
# END:  00:17:28.388
# TEXT:  le Rassemblement National et la Lega,
# ----------
# START:  00:17:25.108
# END:  00:17:28.388
# TEXT:  le Rassemblement National et la Lega,
# ----------
# START:  00:17:28.388
# END:  00:17:31.388
# TEXT:  vient rappeler à quel point
# ----------
# START:  00:17:31.388
# END:  00:17:34.668
# TEXT:  l'extrême droite européenne
# est hétérogène.
# ----------
# START:  00:17:34.668
# END:  00:17:38.988
# TEXT:  Ces derniers temps,
# on a parlé de la montée en puissance
# ----------
# START:  00:17:34.668
# END:  00:17:38.988
# TEXT:  Ces derniers temps,
# on a parlé de la montée en puissance
# ----------
# START:  00:17:38.988
# END:  00:17:41.469
# TEXT:  de ces formations dans les pays.
# ----------
# START:  00:17:41.469
# END:  00:17:43.829
# TEXT:  Quand on agrège les résultats,
# ----------
# START:  00:17:43.829
# END:  00:17:48.829
# TEXT:  ils peuvent obtenir 25 % des sièges
# du futur Parlement européen.
# ----------
# START:  00:17:43.829
# END:  00:17:48.829
# TEXT:  ils peuvent obtenir 25 % des sièges
# du futur Parlement européen.
# ----------
# START:  00:17:48.989
# END:  00:17:50.829
# TEXT:  Les différences
# ----------
# START:  00:17:50.989
# END:  00:17:56.629
# TEXT:  entre ces différents partis
# étaient passées au second plan.
# ----------
# START:  00:17:50.989
# END:  00:17:56.629
# TEXT:  entre ces différents partis
# étaient passées au second plan.
# ----------
# START:  00:17:56.789
# END:  00:18:01.669
# TEXT:  Par exemple, les Hongrois de Viktor
# Orban sont trop pro-russes,
# ----------
# START:  00:17:56.789
# END:  00:18:01.669
# TEXT:  Par exemple, les Hongrois de Viktor
# Orban sont trop pro-russes,
# ----------
# START:  00:18:01.669
# END:  00:18:05.509
# TEXT:  Marine Le Pen est trop radicale pour
# Viktor Orban,
# ----------
# START:  00:18:05.509
# END:  00:18:09.750
# TEXT:  maintenant, l'AfD est trop radicale
# pour Marine Le Pen.
# ----------
# START:  00:18:05.509
# END:  00:18:09.750
# TEXT:  maintenant, l'AfD est trop radicale
# pour Marine Le Pen.
# ----------
# START:  00:18:09.910
# END:  00:18:13.070
# TEXT:  Oui, la droite dure séduit
# de plus en plus d'électeurs.
# ----------
# START:  00:18:13.230
# END:  00:18:20.750
# TEXT:  Elle aura un droit de nuisance
# pour bloquer certaines lois.
# ----------
# START:  00:18:13.230
# END:  00:18:20.750
# TEXT:  Elle aura un droit de nuisance
# pour bloquer certaines lois.
# ----------
# START:  00:18:20.750
# END:  00:18:24.990
# TEXT:  Mais elle n'est pas suffisamment unie
# ----------
# START:  00:18:20.750
# END:  00:18:24.990
# TEXT:  Mais elle n'est pas suffisamment unie
# ----------
# START:  00:18:24.990
# END:  00:18:31.991
# TEXT:  pour espérer imposer une ligne
# politique au niveau européen.
# ----------
# START:  00:18:31.991
# END:  00:18:37.791
# TEXT:  -A une semaine de la fin de son
# procès à New York,
# ----------
# START:  00:18:31.991
# END:  00:18:37.791
# TEXT:  -A une semaine de la fin de son
# procès à New York,
# ----------
# START:  00:18:37.871
# END:  00:18:39.871
# TEXT:  D.Trump en profite
# pour aller dans le Bronx.
# ----------
# START:  00:18:39.951
# END:  00:18:42.311
# TEXT:  Le candidat républicain
# va chercher des électeurs
# ----------
# START:  00:18:39.951
# END:  00:18:42.311
# TEXT:  Le candidat républicain
# va chercher des électeurs
# ----------
# START:  00:18:42.391
# END:  00:18:46.831
# TEXT:  sur un terrain acquis aux démocrates.
# ----------
# START:  00:18:48.351
# END:  00:18:52.231
# TEXT:  -Trump, we love you !
# ----------
# START:  00:18:52.311
# END:  00:18:54.591
# TEXT:  -La scène est inattendue.
# ----------
# START:  00:18:54.671
# END:  00:18:58.352
# TEXT:  Le cirque trumpiste s'arrête
# dans le Bronx.
# ----------
# START:  00:18:54.671
# END:  00:18:58.352
# TEXT:  Le cirque trumpiste s'arrête
# dans le Bronx.
# ----------
# START:  00:18:58.432
# END:  00:19:02.272
# TEXT:  Le républicain, critiqué
# lors des émeutes raciales de 2020,
# ----------
# START:  00:19:02.352
# END:  00:19:04.432
# TEXT:  trouve ici un public.
# ----------
# START:  00:19:02.352
# END:  00:19:04.432
# TEXT:  trouve ici un public.
# ----------
# START:  00:19:04.952
# END:  00:19:06.792
# TEXT:  -On peut être en désaccord
# ----------
# START:  00:19:06.872
# END:  00:19:08.192
# TEXT:  avec certaines choses,
# ----------
# START:  00:19:08.272
# END:  00:19:09.592
# TEXT:  mais il est dans le Bronx.
# ----------
# START:  00:19:09.672
# END:  00:19:12.272
# TEXT:  C'est le premier candidat à venir
# depuis Ronald Reagan.
# ----------
# START:  00:19:09.672
# END:  00:19:12.272
# TEXT:  C'est le premier candidat à venir
# depuis Ronald Reagan.
# ----------
# START:  00:19:12.632
# END:  00:19:14.792
# TEXT:  -Le procès qui se déroule
# à Manhattan
# ----------
# START:  00:19:14.872
# END:  00:19:16.672
# TEXT:  est loin des préoccupations.
# ----------
# START:  00:19:16.752
# END:  00:19:20.632
# TEXT:  Certains s'apprêtent à voter
# républicain pour la première fois.
# ----------
# START:  00:19:16.752
# END:  00:19:20.632
# TEXT:  Certains s'apprêtent à voter
# républicain pour la première fois.
# ----------
# START:  00:19:20.872
# END:  00:19:24.273
# TEXT:  -Les prix montent, les impôts aussi.
# ----------
# START:  00:19:24.353
# END:  00:19:26.753
# TEXT:  Tout ne va pas changer sous Trump,
# ----------
# START:  00:19:26.833
# END:  00:19:31.073
# TEXT:  mais espérons qu'il pourra
# secouer les choses !
# ----------
# START:  00:19:26.833
# END:  00:19:31.073
# TEXT:  mais espérons qu'il pourra
# secouer les choses !
# ----------
# START:  00:19:31.353
# END:  00:19:34.953
# TEXT:  -Devant ce public plus bigarré
# et plus jeune que d'habitude,
# ----------
# START:  00:19:35.033
# END:  00:19:38.793
# TEXT:  le candidat tient
# un discours plus rassembleur.
# ----------
# START:  00:19:35.033
# END:  00:19:38.793
# TEXT:  le candidat tient
# un discours plus rassembleur.
# ----------
# START:  00:19:39.113
# END:  00:19:41.793
# TEXT:  -Ca n'a aucune importance
# ----------
# START:  00:19:41.873
# END:  00:19:43.313
# TEXT:  que vous soyez noirs,
# ----------
# START:  00:19:43.393
# END:  00:19:44.673
# TEXT:  bruns ou blancs.
# ----------
# START:  00:19:43.393
# END:  00:19:44.673
# TEXT:  bruns ou blancs.
# ----------
# START:  00:19:44.753
# END:  00:19:50.354
# TEXT:  Nous sommes tous américains
# et on va s'en sortir ensemble.
# ----------
# START:  00:19:50.634
# END:  00:19:53.314
# TEXT:  -Plus qu'une simple provocation
# ----------
# START:  00:19:50.634
# END:  00:19:53.314
# TEXT:  -Plus qu'une simple provocation
# ----------
# START:  00:19:53.394
# END:  00:19:55.314
# TEXT:  pour détourner l'attention
# ----------
# START:  00:19:55.394
# END:  00:19:59.234
# TEXT:  de son procès, cette apparition
# fait partie d'une stratégie
# ----------
# START:  00:19:59.354
# END:  00:20:02.954
# TEXT:  du candidat républicain
# pour séduire les minorités.
# ----------
# START:  00:19:59.354
# END:  00:20:02.954
# TEXT:  du candidat républicain
# pour séduire les minorités.
# ----------
# START:  00:20:03.034
# END:  00:20:06.354
# TEXT:  Le Bronx, quartier qui compte
# le plus d'électeurs pauvres
# ----------
# START:  00:20:06.434
# END:  00:20:10.274
# TEXT:  et issus des minorités,
# avait voté pour Joe Biden en 2020.
# ----------
# START:  00:20:06.434
# END:  00:20:10.274
# TEXT:  et issus des minorités,
# avait voté pour Joe Biden en 2020.
# ...
# ----------
# START:  00:23:56.283
# END:  00:23:57.923
# TEXT:  -Je voulais que ce soit
# ----------
# START:  00:23:58.003
# END:  00:24:01.483
# TEXT:  comme une pensée spontanée.
# ----------
# START:  00:23:58.003
# END:  00:24:01.483
# TEXT:  comme une pensée spontanée.
# ----------
# START:  00:24:01.563
# END:  00:24:05.404
# TEXT:  J'observe ce qui se passe
# dans ma tête quand j'y réfléchis
# ----------
# START:  00:24:05.484
# END:  00:24:08.564
# TEXT:  et je traduis ça en texte.
# ----------
# START:  00:24:05.484
# END:  00:24:08.564
# TEXT:  et je traduis ça en texte.
# ----------
# START:  00:24:08.804
# END:  00:24:12.324
# TEXT:  -Un livre que N.Sinno ne voulait
# pas écrire, dans lequel elle avoue
# ----------
# START:  00:24:12.404
# END:  00:24:14.884
# TEXT:  souhaiter qu'il ne soit pas lu.
# ----------
# START:  00:24:15.204
# END:  00:24:17.844
# TEXT:  -Je veux que personne ne sache
# que j'ai été violée,
# ----------
# START:  00:24:15.204
# END:  00:24:17.844
# TEXT:  -Je veux que personne ne sache
# que j'ai été violée,
# ----------
# START:  00:24:17.924
# END:  00:24:25.884
# TEXT:  mais j'ai écrit à mes amis
# que c'était une petite bombe
# ----------
# START:  00:24:17.924
# END:  00:24:25.884
# TEXT:  mais j'ai écrit à mes amis
# que c'était une petite bombe
# ----------
# START:  00:24:25.964
# END:  00:24:32.445
# TEXT:  qui ferait tout imploser.
# ----------
# START:  00:24:25.964
# END:  00:24:32.445
# TEXT:  qui ferait tout imploser.
# ----------
# START:  00:24:32.525
# END:  00:24:37.245
# TEXT:  J'avais donc aussi ce désir
# que tout le monde lise ça.
# ----------
# START:  00:24:37.525
# END:  00:24:40.285
# TEXT:  -"Je frotte mes assiettes rageusement
# ----------
# START:  00:24:37.525
# END:  00:24:40.285
# TEXT:  -"Je frotte mes assiettes rageusement
# ----------
# START:  00:24:40.365
# END:  00:24:45.045
# TEXT:  et je pense à la phrase
# que je pourrais dire."
# ----------
# START:  00:24:45.125
# END:  00:24:48.965
# TEXT:  "Il me viole
# depuis que je suis petite."
# ----------
# START:  00:24:45.125
# END:  00:24:48.965
# TEXT:  "Il me viole
# depuis que je suis petite."
# ----------
# START:  00:24:49.445
# END:  00:24:52.925
# TEXT:  -"Triste Tigre" sera traduit
# en plus de 20 langues.
# ----------
# START:  00:24:52.965
# END:  00:24:56.646
# TEXT:  La bombe de N.Sinno
# n'a pas fini d'exploser.
# ----------
# START:  00:24:52.965
# END:  00:24:56.646
# TEXT:  La bombe de N.Sinno
# n'a pas fini d'exploser.
# ----------
# START:  00:24:58.246
# END:  00:25:01.286
# TEXT:  -Elles ont fasciné
# des générations d'archéologues.
# ----------
# START:  00:25:01.406
# END:  00:25:05.246
# TEXT:  Vous vous êtes peut-être déjà demandé
# ----------
# START:  00:25:01.406
# END:  00:25:05.246
# TEXT:  Vous vous êtes peut-être déjà demandé
# ----------
# START:  00:25:05.326
# END:  00:25:08.006
# TEXT:  comment les pyramides
# ont été construites,
# ----------
# START:  00:25:08.086
# END:  00:25:11.126
# TEXT:  alors qu'elles sont en plein désert ?
# ----------
# START:  00:25:11.206
# END:  00:25:13.366
# TEXT:  Réponse !
# ----------
# START:  00:25:11.206
# END:  00:25:13.366
# TEXT:  Réponse !
# ----------
# START:  00:25:15.126
# END:  00:25:18.686
# TEXT:  -Elles ne sont pas avares
# en mystères:
# ----------
# START:  00:25:18.766
# END:  00:25:21.607
# TEXT:  chambres secrètes, trésors cachés...
# ----------
# START:  00:25:18.766
# END:  00:25:21.607
# TEXT:  chambres secrètes, trésors cachés...
# ----------
# START:  00:25:21.687
# END:  00:25:25.047
# TEXT:  L'emplacement des pyramides
# intrigue aussi.
# ----------
# START:  00:25:25.047
# END:  00:25:27.207
# TEXT:  Depuis le plateau de Gizeh,
# ----------
# START:  00:25:27.207
# END:  00:25:30.167
# TEXT:  beaucoup sont alignées
# dans le désert.
# ----------
# START:  00:25:27.207
# END:  00:25:30.167
# TEXT:  beaucoup sont alignées
# dans le désert.
# ----------
# START:  00:25:30.247
# END:  00:25:34.167
# TEXT:  A des kilomètres du Nil actuel,
# ligne de vie du pays,
# ----------
# START:  00:25:34.247
# END:  00:25:36.407
# TEXT:  comme à l'époque des pharaons.
# ----------
# START:  00:25:34.247
# END:  00:25:36.407
# TEXT:  comme à l'époque des pharaons.
# ----------
# START:  00:25:36.487
# END:  00:25:39.367
# TEXT:  Mais des scientifiques ont découvert
# un bras asséché du Nil,
# ----------
# START:  00:25:39.447
# END:  00:25:41.527
# TEXT:  qui passait au pied des monuments.
# ----------
# START:  00:25:41.607
# END:  00:25:44.967
# TEXT:  De quoi acheminer par bateau
# les blocs pour les ériger.
# ----------
# START:  00:25:41.607
# END:  00:25:44.967
# TEXT:  De quoi acheminer par bateau
# les blocs pour les ériger.
# ----------
# START:  00:25:45.047
# END:  00:25:48.568
# TEXT:  Les images radar permettent
# de traquer dans le sous-sol
# ----------
# START:  00:25:48.648
# END:  00:25:54.328
# TEXT:  les sédiments du lit d'un ancien
# fleuve, recouvert par le sable.
# ----------
# START:  00:25:48.648
# END:  00:25:54.328
# TEXT:  les sédiments du lit d'un ancien
# fleuve, recouvert par le sable.
# ----------
# START:  00:25:54.408
# END:  00:25:58.248
# TEXT:  Des mesures confirmées
# par l'extraction de terre.
# ----------
# START:  00:25:58.328
# END:  00:26:02.848
# TEXT:  Comme souvent en égyptologie,
# cette découverte est discutée.
# ----------
# START:  00:25:58.328
# END:  00:26:02.848
# TEXT:  Comme souvent en égyptologie,
# cette découverte est discutée.
# ----------
# START:  00:26:03.808
# END:  00:26:05.808
# TEXT:  -On savait déjà des choses.
# ----------
# START:  00:26:05.888
# END:  00:26:08.368
# TEXT:  On soupçonnait l'existence
# de ce canal.
# ----------
# START:  00:26:05.888
# END:  00:26:08.368
# TEXT:  On soupçonnait l'existence
# de ce canal.
# ----------
# START:  00:26:08.448
# END:  00:26:09.928
# TEXT:  Ce qui est nouveau,
# ----------
# START:  00:26:10.008
# END:  00:26:12.009
# TEXT:  ce sont les images satellite,
# ----------
# START:  00:26:12.089
# END:  00:26:17.889
# TEXT:  qui permettent d'évaluer l'ampleur
# de cette branche du Nil
# ----------
# START:  00:26:12.089
# END:  00:26:17.889
# TEXT:  qui permettent d'évaluer l'ampleur
# de cette branche du Nil
# ----------
# START:  00:26:17.969
# END:  00:26:22.649
# TEXT:  et de confirmer certaines hypothèses.
# ----------
# START:  00:26:25.809
# END:  00:26:29.089
# TEXT:  -Des blocs transportés par bateau:
# plusieurs bas-reliefs le montrent.
# ----------
# START:  00:26:29.169
# END:  00:26:30.649
# TEXT:  L'idée est entérinée en 2013
# ----------
# START:  00:26:30.729
# END:  00:26:33.169
# TEXT:  par la découverte
# des papyrus de la mer Rouge.
# ----------
# START:  00:26:30.729
# END:  00:26:33.169
# TEXT:  par la découverte
# des papyrus de la mer Rouge.
# ----------
# START:  00:26:33.249
# END:  00:26:36.649
# TEXT:  Un chapitre y décrit le quotidien
# des bâtisseurs de pyramides.
# ----------
# START:  00:26:45.970
# END:  00:26:48.370
# TEXT:  Une grande pyramide accessible
# par un port,
# ----------
# START:  00:26:45.970
# END:  00:26:48.370
# TEXT:  Une grande pyramide accessible
# par un port,
# ----------
# START:  00:26:48.450
# END:  00:26:50.850
# TEXT:  comme l'ont montré des sondages
# en 2022.
# ----------
# START:  00:26:50.930
# END:  00:26:54.850
# TEXT:  A Saqqarah, les chercheurs
# ont constaté que les débarcadères
# ----------
# START:  00:26:54.930
# END:  00:26:57.930
# TEXT:  collaient à l'emplacement
# du fleuve asséché.
# ----------
# START:  00:26:54.930
# END:  00:26:57.930
# TEXT:  collaient à l'emplacement
# du fleuve asséché.
# ----------
# START:  00:26:59.330
# END:  00:27:01.890
# TEXT:  -Les Egyptiens
# étaient très astucieux,
# ----------
# START:  00:27:01.970
# END:  00:27:04.411
# TEXT:  très pragmatiques aussi.
# ----------
# START:  00:27:01.970
# END:  00:27:04.411
# TEXT:  très pragmatiques aussi.
# ----------
# START:  00:27:04.491
# END:  00:27:06.091
# TEXT:  C'était la loi du moindre effort.
# ----------
# START:  00:27:06.171
# END:  00:27:08.011
# TEXT:  Ils ont utilisé leur environnement
# ----------
# START:  00:27:08.091
# END:  00:27:10.971
# TEXT:  pour construire les pyramides.
# ----------
# START:  00:27:11.051
# END:  00:27:16.731
# TEXT:  Ils ne subissent pas seulement
# les aléas de la géologie.
# ----------
# START:  00:27:11.051
# END:  00:27:16.731
# TEXT:  Ils ne subissent pas seulement
# les aléas de la géologie.
# ----------
# START:  00:27:16.851
# END:  00:27:21.211
# TEXT:  Ils dominaient leur territoire
# et savaient ce qu'ils faisaient.
# ----------
# START:  00:27:16.851
# END:  00:27:21.211
# TEXT:  Ils dominaient leur territoire
# et savaient ce qu'ils faisaient.
# ----------
# START:  00:27:21.731
# END:  00:27:24.331
# TEXT:  -Un territoire balisé
# avec ce Nil asséché,
# ----------
# START:  00:27:24.451
# END:  00:27:28.812
# TEXT:  que les égyptologues pourront
# explorer de manière ciblée.
# ----------
# START:  00:27:24.451
# END:  00:27:28.812
# TEXT:  que les égyptologues pourront
# explorer de manière ciblée.
# ----------
# START:  00:27:30.292
# END:  00:27:32.612
# TEXT:  -Tennis, surprise au Geneva Open !
# ----------
# START:  00:27:32.692
# END:  00:27:35.172
# TEXT:  Novak Djokovic s'est incliné
# en demi-finale.
# ----------
# START:  00:27:35.252
# END:  00:27:40.652
# TEXT:  Le numéro un mondial a été battu
# 6-4, 0-6, 6-1 par Tomas Machac
# ----------
# START:  00:27:35.252
# END:  00:27:40.652
# TEXT:  Le numéro un mondial a été battu
# 6-4, 0-6, 6-1 par Tomas Machac
# ----------
# START:  00:27:40.732
# END:  00:27:43.012
# TEXT:  au terme d'un match décousu.
# ----------
# START:  00:27:43.092
# END:  00:27:45.412
# TEXT:  Le Serbe dit
# avoir des problèmes d'estomac
# ----------
# START:  00:27:43.092
# END:  00:27:45.412
# TEXT:  Le Serbe dit
# avoir des problèmes d'estomac
# ----------
# START:  00:27:45.492
# END:  00:27:48.892
# TEXT:  et ne pas être rassuré
# avant Roland-Garros.
# ----------
# START:  00:27:48.932
# END:  00:27:53.692
# TEXT:  Tomas Machac participera demain
# à sa première finale ATP.
# ----------
# START:  00:27:48.932
# END:  00:27:53.692
# TEXT:  Tomas Machac participera demain
# à sa première finale ATP.
# ----------
# START:  00:27:55.093
# END:  00:27:58.773
# TEXT:  A 60 ans, Lenny Kravitz
# sort un douzième album.
# ----------
# START:  00:27:58.853
# END:  00:28:09.813
# TEXT:  "Blue Electric Light" ne déroge pas
# à l'icône rock qu'il a toujours été.
# ----------
# START:  00:27:58.853
# END:  00:28:09.813
# TEXT:  "Blue Electric Light" ne déroge pas
# à l'icône rock qu'il a toujours été.
# ----------
# START:  00:27:58.853
# END:  00:28:09.813
# TEXT:  "Blue Electric Light" ne déroge pas
# à l'icône rock qu'il a toujours été.
# ----------
# START:  00:28:12.933
# END:  00:28:17.133
# TEXT:  -Le temps n'a pas d'effet sur lui.
# ----------
# START:  00:28:12.933
# END:  00:28:17.133
# TEXT:  -Le temps n'a pas d'effet sur lui.
# ----------
# START:  00:28:17.213
# END:  00:28:24.854
# TEXT:  Lenny Kravitz en joue
# entre glam et rock.
# ----------
# START:  00:28:17.213
# END:  00:28:24.854
# TEXT:  Lenny Kravitz en joue
# entre glam et rock.
# ----------
# START:  00:28:24.934
# END:  00:28:32.094
# TEXT:  A deux jours de ses 60 ans,
# il sort son 12ème album:
# ----------
# START:  00:28:24.934
# END:  00:28:32.094
# TEXT:  A deux jours de ses 60 ans,
# il sort son 12ème album:
# ----------
# START:  00:28:32.174
# END:  00:28:34.774
# TEXT:  "Blue Electric Light".
# ----------
# START:  00:28:34.854
# END:  00:28:38.814
# TEXT:  Rock
# ----------
# START:  00:28:39.134
# END:  00:28:40.894
# TEXT:  -"Blue Electric Light",
# ----------
# START:  00:28:39.134
# END:  00:28:40.894
# TEXT:  -"Blue Electric Light",
# ----------
# START:  00:28:40.974
# END:  00:28:43.054
# TEXT:  c'est l'énergie, l'amour,
# ----------
# START:  00:28:43.134
# END:  00:28:47.215
# TEXT:  la spiritualité, l'humanité.
# ----------
# START:  00:28:47.295
# END:  00:28:54.575
# TEXT:  C'est cette énergie qui me nourrit.
# ----------
# START:  00:28:47.295
# END:  00:28:54.575
# TEXT:  C'est cette énergie qui me nourrit.
# ----------
# START:  00:28:55.375
# END:  00:28:59.815
# TEXT:  -Une énergie funk, soul et rock,
# toutes ces musiques qu'il vampirise
# ----------
# START:  00:28:55.375
# END:  00:28:59.815
# TEXT:  -Une énergie funk, soul et rock,
# toutes ces musiques qu'il vampirise
# ----------
# START:  00:28:59.895
# END:  00:29:02.255
# TEXT:  depuis ses débuts en 1989.
# ----------
# START:  00:29:02.335
# END:  00:29:09.375
# TEXT:  Il n'a rien inventé, mais
# transforme en pépite ce qui existe.
# ----------
# START:  00:29:02.335
# END:  00:29:09.375
# TEXT:  Il n'a rien inventé, mais
# transforme en pépite ce qui existe.
# ----------
# START:  00:29:09.455
# END:  00:29:15.336
# TEXT:  Lenny Kravitz
# "Are you gonna go my way"
# ----------
# START:  00:29:09.455
# END:  00:29:15.336
# TEXT:  Lenny Kravitz
# "Are you gonna go my way"
# ----------
# START:  00:29:15.416
# END:  00:29:21.136
# TEXT:  Lenny Kravitz
# "American woman"
# ----------
# START:  00:29:15.416
# END:  00:29:21.136
# TEXT:  Lenny Kravitz
# "American woman"
# ----------
# START:  00:29:21.216
# END:  00:29:27.776
# TEXT:  Lenny Kravitz
# "Fly Away"
# ----------
# START:  00:29:28.336
# END:  00:29:31.416
# TEXT:  -Je n'ai jamais essayé
# de faire un tube.
# ----------
# START:  00:29:31.536
# END:  00:29:33.416
# TEXT:  J'attends: quand ça vient, ça vient.
# ----------
# START:  00:29:33.496
# END:  00:29:37.617
# TEXT:  J'utilise mes talents:
# ----------
# START:  00:29:33.496
# END:  00:29:37.617
# TEXT:  J'utilise mes talents:
# ----------
# START:  00:29:37.697
# END:  00:29:40.857
# TEXT:  jouer plusieurs instruments,
# produire, faire les arrangements.
# ----------
# START:  00:29:42.177
# END:  00:29:47.137
# TEXT:  -Lenny Kravitz, l'un des derniers
# gardiens du temple rock,
# ----------
# START:  00:29:42.177
# END:  00:29:47.137
# TEXT:  -Lenny Kravitz, l'un des derniers
# gardiens du temple rock,
# ----------
# START:  00:29:47.217
# END:  00:29:50.217
# TEXT:  une star qui fait du bien.
# ----------
# START:  00:29:50.297
# END:  00:29:55.577
# TEXT:  Son concert au Montreux Jazz cet été
# est d'ailleurs complet.
# ----------
# START:  00:29:50.297
# END:  00:29:55.577
# TEXT:  Son concert au Montreux Jazz cet été
# est d'ailleurs complet.
# ----------
# START:  00:29:55.617
# END:  00:29:59.577
# TEXT:  Rock
# ----------
# START:  00:29:59.697
# END:  00:30:05.978
# TEXT:  ...
# ----------
# START:  00:29:59.697
# END:  00:30:05.978
# TEXT:  ...
# ----------
# START:  00:30:07.298
# END:  00:30:09.778
# TEXT:  -C'est la fin de ce journal,
# merci de l'avoir suivi.
# ----------
# START:  00:30:07.298
# END:  00:30:09.778
# TEXT:  -C'est la fin de ce journal,
# merci de l'avoir suivi.
# ----------
# START:  00:30:09.858
# END:  00:30:12.258
# TEXT:  Tout de suite, la météo,
# puis "Bye bye la Suisse".
# ----------
# START:  00:30:12.338
# END:  00:30:14.658
# TEXT:  Très belle soirée sur la RTS !
# ----------
# START:  00:30:14.778
# END:  00:30:18.338
# TEXT:  Sous-titrage SWISS TXT
# L.Campbell, N.Farag, A.Giddey,
# A.Kosakevitch, J.Szucs
# ----------
# START:  00:30:14.778
# END:  00:30:18.338
# TEXT:  Sous-titrage SWISS TXT
# L.Campbell, N.Farag, A.Giddey,
# A.Kosakevitch, J.Szucs
# ----------
# ---------------------------------------------------------------------------
# MalformedFileError                        Traceback (most recent call last)
# Cell In[4], line 9
#       6 for i in range(1, 233):
#       7     filename = f'./video/subtitle_segments/seg-{i}-f6.vtt'
# ----> 9     captions = webvtt.read(filename)
#      11     for caption in captions:
#      12         print("START: ", caption.start)
#
# File ~/Desktop/mediawatch/venv_mediawatch/lib/python3.12/site-packages/webvtt/webvtt.py:89, in WebVTT.read(cls, file, encoding)
#      81 """
#      82 Read a WebVTT captions file.
#      83
#    (...)
#      86 :returns: a `WebVTT` instance
#      87 """
#      88 with utils.FileWrapper.open(file, encoding=encoding) as fw:
# ---> 89     instance = cls.from_buffer(fw.file)
#      90     if fw.bom_encoding:
#      91         instance.encoding = fw.bom_encoding
#
# File ~/Desktop/mediawatch/venv_mediawatch/lib/python3.12/site-packages/webvtt/webvtt.py:139, in WebVTT.from_buffer(cls, buffer, format)
#     136 _cls = partial(cls, file=getattr(buffer, 'name', None))
#     138 if format == 'vtt':
# --> 139     output = vtt.parse(cls._get_lines(buffer))
#     141     return _cls(
#     142         captions=output.captions,
#     143         styles=output.styles,
#     144         header_comments=output.header_comments,
#     145         footer_comments=output.footer_comments
#     146         )
#     148 if format == 'srt':
#
# File ~/Desktop/mediawatch/venv_mediawatch/lib/python3.12/site-packages/webvtt/vtt.py:256, in parse(lines)
#     249 """
#     250 Parse VTT captions from lines of text.
#     251
#     252 :param lines: lines of text
#     253 :returns: object `ParserOutput` with all parsed items
#     254 """
#     255 if not is_valid_content(lines):
# --> 256     raise MalformedFileError('Invalid format')
#     258 return parse_items(lines)
#
# MalformedFileError: Invalid format

# %%
print(len(transcript))
# Out:
# 459

# %%
subtitle_segments
# Out:
# ['./video/subtitle_segments/seg-1-f6.vtt',
#  './video/subtitle_segments/seg-5-f6.vtt',
#  './video/subtitle_segments/seg-6-f6.vtt',
#  './video/subtitle_segments/seg-6-f6.vtt',
#  './video/subtitle_segments/seg-6-f6.vtt',
#  './video/subtitle_segments/seg-7-f6.vtt',
#  './video/subtitle_segments/seg-8-f6.vtt',
#  './video/subtitle_segments/seg-8-f6.vtt',
#  './video/subtitle_segments/seg-8-f6.vtt',
#  './video/subtitle_segments/seg-9-f6.vtt',
#  './video/subtitle_segments/seg-9-f6.vtt',
#  './video/subtitle_segments/seg-9-f6.vtt',
#  './video/subtitle_segments/seg-10-f6.vtt',
#  './video/subtitle_segments/seg-11-f6.vtt',
#  './video/subtitle_segments/seg-11-f6.vtt',
#  './video/subtitle_segments/seg-11-f6.vtt',
#  './video/subtitle_segments/seg-12-f6.vtt',
#  './video/subtitle_segments/seg-12-f6.vtt',
#  './video/subtitle_segments/seg-13-f6.vtt',
#  './video/subtitle_segments/seg-14-f6.vtt',
#  './video/subtitle_segments/seg-14-f6.vtt',
#  './video/subtitle_segments/seg-14-f6.vtt',
#  './video/subtitle_segments/seg-14-f6.vtt',
#  './video/subtitle_segments/seg-16-f6.vtt',
#  './video/subtitle_segments/seg-16-f6.vtt',
#  './video/subtitle_segments/seg-17-f6.vtt',
#  './video/subtitle_segments/seg-17-f6.vtt',
#  './video/subtitle_segments/seg-18-f6.vtt',
#  './video/subtitle_segments/seg-19-f6.vtt',
#  './video/subtitle_segments/seg-19-f6.vtt',
#  './video/subtitle_segments/seg-19-f6.vtt',
#  './video/subtitle_segments/seg-20-f6.vtt',
#  './video/subtitle_segments/seg-20-f6.vtt',
#  './video/subtitle_segments/seg-21-f6.vtt',
#  './video/subtitle_segments/seg-22-f6.vtt',
#  './video/subtitle_segments/seg-22-f6.vtt',
#  './video/subtitle_segments/seg-22-f6.vtt',
#  './video/subtitle_segments/seg-23-f6.vtt',
#  './video/subtitle_segments/seg-23-f6.vtt',
#  './video/subtitle_segments/seg-24-f6.vtt',
#  './video/subtitle_segments/seg-25-f6.vtt',
#  './video/subtitle_segments/seg-25-f6.vtt',
#  './video/subtitle_segments/seg-26-f6.vtt',
#  './video/subtitle_segments/seg-26-f6.vtt',
#  './video/subtitle_segments/seg-27-f6.vtt',
#  './video/subtitle_segments/seg-28-f6.vtt',
#  './video/subtitle_segments/seg-28-f6.vtt',
#  './video/subtitle_segments/seg-29-f6.vtt',
#  './video/subtitle_segments/seg-29-f6.vtt',
#  './video/subtitle_segments/seg-30-f6.vtt',
#  './video/subtitle_segments/seg-30-f6.vtt',
#  './video/subtitle_segments/seg-31-f6.vtt',
#  './video/subtitle_segments/seg-32-f6.vtt',
#  './video/subtitle_segments/seg-33-f6.vtt',
#  './video/subtitle_segments/seg-33-f6.vtt',
#  './video/subtitle_segments/seg-34-f6.vtt',
#  './video/subtitle_segments/seg-34-f6.vtt',
#  './video/subtitle_segments/seg-34-f6.vtt',
#  './video/subtitle_segments/seg-35-f6.vtt',
#  './video/subtitle_segments/seg-35-f6.vtt',
#  './video/subtitle_segments/seg-36-f6.vtt',
#  './video/subtitle_segments/seg-36-f6.vtt',
#  './video/subtitle_segments/seg-37-f6.vtt',
#  './video/subtitle_segments/seg-38-f6.vtt',
#  './video/subtitle_segments/seg-38-f6.vtt',
#  './video/subtitle_segments/seg-39-f6.vtt',
#  './video/subtitle_segments/seg-39-f6.vtt',
#  './video/subtitle_segments/seg-40-f6.vtt',
#  './video/subtitle_segments/seg-40-f6.vtt',
#  './video/subtitle_segments/seg-41-f6.vtt',
#  './video/subtitle_segments/seg-41-f6.vtt',
#  './video/subtitle_segments/seg-42-f6.vtt',
#  './video/subtitle_segments/seg-42-f6.vtt',
#  './video/subtitle_segments/seg-42-f6.vtt',
#  './video/subtitle_segments/seg-43-f6.vtt',
#  './video/subtitle_segments/seg-43-f6.vtt',
#  './video/subtitle_segments/seg-44-f6.vtt',
#  './video/subtitle_segments/seg-44-f6.vtt',
#  './video/subtitle_segments/seg-45-f6.vtt',
#  './video/subtitle_segments/seg-45-f6.vtt',
#  './video/subtitle_segments/seg-46-f6.vtt',
#  './video/subtitle_segments/seg-46-f6.vtt',
#  './video/subtitle_segments/seg-47-f6.vtt',
#  './video/subtitle_segments/seg-47-f6.vtt',
#  './video/subtitle_segments/seg-48-f6.vtt',
#  './video/subtitle_segments/seg-48-f6.vtt',
#  './video/subtitle_segments/seg-49-f6.vtt',
#  './video/subtitle_segments/seg-49-f6.vtt',
#  './video/subtitle_segments/seg-50-f6.vtt',
#  './video/subtitle_segments/seg-50-f6.vtt',
#  './video/subtitle_segments/seg-51-f6.vtt',
#  './video/subtitle_segments/seg-52-f6.vtt',
#  './video/subtitle_segments/seg-52-f6.vtt',
#  './video/subtitle_segments/seg-53-f6.vtt',
#  './video/subtitle_segments/seg-53-f6.vtt',
#  './video/subtitle_segments/seg-54-f6.vtt',
#  './video/subtitle_segments/seg-54-f6.vtt',
#  './video/subtitle_segments/seg-55-f6.vtt',
#  './video/subtitle_segments/seg-55-f6.vtt',
#  './video/subtitle_segments/seg-56-f6.vtt',
#  './video/subtitle_segments/seg-57-f6.vtt',
#  './video/subtitle_segments/seg-57-f6.vtt',
#  './video/subtitle_segments/seg-58-f6.vtt',
#  './video/subtitle_segments/seg-58-f6.vtt',
#  './video/subtitle_segments/seg-58-f6.vtt',
#  './video/subtitle_segments/seg-59-f6.vtt',
#  './video/subtitle_segments/seg-59-f6.vtt',
#  './video/subtitle_segments/seg-60-f6.vtt',
#  './video/subtitle_segments/seg-60-f6.vtt',
#  './video/subtitle_segments/seg-61-f6.vtt',
#  './video/subtitle_segments/seg-61-f6.vtt',
#  './video/subtitle_segments/seg-62-f6.vtt',
#  './video/subtitle_segments/seg-62-f6.vtt',
#  './video/subtitle_segments/seg-62-f6.vtt',
#  './video/subtitle_segments/seg-62-f6.vtt',
#  './video/subtitle_segments/seg-63-f6.vtt',
#  './video/subtitle_segments/seg-63-f6.vtt',
#  './video/subtitle_segments/seg-64-f6.vtt',
#  './video/subtitle_segments/seg-64-f6.vtt',
#  './video/subtitle_segments/seg-65-f6.vtt',
#  './video/subtitle_segments/seg-65-f6.vtt',
#  './video/subtitle_segments/seg-65-f6.vtt',
#  './video/subtitle_segments/seg-66-f6.vtt',
#  './video/subtitle_segments/seg-66-f6.vtt',
#  './video/subtitle_segments/seg-66-f6.vtt',
#  './video/subtitle_segments/seg-67-f6.vtt',
#  './video/subtitle_segments/seg-67-f6.vtt',
#  './video/subtitle_segments/seg-68-f6.vtt',
#  './video/subtitle_segments/seg-68-f6.vtt',
#  './video/subtitle_segments/seg-69-f6.vtt',
#  './video/subtitle_segments/seg-69-f6.vtt',
#  './video/subtitle_segments/seg-70-f6.vtt',
#  './video/subtitle_segments/seg-70-f6.vtt',
#  './video/subtitle_segments/seg-71-f6.vtt',
#  './video/subtitle_segments/seg-71-f6.vtt',
#  './video/subtitle_segments/seg-72-f6.vtt',
#  './video/subtitle_segments/seg-73-f6.vtt',
#  './video/subtitle_segments/seg-73-f6.vtt',
#  './video/subtitle_segments/seg-73-f6.vtt',
#  './video/subtitle_segments/seg-74-f6.vtt',
#  './video/subtitle_segments/seg-74-f6.vtt',
#  './video/subtitle_segments/seg-75-f6.vtt',
#  './video/subtitle_segments/seg-75-f6.vtt',
#  './video/subtitle_segments/seg-75-f6.vtt',
#  './video/subtitle_segments/seg-76-f6.vtt',
#  './video/subtitle_segments/seg-76-f6.vtt',
#  './video/subtitle_segments/seg-77-f6.vtt',
#  './video/subtitle_segments/seg-77-f6.vtt',
#  './video/subtitle_segments/seg-78-f6.vtt',
#  './video/subtitle_segments/seg-78-f6.vtt',
#  './video/subtitle_segments/seg-78-f6.vtt',
#  './video/subtitle_segments/seg-79-f6.vtt',
#  './video/subtitle_segments/seg-79-f6.vtt',
#  './video/subtitle_segments/seg-80-f6.vtt',
#  './video/subtitle_segments/seg-80-f6.vtt',
#  './video/subtitle_segments/seg-80-f6.vtt',
#  './video/subtitle_segments/seg-81-f6.vtt',
#  './video/subtitle_segments/seg-81-f6.vtt',
#  './video/subtitle_segments/seg-82-f6.vtt',
#  './video/subtitle_segments/seg-82-f6.vtt',
#  './video/subtitle_segments/seg-82-f6.vtt',
#  './video/subtitle_segments/seg-83-f6.vtt',
#  './video/subtitle_segments/seg-84-f6.vtt',
#  './video/subtitle_segments/seg-85-f6.vtt',
#  './video/subtitle_segments/seg-85-f6.vtt',
#  './video/subtitle_segments/seg-86-f6.vtt',
#  './video/subtitle_segments/seg-86-f6.vtt',
#  './video/subtitle_segments/seg-86-f6.vtt',
#  './video/subtitle_segments/seg-87-f6.vtt',
#  './video/subtitle_segments/seg-87-f6.vtt',
#  './video/subtitle_segments/seg-87-f6.vtt',
#  './video/subtitle_segments/seg-88-f6.vtt',
#  './video/subtitle_segments/seg-88-f6.vtt',
#  './video/subtitle_segments/seg-88-f6.vtt',
#  './video/subtitle_segments/seg-89-f6.vtt',
#  './video/subtitle_segments/seg-89-f6.vtt',
#  './video/subtitle_segments/seg-90-f6.vtt',
#  './video/subtitle_segments/seg-91-f6.vtt',
#  './video/subtitle_segments/seg-91-f6.vtt',
#  './video/subtitle_segments/seg-93-f6.vtt',
#  './video/subtitle_segments/seg-93-f6.vtt',
#  './video/subtitle_segments/seg-93-f6.vtt',
#  './video/subtitle_segments/seg-94-f6.vtt',
#  './video/subtitle_segments/seg-94-f6.vtt',
#  './video/subtitle_segments/seg-95-f6.vtt',
#  './video/subtitle_segments/seg-95-f6.vtt',
#  './video/subtitle_segments/seg-96-f6.vtt',
#  './video/subtitle_segments/seg-96-f6.vtt',
#  './video/subtitle_segments/seg-97-f6.vtt',
#  './video/subtitle_segments/seg-97-f6.vtt',
#  './video/subtitle_segments/seg-98-f6.vtt',
#  './video/subtitle_segments/seg-99-f6.vtt',
#  './video/subtitle_segments/seg-99-f6.vtt',
#  './video/subtitle_segments/seg-99-f6.vtt',
#  './video/subtitle_segments/seg-100-f6.vtt',
#  './video/subtitle_segments/seg-100-f6.vtt',
#  './video/subtitle_segments/seg-100-f6.vtt',
#  './video/subtitle_segments/seg-101-f6.vtt',
#  './video/subtitle_segments/seg-101-f6.vtt',
#  './video/subtitle_segments/seg-101-f6.vtt',
#  './video/subtitle_segments/seg-102-f6.vtt',
#  './video/subtitle_segments/seg-102-f6.vtt',
#  './video/subtitle_segments/seg-102-f6.vtt',
#  './video/subtitle_segments/seg-103-f6.vtt',
#  './video/subtitle_segments/seg-103-f6.vtt',
#  './video/subtitle_segments/seg-104-f6.vtt',
#  './video/subtitle_segments/seg-104-f6.vtt',
#  './video/subtitle_segments/seg-104-f6.vtt',
#  './video/subtitle_segments/seg-105-f6.vtt',
#  './video/subtitle_segments/seg-105-f6.vtt',
#  './video/subtitle_segments/seg-106-f6.vtt',
#  './video/subtitle_segments/seg-106-f6.vtt',
#  './video/subtitle_segments/seg-107-f6.vtt',
#  './video/subtitle_segments/seg-107-f6.vtt',
#  './video/subtitle_segments/seg-107-f6.vtt',
#  './video/subtitle_segments/seg-108-f6.vtt',
#  './video/subtitle_segments/seg-108-f6.vtt',
#  './video/subtitle_segments/seg-109-f6.vtt',
#  './video/subtitle_segments/seg-109-f6.vtt',
#  './video/subtitle_segments/seg-110-f6.vtt',
#  './video/subtitle_segments/seg-110-f6.vtt',
#  './video/subtitle_segments/seg-110-f6.vtt',
#  './video/subtitle_segments/seg-111-f6.vtt',
#  './video/subtitle_segments/seg-111-f6.vtt',
#  './video/subtitle_segments/seg-112-f6.vtt',
#  './video/subtitle_segments/seg-112-f6.vtt',
#  './video/subtitle_segments/seg-113-f6.vtt',
#  './video/subtitle_segments/seg-113-f6.vtt',
#  './video/subtitle_segments/seg-115-f6.vtt',
#  './video/subtitle_segments/seg-115-f6.vtt',
#  './video/subtitle_segments/seg-116-f6.vtt',
#  './video/subtitle_segments/seg-116-f6.vtt',
#  './video/subtitle_segments/seg-117-f6.vtt',
#  './video/subtitle_segments/seg-118-f6.vtt',
#  './video/subtitle_segments/seg-118-f6.vtt',
#  './video/subtitle_segments/seg-118-f6.vtt',
#  './video/subtitle_segments/seg-119-f6.vtt',
#  './video/subtitle_segments/seg-119-f6.vtt',
#  './video/subtitle_segments/seg-121-f6.vtt',
#  './video/subtitle_segments/seg-121-f6.vtt',
#  './video/subtitle_segments/seg-121-f6.vtt',
#  './video/subtitle_segments/seg-122-f6.vtt',
#  './video/subtitle_segments/seg-122-f6.vtt',
#  './video/subtitle_segments/seg-122-f6.vtt',
#  './video/subtitle_segments/seg-123-f6.vtt',
#  './video/subtitle_segments/seg-124-f6.vtt',
#  './video/subtitle_segments/seg-124-f6.vtt',
#  './video/subtitle_segments/seg-125-f6.vtt',
#  './video/subtitle_segments/seg-125-f6.vtt',
#  './video/subtitle_segments/seg-126-f6.vtt',
#  './video/subtitle_segments/seg-126-f6.vtt',
#  './video/subtitle_segments/seg-126-f6.vtt',
#  './video/subtitle_segments/seg-127-f6.vtt',
#  './video/subtitle_segments/seg-127-f6.vtt',
#  './video/subtitle_segments/seg-127-f6.vtt',
#  './video/subtitle_segments/seg-128-f6.vtt',
#  './video/subtitle_segments/seg-128-f6.vtt',
#  './video/subtitle_segments/seg-128-f6.vtt',
#  './video/subtitle_segments/seg-129-f6.vtt',
#  './video/subtitle_segments/seg-130-f6.vtt',
#  './video/subtitle_segments/seg-131-f6.vtt',
#  './video/subtitle_segments/seg-131-f6.vtt',
#  './video/subtitle_segments/seg-132-f6.vtt',
#  './video/subtitle_segments/seg-132-f6.vtt',
#  './video/subtitle_segments/seg-132-f6.vtt',
#  './video/subtitle_segments/seg-132-f6.vtt',
#  './video/subtitle_segments/seg-133-f6.vtt',
#  './video/subtitle_segments/seg-134-f6.vtt',
#  './video/subtitle_segments/seg-134-f6.vtt',
#  './video/subtitle_segments/seg-135-f6.vtt',
#  './video/subtitle_segments/seg-135-f6.vtt',
#  './video/subtitle_segments/seg-135-f6.vtt',
#  './video/subtitle_segments/seg-136-f6.vtt',
#  './video/subtitle_segments/seg-136-f6.vtt',
#  './video/subtitle_segments/seg-136-f6.vtt',
#  './video/subtitle_segments/seg-137-f6.vtt',
#  './video/subtitle_segments/seg-137-f6.vtt',
#  './video/subtitle_segments/seg-138-f6.vtt',
#  './video/subtitle_segments/seg-139-f6.vtt',
#  './video/subtitle_segments/seg-139-f6.vtt',
#  './video/subtitle_segments/seg-140-f6.vtt',
#  './video/subtitle_segments/seg-140-f6.vtt',
#  './video/subtitle_segments/seg-141-f6.vtt',
#  './video/subtitle_segments/seg-142-f6.vtt',
#  './video/subtitle_segments/seg-142-f6.vtt',
#  './video/subtitle_segments/seg-143-f6.vtt',
#  './video/subtitle_segments/seg-143-f6.vtt',
#  './video/subtitle_segments/seg-144-f6.vtt',
#  './video/subtitle_segments/seg-145-f6.vtt',
#  './video/subtitle_segments/seg-145-f6.vtt',
#  './video/subtitle_segments/seg-145-f6.vtt',
#  './video/subtitle_segments/seg-146-f6.vtt',
#  './video/subtitle_segments/seg-146-f6.vtt',
#  './video/subtitle_segments/seg-147-f6.vtt',
#  './video/subtitle_segments/seg-147-f6.vtt',
#  './video/subtitle_segments/seg-147-f6.vtt',
#  './video/subtitle_segments/seg-147-f6.vtt',
#  './video/subtitle_segments/seg-148-f6.vtt',
#  './video/subtitle_segments/seg-148-f6.vtt',
#  './video/subtitle_segments/seg-148-f6.vtt',
#  './video/subtitle_segments/seg-149-f6.vtt',
#  './video/subtitle_segments/seg-149-f6.vtt',
#  './video/subtitle_segments/seg-149-f6.vtt',
#  './video/subtitle_segments/seg-150-f6.vtt',
#  './video/subtitle_segments/seg-150-f6.vtt',
#  './video/subtitle_segments/seg-151-f6.vtt',
#  './video/subtitle_segments/seg-151-f6.vtt',
#  './video/subtitle_segments/seg-151-f6.vtt',
#  './video/subtitle_segments/seg-152-f6.vtt',
#  './video/subtitle_segments/seg-152-f6.vtt',
#  './video/subtitle_segments/seg-153-f6.vtt',
#  './video/subtitle_segments/seg-153-f6.vtt',
#  './video/subtitle_segments/seg-153-f6.vtt',
#  './video/subtitle_segments/seg-154-f6.vtt',
#  './video/subtitle_segments/seg-154-f6.vtt',
#  './video/subtitle_segments/seg-155-f6.vtt',
#  './video/subtitle_segments/seg-156-f6.vtt',
#  './video/subtitle_segments/seg-156-f6.vtt',
#  './video/subtitle_segments/seg-156-f6.vtt',
#  './video/subtitle_segments/seg-157-f6.vtt',
#  './video/subtitle_segments/seg-157-f6.vtt',
#  './video/subtitle_segments/seg-157-f6.vtt',
#  './video/subtitle_segments/seg-158-f6.vtt',
#  './video/subtitle_segments/seg-158-f6.vtt',
#  './video/subtitle_segments/seg-159-f6.vtt',
#  './video/subtitle_segments/seg-160-f6.vtt',
#  './video/subtitle_segments/seg-160-f6.vtt',
#  './video/subtitle_segments/seg-160-f6.vtt',
#  './video/subtitle_segments/seg-161-f6.vtt',
#  './video/subtitle_segments/seg-161-f6.vtt',
#  './video/subtitle_segments/seg-161-f6.vtt',
#  './video/subtitle_segments/seg-162-f6.vtt',
#  './video/subtitle_segments/seg-163-f6.vtt',
#  './video/subtitle_segments/seg-163-f6.vtt',
#  './video/subtitle_segments/seg-164-f6.vtt',
#  './video/subtitle_segments/seg-164-f6.vtt',
#  './video/subtitle_segments/seg-164-f6.vtt',
#  './video/subtitle_segments/seg-165-f6.vtt',
#  './video/subtitle_segments/seg-166-f6.vtt',
#  './video/subtitle_segments/seg-167-f6.vtt',
#  './video/subtitle_segments/seg-168-f6.vtt',
#  './video/subtitle_segments/seg-168-f6.vtt',
#  './video/subtitle_segments/seg-169-f6.vtt',
#  './video/subtitle_segments/seg-169-f6.vtt',
#  './video/subtitle_segments/seg-170-f6.vtt',
#  './video/subtitle_segments/seg-170-f6.vtt',
#  './video/subtitle_segments/seg-170-f6.vtt',
#  './video/subtitle_segments/seg-171-f6.vtt',
#  './video/subtitle_segments/seg-172-f6.vtt',
#  './video/subtitle_segments/seg-172-f6.vtt',
#  './video/subtitle_segments/seg-173-f6.vtt',
#  './video/subtitle_segments/seg-173-f6.vtt',
#  './video/subtitle_segments/seg-174-f6.vtt',
#  './video/subtitle_segments/seg-175-f6.vtt',
#  './video/subtitle_segments/seg-176-f6.vtt',
#  './video/subtitle_segments/seg-176-f6.vtt',
#  './video/subtitle_segments/seg-177-f6.vtt',
#  './video/subtitle_segments/seg-178-f6.vtt',
#  './video/subtitle_segments/seg-178-f6.vtt',
#  './video/subtitle_segments/seg-179-f6.vtt',
#  './video/subtitle_segments/seg-179-f6.vtt',
#  './video/subtitle_segments/seg-180-f6.vtt',
#  './video/subtitle_segments/seg-180-f6.vtt',
#  './video/subtitle_segments/seg-181-f6.vtt',
#  './video/subtitle_segments/seg-181-f6.vtt',
#  './video/subtitle_segments/seg-182-f6.vtt',
#  './video/subtitle_segments/seg-182-f6.vtt',
#  './video/subtitle_segments/seg-183-f6.vtt',
#  './video/subtitle_segments/seg-183-f6.vtt',
#  './video/subtitle_segments/seg-184-f6.vtt',
#  './video/subtitle_segments/seg-184-f6.vtt',
#  './video/subtitle_segments/seg-185-f6.vtt',
#  './video/subtitle_segments/seg-185-f6.vtt',
#  './video/subtitle_segments/seg-185-f6.vtt',
#  './video/subtitle_segments/seg-186-f6.vtt',
#  './video/subtitle_segments/seg-187-f6.vtt',
#  './video/subtitle_segments/seg-188-f6.vtt',
#  './video/subtitle_segments/seg-188-f6.vtt',
#  './video/subtitle_segments/seg-189-f6.vtt',
#  './video/subtitle_segments/seg-189-f6.vtt',
#  './video/subtitle_segments/seg-190-f6.vtt',
#  './video/subtitle_segments/seg-190-f6.vtt',
#  './video/subtitle_segments/seg-191-f6.vtt',
#  './video/subtitle_segments/seg-191-f6.vtt',
#  './video/subtitle_segments/seg-192-f6.vtt',
#  './video/subtitle_segments/seg-192-f6.vtt',
#  './video/subtitle_segments/seg-192-f6.vtt',
#  './video/subtitle_segments/seg-193-f6.vtt',
#  './video/subtitle_segments/seg-193-f6.vtt',
#  './video/subtitle_segments/seg-194-f6.vtt',
#  './video/subtitle_segments/seg-194-f6.vtt',
#  './video/subtitle_segments/seg-194-f6.vtt',
#  './video/subtitle_segments/seg-195-f6.vtt',
#  './video/subtitle_segments/seg-195-f6.vtt',
#  './video/subtitle_segments/seg-196-f6.vtt',
#  './video/subtitle_segments/seg-196-f6.vtt',
#  './video/subtitle_segments/seg-196-f6.vtt',
#  './video/subtitle_segments/seg-197-f6.vtt',
#  './video/subtitle_segments/seg-197-f6.vtt',
#  './video/subtitle_segments/seg-198-f6.vtt',
#  './video/subtitle_segments/seg-198-f6.vtt',
#  './video/subtitle_segments/seg-199-f6.vtt',
#  './video/subtitle_segments/seg-199-f6.vtt',
#  './video/subtitle_segments/seg-200-f6.vtt',
#  './video/subtitle_segments/seg-200-f6.vtt',
#  './video/subtitle_segments/seg-200-f6.vtt',
#  './video/subtitle_segments/seg-201-f6.vtt',
#  './video/subtitle_segments/seg-202-f6.vtt',
#  './video/subtitle_segments/seg-202-f6.vtt',
#  './video/subtitle_segments/seg-202-f6.vtt',
#  './video/subtitle_segments/seg-203-f6.vtt',
#  './video/subtitle_segments/seg-204-f6.vtt',
#  './video/subtitle_segments/seg-205-f6.vtt',
#  './video/subtitle_segments/seg-205-f6.vtt',
#  './video/subtitle_segments/seg-205-f6.vtt',
#  './video/subtitle_segments/seg-206-f6.vtt',
#  './video/subtitle_segments/seg-206-f6.vtt',
#  './video/subtitle_segments/seg-207-f6.vtt',
#  './video/subtitle_segments/seg-207-f6.vtt',
#  './video/subtitle_segments/seg-207-f6.vtt',
#  './video/subtitle_segments/seg-207-f6.vtt',
#  './video/subtitle_segments/seg-208-f6.vtt',
#  './video/subtitle_segments/seg-209-f6.vtt',
#  './video/subtitle_segments/seg-209-f6.vtt',
#  './video/subtitle_segments/seg-210-f6.vtt',
#  './video/subtitle_segments/seg-210-f6.vtt',
#  './video/subtitle_segments/seg-210-f6.vtt',
#  './video/subtitle_segments/seg-211-f6.vtt',
#  './video/subtitle_segments/seg-211-f6.vtt',
#  './video/subtitle_segments/seg-212-f6.vtt',
#  './video/subtitle_segments/seg-212-f6.vtt',
#  './video/subtitle_segments/seg-213-f6.vtt',
#  './video/subtitle_segments/seg-213-f6.vtt',
#  './video/subtitle_segments/seg-215-f6.vtt',
#  './video/subtitle_segments/seg-216-f6.vtt',
#  './video/subtitle_segments/seg-217-f6.vtt',
#  './video/subtitle_segments/seg-218-f6.vtt',
#  './video/subtitle_segments/seg-218-f6.vtt',
#  './video/subtitle_segments/seg-218-f6.vtt',
#  './video/subtitle_segments/seg-219-f6.vtt',
#  './video/subtitle_segments/seg-219-f6.vtt',
#  './video/subtitle_segments/seg-219-f6.vtt',
#  './video/subtitle_segments/seg-220-f6.vtt',
#  './video/subtitle_segments/seg-221-f6.vtt',
#  './video/subtitle_segments/seg-221-f6.vtt',
#  './video/subtitle_segments/seg-222-f6.vtt',
#  './video/subtitle_segments/seg-223-f6.vtt',
#  './video/subtitle_segments/seg-224-f6.vtt',
#  './video/subtitle_segments/seg-225-f6.vtt',
#  './video/subtitle_segments/seg-225-f6.vtt',
#  './video/subtitle_segments/seg-225-f6.vtt',
#  './video/subtitle_segments/seg-226-f6.vtt',
#  './video/subtitle_segments/seg-226-f6.vtt',
#  './video/subtitle_segments/seg-227-f6.vtt',
#  './video/subtitle_segments/seg-227-f6.vtt',
#  './video/subtitle_segments/seg-229-f6.vtt',
#  './video/subtitle_segments/seg-230-f6.vtt',
#  './video/subtitle_segments/seg-230-f6.vtt',
#  './video/subtitle_segments/seg-230-f6.vtt']

# %%
video_segments[18]
# Out:
# './video/video_segments/seg-13-f3-v1.m4s'

# %%
video_segments[49]
# Out:
# './video/video_segments/seg-30-f3-v1.m4s'

# %%
for caption in transcript:
    print(caption.text)
# Out:
# ...
# -Mesdames, Messieurs,
# bonsoir et bienvenue.
# Insultes, menaces et intimidation,
# c'est ce que vivent
# les étudiants de l'EPLF
# qui émettent un avis contraire
# au mouvement propalestinien.
# Le président de l'EPFL,
# Martin Vetterli, est avec nous.
# Une manifestation spectaculaire
# contre la géothermie
# dans la commune de Haute-Sorne (JU).
# Des militants en colère
# et des dégâts considérables.
# A deux semaines
# des élections européennes,
# alors qu'on parle
# d'un excellent score tout à droite,
# l'AfD a été exclu de son groupe
# parlementaire à Bruxelles.
# Sa tête de liste
# enchaîne les dérapages.
# Nous percerons un des mystères
# qui entourent les pyramides.
# Comment ont-elles été construites ?
# Il y a une réponse récente.
# 60 ans et toujours aussi glamour.
# L'icône du rock Lenny Kravitz
# sort un nouvel album.
# Le climat est délétère à l'EPFL
# sur fond de guerre
# entre Israël et le Hamas.
# Les étudiants qui émettent
# un avis contraire
# au mouvement propalestinien
# sont menacés.
# Des jeunes ont peur
# d'aller sur le campus.
# -Si ce groupe de discussion
# sur la guerre au Moyen-Orient
# par des étudiants de l'EPFL
# a été depuis supprimé,
# il en subsiste
# ces captures d'écran.
# Des menaces de mort dirigées
# contre des étudiants
# qui souhaitaient apaiser
# des tensions.
# Ces révélations du journal Le Temps
# décrivent une radicalisation
# sur le campus de l'EPFL.
# Cet étudiant visé ne s'affole pas,
# mais avoue être sur ses gardes.
# -Une limite a été franchie
# parce que c'est un événement
# qui n'a jamais été vu sur le campus.
# On a peur,
# on regarde un peu derrière nous.
# -La direction de l'EPFL
# organisait cet après-midi
# une discussion
# pour éviter toute escalade.
# Si la démarche a été saluée,
# certains en ont profité
# pour remettre en doute
# le témoignage des étudiants menacés.
# -La première réaction dans
# l'auditoire, c'est "ils mentent".
# Ils parlent de menaces de mort,
# donc forcément ils mentent.
# -Du côté
# des manifestants propalestiniens,
# on condamne fermement
# toutes attitudes discriminatoires.
# -Menacer de mort pour des idées
# politiques,
# ce n'est pas acceptable,
# surtout pas dans notre école.
# Ca ne reflète pas
# la majorité des étudiants.
# -Le groupe propalestinien considère
# que la direction porte
# une part de responsabilité
# en limitant la liberté d'expression.
# La direction de l'EPFL doit faire
# la lumière sur ces événements.
# -Martin Vetterli, bonsoir.
# Le Temps révèle que des étudiants
# de votre établissement
# sont harcelés car ils pensent
# différemment, et parlent de paix.
# Un étudiant est menacé de mort
# sur les réseaux sociaux:
# "il faut tuer Nicolas et son gang".
# Une autre est intimidée:
# "on a vu où tu étais assise".
# Quelle est votre réaction ?
# - Je suis très triste
# qu'il y a une telle tension
# sur le campus.
# Ce sont les excès
# des réseaux sociaux.
# Si on n'est pas dans le cadre légal,
# par rapport aux lois
# sur le racisme et l'antisémitisme,
# on donne
# le support à notre communauté.
# Nos étudiants ont des canaux où ils
# peuvent venir chercher de l'aide.
# Et on prendra
# les mesures nécessaires.
# Des plaintes pourront être portées.
# -On entend des étudiants juifs
# qui ont peur de venir sur le campus.
# Leur sécurité est garantie ?
# -C'est notre première priorité.
# La sécurité de tous sur le campus.
# On a parlé avec ces gens,
# ils se sont exprimés.
# Ils ont besoin d'être protégés,
# comme tout le monde.
# -Vous reconnaissez
# qu'il y a une dérive
# de certains membres
# des militants propalestiniens ?
# -Il y a toujours des dérives.
# Il y a un large spectre
# d'opinions sur le campus.
# Notre mission
# est de garder une unité.
# -Comment on en est arrivé là ?
# Y a-t-il aussi une responsabilité
# de la part des grandes écoles
# de laisser entrer ces discussions
# politiques sur le campus ?
# L'université ne doit-elle
# pas être totalement neutre ?
# -L'université en tant qu'institution
# doit rester neutre
# pour permettre un débat.
# Mais chacun est un être humain
# qui peut s'exprimer en son nom.
# Il ne faut pas
# qu'il y ait de dérive.
# Il ne faut pas qu'il y ait le genre
# d'excès dont vous avez parlé.
# -On a atteint
# à ce niveau-là du rouge.
# Qu'est-ce que vous allez faire
# pour remettre de l'ordre ?
# -On n'est pas dans le désordre.
# Sur le campus, ça se passe bien.
# Plusieurs centaines de participants
# représentant les étudiants,
# les employés et les profs ont parlé
# et ça s'est bien passé.
# Tous nos canaux de soutien sont
# à disposition de toute la communauté.
# -Vous appelez les étudiants
# à s'adresser à vos canaux de soutien
# si quelque chose se passe.
# -On a créé
# une commission spécifique.
# On va regarder
# ces différentes dimensions.
# Cette commission
# est dirigée par ma collègue.
# -Ce matin,
# dans la commune de Haute-Sorne,
# ils étaient une centaine
# à exprimer leur colère
# contre le projet
# de géothermie profonde.
# La police a dû intervenir.
# -Un puissant
# jet de lisier annonce la couleur.
# La manifestation
# contre la géothermie profonde
# à Haute-Sorne (JU) a largement
# dépassé le cadre pacifiste.
# Une centaine de personnes a mis
# les services de sécurité
# à l'épreuve ce vendredi matin
# avec cette intrusion
# sur le site de forage.
# Le rassemblement a démarré
# dans une humeur festive
# avant de dégénérer.
# -Si je n'ai pas les fenêtres fermées,
# j'ai une vibration dans le corps.
# C'est nuit et jour.
# Ce qu'ils font est hyper violent.
# Aujourd'hui,
# il y a eu des actes de violence,
# mais je ne regrette pas
# que ça se soit passé.
# -L'objet de la discorde
# est cette tour de forage,
# en activité
# depuis mardi dernier.
# Le gouvernement jurassien
# déplore l'escalade de la violence.
# -Le gouvernement estime
# qu'on peut être opposé au projet.
# On peut manifester.
# Aujourd'hui,
# des limites ont été franchies.
# Il y a des questions
# de sécurité et de propriété privée.
# On a peut-être franchi une étape.
# -Une trentaine de policiers est
# intervenue pour disperser la foule.
# Une nouvelle manifestation
# est déjà annoncée mercredi prochain.
# -Lausanne et sa lutte
# contre la drogue.
# La ville ouvre un deuxième local
# d'injection à la place de la Riponne,
# connue pour la présence
# de toxicomanes.
# Cet espace est présenté
# comme une alternative
# à la consommation
# dans l'espace public.
# -C’est un local tout neuf.
# Des box pour l’inhalation
# et l'injection, une salle de repos.
# A partir de lundi, les consommateurs
# de cocaïne, héroïne et autres
# pourront en bénéficier
# en plein centre-ville de Lausanne.
# -On vise des personnes
# très désinsérées
# qui consomment dans l’espace public,
# ça crée des inquiétudes
# et des nuisances pour le voisinage,
# et des risques pour la santé
# de ceux qui consomment.
# -Pas de distribution de drogue sur
# place, mais du matériel stérile.
# Et la possibilité d’un suivi social.
# Le deuxième espace de consommation
# sécurisée de la capitale vaudoise.
# Un premier local a été ouvert
# il y a 6 ans à 500 m de là.
# L'équipe y enregistre en moyenne
# 95 prises de drogues par jour.
# -On a des temps d’attente
# pouvant aller jusqu'à une demi-heure.
# On sait que les personnes
# dans l’urgence de la consommation
# peinent à attendre
# plus que 10-15 min.
# On arrive
# aux limites du projet actuel.
# -Le local tout juste inauguré
# est à quelques mètres
# du lieu de rassemblement habituel
# des personnes toxicomanes,
# sur la place de la Riponne.
# -C’est très bien.
# On aura une salle de repos,
# on pourra se poser,
# ils pourront nous surveiller.
# -Les gens qui consomment
# seront en sécurité
# et ne font pas ça
# dans la rue devant des enfants.
# -Les deux espaces
# de consommation sécurisée
# sont financés
# par la Ville et le Canton.
# Ils complètent une série
# de mesures prises l'été 2023.
# La nouvelle antenne de la Riponne
# est un projet pilote.
# Son efficacité
# sera évaluée dans une année.
# -Le personnel de Vetropack
# entame une grève
# à durée indéterminée.
# La majorité des employés
# de Saint-Prex (VD)
# a arrêté de travailler.
# Yoan Rithner, vous êtes sur place.
# Pas de licenciement
# sans plan social,
# c'est le coeur des revendications.
# -Exactement.
# Un plan social digne de ce nom.
# C'est actuellement loin d'être
# le cas pour les employés
# qui ont décidé
# de débrayer en fin de matinée.
# La production
# des bouteilles est à l'arrêt.
# Les palettes ne sont plus livrées.
# "On n'a plus rien à perdre"
# a dit un des employés depuis
# l'annonce de la fermeture de l'usine.
# Pour l'instant, la direction refuse
# d'entrer dans des véritables
# négociations.
# Il y a une cinquantaine d'employés
# qui n'auraient droit
# à aucune indemnité.
# Une trentaine d'autres
# n'aurait droit qu'à un demi-salaire.
# La direction a réagi
# en fin d'après-midi.
# Elle a dit
# ne pas comprendre la grève.
# Les discussions
# sont encore en cours.
# Elle demande un arrêt de la grève
# sinon elle risque de retarder
# le versement des indemnités
# pour les personnes licenciées.
# Les premiers licenciements
# devraient être annoncés
# au courant
# de la semaine prochaine.
# -De la prison ferme
# pour l'ex-entraîneur de foot
# et avocat à Neuchâtel.
# Il passera une année
# derrière les barreaux
# pour des actes sexuels sur mineurs.
# Une peine alourdie en appel.
# -34 mois de prison dont 12 fermes
# et une interdiction à vie
# d'exercer toute activité
# auprès de mineurs.
# Cet avocat et ex-entraîneur de foot
# condamné pour contrainte sexuelle
# et actes d'ordre sexuel
# avec des enfants.
# Les faits datent de 2017 à 2020.
# L'entraîneur rencontre
# des adolescents
# dans le cadre du football
# à La Chaux-de-Fonds.
# Les jeunes sont en difficulté
# scolaire ou familiale,
# il les engage dans son étude
# comme stagiaires ou apprentis.
# Il leur offre des cadeaux.
# Parfois, les jeunes dorment
# chez l'avocat qui leur demande
# de se déshabiller
# ou se doucher devant lui.
# Ils ont parfois reçu des claques
# ou des fessées,
# à plusieurs reprises, l'accusé
# a touché leurs parties intimes.
# La Cour d'appel a revu à la hausse
# la peine du premier procès.
# Soulagement des plaignants
# et de la procureure.
# -Le Ministère public
# est satisfait du jugement.
# Il a obtenu ce qu'il avait requis,
# notamment sur la contrainte sexuelle.
# C'était ce qui n'avait pas été retenu
# en première instance.
# -Du côté de la défense,
# on dénonce un procès émotionnel
# et trop de poids accordé
# aux témoignages des plaignants.
# -Très sévère,
# j'ai le sentiment
# qu'on se focalise
# sur la parole des plaignants,
# qui est importante,
# mais qu'on occulte la défense.
# -La défense a annoncé faire recours
# auprès du Tribunal fédéral.
# -La Cour internationale de justice
# ordonne à Israël
# d'arrêter immédiatement
# son offensive militaire à Rafah.
# Une ordonnance juridiquement
# contraignante,
# mais que la Cour n'a aucun moyen
# de faire respecter.
# Près des élections européennes,
# le parti allemand AfD
# mis sur la touche à Bruxelles.
# Sa tête de liste
# cumule les dérapages,
# comme estimer qu'un nazi n'est
# pas automatiquement un criminel.
# L'extrême droite italienne
# et française a condamné ces propos.
# -Maximilian Krah est l'acteur
# du dernier épisode
# d'une série de scandales,
# eurodéputé et candidat du parti
# d'extrême droite allemand (AfD)
# aux élections européennes
# le mois prochain.
# Dans une interview récente,
# ses propos ont choqué.
# Des propos inadmissibles
# même pour le Rassemblement
# National et la Lega,
# les partis d'extrême droite
# français et italien.
# Ils ont annoncé
# leur rupture avec l'AfD.
# Hier, le groupe qui les fédérait
# au Parlement européen,
# annonce l'exclusion
# de M.Krah et de ses 8 collègues.
# -Nous allons maintenant
# mener une campagne intensive
# pendant deux semaines
# et nous veillerons à regagner
# la confiance
# de nos partenaires internationaux.
# Et nous serons
# à nouveau membres du groupe.
# -C'est tout le parti
# qui crée le malaise.
# En janvier,
# la presse révélait
# une réunion secrète
# de partis identitaires, dont l'AfD.
# L'un des thèmes abordés:
# un projet
# d'expulsion massive d'Allemagne
# de personnes étrangères
# ou d'origine étrangère.
# A l'époque, le Rassemblement
# National avait pris ses distances.
# -Je considère que nous avons
# une opposition flagrante avec l'AfD
# et nous serons amenés à discuter
# de divergences aussi importantes.
# -M.Krah est soupçonné d'avoir touché
# des financements russes et chinois.
# L'un de ses assistants a été arrêté,
# accusé d'avoir espionné
# pour le compte de Pékin.
# -Les élections européennes
# sont dans deux semaines.
# On parle beaucoup
# de la montée de l'extrême droite.
# Isabelle Ory,
# Maximilian Krah est-il en train
# de faire exploser l'extrême droite ?
# -Cette crise entre l'AfD
# et ses
# deux grands partenaires européens,
# le Rassemblement National et la Lega,
# vient rappeler à quel point
# l'extrême droite européenne
# est hétérogène.
# Ces derniers temps,
# on a parlé de la montée en puissance
# de ces formations dans les pays.
# Quand on agrège les résultats,
# ils peuvent obtenir 25 % des sièges
# du futur Parlement européen.
# Les différences
# entre ces différents partis
# étaient passées au second plan.
# Par exemple, les Hongrois de Viktor
# Orban sont trop pro-russes,
# Marine Le Pen est trop radicale pour
# Viktor Orban,
# maintenant, l'AfD est trop radicale
# pour Marine Le Pen.
# Oui, la droite dure séduit
# de plus en plus d'électeurs.
# Elle aura un droit de nuisance
# pour bloquer certaines lois.
# Mais elle n'est pas suffisamment unie
# pour espérer imposer une ligne
# politique au niveau européen.
# -A une semaine de la fin de son
# procès à New York,
# D.Trump en profite
# pour aller dans le Bronx.
# Le candidat républicain
# va chercher des électeurs
# sur un terrain acquis aux démocrates.
# -Trump, we love you !
# -La scène est inattendue.
# Le cirque trumpiste s'arrête
# dans le Bronx.
# Le républicain, critiqué
# lors des émeutes raciales de 2020,
# trouve ici un public.
# -On peut être en désaccord
# avec certaines choses,
# mais il est dans le Bronx.
# C'est le premier candidat à venir
# depuis Ronald Reagan.
# -Le procès qui se déroule
# à Manhattan
# est loin des préoccupations.
# Certains s'apprêtent à voter
# républicain pour la première fois.
# -Les prix montent, les impôts aussi.
# Tout ne va pas changer sous Trump,
# mais espérons qu'il pourra
# secouer les choses !
# -Devant ce public plus bigarré
# et plus jeune que d'habitude,
# le candidat tient
# un discours plus rassembleur.
# -Ca n'a aucune importance
# que vous soyez noirs,
# bruns ou blancs.
# Nous sommes tous américains
# et on va s'en sortir ensemble.
# -Plus qu'une simple provocation
# pour détourner l'attention
# de son procès, cette apparition
# fait partie d'une stratégie
# du candidat républicain
# pour séduire les minorités.
# Le Bronx, quartier qui compte
# le plus d'électeurs pauvres
# et issus des minorités,
# avait voté pour Joe Biden en 2020.
# -Il m'a donné la chance d'être ici,
# alors je soutiens l'oncle Biden.
# Il a permis à notre famille
# de rester aux Etats-Unis.
# -Mais ici, on n'a pas ressenti
# les bons chiffres
# de l'économie américaine.
# -Quand Trump était au pouvoir,
# il y avait plus d'emplois,
# moins de chômage.
# -Je ne voterai pas cette année.
# Avec Biden,
# je ne vois aucun changement.
# Et Trump est trop raciste à mon avis.
# -Les républicains ne gagneront
# sans doute pas dans le Bronx,
# mais pour les démocrates,
# le vote des minorités
# est loin d'être acquis.
# -La SSR lance un sondage national
# pour prendre le pouls
# de la population suisse.
# Le nom de cette enquête:
# "Comment ça va la Suisse ?"
# On attend vos réponses !
# -Pas besoin d'être journaliste
# pour poser cette question.
# -Comment allez-vous ?
# -Super bien.
# -Notre média de service public
# veut poursuivre ce dialogue.
# C'est pourquoi la SSR lance
# le 2ème volet de l'enquête
# "Comment ça va la Suisse ?".
# Un nouveau sondage est en ligne
# sur www.rts.ch/info/dialogue/:
# 290 questions d'actualité
# sur l'éducation, la politique
# et le travail,
# déjà présentées au printemps 2023.
# Objectif: brosser le portrait de
# la Suisse et mesurer son évolution.
# Archives
# -Quelle est la qualité principale
# des Suisses ?
# 42 % répondent "travailleurs".
# -L'an dernier, 50'000 personnes
# ont participé au sondage.
# -C'est important de comprendre,
# d'être proche de notre public,
# de comprendre les sujets
# qui les occupent,
# ça nous permet de faire
# du journalisme pertinent.
# -Impossible de conclure
# sans poser cette question.
# -Comment va la Suisse ?
# -Bien, en général.
# -Et vous ?
# -Très bien, merci.
# -Neige Sinno a reçu
# le Choix Goncourt de la Suisse.
# Son livre sur l'inceste
# "Triste Tigre" a été le plus encensé
# de la saison littéraire.
# -Une standing ovation
# dans une salle pleine,
# une preuve du succès
# de "Triste Tigre" de Neige Sinno,
# qui a raflé des dizaines de prix et
# s'est vendu à 300'000 exemplaires.
# -"Triste Tigre"
# ne laisse pas indemne,
# il y a un avant et un après.
# -Hier, l'autrice a reçu
# le Choix Goncourt de la Suisse,
# prix décerné par les étudiants
# de 9 universités et hautes écoles.
# "Triste Tigre"
# est un ovni littéraire,
# alternant entre le récit
# de l'inceste subi par N.Sinno
# et des extraits de romans
# et poèmes qu'elle invoque
# pour expliquer ce qu'elle a subi.
# -C'est très riche.
# -Comment peut-on écrire de manière
# si sublime une chose si terrible ?
# -Je voulais que ce soit
# comme une pensée spontanée.
# J'observe ce qui se passe
# dans ma tête quand j'y réfléchis
# et je traduis ça en texte.
# -Un livre que N.Sinno ne voulait
# pas écrire, dans lequel elle avoue
# souhaiter qu'il ne soit pas lu.
# -Je veux que personne ne sache
# que j'ai été violée,
# mais j'ai écrit à mes amis
# que c'était une petite bombe
# qui ferait tout imploser.
# J'avais donc aussi ce désir
# que tout le monde lise ça.
# -"Je frotte mes assiettes rageusement
# et je pense à la phrase
# que je pourrais dire."
# "Il me viole
# depuis que je suis petite."
# -"Triste Tigre" sera traduit
# en plus de 20 langues.
# La bombe de N.Sinno
# n'a pas fini d'exploser.
# -Elles ont fasciné
# des générations d'archéologues.
# Vous vous êtes peut-être déjà demandé
# comment les pyramides
# ont été construites,
# alors qu'elles sont en plein désert ?
# Réponse !
# -Elles ne sont pas avares
# en mystères:
# chambres secrètes, trésors cachés...
# L'emplacement des pyramides
# intrigue aussi.
# Depuis le plateau de Gizeh,
# beaucoup sont alignées
# dans le désert.
# A des kilomètres du Nil actuel,
# ligne de vie du pays,
# comme à l'époque des pharaons.
# Mais des scientifiques ont découvert
# un bras asséché du Nil,
# qui passait au pied des monuments.
# De quoi acheminer par bateau
# les blocs pour les ériger.
# Les images radar permettent
# de traquer dans le sous-sol
# les sédiments du lit d'un ancien
# fleuve, recouvert par le sable.
# Des mesures confirmées
# par l'extraction de terre.
# Comme souvent en égyptologie,
# cette découverte est discutée.
# -On savait déjà des choses.
# On soupçonnait l'existence
# de ce canal.
# Ce qui est nouveau,
# ce sont les images satellite,
# qui permettent d'évaluer l'ampleur
# de cette branche du Nil
# et de confirmer certaines hypothèses.
# -Des blocs transportés par bateau:
# plusieurs bas-reliefs le montrent.
# L'idée est entérinée en 2013
# par la découverte
# des papyrus de la mer Rouge.
# Un chapitre y décrit le quotidien
# des bâtisseurs de pyramides.
# Une grande pyramide accessible
# par un port,
# comme l'ont montré des sondages
# en 2022.
# A Saqqarah, les chercheurs
# ont constaté que les débarcadères
# collaient à l'emplacement
# du fleuve asséché.
# -Les Egyptiens
# étaient très astucieux,
# très pragmatiques aussi.
# C'était la loi du moindre effort.
# Ils ont utilisé leur environnement
# pour construire les pyramides.
# Ils ne subissent pas seulement
# les aléas de la géologie.
# Ils dominaient leur territoire
# et savaient ce qu'ils faisaient.
# -Un territoire balisé
# avec ce Nil asséché,
# que les égyptologues pourront
# explorer de manière ciblée.
# -Tennis, surprise au Geneva Open !
# Novak Djokovic s'est incliné
# en demi-finale.
# Le numéro un mondial a été battu
# 6-4, 0-6, 6-1 par Tomas Machac
# au terme d'un match décousu.
# Le Serbe dit
# avoir des problèmes d'estomac
# et ne pas être rassuré
# avant Roland-Garros.
# Tomas Machac participera demain
# à sa première finale ATP.
# A 60 ans, Lenny Kravitz
# sort un douzième album.
# "Blue Electric Light" ne déroge pas
# à l'icône rock qu'il a toujours été.
# -Le temps n'a pas d'effet sur lui.
# Lenny Kravitz en joue
# entre glam et rock.
# A deux jours de ses 60 ans,
# il sort son 12ème album:
# "Blue Electric Light".
# Rock
# -"Blue Electric Light",
# c'est l'énergie, l'amour,
# la spiritualité, l'humanité.
# C'est cette énergie qui me nourrit.
# -Une énergie funk, soul et rock,
# toutes ces musiques qu'il vampirise
# depuis ses débuts en 1989.
# Il n'a rien inventé, mais
# transforme en pépite ce qui existe.
# Lenny Kravitz
# "Are you gonna go my way"
# Lenny Kravitz
# "American woman"
# Lenny Kravitz
# "Fly Away"
# -Je n'ai jamais essayé
# de faire un tube.
# J'attends: quand ça vient, ça vient.
# J'utilise mes talents:
# jouer plusieurs instruments,
# produire, faire les arrangements.
# -Lenny Kravitz, l'un des derniers
# gardiens du temple rock,
# une star qui fait du bien.
# Son concert au Montreux Jazz cet été
# est d'ailleurs complet.
# -C'est la fin de ce journal,
# merci de l'avoir suivi.
# Tout de suite, la météo,
# puis "Bye bye la Suisse".
# Très belle soirée sur la RTS !
# Sous-titrage SWISS TXT
# L.Campbell, N.Farag, A.Giddey,
# A.Kosakevitch, J.Szucs

# %% [markdown]
# ### LLM topic identification

# %%
url = "https://il.srgssr.ch/integrationlayer/2.0/mediaComposition/byUrn/urn:rts:video:14926430.json?onlyChapters=false&vector=portalplay"
res = requests.get(url)

# %%
metadata = json.loads(res.text)
metadata
# Out:
# {'chapterUrn': 'urn:rts:video:14926430',
#  'episode': {'id': '14822978',
#   'title': '19h30',
#   'publishedDate': '2024-05-24T19:30:00+02:00',
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926429.image/16x9',
#   'imageTitle': '19h30 [RTS]'},
#  'show': {'id': '105932',
#   'vendor': 'RTS',
#   'transmission': 'TV',
#   'urn': 'urn:rts:show:tv:105932',
#   'title': '19h30',
#   'lead': "L'édition du soir du téléjournal.",
#   'imageUrl': 'https://www.rts.ch/2023/09/28/17/48/14256748.image/16x9',
#   'imageTitle': 'RTS Info - Le 19h30 [RTS]',
#   'bannerImageUrl': 'https://www.rts.ch/2023/09/28/17/48/14256748.image/3x1',
#   'posterImageUrl': 'https://www.rts.ch/2023/08/22/16/37/14257151.image/2x3',
#   'posterImageIsFallbackUrl': False,
#   'primaryChannelId': '143932a79bb5a123a646b68b1d1188d7ae493e5b',
#   'primaryChannelUrn': 'urn:rts:channel:tv:143932a79bb5a123a646b68b1d1188d7ae493e5b',
#   'availableAudioLanguageList': [{'locale': 'fr', 'language': 'Français'}],
#   'availableVideoQualityList': ['SD', 'HD'],
#   'audioDescriptionAvailable': False,
#   'subtitlesAvailable': True,
#   'multiAudioLanguagesAvailable': False,
#   'topicList': [{'id': '908',
#     'vendor': 'RTS',
#     'transmission': 'TV',
#     'urn': 'urn:rts:topic:tv:908',
#     'title': '19h30'},
#    {'id': '904',
#     'vendor': 'RTS',
#     'transmission': 'TV',
#     'urn': 'urn:rts:topic:tv:904',
#     'title': 'Vidéos'},
#    {'id': '665',
#     'vendor': 'RTS',
#     'transmission': 'TV',
#     'urn': 'urn:rts:topic:tv:665',
#     'title': 'Info'}],
#   'allowIndexing': True},
#  'channel': {'id': '143932a79bb5a123a646b68b1d1188d7ae493e5b',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:channel:tv:143932a79bb5a123a646b68b1d1188d7ae493e5b',
#   'title': 'RTS 1',
#   'imageUrl': 'https://www.rts.ch/2023/09/28/17/48/14256748.image/16x9',
#   'imageUrlRaw': 'https://il.srgssr.ch/image-service/dynamic/857dda.svg',
#   'imageTitle': 'RTS Info - Le 19h30 [RTS]',
#   'transmission': 'TV'},
#  'chapterList': [{'id': '14926430',
#    'mediaType': 'VIDEO',
#    'vendor': 'RTS',
#    'urn': 'urn:rts:video:14926430',
#    'title': '19h30',
#    'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926429.image/16x9',
#    'imageTitle': '19h30 [RTS]',
#    'type': 'EPISODE',
#    'date': '2024-05-24T19:30:00+02:00',
#    'duration': 1830760,
#    'validFrom': '2024-05-24T20:04:12+02:00',
#    'playableAbroad': True,
#    'socialCountList': [{'key': 'srgView', 'value': 9335},
#     {'key': 'srgLike', 'value': 0},
#     {'key': 'fbShare', 'value': 1},
#     {'key': 'twitterShare', 'value': 0},
#     {'key': 'googleShare', 'value': 0},
#     {'key': 'whatsAppShare', 'value': 33}],
#    'displayable': True,
#    'position': 0,
#    'noEmbed': False,
#    'subtitleList': [{'locale': 'fr',
#      'language': 'Français',
#      'source': 'EXTERNAL',
#      'url': 'https://rts-vod-dd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765_fra-sdh.ttml',
#      'format': 'TTML'}],
#    'analyticsData': {'ns_st_ep': '19h30',
#     'ns_st_ty': 'Video',
#     'ns_st_ci': '14926430',
#     'ns_st_el': '1830760',
#     'ns_st_cl': '1830760',
#     'ns_st_sl': '1830760',
#     'srg_mgeobl': 'false',
#     'ns_st_tp': '13',
#     'ns_st_cn': '1',
#     'ns_st_ct': 'vc12',
#     'ns_st_pn': '1',
#     'ns_st_cdm': 'to',
#     'ns_st_cmt': 'fc'},
#    'analyticsMetadata': {'media_segment': '19h30',
#     'media_type': 'Video',
#     'media_segment_id': '14926430',
#     'media_episode_length': '1831',
#     'media_segment_length': '1831',
#     'media_number_of_segment_selected': '1',
#     'media_number_of_segments_total': '13',
#     'media_duration_category': 'long',
#     'media_is_geoblocked': 'false',
#     'media_is_web_only': 'false',
#     'media_production_source': 'produced.for.broadcasting',
#     'media_urn': 'urn:rts:video:14926430',
#     'media_sub_set_id': 'EPISODE',
#     'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#     'media_signlanguage_on': 'false'},
#    'eventData': '$3a03521ab39c4740$...',
#    'resourceList': [{'url': 'https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/master.m3u8',
#      'quality': 'HD',
#      'protocol': 'HLS',
#      'encoding': 'H264',
#      'mimeType': 'application/x-mpegURL',
#      'presentation': 'DEFAULT',
#      'streaming': 'HLS',
#      'dvr': False,
#      'live': False,
#      'mediaContainer': 'FMP4',
#      'audioCodec': 'AAC',
#      'videoCodec': 'H264',
#      'tokenType': 'NONE',
#      'audioTrackList': [{'locale': 'fr',
#        'language': 'Français',
#        'source': 'HLS'}],
#      'subtitleInformationList': [{'locale': 'fr',
#        'language': 'Français (SDH)',
#        'source': 'HLS',
#        'type': 'SDH'}],
#      'analyticsData': {'srg_mqual': 'HD', 'srg_mpres': 'DEFAULT'},
#      'analyticsMetadata': {'media_streaming_quality': 'HD',
#       'media_special_format': 'DEFAULT',
#       'media_url': 'https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/master.m3u8'}}],
#    'segmentList': [{'id': '14926404',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926404',
#      'title': "À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux",
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926395.image/16x9',
#      'imageTitle': "À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux [RTS]",
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 137200,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 1,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': "À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux",
#       'media_type': 'Video',
#       'media_segment_id': '14926404',
#       'media_episode_length': '1831',
#       'media_segment_length': '137',
#       'media_number_of_segment_selected': '1',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926404',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$ffb99f88d16c04b9$...',
#      'markIn': 75520,
#      'markOut': 212720},
#     {'id': '14926406',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926406',
#      'title': "Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien",
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926405.image/16x9',
#      'imageTitle': "Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien [RTS]",
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 203960,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 2,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': "Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien",
#       'media_type': 'Video',
#       'media_segment_id': '14926406',
#       'media_episode_length': '1831',
#       'media_segment_length': '204',
#       'media_number_of_segment_selected': '2',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926406',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$8c5880ebf7c1efce$...',
#      'markIn': 212720,
#      'markOut': 416680},
#     {'id': '14926408',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926408',
#      'title': 'Haute-Sorne (JU): la manifestation contre la géothermie profonde a dégénéré',
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926407.image/16x9',
#      'imageTitle': 'Haute-Sorne (JU): la manifestation contre la géothermie profonde a dégénéré [RTS]',
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 99520,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 3,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': 'Haute-Sorne (JU): la manifestation contre la géothermie profonde a dégénéré',
#       'media_type': 'Video',
#       'media_segment_id': '14926408',
#       'media_episode_length': '1831',
#       'media_segment_length': '100',
#       'media_number_of_segment_selected': '3',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926408',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$1faaee7cd701833e$...',
#      'markIn': 416680,
#      'markOut': 516200},
#     {'id': '14926410',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926410',
#      'title': 'Drogue: un deuxième espace de consommation sécurisé ouvre à Lausanne',
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926409.image/16x9',
#      'imageTitle': 'Drogue: un deuxième espace de consommation sécurisé ouvre à Lausanne [RTS]',
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 137000,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 4,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': 'Drogue: un deuxième espace de consommation sécurisé ouvre à Lausanne',
#       'media_type': 'Video',
#       'media_segment_id': '14926410',
#       'media_episode_length': '1831',
#       'media_segment_length': '137',
#       'media_number_of_segment_selected': '4',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926410',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$a5ca92f544e411f0$...',
#      'markIn': 516200,
#      'markOut': 653200},
#     {'id': '14926412',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926412',
#      'title': 'Le journaliste Yoan Rithner revient sur la grève entamée vendredi par le personnel de Vetropack à Saint-Prex dans le canton de Vaud',
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926411.image/16x9',
#      'imageTitle': 'Le journaliste Yoan Rithner revient sur la grève entamée vendredi par le personnel de Vetropack à Saint-Prex dans le canton de Vaud [RTS]',
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 102120,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 5,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': 'Le journaliste Yoan Rithner revient sur la grève entamée vendredi par le personnel de Vetropack à Saint-Prex dans le canton de Vaud',
#       'media_type': 'Video',
#       'media_segment_id': '14926412',
#       'media_episode_length': '1831',
#       'media_segment_length': '102',
#       'media_number_of_segment_selected': '5',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926412',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$7b9b1415320b95ce$...',
#      'markIn': 653200,
#      'markOut': 755320},
#     {'id': '14926414',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926414',
#      'title': 'À Neuchâtel, un ex-entraîneur de football amateur condamné pour abus sexuels sur des enfants',
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926413.image/16x9',
#      'imageTitle': 'À Neuchâtel, un ex-entraîneur de football amateur condamné pour abus sexuels sur des enfants [RTS]',
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 112480,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 6,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': 'À Neuchâtel, un ex-entraîneur de football amateur condamné pour abus sexuels sur des enfants',
#       'media_type': 'Video',
#       'media_segment_id': '14926414',
#       'media_episode_length': '1831',
#       'media_segment_length': '112',
#       'media_number_of_segment_selected': '6',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926414',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$636ae4551314a3ae$...',
#      'markIn': 755320,
#      'markOut': 867800},
#     {'id': '14926416',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926416',
#      'title': "Un candidat de l'AFD aux élections européennes crée le malaise avec des propos choquants",
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926415.image/16x9',
#      'imageTitle': "Un candidat de l'AFD aux élections européennes crée le malaise avec des propos choquants [RTS]",
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 133880,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 7,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': "Un candidat de l'AFD aux élections européennes crée le malaise avec des propos choquants",
#       'media_type': 'Video',
#       'media_segment_id': '14926416',
#       'media_episode_length': '1831',
#       'media_segment_length': '134',
#       'media_number_of_segment_selected': '7',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926416',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$a537e73c24c0ccb9$...',
#      'markIn': 889720,
#      'markOut': 1023600},
#     {'id': '14926418',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926418',
#      'title': "Isabelle Ory, correspondante de la RTS auprès de l'UE, analyse l'impact de l'exclusion de l'Afd pour l'extrême droite, après les déclarations chocs de l'un des candidats du parti allemand",
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926417.image/16x9',
#      'imageTitle': "Isabelle Ory, correspondante de la RTS auprès de l'UE, analyse l'impact de l'exclusion de l'Afd pour l'extrême droite, après les déclarations chocs de l'un des candidats du parti allemand [RTS]",
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 85480,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 8,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': "Isabelle Ory, correspondante de la RTS auprès de l'UE, analyse l'impact de l'exclusion de l'Afd pour l'extrême droite, après les déclarations chocs de l'un des candidats du parti allemand",
#       'media_type': 'Video',
#       'media_segment_id': '14926418',
#       'media_episode_length': '1831',
#       'media_segment_length': '85',
#       'media_number_of_segment_selected': '8',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926418',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$e7cb5c14b74c1e94$...',
#      'markIn': 1023600,
#      'markOut': 1109080},
#     {'id': '14926420',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926420',
#      'title': "Une semaine avant la fin de son procès à New York, le candidat républicain Donald Trump s'est rendu dans le Bronx pour y chercher des électeurs",
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926419.image/16x9',
#      'imageTitle': "Une semaine avant la fin de son procès à New York, le candidat républicain Donald Trump s'est rendu dans le Bronx pour y chercher des électeurs [RTS]",
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 143080,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 9,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': "Une semaine avant la fin de son procès à New York, le candidat républicain Donald Trump s'est rendu dans le Bronx pour y chercher des électeurs",
#       'media_type': 'Video',
#       'media_segment_id': '14926420',
#       'media_episode_length': '1831',
#       'media_segment_length': '143',
#       'media_number_of_segment_selected': '9',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926420',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$a83cae56260f7b1f$...',
#      'markIn': 1109080,
#      'markOut': 1252160},
#     {'id': '14926422',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926422',
#      'title': '"Comment ça va la Suisse?", une enquête comme un dialogue sur un quai de gare',
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926421.image/16x9',
#      'imageTitle': '"Comment ça va la Suisse?", une enquête comme un dialogue sur un quai de gare [RTS]',
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 107440,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 10,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': '"Comment ça va la Suisse?", une enquête comme un dialogue sur un quai de gare',
#       'media_type': 'Video',
#       'media_segment_id': '14926422',
#       'media_episode_length': '1831',
#       'media_segment_length': '107',
#       'media_number_of_segment_selected': '10',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926422',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$015ff86bec742eed$...',
#      'markIn': 1252160,
#      'markOut': 1359600},
#     {'id': '14926424',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926424',
#      'title': 'Triste tigre", ovni littéraire de Neige Sinno, primé par le choix Goncourt de la Suisse',
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926423.image/16x9',
#      'imageTitle': 'Triste tigre", ovni littéraire de Neige Sinno, primé par le choix Goncourt de la Suisse [RTS]',
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 138320,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 11,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': 'Triste tigre", ovni littéraire de Neige Sinno, primé par le choix Goncourt de la Suisse',
#       'media_type': 'Video',
#       'media_segment_id': '14926424',
#       'media_episode_length': '1831',
#       'media_segment_length': '138',
#       'media_number_of_segment_selected': '11',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926424',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$252dfb2e9e1cf9d5$...',
#      'markIn': 1359600,
#      'markOut': 1497920},
#     {'id': '14926426',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926426',
#      'title': "Un bras du Nil aujourd'hui asséché aurait servi de voie d'accès pour construire les pyramides",
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926425.image/16x9',
#      'imageTitle': "Un bras du Nil aujourd'hui asséché aurait servi de voie d'accès pour construire les pyramides [RTS]",
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 151600,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 12,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': "Un bras du Nil aujourd'hui asséché aurait servi de voie d'accès pour construire les pyramides",
#       'media_type': 'Video',
#       'media_segment_id': '14926426',
#       'media_episode_length': '1831',
#       'media_segment_length': '152',
#       'media_number_of_segment_selected': '12',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926426',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$d08a99d19cbe2a2a$...',
#      'markIn': 1497920,
#      'markOut': 1649520},
#     {'id': '14926428',
#      'mediaType': 'VIDEO',
#      'vendor': 'RTS',
#      'urn': 'urn:rts:video:14926428',
#      'title': 'Le musicien américain Lenny Kravitz a sorti vendredi son douzième album "Blue Electric Light", qui allie le glamour et le rock, principales caractéristiques de l\'artiste',
#      'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926427.image/16x9',
#      'imageTitle': 'Le musicien américain Lenny Kravitz a sorti vendredi son douzième album "Blue Electric Light", qui allie le glamour et le rock, principales caractéristiques de l\'artiste [RTS]',
#      'type': 'CLIP',
#      'date': '2024-05-24T19:30:00+02:00',
#      'duration': 131920,
#      'validFrom': '2024-05-24T20:04:12+02:00',
#      'playableAbroad': True,
#      'displayable': True,
#      'fullLengthUrn': 'urn:rts:video:14926430',
#      'position': 13,
#      'noEmbed': False,
#      'analyticsMetadata': {'media_segment': 'Le musicien américain Lenny Kravitz a sorti vendredi son douzième album "Blue Electric Light", qui allie le glamour et le rock, principales caractéristiques de l\'artiste',
#       'media_type': 'Video',
#       'media_segment_id': '14926428',
#       'media_episode_length': '1831',
#       'media_segment_length': '132',
#       'media_number_of_segment_selected': '13',
#       'media_number_of_segments_total': '13',
#       'media_duration_category': 'short',
#       'media_is_geoblocked': 'false',
#       'media_is_web_only': 'false',
#       'media_production_source': 'produced.for.broadcasting',
#       'media_urn': 'urn:rts:video:14926428',
#       'media_sub_set_id': 'CLIP',
#       'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#       'media_signlanguage_on': 'false'},
#      'eventData': '$a7455a8cf22c0d28$...',
#      'markIn': 1673880,
#      'markOut': 1805800}],
#    'aspectRatio': '16:9',
#    'spriteSheet': {'urn': 'urn:rts:video:14926430',
#     'rows': 23,
#     'columns': 20,
#     'thumbnailHeight': 84,
#     'thumbnailWidth': 150,
#     'interval': 4000,
#     'url': 'https://il.srgssr.ch/spritesheet/urn/rts/video/14926430/sprite-14926430.jpeg'}}],
#  'topicList': [{'id': '908',
#    'vendor': 'RTS',
#    'transmission': 'TV',
#    'urn': 'urn:rts:topic:tv:908',
#    'title': '19h30'},
#   {'id': '904',
#    'vendor': 'RTS',
#    'transmission': 'TV',
#    'urn': 'urn:rts:topic:tv:904',
#    'title': 'Vidéos'},
#   {'id': '665',
#    'vendor': 'RTS',
#    'transmission': 'TV',
#    'urn': 'urn:rts:topic:tv:665',
#    'title': 'Info'}],
#  'analyticsData': {'srg_pr_id': '14822978',
#   'srg_plid': '105932',
#   'ns_st_pl': '19h30',
#   'ns_st_pr': '19h30 du 24.05.2024',
#   'ns_st_dt': '2024-05-24',
#   'ns_st_ddt': '2024-05-24',
#   'ns_st_tdt': '2024-05-24',
#   'ns_st_tm': '19:30',
#   'ns_st_tep': '500539382',
#   'ns_st_li': '0',
#   'ns_st_stc': '0867',
#   'ns_st_st': 'RTS Online',
#   'ns_st_tpr': '105932',
#   'ns_st_en': '*null',
#   'ns_st_ge': '*null',
#   'ns_st_ia': '*null',
#   'ns_st_ce': '1',
#   'ns_st_cdm': 'to',
#   'ns_st_cmt': 'fc',
#   'srg_unit': 'RTS',
#   'srg_c1': 'full',
#   'srg_c2': 'video_info_journal-19h30',
#   'srg_c3': 'RTS 1',
#   'srg_tv_id': '500539382'},
#  'analyticsMetadata': {'media_episode_id': '14822978',
#   'media_show_id': '105932',
#   'media_show': '19h30',
#   'media_episode': '19h30 du 24.05.2024',
#   'media_is_livestream': 'false',
#   'media_full_length': 'full',
#   'media_enterprise_units': 'RTS',
#   'media_joker1': 'full',
#   'media_joker2': 'video_info_journal-19h30',
#   'media_joker3': 'RTS 1',
#   'media_is_web_only': 'false',
#   'media_production_source': 'produced.for.broadcasting',
#   'media_tv_id': '500539382',
#   'media_thumbnail': 'https://www.rts.ch/2024/05/25/14/48/14926429.image/16x9',
#   'media_publication_date': '2024-05-24',
#   'media_publication_time': '20:04:12',
#   'media_publication_datetime': '2024-05-24T20:04:12+02:00',
#   'media_tv_date': '2024-05-24',
#   'media_tv_time': '19:30:00',
#   'media_tv_datetime': '2024-05-24T19:30:00+02:00',
#   'media_content_group': '19h30,Vidéos,Info',
#   'media_channel_id': '143932a79bb5a123a646b68b1d1188d7ae493e5b',
#   'media_channel_cs': '0867',
#   'media_channel_name': 'RTS 1',
#   'media_since_publication_d': '115',
#   'media_since_publication_h': '2782',
#   'media_signlanguage_on': 'false'}}

# %%
segment_list = metadata["chapterList"][0]["segmentList"]
segment_list
# Out:
# [{'id': '14926404',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926404',
#   'title': "À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux",
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926395.image/16x9',
#   'imageTitle': "À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux [RTS]",
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 137200,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 1,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': "À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux",
#    'media_type': 'Video',
#    'media_segment_id': '14926404',
#    'media_episode_length': '1831',
#    'media_segment_length': '137',
#    'media_number_of_segment_selected': '1',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926404',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$ffb99f88d16c04b9$...',
#   'markIn': 75520,
#   'markOut': 212720},
#  {'id': '14926406',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926406',
#   'title': "Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien",
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926405.image/16x9',
#   'imageTitle': "Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien [RTS]",
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 203960,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 2,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': "Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien",
#    'media_type': 'Video',
#    'media_segment_id': '14926406',
#    'media_episode_length': '1831',
#    'media_segment_length': '204',
#    'media_number_of_segment_selected': '2',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926406',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$8c5880ebf7c1efce$...',
#   'markIn': 212720,
#   'markOut': 416680},
#  {'id': '14926408',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926408',
#   'title': 'Haute-Sorne (JU): la manifestation contre la géothermie profonde a dégénéré',
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926407.image/16x9',
#   'imageTitle': 'Haute-Sorne (JU): la manifestation contre la géothermie profonde a dégénéré [RTS]',
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 99520,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 3,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': 'Haute-Sorne (JU): la manifestation contre la géothermie profonde a dégénéré',
#    'media_type': 'Video',
#    'media_segment_id': '14926408',
#    'media_episode_length': '1831',
#    'media_segment_length': '100',
#    'media_number_of_segment_selected': '3',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926408',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$1faaee7cd701833e$...',
#   'markIn': 416680,
#   'markOut': 516200},
#  {'id': '14926410',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926410',
#   'title': 'Drogue: un deuxième espace de consommation sécurisé ouvre à Lausanne',
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926409.image/16x9',
#   'imageTitle': 'Drogue: un deuxième espace de consommation sécurisé ouvre à Lausanne [RTS]',
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 137000,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 4,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': 'Drogue: un deuxième espace de consommation sécurisé ouvre à Lausanne',
#    'media_type': 'Video',
#    'media_segment_id': '14926410',
#    'media_episode_length': '1831',
#    'media_segment_length': '137',
#    'media_number_of_segment_selected': '4',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926410',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$a5ca92f544e411f0$...',
#   'markIn': 516200,
#   'markOut': 653200},
#  {'id': '14926412',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926412',
#   'title': 'Le journaliste Yoan Rithner revient sur la grève entamée vendredi par le personnel de Vetropack à Saint-Prex dans le canton de Vaud',
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926411.image/16x9',
#   'imageTitle': 'Le journaliste Yoan Rithner revient sur la grève entamée vendredi par le personnel de Vetropack à Saint-Prex dans le canton de Vaud [RTS]',
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 102120,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 5,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': 'Le journaliste Yoan Rithner revient sur la grève entamée vendredi par le personnel de Vetropack à Saint-Prex dans le canton de Vaud',
#    'media_type': 'Video',
#    'media_segment_id': '14926412',
#    'media_episode_length': '1831',
#    'media_segment_length': '102',
#    'media_number_of_segment_selected': '5',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926412',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$7b9b1415320b95ce$...',
#   'markIn': 653200,
#   'markOut': 755320},
#  {'id': '14926414',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926414',
#   'title': 'À Neuchâtel, un ex-entraîneur de football amateur condamné pour abus sexuels sur des enfants',
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926413.image/16x9',
#   'imageTitle': 'À Neuchâtel, un ex-entraîneur de football amateur condamné pour abus sexuels sur des enfants [RTS]',
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 112480,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 6,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': 'À Neuchâtel, un ex-entraîneur de football amateur condamné pour abus sexuels sur des enfants',
#    'media_type': 'Video',
#    'media_segment_id': '14926414',
#    'media_episode_length': '1831',
#    'media_segment_length': '112',
#    'media_number_of_segment_selected': '6',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926414',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$636ae4551314a3ae$...',
#   'markIn': 755320,
#   'markOut': 867800},
#  {'id': '14926416',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926416',
#   'title': "Un candidat de l'AFD aux élections européennes crée le malaise avec des propos choquants",
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926415.image/16x9',
#   'imageTitle': "Un candidat de l'AFD aux élections européennes crée le malaise avec des propos choquants [RTS]",
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 133880,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 7,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': "Un candidat de l'AFD aux élections européennes crée le malaise avec des propos choquants",
#    'media_type': 'Video',
#    'media_segment_id': '14926416',
#    'media_episode_length': '1831',
#    'media_segment_length': '134',
#    'media_number_of_segment_selected': '7',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926416',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$a537e73c24c0ccb9$...',
#   'markIn': 889720,
#   'markOut': 1023600},
#  {'id': '14926418',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926418',
#   'title': "Isabelle Ory, correspondante de la RTS auprès de l'UE, analyse l'impact de l'exclusion de l'Afd pour l'extrême droite, après les déclarations chocs de l'un des candidats du parti allemand",
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926417.image/16x9',
#   'imageTitle': "Isabelle Ory, correspondante de la RTS auprès de l'UE, analyse l'impact de l'exclusion de l'Afd pour l'extrême droite, après les déclarations chocs de l'un des candidats du parti allemand [RTS]",
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 85480,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 8,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': "Isabelle Ory, correspondante de la RTS auprès de l'UE, analyse l'impact de l'exclusion de l'Afd pour l'extrême droite, après les déclarations chocs de l'un des candidats du parti allemand",
#    'media_type': 'Video',
#    'media_segment_id': '14926418',
#    'media_episode_length': '1831',
#    'media_segment_length': '85',
#    'media_number_of_segment_selected': '8',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926418',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$e7cb5c14b74c1e94$...',
#   'markIn': 1023600,
#   'markOut': 1109080},
#  {'id': '14926420',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926420',
#   'title': "Une semaine avant la fin de son procès à New York, le candidat républicain Donald Trump s'est rendu dans le Bronx pour y chercher des électeurs",
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926419.image/16x9',
#   'imageTitle': "Une semaine avant la fin de son procès à New York, le candidat républicain Donald Trump s'est rendu dans le Bronx pour y chercher des électeurs [RTS]",
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 143080,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 9,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': "Une semaine avant la fin de son procès à New York, le candidat républicain Donald Trump s'est rendu dans le Bronx pour y chercher des électeurs",
#    'media_type': 'Video',
#    'media_segment_id': '14926420',
#    'media_episode_length': '1831',
#    'media_segment_length': '143',
#    'media_number_of_segment_selected': '9',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926420',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$a83cae56260f7b1f$...',
#   'markIn': 1109080,
#   'markOut': 1252160},
#  {'id': '14926422',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926422',
#   'title': '"Comment ça va la Suisse?", une enquête comme un dialogue sur un quai de gare',
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926421.image/16x9',
#   'imageTitle': '"Comment ça va la Suisse?", une enquête comme un dialogue sur un quai de gare [RTS]',
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 107440,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 10,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': '"Comment ça va la Suisse?", une enquête comme un dialogue sur un quai de gare',
#    'media_type': 'Video',
#    'media_segment_id': '14926422',
#    'media_episode_length': '1831',
#    'media_segment_length': '107',
#    'media_number_of_segment_selected': '10',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926422',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$015ff86bec742eed$...',
#   'markIn': 1252160,
#   'markOut': 1359600},
#  {'id': '14926424',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926424',
#   'title': 'Triste tigre", ovni littéraire de Neige Sinno, primé par le choix Goncourt de la Suisse',
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926423.image/16x9',
#   'imageTitle': 'Triste tigre", ovni littéraire de Neige Sinno, primé par le choix Goncourt de la Suisse [RTS]',
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 138320,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 11,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': 'Triste tigre", ovni littéraire de Neige Sinno, primé par le choix Goncourt de la Suisse',
#    'media_type': 'Video',
#    'media_segment_id': '14926424',
#    'media_episode_length': '1831',
#    'media_segment_length': '138',
#    'media_number_of_segment_selected': '11',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926424',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$252dfb2e9e1cf9d5$...',
#   'markIn': 1359600,
#   'markOut': 1497920},
#  {'id': '14926426',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926426',
#   'title': "Un bras du Nil aujourd'hui asséché aurait servi de voie d'accès pour construire les pyramides",
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926425.image/16x9',
#   'imageTitle': "Un bras du Nil aujourd'hui asséché aurait servi de voie d'accès pour construire les pyramides [RTS]",
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 151600,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 12,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': "Un bras du Nil aujourd'hui asséché aurait servi de voie d'accès pour construire les pyramides",
#    'media_type': 'Video',
#    'media_segment_id': '14926426',
#    'media_episode_length': '1831',
#    'media_segment_length': '152',
#    'media_number_of_segment_selected': '12',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926426',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$d08a99d19cbe2a2a$...',
#   'markIn': 1497920,
#   'markOut': 1649520},
#  {'id': '14926428',
#   'mediaType': 'VIDEO',
#   'vendor': 'RTS',
#   'urn': 'urn:rts:video:14926428',
#   'title': 'Le musicien américain Lenny Kravitz a sorti vendredi son douzième album "Blue Electric Light", qui allie le glamour et le rock, principales caractéristiques de l\'artiste',
#   'imageUrl': 'https://www.rts.ch/2024/05/25/14/48/14926427.image/16x9',
#   'imageTitle': 'Le musicien américain Lenny Kravitz a sorti vendredi son douzième album "Blue Electric Light", qui allie le glamour et le rock, principales caractéristiques de l\'artiste [RTS]',
#   'type': 'CLIP',
#   'date': '2024-05-24T19:30:00+02:00',
#   'duration': 131920,
#   'validFrom': '2024-05-24T20:04:12+02:00',
#   'playableAbroad': True,
#   'displayable': True,
#   'fullLengthUrn': 'urn:rts:video:14926430',
#   'position': 13,
#   'noEmbed': False,
#   'analyticsMetadata': {'media_segment': 'Le musicien américain Lenny Kravitz a sorti vendredi son douzième album "Blue Electric Light", qui allie le glamour et le rock, principales caractéristiques de l\'artiste',
#    'media_type': 'Video',
#    'media_segment_id': '14926428',
#    'media_episode_length': '1831',
#    'media_segment_length': '132',
#    'media_number_of_segment_selected': '13',
#    'media_number_of_segments_total': '13',
#    'media_duration_category': 'short',
#    'media_is_geoblocked': 'false',
#    'media_is_web_only': 'false',
#    'media_production_source': 'produced.for.broadcasting',
#    'media_urn': 'urn:rts:video:14926428',
#    'media_sub_set_id': 'CLIP',
#    'media_topic_list': 'urn:rts:topic:tv:908,urn:rts:topic:tv:904,urn:rts:topic:tv:665',
#    'media_signlanguage_on': 'false'},
#   'eventData': '$a7455a8cf22c0d28$...',
#   'markIn': 1673880,
#   'markOut': 1805800}]

# %%
for i, segment in enumerate(segment_list):
    print(f"{i}: ", segment["title"])
# Out:
# 0:  À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux
# 1:  Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien
# 2:  Haute-Sorne (JU): la manifestation contre la géothermie profonde a dégénéré
# 3:  Drogue: un deuxième espace de consommation sécurisé ouvre à Lausanne
# 4:  Le journaliste Yoan Rithner revient sur la grève entamée vendredi par le personnel de Vetropack à Saint-Prex dans le canton de Vaud
# 5:  À Neuchâtel, un ex-entraîneur de football amateur condamné pour abus sexuels sur des enfants
# 6:  Un candidat de l'AFD aux élections européennes crée le malaise avec des propos choquants
# 7:  Isabelle Ory, correspondante de la RTS auprès de l'UE, analyse l'impact de l'exclusion de l'Afd pour l'extrême droite, après les déclarations chocs de l'un des candidats du parti allemand
# 8:  Une semaine avant la fin de son procès à New York, le candidat républicain Donald Trump s'est rendu dans le Bronx pour y chercher des électeurs
# 9:  "Comment ça va la Suisse?", une enquête comme un dialogue sur un quai de gare
# 10:  Triste tigre", ovni littéraire de Neige Sinno, primé par le choix Goncourt de la Suisse
# 11:  Un bras du Nil aujourd'hui asséché aurait servi de voie d'accès pour construire les pyramides
# 12:  Le musicien américain Lenny Kravitz a sorti vendredi son douzième album "Blue Electric Light", qui allie le glamour et le rock, principales caractéristiques de l'artiste

# %%
clip_topics = {i:segment["title"] for i, segment in enumerate(segment_list)}
clip_topics
# Out:
# {0: "À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux",
#  1: "Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien",
#  2: 'Haute-Sorne (JU): la manifestation contre la géothermie profonde a dégénéré',
#  3: 'Drogue: un deuxième espace de consommation sécurisé ouvre à Lausanne',
#  4: 'Le journaliste Yoan Rithner revient sur la grève entamée vendredi par le personnel de Vetropack à Saint-Prex dans le canton de Vaud',
#  5: 'À Neuchâtel, un ex-entraîneur de football amateur condamné pour abus sexuels sur des enfants',
#  6: "Un candidat de l'AFD aux élections européennes crée le malaise avec des propos choquants",
#  7: "Isabelle Ory, correspondante de la RTS auprès de l'UE, analyse l'impact de l'exclusion de l'Afd pour l'extrême droite, après les déclarations chocs de l'un des candidats du parti allemand",
#  8: "Une semaine avant la fin de son procès à New York, le candidat républicain Donald Trump s'est rendu dans le Bronx pour y chercher des électeurs",
#  9: '"Comment ça va la Suisse?", une enquête comme un dialogue sur un quai de gare',
#  10: 'Triste tigre", ovni littéraire de Neige Sinno, primé par le choix Goncourt de la Suisse',
#  11: "Un bras du Nil aujourd'hui asséché aurait servi de voie d'accès pour construire les pyramides",
#  12: 'Le musicien américain Lenny Kravitz a sorti vendredi son douzième album "Blue Electric Light", qui allie le glamour et le rock, principales caractéristiques de l\'artiste'}

# %%
system_prompt = """You are an expert at identifying topics related to: "Palestine".

This topic can be explored through multiple angles, including but not limited to:

    - Israel-Hamas war
    - Israel
    - Hamas
    - PLO
    - Palestine
    - Gaza
    - West Bank
    - Occupied Territories

Given the dictionary of titles below, your task is to identify keys that reference the topic and its angles. Return a list of keys refering to "Palestine".
RETURN ONLY A LIST OF INT.

**Example**: 

TITLES: {{0: "À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux",
 1: "Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien",
 2: 'Haute-Sorne (JU): la manifestation contre la géothermie profonde a dégénéré',
 3: 'Drogue: un deuxième espace de consommation sécurisé ouvre à Lausanne',
 4: 'Le journaliste Yoan Rithner revient sur la grève entamée vendredi par le personnel de Vetropack à Saint-Prex dans le canton de Vaud',
 5: 'À Neuchâtel, un ex-entraîneur de football amateur condamné pour abus sexuels sur des enfants',
 6: "Un candidat de l'AFD aux élections européennes crée le malaise avec des propos choquants",
 7: "Isabelle Ory, correspondante de la RTS auprès de l'UE, analyse l'impact de l'exclusion de l'Afd pour l'extrême droite, après les déclarations chocs de l'un des candidats du parti allemand",
 8: "Une semaine avant la fin de son procès à New York, le candidat républicain Donald Trump s'est rendu dans le Bronx pour y chercher des électeurs",
 9: '"Comment ça va la Suisse?", une enquête comme un dialogue sur un quai de gare',
 10: 'Triste tigre", ovni littéraire de Neige Sinno, primé par le choix Goncourt de la Suisse',
 11: "Un bras du Nil aujourd'hui asséché aurait servi de voie d'accès pour construire les pyramides",
 12: 'Le musicien américain Lenny Kravitz a sorti vendredi son douzième album "Blue Electric Light", qui allie le glamour et le rock, principales caractéristiques de l\'artiste'}}
    
TOPICS:[0, 1]

TITLES: {text}
TOPICS:"""

# %%
messages = [{"role": "system", "content": system_prompt.format(text=clip_topics)},]
topic_keys = llm_client.chat.completions.create(
                model="gpt-4o",
                stream=False,
                temperature=0,
                top_p=0.95,
                max_tokens=4096,
                messages=messages
            ).choices[0].message.content
print(topic_keys)
# Out:
# [0, 1]

# %%
topic_keys = ast.literal_eval(topic_keys)

# %%
transcript_ts = [caption.end_in_seconds for caption in transcript]
transcript_ts
# Out:
# [13,
#  16,
#  18,
#  22,
#  25,
#  31,
#  34,
#  37,
#  41,
#  44,
#  47,
#  51,
#  54,
#  61,
#  63,
#  66,
#  69,
#  72,
#  80,
#  82,
#  85,
#  87,
#  97,
#  102,
#  105,
#  108,
#  113,
#  115,
#  123,
#  125,
#  130,
#  133,
#  137,
#  145,
#  148,
#  150,
#  154,
#  158,
#  162,
#  172,
#  175,
#  178,
#  181,
#  184,
#  195,
#  199,
#  201,
#  204,
#  211,
#  215,
#  221,
#  227,
#  234,
#  237,
#  241,
#  244,
#  246,
#  250,
#  254,
#  258,
#  261,
#  265,
#  272,
#  277,
#  281,
#  285,
#  290,
#  292,
#  296,
#  299,
#  304,
#  308,
#  310,
#  314,
#  317,
#  323,
#  327,
#  330,
#  335,
#  339,
#  343,
#  347,
#  349,
#  353,
#  355,
#  361,
#  366,
#  372,
#  375,
#  378,
#  384,
#  387,
#  393,
#  398,
#  402,
#  406,
#  409,
#  415,
#  420,
#  424,
#  428,
#  431,
#  435,
#  439,
#  443,
#  445,
#  448,
#  451,
#  458,
#  460,
#  465,
#  467,
#  469,
#  471,
#  473,
#  479,
#  482,
#  484,
#  489,
#  492,
#  494,
#  496,
#  498,
#  502,
#  504,
#  510,
#  515,
#  519,
#  522,
#  525,
#  528,
#  532,
#  536,
#  543,
#  547,
#  552,
#  555,
#  558,
#  562,
#  564,
#  567,
#  572,
#  574,
#  578,
#  583,
#  588,
#  591,
#  593,
#  596,
#  599,
#  604,
#  607,
#  610,
#  612,
#  614,
#  615,
#  621,
#  624,
#  628,
#  630,
#  633,
#  640,
#  649,
#  652,
#  656,
#  658,
#  660,
#  664,
#  667,
#  670,
#  675,
#  677,
#  679,
#  683,
#  687,
#  692,
#  697,
#  701,
#  712,
#  715,
#  718,
#  721,
#  724,
#  728,
#  732,
#  737,
#  741,
#  746,
#  750,
#  754,
#  762,
#  763,
#  767,
#  770,
#  772,
#  773,
#  778,
#  780,
#  783,
#  786,
#  789,
#  791,
#  794,
#  796,
#  800,
#  802,
#  806,
#  809,
#  812,
#  816,
#  821,
#  826,
#  828,
#  830,
#  832,
#  835,
#  840,
#  844,
#  848,
#  850,
#  852,
#  856,
#  863,
#  867,
#  871,
#  875,
#  878,
#  888,
#  892,
#  896,
#  900,
#  905,
#  912,
#  917,
#  918,
#  923,
#  926,
#  931,
#  940,
#  942,
#  945,
#  948,
#  951,
#  959,
#  965,
#  967,
#  970,
#  972,
#  975,
#  978,
#  980,
#  984,
#  987,
#  989,
#  992,
#  996,
#  998,
#  1000,
#  1010,
#  1017,
#  1019,
#  1022,
#  1027,
#  1029,
#  1030,
#  1038,
#  1041,
#  1045,
#  1048,
#  1051,
#  1054,
#  1058,
#  1061,
#  1063,
#  1068,
#  1070,
#  1076,
#  1081,
#  1085,
#  1089,
#  1093,
#  1100,
#  1104,
#  1111,
#  1117,
#  1119,
#  1122,
#  1126,
#  1132,
#  1134,
#  1138,
#  1142,
#  1144,
#  1146,
#  1148,
#  1149,
#  1152,
#  1154,
#  1156,
#  1160,
#  1164,
#  1166,
#  1171,
#  1174,
#  1178,
#  1181,
#  1183,
#  1184,
#  1190,
#  1193,
#  1195,
#  1199,
#  1202,
#  1206,
#  1210,
#  1216,
#  1220,
#  1222,
#  1225,
#  1228,
#  1230,
#  1233,
#  1238,
#  1244,
#  1247,
#  1249,
#  1252,
#  1256,
#  1258,
#  1262,
#  1267,
#  1272,
#  1275,
#  1281,
#  1284,
#  1286,
#  1294,
#  1302,
#  1307,
#  1314,
#  1318,
#  1319,
#  1323,
#  1329,
#  1332,
#  1334,
#  1339,
#  1346,
#  1350,
#  1353,
#  1358,
#  1364,
#  1369,
#  1372,
#  1381,
#  1387,
#  1393,
#  1396,
#  1401,
#  1405,
#  1410,
#  1413,
#  1417,
#  1422,
#  1425,
#  1427,
#  1435,
#  1437,
#  1441,
#  1445,
#  1448,
#  1452,
#  1454,
#  1457,
#  1465,
#  1472,
#  1477,
#  1480,
#  1485,
#  1488,
#  1492,
#  1496,
#  1501,
#  1505,
#  1508,
#  1511,
#  1513,
#  1518,
#  1521,
#  1525,
#  1527,
#  1530,
#  1534,
#  1536,
#  1539,
#  1541,
#  1544,
#  1548,
#  1554,
#  1558,
#  1562,
#  1565,
#  1568,
#  1569,
#  1572,
#  1577,
#  1582,
#  1589,
#  1590,
#  1593,
#  1596,
#  1608,
#  1610,
#  1614,
#  1617,
#  1621,
#  1624,
#  1626,
#  1628,
#  1630,
#  1636,
#  1641,
#  1644,
#  1648,
#  1652,
#  1655,
#  1660,
#  1663,
#  1665,
#  1668,
#  1673,
#  1678,
#  1689,
#  1697,
#  1704,
#  1712,
#  1714,
#  1718,
#  1720,
#  1723,
#  1727,
#  1734,
#  1739,
#  1742,
#  1749,
#  1755,
#  1761,
#  1767,
#  1771,
#  1773,
#  1777,
#  1780,
#  1787,
#  1790,
#  1795,
#  1809,
#  1812,
#  1814,
#  1818]

# %%
transcript
# Out:
# [<Caption start='00:00:00.000' end='00:00:13.948' text='...' identifier=None>,
#  <Caption start='00:00:14.228' end='00:00:16.428' text='-Mesdames, Messieurs,\\nbonsoir et bienvenue.' identifier=None>,
#  <Caption start='00:00:16.508' end='00:00:18.868' text='Insultes, menaces et intimidation,' identifier=None>,
#  <Caption start='00:00:18.948' end='00:00:22.228' text="c'est ce que vivent\\nles étudiants de l'EPLF" identifier=None>,
#  <Caption start='00:00:22.308' end='00:00:25.348' text='qui émettent un avis contraire\\nau mouvement propalestinien.' identifier=None>,
#  <Caption start='00:00:25.428' end='00:00:31.388' text="Le président de l'EPFL,\\nMartin Vetterli, est avec nous." identifier=None>,
#  <Caption start='00:00:32.148' end='00:00:34.788' text='Une manifestation spectaculaire' identifier=None>,
#  <Caption start='00:00:34.868' end='00:00:37.549' text='contre la géothermie\\ndans la commune de Haute-Sorne (JU).' identifier=None>,
#  <Caption start='00:00:37.589' end='00:00:41.189' text='Des militants en colère\\net des dégâts considérables.' identifier=None>,
#  <Caption start='00:00:41.989' end='00:00:44.469' text='A deux semaines\\ndes élections européennes,' identifier=None>,
#  <Caption start='00:00:44.549' end='00:00:47.189' text="alors qu'on parle\\nd'un excellent score tout à droite," identifier=None>,
#  <Caption start='00:00:47.269' end='00:00:51.389' text="l'AfD a été exclu de son groupe\\nparlementaire à Bruxelles." identifier=None>,
#  <Caption start='00:00:51.469' end='00:00:54.949' text='Sa tête de liste\\nenchaîne les dérapages.' identifier=None>,
#  <Caption start='00:00:56.589' end='00:01:01.269' text='Nous percerons un des mystères\\nqui entourent les pyramides.' identifier=None>,
#  <Caption start='00:01:01.349' end='00:01:03.870' text='Comment ont-elles été construites ?' identifier=None>,
#  <Caption start='00:01:03.910' end='00:01:06.390' text='Il y a une réponse récente.' identifier=None>,
#  <Caption start='00:01:07.550' end='00:01:09.390' text='60 ans et toujours aussi glamour.' identifier=None>,
#  <Caption start='00:01:09.470' end='00:01:12.670' text="L'icône du rock Lenny Kravitz\\nsort un nouvel album." identifier=None>,
#  <Caption start='00:01:16.150' end='00:01:20.630' text="Le climat est délétère à l'EPFL" identifier=None>,
#  <Caption start='00:01:20.710' end='00:01:22.990' text='sur fond de guerre\\nentre Israël et le Hamas.' identifier=None>,
#  <Caption start='00:01:23.070' end='00:01:25.190' text='Les étudiants qui émettent\\nun avis contraire' identifier=None>,
#  <Caption start='00:01:25.270' end='00:01:27.590' text='au mouvement propalestinien\\nsont menacés.' identifier=None>,
#  <Caption start='00:01:27.670' end='00:01:37.271' text="Des jeunes ont peur\\nd'aller sur le campus." identifier=None>,
#  <Caption start='00:01:39.671' end='00:01:42.431' text='-Si ce groupe de discussion\\nsur la guerre au Moyen-Orient' identifier=None>,
#  <Caption start='00:01:42.471' end='00:01:45.911' text="par des étudiants de l'EPFL\\na été depuis supprimé," identifier=None>,
#  <Caption start='00:01:45.991' end='00:01:48.911' text="il en subsiste\\nces captures d'écran." identifier=None>,
#  <Caption start='00:01:51.511' end='00:01:53.711' text='Des menaces de mort dirigées\\ncontre des étudiants' identifier=None>,
#  <Caption start='00:01:53.791' end='00:01:55.712' text='qui souhaitaient apaiser\\ndes tensions.' identifier=None>,
#  <Caption start='00:02:01.752' end='00:02:03.432' text='Ces révélations du journal Le Temps' identifier=None>,
#  <Caption start='00:02:03.512' end='00:02:05.912' text="décrivent une radicalisation\\nsur le campus de l'EPFL." identifier=None>,
#  <Caption start='00:02:05.992' end='00:02:10.632' text="Cet étudiant visé ne s'affole pas,\\nmais avoue être sur ses gardes." identifier=None>,
#  <Caption start='00:02:12.272' end='00:02:13.712' text='-Une limite a été franchie' identifier=None>,
#  <Caption start='00:02:13.792' end='00:02:17.072' text="parce que c'est un événement\\nqui n'a jamais été vu sur le campus." identifier=None>,
#  <Caption start='00:02:17.152' end='00:02:25.393' text='On a peur,\\non regarde un peu derrière nous.' identifier=None>,
#  <Caption start='00:02:25.873' end='00:02:28.473' text="-La direction de l'EPFL\\norganisait cet après-midi" identifier=None>,
#  <Caption start='00:02:28.553' end='00:02:30.993' text='une discussion\\npour éviter toute escalade.' identifier=None>,
#  <Caption start='00:02:31.073' end='00:02:34.913' text='Si la démarche a été saluée,\\ncertains en ont profité' identifier=None>,
#  <Caption start='00:02:35.033' end='00:02:38.593' text='pour remettre en doute\\nle témoignage des étudiants menacés.' identifier=None>,
#  <Caption start='00:02:38.873' end='00:02:42.913' text='-La première réaction dans\\nl\'auditoire, c\'est "ils mentent".' identifier=None>,
#  <Caption start='00:02:42.993' end='00:02:52.074' text='Ils parlent de menaces de mort,\\ndonc forcément ils mentent.' identifier=None>,
#  <Caption start='00:02:52.514' end='00:02:55.554' text='-Du côté\\ndes manifestants propalestiniens,' identifier=None>,
#  <Caption start='00:02:55.594' end='00:02:58.394' text='on condamne fermement\\ntoutes attitudes discriminatoires.' identifier=None>,
#  <Caption start='00:02:58.634' end='00:03:01.554' text='-Menacer de mort pour des idées\\npolitiques,' identifier=None>,
#  <Caption start='00:03:01.634' end='00:03:04.834' text="ce n'est pas acceptable,\\nsurtout pas dans notre école." identifier=None>,
#  <Caption start='00:03:04.914' end='00:03:15.915' text='Ca ne reflète pas\\nla majorité des étudiants.' identifier=None>,
#  <Caption start='00:03:16.595' end='00:03:19.035' text='-Le groupe propalestinien considère' identifier=None>,
#  <Caption start='00:03:19.115' end='00:03:21.915' text='que la direction porte\\nune part de responsabilité' identifier=None>,
#  <Caption start='00:03:21.995' end='00:03:24.475' text="en limitant la liberté d'expression." identifier=None>,
#  <Caption start='00:03:24.555' end='00:03:31.395' text="La direction de l'EPFL doit faire\\nla lumière sur ces événements." identifier=None>,
#  <Caption start='00:03:32.995' end='00:03:35.115' text='-Martin Vetterli, bonsoir.' identifier=None>,
#  <Caption start='00:03:35.195' end='00:03:41.916' text='Le Temps révèle que des étudiants\\nde votre établissement' identifier=None>,
#  <Caption start='00:03:41.996' end='00:03:47.236' text='sont harcelés car ils pensent\\ndifféremment, et parlent de paix.' identifier=None>,
#  <Caption start='00:03:47.316' end='00:03:54.396' text='Un étudiant est menacé de mort\\nsur les réseaux sociaux:' identifier=None>,
#  <Caption start='00:03:54.476' end='00:03:57.196' text='"il faut tuer Nicolas et son gang".' identifier=None>,
#  <Caption start='00:03:57.276' end='00:04:01.556' text='Une autre est intimidée:\\n"on a vu où tu étais assise".' identifier=None>,
#  <Caption start='00:04:01.636' end='00:04:04.437' text='Quelle est votre réaction ?' identifier=None>,
#  <Caption start='00:04:04.437' end='00:04:06.477' text='- Je suis très triste' identifier=None>,
#  <Caption start='00:04:06.477' end='00:04:10.477' text="qu'il y a une telle tension\\nsur le campus." identifier=None>,
#  <Caption start='00:04:10.477' end='00:04:14.077' text='Ce sont les excès\\ndes réseaux sociaux.' identifier=None>,
#  <Caption start='00:04:14.237' end='00:04:18.317' text="Si on n'est pas dans le cadre légal," identifier=None>,
#  <Caption start='00:04:18.477' end='00:04:21.117' text="par rapport aux lois\\nsur le racisme et l'antisémitisme," identifier=None>,
#  <Caption start='00:04:21.117' end='00:04:25.357' text='on donne\\nle support à notre communauté.' identifier=None>,
#  <Caption start='00:04:25.357' end='00:04:32.918' text="Nos étudiants ont des canaux où ils\\npeuvent venir chercher de l'aide." identifier=None>,
#  <Caption start='00:04:32.918' end='00:04:37.038' text='Et on prendra\\nles mesures nécessaires.' identifier=None>,
#  <Caption start='00:04:38.798' end='00:04:41.838' text='Des plaintes pourront être portées.' identifier=None>,
#  <Caption start='00:04:41.998' end='00:04:45.798' text='-On entend des étudiants juifs' identifier=None>,
#  <Caption start='00:04:45.798' end='00:04:50.518' text='qui ont peur de venir sur le campus.' identifier=None>,
#  <Caption start='00:04:50.678' end='00:04:52.878' text='Leur sécurité est garantie ?' identifier=None>,
#  <Caption start='00:04:52.878' end='00:04:56.079' text="-C'est notre première priorité." identifier=None>,
#  <Caption start='00:04:56.079' end='00:04:59.599' text='La sécurité de tous sur le campus.' identifier=None>,
#  <Caption start='00:04:59.599' end='00:05:04.359' text='On a parlé avec ces gens,\\nils se sont exprimés.' identifier=None>,
#  <Caption start='00:05:04.519' end='00:05:08.039' text="Ils ont besoin d'être protégés,\\ncomme tout le monde." identifier=None>,
#  <Caption start='00:05:08.039' end='00:05:10.679' text="-Vous reconnaissez\\nqu'il y a une dérive" identifier=None>,
#  <Caption start='00:05:10.679' end='00:05:14.359' text='de certains membres\\ndes militants propalestiniens ?' identifier=None>,
#  <Caption start='00:05:14.519' end='00:05:17.919' text='-Il y a toujours des dérives.' identifier=None>,
#  <Caption start='00:05:17.919' end='00:05:23.440' text="Il y a un large spectre\\nd'opinions sur le campus." identifier=None>,
#  <Caption start='00:05:23.440' end='00:05:27.760' text='Notre mission\\nest de garder une unité.' identifier=None>,
#  <Caption start='00:05:27.760' end='00:05:30.120' text='-Comment on en est arrivé là ?' identifier=None>,
#  <Caption start='00:05:30.120' end='00:05:35.000' text='Y a-t-il aussi une responsabilité\\nde la part des grandes écoles' identifier=None>,
#  <Caption start='00:05:35.000' end='00:05:39.600' text='de laisser entrer ces discussions\\npolitiques sur le campus ?' identifier=None>,
#  <Caption start='00:05:39.600' end='00:05:43.800' text="L'université ne doit-elle\\npas être totalement neutre ?" identifier=None>,
#  <Caption start='00:05:43.960' end='00:05:47.641' text="-L'université en tant qu'institution\\ndoit rester neutre" identifier=None>,
#  <Caption start='00:05:47.641' end='00:05:49.281' text='pour permettre un débat.' identifier=None>,
#  <Caption start='00:05:49.281' end='00:05:53.441' text="Mais chacun est un être humain\\nqui peut s'exprimer en son nom." identifier=None>,
#  <Caption start='00:05:53.441' end='00:05:55.921' text="Il ne faut pas\\nqu'il y ait de dérive." identifier=None>,
#  <Caption start='00:05:56.081' end='00:06:01.921' text="Il ne faut pas qu'il y ait le genre\\nd'excès dont vous avez parlé." identifier=None>,
#  <Caption start='00:06:02.841' end='00:06:06.601' text='-On a atteint\\nà ce niveau-là du rouge.' identifier=None>,
#  <Caption start='00:06:06.601' end='00:06:12.322' text="Qu'est-ce que vous allez faire\\npour remettre de l'ordre ?" identifier=None>,
#  <Caption start='00:06:12.322' end='00:06:15.482' text="-On n'est pas dans le désordre." identifier=None>,
#  <Caption start='00:06:15.482' end='00:06:18.722' text='Sur le campus, ça se passe bien.' identifier=None>,
#  <Caption start='00:06:19.882' end='00:06:24.042' text='Plusieurs centaines de participants\\nreprésentant les étudiants,' identifier=None>,
#  <Caption start='00:06:24.042' end='00:06:27.922' text="les employés et les profs ont parlé\\net ça s'est bien passé." identifier=None>,
#  <Caption start='00:06:27.922' end='00:06:33.162' text='Tous nos canaux de soutien sont\\nà disposition de toute la communauté.' identifier=None>,
#  <Caption start='00:06:33.162' end='00:06:38.043' text="-Vous appelez les étudiants\\nà s'adresser à vos canaux de soutien" identifier=None>,
#  <Caption start='00:06:38.203' end='00:06:42.203' text='si quelque chose se passe.' identifier=None>,
#  <Caption start='00:06:42.363' end='00:06:46.243' text='-On a créé\\nune commission spécifique.' identifier=None>,
#  <Caption start='00:06:46.403' end='00:06:49.443' text='On va regarder\\nces différentes dimensions.' identifier=None>,
#  <Caption start='00:06:49.603' end='00:06:55.723' text='Cette commission\\nest dirigée par ma collègue.' identifier=None>,
#  <Caption start='00:06:55.723' end='00:07:00.003' text='-Ce matin,\\ndans la commune de Haute-Sorne,' identifier=None>,
#  <Caption start='00:07:00.003' end='00:07:04.844' text='ils étaient une centaine\\nà exprimer leur colère' identifier=None>,
#  <Caption start='00:07:04.844' end='00:07:08.924' text='contre le projet\\nde géothermie profonde.' identifier=None>,
#  <Caption start='00:07:08.924' end='00:07:11.644' text='La police a dû intervenir.' identifier=None>,
#  <Caption start='00:07:13.484' end='00:07:15.964' text='-Un puissant\\njet de lisier annonce la couleur.' identifier=None>,
#  <Caption start='00:07:16.044' end='00:07:19.524' text='La manifestation\\ncontre la géothermie profonde' identifier=None>,
#  <Caption start='00:07:19.604' end='00:07:23.524' text='à Haute-Sorne (JU) a largement\\ndépassé le cadre pacifiste.' identifier=None>,
#  <Caption start='00:07:23.604' end='00:07:25.564' text='Une centaine de personnes a mis' identifier=None>,
#  <Caption start='00:07:25.644' end='00:07:28.325' text="les services de sécurité\\nà l'épreuve ce vendredi matin" identifier=None>,
#  <Caption start='00:07:28.405' end='00:07:31.165' text='avec cette intrusion\\nsur le site de forage.' identifier=None>,
#  <Caption start='00:07:33.805' end='00:07:38.085' text='Le rassemblement a démarré\\ndans une humeur festive' identifier=None>,
#  <Caption start='00:07:38.165' end='00:07:40.925' text='avant de dégénérer.' identifier=None>,
#  <Caption start='00:07:42.965' end='00:07:45.005' text="-Si je n'ai pas les fenêtres fermées," identifier=None>,
#  <Caption start='00:07:45.085' end='00:07:47.605' text="j'ai une vibration dans le corps." identifier=None>,
#  <Caption start='00:07:47.685' end='00:07:49.045' text="C'est nuit et jour." identifier=None>,
#  <Caption start='00:07:49.125' end='00:07:51.285' text="Ce qu'ils font est hyper violent." identifier=None>,
#  <Caption start='00:07:51.365' end='00:07:53.966' text="Aujourd'hui,\\nil y a eu des actes de violence," identifier=None>,
#  <Caption start='00:07:54.046' end='00:07:59.126' text='mais je ne regrette pas\\nque ça se soit passé.' identifier=None>,
#  <Caption start='00:07:59.566' end='00:08:02.366' text="-L'objet de la discorde\\nest cette tour de forage," identifier=None>,
#  <Caption start='00:08:02.446' end='00:08:04.406' text='en activité\\ndepuis mardi dernier.' identifier=None>,
#  <Caption start='00:08:04.486' end='00:08:09.846' text="Le gouvernement jurassien\\ndéplore l'escalade de la violence." identifier=None>,
#  <Caption start='00:08:10.566' end='00:08:12.326' text='-Le gouvernement estime' identifier=None>,
#  <Caption start='00:08:12.406' end='00:08:14.486' text="qu'on peut être opposé au projet." identifier=None>,
#  <Caption start='00:08:14.566' end='00:08:16.046' text='On peut manifester.' identifier=None>,
#  <Caption start='00:08:16.126' end='00:08:18.087' text="Aujourd'hui,\\ndes limites ont été franchies." identifier=None>,
#  <Caption start='00:08:18.167' end='00:08:22.207' text='Il y a des questions\\nde sécurité et de propriété privée.' identifier=None>,
#  <Caption start='00:08:22.287' end='00:08:24.967' text='On a peut-être franchi une étape.' identifier=None>,
#  <Caption start='00:08:26.367' end='00:08:30.927' text='-Une trentaine de policiers est\\nintervenue pour disperser la foule.' identifier=None>,
#  <Caption start='00:08:31.007' end='00:08:35.727' text='Une nouvelle manifestation\\nest déjà annoncée mercredi prochain.' identifier=None>,
#  <Caption start='00:08:37.207' end='00:08:39.287' text='-Lausanne et sa lutte\\ncontre la drogue.' identifier=None>,
#  <Caption start='00:08:39.367' end='00:08:42.967' text="La ville ouvre un deuxième local\\nd'injection à la place de la Riponne," identifier=None>,
#  <Caption start='00:08:43.047' end='00:08:45.648' text='connue pour la présence\\nde toxicomanes.' identifier=None>,
#  <Caption start='00:08:45.728' end='00:08:48.928' text='Cet espace est présenté\\ncomme une alternative' identifier=None>,
#  <Caption start='00:08:49.008' end='00:08:52.488' text="à la consommation\\ndans l'espace public." identifier=None>,
#  <Caption start='00:08:54.168' end='00:08:56.008' text='-C’est un local tout neuf.' identifier=None>,
#  <Caption start='00:08:56.088' end='00:09:03.408' text="Des box pour l’inhalation\\net l'injection, une salle de repos." identifier=None>,
#  <Caption start='00:09:03.488' end='00:09:07.688' text='A partir de lundi, les consommateurs\\nde cocaïne, héroïne et autres' identifier=None>,
#  <Caption start='00:09:07.768' end='00:09:12.369' text='pourront en bénéficier\\nen plein centre-ville de Lausanne.' identifier=None>,
#  <Caption start='00:09:13.049' end='00:09:15.569' text='-On vise des personnes\\ntrès désinsérées' identifier=None>,
#  <Caption start='00:09:15.649' end='00:09:18.329' text='qui consomment dans l’espace public,' identifier=None>,
#  <Caption start='00:09:18.409' end='00:09:22.329' text='ça crée des inquiétudes' identifier=None>,
#  <Caption start='00:09:22.409' end='00:09:24.889' text='et des nuisances pour le voisinage,' identifier=None>,
#  <Caption start='00:09:24.969' end='00:09:27.889' text='et des risques pour la santé\\nde ceux qui consomment.' identifier=None>,
#  <Caption start='00:09:28.729' end='00:09:32.169' text='-Pas de distribution de drogue sur\\nplace, mais du matériel stérile.' identifier=None>,
#  <Caption start='00:09:32.249' end='00:09:34.770' text='Et la possibilité d’un suivi social.' identifier=None>,
#  <Caption start='00:09:34.810' end='00:09:38.970' text='Le deuxième espace de consommation\\nsécurisée de la capitale vaudoise.' identifier=None>,
#  <Caption start='00:09:39.050' end='00:09:43.570' text='Un premier local a été ouvert\\nil y a 6 ans à 500 m de là.' identifier=None>,
#  <Caption start='00:09:43.650' end='00:09:48.450' text="L'équipe y enregistre en moyenne\\n95 prises de drogues par jour." identifier=None>,
#  <Caption start='00:09:49.770' end='00:09:51.530' text='-On a des temps d’attente' identifier=None>,
#  <Caption start='00:09:51.610' end='00:09:53.650' text="pouvant aller jusqu'à une demi-heure." identifier=None>,
#  <Caption start='00:09:53.730' end='00:09:56.890' text='On sait que les personnes\\ndans l’urgence de la consommation' identifier=None>,
#  <Caption start='00:09:56.930' end='00:09:59.210' text='peinent à attendre\\nplus que 10-15 min.' identifier=None>,
#  <Caption start='00:09:59.290' end='00:10:04.411' text='On arrive\\naux limites du projet actuel.' identifier=None>,
#  <Caption start='00:10:04.971' end='00:10:07.891' text='-Le local tout juste inauguré\\nest à quelques mètres' identifier=None>,
#  <Caption start='00:10:07.971' end='00:10:10.851' text='du lieu de rassemblement habituel\\ndes personnes toxicomanes,' identifier=None>,
#  <Caption start='00:10:10.931' end='00:10:12.611' text='sur la place de la Riponne.' identifier=None>,
#  <Caption start='00:10:13.011' end='00:10:14.371' text='-C’est très bien.' identifier=None>,
#  <Caption start='00:10:14.451' end='00:10:15.931' text='On aura une salle de repos,' identifier=None>,
#  <Caption start='00:10:16.011' end='00:10:21.371' text='on pourra se poser,\\nils pourront nous surveiller.' identifier=None>,
#  <Caption start='00:10:21.651' end='00:10:24.651' text='-Les gens qui consomment\\nseront en sécurité' identifier=None>,
#  <Caption start='00:10:24.731' end='00:10:28.172' text='et ne font pas ça\\ndans la rue devant des enfants.' identifier=None>,
#  <Caption start='00:10:28.452' end='00:10:30.932' text='-Les deux espaces\\nde consommation sécurisée' identifier=None>,
#  <Caption start='00:10:31.012' end='00:10:33.492' text='sont financés\\npar la Ville et le Canton.' identifier=None>,
#  <Caption start='00:10:37.092' end='00:10:40.532' text="Ils complètent une série\\nde mesures prises l'été 2023." identifier=None>,
#  <Caption start='00:10:46.572' end='00:10:49.732' text='La nouvelle antenne de la Riponne\\nest un projet pilote.' identifier=None>,
#  <Caption start='00:10:49.812' end='00:10:52.973' text='Son efficacité\\nsera évaluée dans une année.' identifier=None>,
#  <Caption start='00:10:54.493' end='00:10:56.453' text='-Le personnel de Vetropack' identifier=None>,
#  <Caption start='00:10:56.533' end='00:10:58.693' text='entame une grève\\nà durée indéterminée.' identifier=None>,
#  <Caption start='00:10:58.773' end='00:11:00.933' text='La majorité des employés\\nde Saint-Prex (VD)' identifier=None>,
#  <Caption start='00:11:01.013' end='00:11:04.133' text='a arrêté de travailler.' identifier=None>,
#  <Caption start='00:11:05.853' end='00:11:07.613' text='Yoan Rithner, vous êtes sur place.' identifier=None>,
#  <Caption start='00:11:07.693' end='00:11:10.093' text='Pas de licenciement\\nsans plan social,' identifier=None>,
#  <Caption start='00:11:10.173' end='00:11:15.373' text="c'est le coeur des revendications." identifier=None>,
#  <Caption start='00:11:15.373' end='00:11:17.214' text='-Exactement.' identifier=None>,
#  <Caption start='00:11:17.374' end='00:11:19.614' text='Un plan social digne de ce nom.' identifier=None>,
#  <Caption start='00:11:19.614' end='00:11:23.534' text="C'est actuellement loin d'être\\nle cas pour les employés" identifier=None>,
#  <Caption start='00:11:23.534' end='00:11:27.894' text='qui ont décidé\\nde débrayer en fin de matinée.' identifier=None>,
#  <Caption start='00:11:27.894' end='00:11:32.054' text="La production\\ndes bouteilles est à l'arrêt." identifier=None>,
#  <Caption start='00:11:32.054' end='00:11:37.214' text='Les palettes ne sont plus livrées.' identifier=None>,
#  <Caption start='00:11:37.214' end='00:11:41.294' text='"On n\'a plus rien à perdre"' identifier=None>,
#  <Caption start='00:11:41.294' end='00:11:52.775' text="a dit un des employés depuis\\nl'annonce de la fermeture de l'usine." identifier=None>,
#  <Caption start='00:11:52.935' end='00:11:55.615' text="Pour l'instant, la direction refuse" identifier=None>,
#  <Caption start='00:11:55.615' end='00:11:58.735' text="d'entrer dans des véritables\\nnégociations." identifier=None>,
#  <Caption start='00:11:58.735' end='00:12:01.375' text="Il y a une cinquantaine d'employés" identifier=None>,
#  <Caption start='00:12:01.375' end='00:12:04.415' text="qui n'auraient droit\\nà aucune indemnité." identifier=None>,
#  <Caption start='00:12:04.415' end='00:12:08.976' text="Une trentaine d'autres\\nn'aurait droit qu'à un demi-salaire." identifier=None>,
#  <Caption start='00:12:09.136' end='00:12:12.736' text="La direction a réagi\\nen fin d'après-midi." identifier=None>,
#  <Caption start='00:12:12.736' end='00:12:17.856' text='Elle a dit\\nne pas comprendre la grève.' identifier=None>,
#  <Caption start='00:12:17.856' end='00:12:21.056' text='Les discussions\\nsont encore en cours.' identifier=None>,
#  <Caption start='00:12:21.056' end='00:12:26.176' text='Elle demande un arrêt de la grève\\nsinon elle risque de retarder' identifier=None>,
#  <Caption start='00:12:26.176' end='00:12:30.896' text='le versement des indemnités\\npour les personnes licenciées.' identifier=None>,
#  <Caption start='00:12:30.896' end='00:12:34.977' text='Les premiers licenciements\\ndevraient être annoncés' identifier=None>,
#  <Caption start='00:12:34.977' end='00:12:42.097' text='au courant\\nde la semaine prochaine.' identifier=None>,
#  <Caption start='00:12:42.097' end='00:12:43.577' text='-De la prison ferme' identifier=None>,
#  <Caption start='00:12:43.577' end='00:12:47.457' text="pour l'ex-entraîneur de foot\\net avocat à Neuchâtel." identifier=None>,
#  <Caption start='00:12:47.457' end='00:12:50.617' text='Il passera une année\\nderrière les barreaux' identifier=None>,
#  <Caption start='00:12:50.697' end='00:12:52.297' text='pour des actes sexuels sur mineurs.' identifier=None>,
#  <Caption start='00:12:52.377' end='00:12:53.857' text='Une peine alourdie en appel.' identifier=None>,
#  <Caption start='00:12:55.497' end='00:12:58.137' text='-34 mois de prison dont 12 fermes\\net une interdiction à vie' identifier=None>,
#  <Caption start='00:12:58.217' end='00:13:00.138' text="d'exercer toute activité\\nauprès de mineurs." identifier=None>,
#  <Caption start='00:13:00.218' end='00:13:03.378' text='Cet avocat et ex-entraîneur de foot\\ncondamné pour contrainte sexuelle' identifier=None>,
#  <Caption start='00:13:03.458' end='00:13:06.618' text="et actes d'ordre sexuel\\navec des enfants." identifier=None>,
#  <Caption start='00:13:06.698' end='00:13:09.818' text='Les faits datent de 2017 à 2020.' identifier=None>,
#  <Caption start='00:13:09.898' end='00:13:11.898' text="L'entraîneur rencontre\\ndes adolescents" identifier=None>,
#  <Caption start='00:13:11.978' end='00:13:14.058' text='dans le cadre du football\\nà La Chaux-de-Fonds.' identifier=None>,
#  <Caption start='00:13:14.138' end='00:13:16.658' text='Les jeunes sont en difficulté\\nscolaire ou familiale,' identifier=None>,
#  <Caption start='00:13:16.738' end='00:13:20.058' text='il les engage dans son étude\\ncomme stagiaires ou apprentis.' identifier=None>,
#  <Caption start='00:13:20.138' end='00:13:22.098' text='Il leur offre des cadeaux.' identifier=None>,
#  <Caption start='00:13:22.178' end='00:13:26.219' text="Parfois, les jeunes dorment\\nchez l'avocat qui leur demande" identifier=None>,
#  <Caption start='00:13:26.339' end='00:13:29.019' text='de se déshabiller\\nou se doucher devant lui.' identifier=None>,
#  <Caption start='00:13:29.099' end='00:13:32.779' text='Ils ont parfois reçu des claques\\nou des fessées,' identifier=None>,
#  <Caption start='00:13:32.819' end='00:13:36.379' text="à plusieurs reprises, l'accusé\\na touché leurs parties intimes." identifier=None>,
#  <Caption start='00:13:36.459' end='00:13:41.659' text="La Cour d'appel a revu à la hausse\\nla peine du premier procès." identifier=None>,
#  <Caption start='00:13:41.739' end='00:13:46.259' text='Soulagement des plaignants\\net de la procureure.' identifier=None>,
#  <Caption start='00:13:46.699' end='00:13:48.179' text='-Le Ministère public' identifier=None>,
#  <Caption start='00:13:48.259' end='00:13:50.099' text='est satisfait du jugement.' identifier=None>,
#  <Caption start='00:13:50.179' end='00:13:52.500' text="Il a obtenu ce qu'il avait requis," identifier=None>,
#  <Caption start='00:13:52.580' end='00:13:55.740' text='notamment sur la contrainte sexuelle.' identifier=None>,
#  <Caption start='00:13:55.820' end='00:14:00.700' text="C'était ce qui n'avait pas été retenu\\nen première instance." identifier=None>,
#  <Caption start='00:14:00.980' end='00:14:04.980' text='-Du côté de la défense,\\non dénonce un procès émotionnel' identifier=None>,
#  <Caption start='00:14:05.060' end='00:14:08.300' text='et trop de poids accordé\\naux témoignages des plaignants.' identifier=None>,
#  <Caption start='00:14:08.580' end='00:14:10.220' text='-Très sévère,' identifier=None>,
#  <Caption start='00:14:10.300' end='00:14:12.020' text="j'ai le sentiment" identifier=None>,
#  <Caption start='00:14:12.100' end='00:14:16.901' text="qu'on se focalise\\nsur la parole des plaignants," identifier=None>,
#  <Caption start='00:14:16.981' end='00:14:23.061' text="qui est importante,\\nmais qu'on occulte la défense." identifier=None>,
#  <Caption start='00:14:23.541' end='00:14:27.781' text='-La défense a annoncé faire recours\\nauprès du Tribunal fédéral.' identifier=None>,
#  <Caption start='00:14:29.061' end='00:14:31.861' text='-La Cour internationale de justice\\nordonne à Israël' identifier=None>,
#  <Caption start='00:14:31.941' end='00:14:35.181' text="d'arrêter immédiatement\\nson offensive militaire à Rafah." identifier=None>,
#  <Caption start='00:14:35.261' end='00:14:38.461' text='Une ordonnance juridiquement\\ncontraignante,' identifier=None>,
#  <Caption start='00:14:38.541' end='00:14:48.302' text="mais que la Cour n'a aucun moyen\\nde faire respecter." identifier=None>,
#  <Caption start='00:14:50.582' end='00:14:52.702' text='Près des élections européennes,' identifier=None>,
#  <Caption start='00:14:52.782' end='00:14:56.702' text='le parti allemand AfD\\nmis sur la touche à Bruxelles.' identifier=None>,
#  <Caption start='00:14:56.782' end='00:15:00.262' text='Sa tête de liste\\ncumule les dérapages,' identifier=None>,
#  <Caption start='00:15:00.342' end='00:15:05.582' text="comme estimer qu'un nazi n'est\\npas automatiquement un criminel." identifier=None>,
#  <Caption start='00:15:05.662' end='00:15:12.663' text="L'extrême droite italienne\\net française a condamné ces propos." identifier=None>,
#  <Caption start='00:15:14.383' end='00:15:17.023' text="-Maximilian Krah est l'acteur\\ndu dernier épisode" identifier=None>,
#  <Caption start='00:15:17.103' end='00:15:18.663' text="d'une série de scandales," identifier=None>,
#  <Caption start='00:15:18.743' end='00:15:23.343' text="eurodéputé et candidat du parti\\nd'extrême droite allemand (AfD)" identifier=None>,
#  <Caption start='00:15:23.423' end='00:15:26.103' text='aux élections européennes\\nle mois prochain.' identifier=None>,
#  <Caption start='00:15:26.183' end='00:15:31.023' text='Dans une interview récente,\\nses propos ont choqué.' identifier=None>,
#  <Caption start='00:15:39.144' end='00:15:40.544' text='Des propos inadmissibles' identifier=None>,
#  <Caption start='00:15:40.624' end='00:15:42.984' text='même pour le Rassemblement\\nNational et la Lega,' identifier=None>,
#  <Caption start='00:15:43.064' end='00:15:45.624' text="les partis d'extrême droite\\nfrançais et italien." identifier=None>,
#  <Caption start='00:15:45.704' end='00:15:48.504' text="Ils ont annoncé\\nleur rupture avec l'AfD." identifier=None>,
#  <Caption start='00:15:48.584' end='00:15:51.584' text='Hier, le groupe qui les fédérait\\nau Parlement européen,' identifier=None>,
#  <Caption start='00:15:51.664' end='00:15:59.545' text="annonce l'exclusion\\nde M.Krah et de ses 8 collègues." identifier=None>,
#  <Caption start='00:15:59.945' end='00:16:05.665' text='-Nous allons maintenant' identifier=None>,
#  <Caption start='00:16:05.705' end='00:16:07.625' text='mener une campagne intensive' identifier=None>,
#  <Caption start='00:16:07.705' end='00:16:10.465' text='pendant deux semaines\\net nous veillerons à regagner' identifier=None>,
#  <Caption start='00:16:10.545' end='00:16:12.745' text='la confiance\\nde nos partenaires internationaux.' identifier=None>,
#  <Caption start='00:16:12.825' end='00:16:15.705' text='Et nous serons\\nà nouveau membres du groupe.' identifier=None>,
#  <Caption start='00:16:16.145' end='00:16:18.745' text="-C'est tout le parti\\nqui crée le malaise." identifier=None>,
#  <Caption start='00:16:18.825' end='00:16:20.625' text='En janvier,\\nla presse révélait' identifier=None>,
#  <Caption start='00:16:20.705' end='00:16:24.266' text="une réunion secrète\\nde partis identitaires, dont l'AfD." identifier=None>,
#  <Caption start='00:16:24.346' end='00:16:27.186' text="L'un des thèmes abordés:" identifier=None>,
#  <Caption start='00:16:27.266' end='00:16:29.906' text="un projet\\nd'expulsion massive d'Allemagne" identifier=None>,
#  <Caption start='00:16:29.986' end='00:16:32.626' text="de personnes étrangères\\nou d'origine étrangère." identifier=None>,
#  <Caption start='00:16:32.706' end='00:16:36.626' text="A l'époque, le Rassemblement\\nNational avait pris ses distances." identifier=None>,
#  <Caption start='00:16:37.026' end='00:16:38.626' text='-Je considère que nous avons' identifier=None>,
#  <Caption start='00:16:38.746' end='00:16:40.866' text="une opposition flagrante avec l'AfD" identifier=None>,
#  <Caption start='00:16:40.946' end='00:16:50.307' text='et nous serons amenés à discuter\\nde divergences aussi importantes.' identifier=None>,
#  <Caption start='00:16:50.907' end='00:16:57.227' text="-M.Krah est soupçonné d'avoir touché\\ndes financements russes et chinois." identifier=None>,
#  <Caption start='00:16:57.307' end='00:16:59.747' text="L'un de ses assistants a été arrêté," identifier=None>,
#  <Caption start='00:16:59.827' end='00:17:02.827' text="accusé d'avoir espionné\\npour le compte de Pékin." identifier=None>,
#  <Caption start='00:17:04.427' end='00:17:07.107' text='-Les élections européennes\\nsont dans deux semaines.' identifier=None>,
#  <Caption start='00:17:07.187' end='00:17:09.787' text="On parle beaucoup\\nde la montée de l'extrême droite." identifier=None>,
#  <Caption start='00:17:09.867' end='00:17:10.987' text='Isabelle Ory,' identifier=None>,
#  <Caption start='00:17:11.067' end='00:17:18.708' text="Maximilian Krah est-il en train\\nde faire exploser l'extrême droite ?" identifier=None>,
#  <Caption start='00:17:18.708' end='00:17:21.428' text="-Cette crise entre l'AfD" identifier=None>,
#  <Caption start='00:17:21.588' end='00:17:25.108' text='et ses\\ndeux grands partenaires européens,' identifier=None>,
#  <Caption start='00:17:25.108' end='00:17:28.388' text='le Rassemblement National et la Lega,' identifier=None>,
#  <Caption start='00:17:28.388' end='00:17:31.388' text='vient rappeler à quel point' identifier=None>,
#  <Caption start='00:17:31.388' end='00:17:34.668' text="l'extrême droite européenne\\nest hétérogène." identifier=None>,
#  <Caption start='00:17:34.668' end='00:17:38.988' text='Ces derniers temps,\\non a parlé de la montée en puissance' identifier=None>,
#  <Caption start='00:17:38.988' end='00:17:41.469' text='de ces formations dans les pays.' identifier=None>,
#  <Caption start='00:17:41.469' end='00:17:43.829' text='Quand on agrège les résultats,' identifier=None>,
#  <Caption start='00:17:43.829' end='00:17:48.829' text='ils peuvent obtenir 25 % des sièges\\ndu futur Parlement européen.' identifier=None>,
#  <Caption start='00:17:48.989' end='00:17:50.829' text='Les différences' identifier=None>,
#  <Caption start='00:17:50.989' end='00:17:56.629' text='entre ces différents partis\\nétaient passées au second plan.' identifier=None>,
#  <Caption start='00:17:56.789' end='00:18:01.669' text='Par exemple, les Hongrois de Viktor\\nOrban sont trop pro-russes,' identifier=None>,
#  <Caption start='00:18:01.669' end='00:18:05.509' text='Marine Le Pen est trop radicale pour\\nViktor Orban,' identifier=None>,
#  <Caption start='00:18:05.509' end='00:18:09.750' text="maintenant, l'AfD est trop radicale\\npour Marine Le Pen." identifier=None>,
#  <Caption start='00:18:09.910' end='00:18:13.070' text="Oui, la droite dure séduit\\nde plus en plus d'électeurs." identifier=None>,
#  <Caption start='00:18:13.230' end='00:18:20.750' text='Elle aura un droit de nuisance\\npour bloquer certaines lois.' identifier=None>,
#  <Caption start='00:18:20.750' end='00:18:24.990' text="Mais elle n'est pas suffisamment unie" identifier=None>,
#  <Caption start='00:18:24.990' end='00:18:31.991' text='pour espérer imposer une ligne\\npolitique au niveau européen.' identifier=None>,
#  <Caption start='00:18:31.991' end='00:18:37.791' text='-A une semaine de la fin de son\\nprocès à New York,' identifier=None>,
#  <Caption start='00:18:37.871' end='00:18:39.871' text='D.Trump en profite\\npour aller dans le Bronx.' identifier=None>,
#  <Caption start='00:18:39.951' end='00:18:42.311' text='Le candidat républicain\\nva chercher des électeurs' identifier=None>,
#  <Caption start='00:18:42.391' end='00:18:46.831' text='sur un terrain acquis aux démocrates.' identifier=None>,
#  <Caption start='00:18:48.351' end='00:18:52.231' text='-Trump, we love you !' identifier=None>,
#  <Caption start='00:18:52.311' end='00:18:54.591' text='-La scène est inattendue.' identifier=None>,
#  <Caption start='00:18:54.671' end='00:18:58.352' text="Le cirque trumpiste s'arrête\\ndans le Bronx." identifier=None>,
#  <Caption start='00:18:58.432' end='00:19:02.272' text='Le républicain, critiqué\\nlors des émeutes raciales de 2020,' identifier=None>,
#  <Caption start='00:19:02.352' end='00:19:04.432' text='trouve ici un public.' identifier=None>,
#  <Caption start='00:19:04.952' end='00:19:06.792' text='-On peut être en désaccord' identifier=None>,
#  <Caption start='00:19:06.872' end='00:19:08.192' text='avec certaines choses,' identifier=None>,
#  <Caption start='00:19:08.272' end='00:19:09.592' text='mais il est dans le Bronx.' identifier=None>,
#  <Caption start='00:19:09.672' end='00:19:12.272' text="C'est le premier candidat à venir\\ndepuis Ronald Reagan." identifier=None>,
#  <Caption start='00:19:12.632' end='00:19:14.792' text='-Le procès qui se déroule\\nà Manhattan' identifier=None>,
#  <Caption start='00:19:14.872' end='00:19:16.672' text='est loin des préoccupations.' identifier=None>,
#  <Caption start='00:19:16.752' end='00:19:20.632' text="Certains s'apprêtent à voter\\nrépublicain pour la première fois." identifier=None>,
#  <Caption start='00:19:20.872' end='00:19:24.273' text='-Les prix montent, les impôts aussi.' identifier=None>,
#  <Caption start='00:19:24.353' end='00:19:26.753' text='Tout ne va pas changer sous Trump,' identifier=None>,
#  <Caption start='00:19:26.833' end='00:19:31.073' text="mais espérons qu'il pourra\\nsecouer les choses !" identifier=None>,
#  <Caption start='00:19:31.353' end='00:19:34.953' text="-Devant ce public plus bigarré\\net plus jeune que d'habitude," identifier=None>,
#  <Caption start='00:19:35.033' end='00:19:38.793' text='le candidat tient\\nun discours plus rassembleur.' identifier=None>,
#  <Caption start='00:19:39.113' end='00:19:41.793' text="-Ca n'a aucune importance" identifier=None>,
#  <Caption start='00:19:41.873' end='00:19:43.313' text='que vous soyez noirs,' identifier=None>,
#  <Caption start='00:19:43.393' end='00:19:44.673' text='bruns ou blancs.' identifier=None>,
#  <Caption start='00:19:44.753' end='00:19:50.354' text="Nous sommes tous américains\\net on va s'en sortir ensemble." identifier=None>,
#  <Caption start='00:19:50.634' end='00:19:53.314' text="-Plus qu'une simple provocation" identifier=None>,
#  <Caption start='00:19:53.394' end='00:19:55.314' text="pour détourner l'attention" identifier=None>,
#  <Caption start='00:19:55.394' end='00:19:59.234' text="de son procès, cette apparition\\nfait partie d'une stratégie" identifier=None>,
#  <Caption start='00:19:59.354' end='00:20:02.954' text='du candidat républicain\\npour séduire les minorités.' identifier=None>,
#  <Caption start='00:20:03.034' end='00:20:06.354' text="Le Bronx, quartier qui compte\\nle plus d'électeurs pauvres" identifier=None>,
#  <Caption start='00:20:06.434' end='00:20:10.274' text='et issus des minorités,\\navait voté pour Joe Biden en 2020.' identifier=None>,
#  <Caption start='00:20:10.834' end='00:20:16.115' text="-Il m'a donné la chance d'être ici,\\nalors je soutiens l'oncle Biden." identifier=None>,
#  <Caption start='00:20:16.195' end='00:20:20.315' text='Il a permis à notre famille\\nde rester aux Etats-Unis.' identifier=None>,
#  <Caption start='00:20:20.555' end='00:20:22.555' text="-Mais ici, on n'a pas ressenti" identifier=None>,
#  <Caption start='00:20:22.635' end='00:20:25.075' text="les bons chiffres\\nde l'économie américaine." identifier=None>,
#  <Caption start='00:20:25.315' end='00:20:28.235' text="-Quand Trump était au pouvoir,\\nil y avait plus d'emplois," identifier=None>,
#  <Caption start='00:20:28.275' end='00:20:30.275' text='moins de chômage.' identifier=None>,
#  <Caption start='00:20:30.355' end='00:20:33.155' text='-Je ne voterai pas cette année.' identifier=None>,
#  <Caption start='00:20:33.235' end='00:20:38.475' text='Avec Biden,\\nje ne vois aucun changement.' identifier=None>,
#  <Caption start='00:20:38.555' end='00:20:44.516' text='Et Trump est trop raciste à mon avis.' identifier=None>,
#  <Caption start='00:20:44.916' end='00:20:47.996' text='-Les républicains ne gagneront\\nsans doute pas dans le Bronx,' identifier=None>,
#  <Caption start='00:20:48.076' end='00:20:49.996' text='mais pour les démocrates,' identifier=None>,
#  <Caption start='00:20:50.076' end='00:20:52.276' text="le vote des minorités\\nest loin d'être acquis." identifier=None>,
#  <Caption start='00:20:53.996' end='00:20:56.276' text='-La SSR lance un sondage national' identifier=None>,
#  <Caption start='00:20:56.356' end='00:20:58.916' text='pour prendre le pouls\\nde la population suisse.' identifier=None>,
#  <Caption start='00:20:58.996' end='00:21:02.756' text='Le nom de cette enquête:\\n"Comment ça va la Suisse ?"' identifier=None>,
#  <Caption start='00:21:02.836' end='00:21:07.797' text='On attend vos réponses !' identifier=None>,
#  <Caption start='00:21:09.157' end='00:21:12.437' text="-Pas besoin d'être journaliste\\npour poser cette question." identifier=None>,
#  <Caption start='00:21:12.517' end='00:21:15.837' text='-Comment allez-vous ?\\n-Super bien.' identifier=None>,
#  <Caption start='00:21:15.917' end='00:21:21.117' text='-Notre média de service public\\nveut poursuivre ce dialogue.' identifier=None>,
#  <Caption start='00:21:21.197' end='00:21:24.677' text="C'est pourquoi la SSR lance\\nle 2ème volet de l'enquête" identifier=None>,
#  <Caption start='00:21:24.757' end='00:21:26.837' text='"Comment ça va la Suisse ?".' identifier=None>,
#  <Caption start='00:21:26.917' end='00:21:34.358' text='Un nouveau sondage est en ligne\\nsur www.rts.ch/info/dialogue/:' identifier=None>,
#  <Caption start='00:21:34.438' end='00:21:42.478' text="290 questions d'actualité\\nsur l'éducation, la politique" identifier=None>,
#  <Caption start='00:21:42.558' end='00:21:47.878' text='et le travail,\\ndéjà présentées au printemps 2023.' identifier=None>,
#  <Caption start='00:21:47.958' end='00:21:54.518' text='Objectif: brosser le portrait de\\nla Suisse et mesurer son évolution.' identifier=None>,
#  <Caption start='00:21:54.598' end='00:21:58.639' text='Archives\\n-Quelle est la qualité principale' identifier=None>,
#  <Caption start='00:21:58.719' end='00:21:59.999' text='des Suisses ?' identifier=None>,
#  <Caption start='00:22:00.079' end='00:22:03.799' text='42 % répondent "travailleurs".' identifier=None>,
#  <Caption start='00:22:03.879' end='00:22:09.719' text="-L'an dernier, 50'000 personnes\\nont participé au sondage." identifier=None>,
#  <Caption start='00:22:09.959' end='00:22:12.639' text="-C'est important de comprendre," identifier=None>,
#  <Caption start='00:22:12.719' end='00:22:14.839' text="d'être proche de notre public," identifier=None>,
#  <Caption start='00:22:14.879' end='00:22:19.279' text='de comprendre les sujets\\nqui les occupent,' identifier=None>,
#  <Caption start='00:22:19.359' end='00:22:26.600' text='ça nous permet de faire\\ndu journalisme pertinent.' identifier=None>,
#  <Caption start='00:22:26.880' end='00:22:30.120' text='-Impossible de conclure\\nsans poser cette question.' identifier=None>,
#  <Caption start='00:22:30.200' end='00:22:33.880' text='-Comment va la Suisse ?\\n-Bien, en général.' identifier=None>,
#  <Caption start='00:22:33.960' end='00:22:38.040' text='-Et vous ?\\n-Très bien, merci.' identifier=None>,
#  <Caption start='00:22:39.560' end='00:22:44.880' text='-Neige Sinno a reçu\\nle Choix Goncourt de la Suisse.' identifier=None>,
#  <Caption start='00:22:44.960' end='00:22:49.801' text='Son livre sur l\'inceste\\n"Triste Tigre" a été le plus encensé' identifier=None>,
#  <Caption start='00:22:49.881' end='00:22:52.041' text='de la saison littéraire.' identifier=None>,
#  <Caption start='00:22:57.681' end='00:23:01.921' text='-Une standing ovation\\ndans une salle pleine,' identifier=None>,
#  <Caption start='00:23:02.001' end='00:23:07.921' text='une preuve du succès\\nde "Triste Tigre" de Neige Sinno,' identifier=None>,
#  <Caption start='00:23:08.001' end='00:23:13.482' text="qui a raflé des dizaines de prix et\\ns'est vendu à 300'000 exemplaires." identifier=None>,
#  <Caption start='00:23:14.362' end='00:23:16.522' text='-"Triste Tigre"\\nne laisse pas indemne,' identifier=None>,
#  <Caption start='00:23:16.602' end='00:23:21.922' text='il y a un avant et un après.' identifier=None>,
#  <Caption start='00:23:22.202' end='00:23:25.802' text="-Hier, l'autrice a reçu\\nle Choix Goncourt de la Suisse," identifier=None>,
#  <Caption start='00:23:25.882' end='00:23:30.362' text='prix décerné par les étudiants\\nde 9 universités et hautes écoles.' identifier=None>,
#  <Caption start='00:23:30.442' end='00:23:33.922' text='"Triste Tigre"\\nest un ovni littéraire,' identifier=None>,
#  <Caption start='00:23:34.002' end='00:23:37.522' text="alternant entre le récit\\nde l'inceste subi par N.Sinno" identifier=None>,
#  <Caption start='00:23:37.602' end='00:23:42.123' text="et des extraits de romans\\net poèmes qu'elle invoque" identifier=None>,
#  <Caption start='00:23:42.203' end='00:23:45.243' text="pour expliquer ce qu'elle a subi." identifier=None>,
#  <Caption start='00:23:45.523' end='00:23:47.723' text="-C'est très riche." identifier=None>,
#  <Caption start='00:23:47.803' end='00:23:55.923' text='-Comment peut-on écrire de manière\\nsi sublime une chose si terrible ?' identifier=None>,
#  <Caption start='00:23:56.283' end='00:23:57.923' text='-Je voulais que ce soit' identifier=None>,
#  <Caption start='00:23:58.003' end='00:24:01.483' text='comme une pensée spontanée.' identifier=None>,
#  <Caption start='00:24:01.563' end='00:24:05.404' text="J'observe ce qui se passe\\ndans ma tête quand j'y réfléchis" identifier=None>,
#  <Caption start='00:24:05.484' end='00:24:08.564' text='et je traduis ça en texte.' identifier=None>,
#  <Caption start='00:24:08.804' end='00:24:12.324' text='-Un livre que N.Sinno ne voulait\\npas écrire, dans lequel elle avoue' identifier=None>,
#  <Caption start='00:24:12.404' end='00:24:14.884' text="souhaiter qu'il ne soit pas lu." identifier=None>,
#  <Caption start='00:24:15.204' end='00:24:17.844' text="-Je veux que personne ne sache\\nque j'ai été violée," identifier=None>,
#  <Caption start='00:24:17.924' end='00:24:25.884' text="mais j'ai écrit à mes amis\\nque c'était une petite bombe" identifier=None>,
#  <Caption start='00:24:25.964' end='00:24:32.445' text='qui ferait tout imploser.' identifier=None>,
#  <Caption start='00:24:32.525' end='00:24:37.245' text="J'avais donc aussi ce désir\\nque tout le monde lise ça." identifier=None>,
#  <Caption start='00:24:37.525' end='00:24:40.285' text='-"Je frotte mes assiettes rageusement' identifier=None>,
#  <Caption start='00:24:40.365' end='00:24:45.045' text='et je pense à la phrase\\nque je pourrais dire."' identifier=None>,
#  <Caption start='00:24:45.125' end='00:24:48.965' text='"Il me viole\\ndepuis que je suis petite."' identifier=None>,
#  <Caption start='00:24:49.445' end='00:24:52.925' text='-"Triste Tigre" sera traduit\\nen plus de 20 langues.' identifier=None>,
#  <Caption start='00:24:52.965' end='00:24:56.646' text="La bombe de N.Sinno\\nn'a pas fini d'exploser." identifier=None>,
#  <Caption start='00:24:58.246' end='00:25:01.286' text="-Elles ont fasciné\\ndes générations d'archéologues." identifier=None>,
#  <Caption start='00:25:01.406' end='00:25:05.246' text='Vous vous êtes peut-être déjà demandé' identifier=None>,
#  <Caption start='00:25:05.326' end='00:25:08.006' text='comment les pyramides\\nont été construites,' identifier=None>,
#  <Caption start='00:25:08.086' end='00:25:11.126' text="alors qu'elles sont en plein désert ?" identifier=None>,
#  <Caption start='00:25:11.206' end='00:25:13.366' text='Réponse !' identifier=None>,
#  <Caption start='00:25:15.126' end='00:25:18.686' text='-Elles ne sont pas avares\\nen mystères:' identifier=None>,
#  <Caption start='00:25:18.766' end='00:25:21.607' text='chambres secrètes, trésors cachés...' identifier=None>,
#  <Caption start='00:25:21.687' end='00:25:25.047' text="L'emplacement des pyramides\\nintrigue aussi." identifier=None>,
#  <Caption start='00:25:25.047' end='00:25:27.207' text='Depuis le plateau de Gizeh,' identifier=None>,
#  <Caption start='00:25:27.207' end='00:25:30.167' text='beaucoup sont alignées\\ndans le désert.' identifier=None>,
#  <Caption start='00:25:30.247' end='00:25:34.167' text='A des kilomètres du Nil actuel,\\nligne de vie du pays,' identifier=None>,
#  <Caption start='00:25:34.247' end='00:25:36.407' text="comme à l'époque des pharaons." identifier=None>,
#  <Caption start='00:25:36.487' end='00:25:39.367' text='Mais des scientifiques ont découvert\\nun bras asséché du Nil,' identifier=None>,
#  <Caption start='00:25:39.447' end='00:25:41.527' text='qui passait au pied des monuments.' identifier=None>,
#  <Caption start='00:25:41.607' end='00:25:44.967' text='De quoi acheminer par bateau\\nles blocs pour les ériger.' identifier=None>,
#  <Caption start='00:25:45.047' end='00:25:48.568' text='Les images radar permettent\\nde traquer dans le sous-sol' identifier=None>,
#  <Caption start='00:25:48.648' end='00:25:54.328' text="les sédiments du lit d'un ancien\\nfleuve, recouvert par le sable." identifier=None>,
#  <Caption start='00:25:54.408' end='00:25:58.248' text="Des mesures confirmées\\npar l'extraction de terre." identifier=None>,
#  <Caption start='00:25:58.328' end='00:26:02.848' text='Comme souvent en égyptologie,\\ncette découverte est discutée.' identifier=None>,
#  <Caption start='00:26:03.808' end='00:26:05.808' text='-On savait déjà des choses.' identifier=None>,
#  <Caption start='00:26:05.888' end='00:26:08.368' text="On soupçonnait l'existence\\nde ce canal." identifier=None>,
#  <Caption start='00:26:08.448' end='00:26:09.928' text='Ce qui est nouveau,' identifier=None>,
#  <Caption start='00:26:10.008' end='00:26:12.009' text='ce sont les images satellite,' identifier=None>,
#  <Caption start='00:26:12.089' end='00:26:17.889' text="qui permettent d'évaluer l'ampleur\\nde cette branche du Nil" identifier=None>,
#  <Caption start='00:26:17.969' end='00:26:22.649' text='et de confirmer certaines hypothèses.' identifier=None>,
#  <Caption start='00:26:25.809' end='00:26:29.089' text='-Des blocs transportés par bateau:\\nplusieurs bas-reliefs le montrent.' identifier=None>,
#  <Caption start='00:26:29.169' end='00:26:30.649' text="L'idée est entérinée en 2013" identifier=None>,
#  <Caption start='00:26:30.729' end='00:26:33.169' text='par la découverte\\ndes papyrus de la mer Rouge.' identifier=None>,
#  <Caption start='00:26:33.249' end='00:26:36.649' text='Un chapitre y décrit le quotidien\\ndes bâtisseurs de pyramides.' identifier=None>,
#  <Caption start='00:26:45.970' end='00:26:48.370' text='Une grande pyramide accessible\\npar un port,' identifier=None>,
#  <Caption start='00:26:48.450' end='00:26:50.850' text="comme l'ont montré des sondages\\nen 2022." identifier=None>,
#  <Caption start='00:26:50.930' end='00:26:54.850' text='A Saqqarah, les chercheurs\\nont constaté que les débarcadères' identifier=None>,
#  <Caption start='00:26:54.930' end='00:26:57.930' text="collaient à l'emplacement\\ndu fleuve asséché." identifier=None>,
#  <Caption start='00:26:59.330' end='00:27:01.890' text='-Les Egyptiens\\nétaient très astucieux,' identifier=None>,
#  <Caption start='00:27:01.970' end='00:27:04.411' text='très pragmatiques aussi.' identifier=None>,
#  <Caption start='00:27:04.491' end='00:27:06.091' text="C'était la loi du moindre effort." identifier=None>,
#  <Caption start='00:27:06.171' end='00:27:08.011' text='Ils ont utilisé leur environnement' identifier=None>,
#  <Caption start='00:27:08.091' end='00:27:10.971' text='pour construire les pyramides.' identifier=None>,
#  <Caption start='00:27:11.051' end='00:27:16.731' text='Ils ne subissent pas seulement\\nles aléas de la géologie.' identifier=None>,
#  <Caption start='00:27:16.851' end='00:27:21.211' text="Ils dominaient leur territoire\\net savaient ce qu'ils faisaient." identifier=None>,
#  <Caption start='00:27:21.731' end='00:27:24.331' text='-Un territoire balisé\\navec ce Nil asséché,' identifier=None>,
#  <Caption start='00:27:24.451' end='00:27:28.812' text='que les égyptologues pourront\\nexplorer de manière ciblée.' identifier=None>,
#  <Caption start='00:27:30.292' end='00:27:32.612' text='-Tennis, surprise au Geneva Open !' identifier=None>,
#  <Caption start='00:27:32.692' end='00:27:35.172' text="Novak Djokovic s'est incliné\\nen demi-finale." identifier=None>,
#  <Caption start='00:27:35.252' end='00:27:40.652' text='Le numéro un mondial a été battu\\n6-4, 0-6, 6-1 par Tomas Machac' identifier=None>,
#  <Caption start='00:27:40.732' end='00:27:43.012' text="au terme d'un match décousu." identifier=None>,
#  <Caption start='00:27:43.092' end='00:27:45.412' text="Le Serbe dit\\navoir des problèmes d'estomac" identifier=None>,
#  <Caption start='00:27:45.492' end='00:27:48.892' text='et ne pas être rassuré\\navant Roland-Garros.' identifier=None>,
#  <Caption start='00:27:48.932' end='00:27:53.692' text='Tomas Machac participera demain\\nà sa première finale ATP.' identifier=None>,
#  <Caption start='00:27:55.093' end='00:27:58.773' text='A 60 ans, Lenny Kravitz\\nsort un douzième album.' identifier=None>,
#  <Caption start='00:27:58.853' end='00:28:09.813' text='"Blue Electric Light" ne déroge pas\\nà l\'icône rock qu\'il a toujours été.' identifier=None>,
#  <Caption start='00:28:12.933' end='00:28:17.133' text="-Le temps n'a pas d'effet sur lui." identifier=None>,
#  <Caption start='00:28:17.213' end='00:28:24.854' text='Lenny Kravitz en joue\\nentre glam et rock.' identifier=None>,
#  <Caption start='00:28:24.934' end='00:28:32.094' text='A deux jours de ses 60 ans,\\nil sort son 12ème album:' identifier=None>,
#  <Caption start='00:28:32.174' end='00:28:34.774' text='"Blue Electric Light".' identifier=None>,
#  <Caption start='00:28:34.854' end='00:28:38.814' text='Rock' identifier=None>,
#  <Caption start='00:28:39.134' end='00:28:40.894' text='-"Blue Electric Light",' identifier=None>,
#  <Caption start='00:28:40.974' end='00:28:43.054' text="c'est l'énergie, l'amour," identifier=None>,
#  <Caption start='00:28:43.134' end='00:28:47.215' text="la spiritualité, l'humanité." identifier=None>,
#  <Caption start='00:28:47.295' end='00:28:54.575' text="C'est cette énergie qui me nourrit." identifier=None>,
#  <Caption start='00:28:55.375' end='00:28:59.815' text="-Une énergie funk, soul et rock,\\ntoutes ces musiques qu'il vampirise" identifier=None>,
#  <Caption start='00:28:59.895' end='00:29:02.255' text='depuis ses débuts en 1989.' identifier=None>,
#  <Caption start='00:29:02.335' end='00:29:09.375' text="Il n'a rien inventé, mais\\ntransforme en pépite ce qui existe." identifier=None>,
#  <Caption start='00:29:09.455' end='00:29:15.336' text='Lenny Kravitz\\n"Are you gonna go my way"' identifier=None>,
#  <Caption start='00:29:15.416' end='00:29:21.136' text='Lenny Kravitz\\n"American woman"' identifier=None>,
#  <Caption start='00:29:21.216' end='00:29:27.776' text='Lenny Kravitz\\n"Fly Away"' identifier=None>,
#  <Caption start='00:29:28.336' end='00:29:31.416' text="-Je n'ai jamais essayé\\nde faire un tube." identifier=None>,
#  <Caption start='00:29:31.536' end='00:29:33.416' text="J'attends: quand ça vient, ça vient." identifier=None>,
#  <Caption start='00:29:33.496' end='00:29:37.617' text="J'utilise mes talents:" identifier=None>,
#  <Caption start='00:29:37.697' end='00:29:40.857' text='jouer plusieurs instruments,\\nproduire, faire les arrangements.' identifier=None>,
#  <Caption start='00:29:42.177' end='00:29:47.137' text="-Lenny Kravitz, l'un des derniers\\ngardiens du temple rock," identifier=None>,
#  <Caption start='00:29:47.217' end='00:29:50.217' text='une star qui fait du bien.' identifier=None>,
#  <Caption start='00:29:50.297' end='00:29:55.577' text="Son concert au Montreux Jazz cet été\\nest d'ailleurs complet." identifier=None>,
#  <Caption start='00:30:07.298' end='00:30:09.778' text="-C'est la fin de ce journal,\\nmerci de l'avoir suivi." identifier=None>,
#  <Caption start='00:30:09.858' end='00:30:12.258' text='Tout de suite, la météo,\\npuis "Bye bye la Suisse".' identifier=None>,
#  <Caption start='00:30:12.338' end='00:30:14.658' text='Très belle soirée sur la RTS !' identifier=None>,
#  <Caption start='00:30:14.778' end='00:30:18.338' text='Sous-titrage SWISS TXT\\nL.Campbell, N.Farag, A.Giddey,\\nA.Kosakevitch, J.Szucs' identifier=None>]

# %%
transcript[18].start
# Out:
# '00:01:16.150'

# %%
# Out:
# 212

# %%
start = transcript[relevant_clip_topics[key]["start_idx"]].start_in_seconds
[f"start: {x.start_in_seconds - start} end: {x.end_in_seconds - start} text: {x.text}" for x in transcript[relevant_clip_topics[key]["start_idx"]:relevant_clip_topics[key]["end_idx"]]]
# Out:
# ['start: 0 end: 3 text: -Martin Vetterli, bonsoir.',
#  'start: 3 end: 9 text: Le Temps révèle que des étudiants\nde votre établissement',
#  'start: 9 end: 15 text: sont harcelés car ils pensent\ndifféremment, et parlent de paix.',
#  'start: 15 end: 22 text: Un étudiant est menacé de mort\nsur les réseaux sociaux:',
#  'start: 22 end: 25 text: "il faut tuer Nicolas et son gang".',
#  'start: 25 end: 29 text: Une autre est intimidée:\n"on a vu où tu étais assise".',
#  'start: 29 end: 32 text: Quelle est votre réaction ?',
#  'start: 32 end: 34 text: - Je suis très triste',
#  "start: 34 end: 38 text: qu'il y a une telle tension\nsur le campus.",
#  'start: 38 end: 42 text: Ce sont les excès\ndes réseaux sociaux.',
#  "start: 42 end: 46 text: Si on n'est pas dans le cadre légal,",
#  "start: 46 end: 49 text: par rapport aux lois\nsur le racisme et l'antisémitisme,",
#  'start: 49 end: 53 text: on donne\nle support à notre communauté.',
#  "start: 53 end: 60 text: Nos étudiants ont des canaux où ils\npeuvent venir chercher de l'aide.",
#  'start: 60 end: 65 text: Et on prendra\nles mesures nécessaires.',
#  'start: 66 end: 69 text: Des plaintes pourront être portées.',
#  'start: 69 end: 73 text: -On entend des étudiants juifs',
#  'start: 73 end: 78 text: qui ont peur de venir sur le campus.',
#  'start: 78 end: 80 text: Leur sécurité est garantie ?',
#  "start: 80 end: 84 text: -C'est notre première priorité.",
#  'start: 84 end: 87 text: La sécurité de tous sur le campus.',
#  'start: 87 end: 92 text: On a parlé avec ces gens,\nils se sont exprimés.',
#  "start: 92 end: 96 text: Ils ont besoin d'être protégés,\ncomme tout le monde.",
#  "start: 96 end: 98 text: -Vous reconnaissez\nqu'il y a une dérive",
#  'start: 98 end: 102 text: de certains membres\ndes militants propalestiniens ?',
#  'start: 102 end: 105 text: -Il y a toujours des dérives.',
#  "start: 105 end: 111 text: Il y a un large spectre\nd'opinions sur le campus.",
#  'start: 111 end: 115 text: Notre mission\nest de garder une unité.',
#  'start: 115 end: 118 text: -Comment on en est arrivé là ?',
#  'start: 118 end: 123 text: Y a-t-il aussi une responsabilité\nde la part des grandes écoles',
#  'start: 123 end: 127 text: de laisser entrer ces discussions\npolitiques sur le campus ?',
#  "start: 127 end: 131 text: L'université ne doit-elle\npas être totalement neutre ?",
#  "start: 131 end: 135 text: -L'université en tant qu'institution\ndoit rester neutre",
#  'start: 135 end: 137 text: pour permettre un débat.',
#  "start: 137 end: 141 text: Mais chacun est un être humain\nqui peut s'exprimer en son nom.",
#  "start: 141 end: 143 text: Il ne faut pas\nqu'il y ait de dérive.",
#  "start: 144 end: 149 text: Il ne faut pas qu'il y ait le genre\nd'excès dont vous avez parlé.",
#  'start: 150 end: 154 text: -On a atteint\nà ce niveau-là du rouge.',
#  "start: 154 end: 160 text: Qu'est-ce que vous allez faire\npour remettre de l'ordre ?",
#  "start: 160 end: 163 text: -On n'est pas dans le désordre.",
#  'start: 163 end: 166 text: Sur le campus, ça se passe bien.',
#  'start: 167 end: 172 text: Plusieurs centaines de participants\nreprésentant les étudiants,',
#  "start: 172 end: 175 text: les employés et les profs ont parlé\net ça s'est bien passé.",
#  'start: 175 end: 181 text: Tous nos canaux de soutien sont\nà disposition de toute la communauté.',
#  "start: 181 end: 186 text: -Vous appelez les étudiants\nà s'adresser à vos canaux de soutien",
#  'start: 186 end: 190 text: si quelque chose se passe.',
#  'start: 190 end: 194 text: -On a créé\nune commission spécifique.',
#  'start: 194 end: 197 text: On va regarder\nces différentes dimensions.',
#  'start: 197 end: 203 text: Cette commission\nest dirigée par ma collègue.']

# %%
relevant_clip_topics = {}
for key in topic_keys:
    relevant_clip_topics[key] = {"title": clip_topics[key]}
    relevant_clip_topics[key]["markIn"] = segment_list[key]["markIn"]/1000
    relevant_clip_topics[key]["markOut"] = segment_list[key]["markOut"]/1000
    idx = [i for i, ts in enumerate(transcript_ts) if relevant_clip_topics[key]["markIn"] <= ts <= relevant_clip_topics[key]["markOut"]]
    relevant_clip_topics[key]["start_idx"] = idx[0]
    relevant_clip_topics[key]["end_idx"] = idx[-1]+1
    relevant_clip_topics[key]["transcript"] = "".join([x.text for x in transcript[relevant_clip_topics[key]["start_idx"]:relevant_clip_topics[key]["end_idx"]]])
    start = transcript[relevant_clip_topics[key]["start_idx"]].start_in_seconds - 6
    relevant_clip_topics[key]["transcript_ts"] = "\n".join([f"start: {x.start_in_seconds - start} end: {x.end_in_seconds - start} text: {x.text}" for x in transcript[relevant_clip_topics[key]["start_idx"]:relevant_clip_topics[key]["end_idx"]]])
    relevant_clip_topics[key]["video_start"] = video_segments[relevant_clip_topics[key]["start_idx"]]
    relevant_clip_topics[key]["video_end"] = video_segments[relevant_clip_topics[key]["end_idx"]]
    relevant_clip_topics[key]["video_start_idx"] = int(relevant_clip_topics[key]["video_start"].split("seg-")[-1].split("-")[0])
    relevant_clip_topics[key]["video_end_idx"] = int(relevant_clip_topics[key]["video_end"].split("seg-")[-1].split("-")[0])
    relevant_clip_topics[key]["audio_start"] = audio_segments[relevant_clip_topics[key]["start_idx"]]
    relevant_clip_topics[key]["audio_end"] = audio_segments[relevant_clip_topics[key]["end_idx"]]
    relevant_clip_topics[key]["subtitle_start"] = subtitle_segments[relevant_clip_topics[key]["start_idx"]]
    relevant_clip_topics[key]["subtitle_end"] = subtitle_segments[relevant_clip_topics[key]["end_idx"]]

relevant_clip_topics
# Out:
# {0: {'title': "À l'EPFL, des étudiants pro-palestiniens mais modérés, menacés par les plus radicaux",
#   'markIn': 75.52,
#   'markOut': 212.72,
#   'start_idx': 18,
#   'end_idx': 49,
#   'transcript': 'Le climat est délétère à l\'EPFLsur fond de guerre\nentre Israël et le Hamas.Les étudiants qui émettent\nun avis contraireau mouvement propalestinien\nsont menacés.Des jeunes ont peur\nd\'aller sur le campus.-Si ce groupe de discussion\nsur la guerre au Moyen-Orientpar des étudiants de l\'EPFL\na été depuis supprimé,il en subsiste\nces captures d\'écran.Des menaces de mort dirigées\ncontre des étudiantsqui souhaitaient apaiser\ndes tensions.Ces révélations du journal Le Tempsdécrivent une radicalisation\nsur le campus de l\'EPFL.Cet étudiant visé ne s\'affole pas,\nmais avoue être sur ses gardes.-Une limite a été franchieparce que c\'est un événement\nqui n\'a jamais été vu sur le campus.On a peur,\non regarde un peu derrière nous.-La direction de l\'EPFL\norganisait cet après-midiune discussion\npour éviter toute escalade.Si la démarche a été saluée,\ncertains en ont profitépour remettre en doute\nle témoignage des étudiants menacés.-La première réaction dans\nl\'auditoire, c\'est "ils mentent".Ils parlent de menaces de mort,\ndonc forcément ils mentent.-Du côté\ndes manifestants propalestiniens,on condamne fermement\ntoutes attitudes discriminatoires.-Menacer de mort pour des idées\npolitiques,ce n\'est pas acceptable,\nsurtout pas dans notre école.Ca ne reflète pas\nla majorité des étudiants.-Le groupe propalestinien considèreque la direction porte\nune part de responsabilitéen limitant la liberté d\'expression.La direction de l\'EPFL doit faire\nla lumière sur ces événements.',
#   'transcript_ts': 'start: 6 end: 10 text: Le climat est délétère à l\'EPFL\nstart: 10 end: 12 text: sur fond de guerre\nentre Israël et le Hamas.\nstart: 13 end: 15 text: Les étudiants qui émettent\nun avis contraire\nstart: 15 end: 17 text: au mouvement propalestinien\nsont menacés.\nstart: 17 end: 27 text: Des jeunes ont peur\nd\'aller sur le campus.\nstart: 29 end: 32 text: -Si ce groupe de discussion\nsur la guerre au Moyen-Orient\nstart: 32 end: 35 text: par des étudiants de l\'EPFL\na été depuis supprimé,\nstart: 35 end: 38 text: il en subsiste\nces captures d\'écran.\nstart: 41 end: 43 text: Des menaces de mort dirigées\ncontre des étudiants\nstart: 43 end: 45 text: qui souhaitaient apaiser\ndes tensions.\nstart: 51 end: 53 text: Ces révélations du journal Le Temps\nstart: 53 end: 55 text: décrivent une radicalisation\nsur le campus de l\'EPFL.\nstart: 55 end: 60 text: Cet étudiant visé ne s\'affole pas,\nmais avoue être sur ses gardes.\nstart: 62 end: 63 text: -Une limite a été franchie\nstart: 63 end: 67 text: parce que c\'est un événement\nqui n\'a jamais été vu sur le campus.\nstart: 67 end: 75 text: On a peur,\non regarde un peu derrière nous.\nstart: 75 end: 78 text: -La direction de l\'EPFL\norganisait cet après-midi\nstart: 78 end: 80 text: une discussion\npour éviter toute escalade.\nstart: 81 end: 84 text: Si la démarche a été saluée,\ncertains en ont profité\nstart: 85 end: 88 text: pour remettre en doute\nle témoignage des étudiants menacés.\nstart: 88 end: 92 text: -La première réaction dans\nl\'auditoire, c\'est "ils mentent".\nstart: 92 end: 102 text: Ils parlent de menaces de mort,\ndonc forcément ils mentent.\nstart: 102 end: 105 text: -Du côté\ndes manifestants propalestiniens,\nstart: 105 end: 108 text: on condamne fermement\ntoutes attitudes discriminatoires.\nstart: 108 end: 111 text: -Menacer de mort pour des idées\npolitiques,\nstart: 111 end: 114 text: ce n\'est pas acceptable,\nsurtout pas dans notre école.\nstart: 114 end: 125 text: Ca ne reflète pas\nla majorité des étudiants.\nstart: 126 end: 129 text: -Le groupe propalestinien considère\nstart: 129 end: 131 text: que la direction porte\nune part de responsabilité\nstart: 131 end: 134 text: en limitant la liberté d\'expression.\nstart: 134 end: 141 text: La direction de l\'EPFL doit faire\nla lumière sur ces événements.',
#   'video_start': './video/video_segments/seg-13-f3-v1.m4s',
#   'video_end': './video/video_segments/seg-30-f3-v1.m4s',
#   'video_start_idx': 13,
#   'video_end_idx': 30,
#   'audio_start': './video/subtitle_segments/seg-13-f1-a1.m4s',
#   'audio_end': './video/subtitle_segments/seg-30-f1-a1.m4s',
#   'subtitle_start': './video/subtitle_segments/seg-13-f6.vtt',
#   'subtitle_end': './video/subtitle_segments/seg-30-f6.vtt'},
#  1: {'title': "Le président de l'EPFL Martin Vetterli revient sur le sentiment de peur ressenti par certains étudiants de l'établissement, critiques au mouvement pro-palestinien",
#   'markIn': 212.72,
#   'markOut': 416.68,
#   'start_idx': 49,
#   'end_idx': 98,
#   'transcript': '-Martin Vetterli, bonsoir.Le Temps révèle que des étudiants\nde votre établissementsont harcelés car ils pensent\ndifféremment, et parlent de paix.Un étudiant est menacé de mort\nsur les réseaux sociaux:"il faut tuer Nicolas et son gang".Une autre est intimidée:\n"on a vu où tu étais assise".Quelle est votre réaction ?- Je suis très tristequ\'il y a une telle tension\nsur le campus.Ce sont les excès\ndes réseaux sociaux.Si on n\'est pas dans le cadre légal,par rapport aux lois\nsur le racisme et l\'antisémitisme,on donne\nle support à notre communauté.Nos étudiants ont des canaux où ils\npeuvent venir chercher de l\'aide.Et on prendra\nles mesures nécessaires.Des plaintes pourront être portées.-On entend des étudiants juifsqui ont peur de venir sur le campus.Leur sécurité est garantie ?-C\'est notre première priorité.La sécurité de tous sur le campus.On a parlé avec ces gens,\nils se sont exprimés.Ils ont besoin d\'être protégés,\ncomme tout le monde.-Vous reconnaissez\nqu\'il y a une dérivede certains membres\ndes militants propalestiniens ?-Il y a toujours des dérives.Il y a un large spectre\nd\'opinions sur le campus.Notre mission\nest de garder une unité.-Comment on en est arrivé là ?Y a-t-il aussi une responsabilité\nde la part des grandes écolesde laisser entrer ces discussions\npolitiques sur le campus ?L\'université ne doit-elle\npas être totalement neutre ?-L\'université en tant qu\'institution\ndoit rester neutrepour permettre un débat.Mais chacun est un être humain\nqui peut s\'exprimer en son nom.Il ne faut pas\nqu\'il y ait de dérive.Il ne faut pas qu\'il y ait le genre\nd\'excès dont vous avez parlé.-On a atteint\nà ce niveau-là du rouge.Qu\'est-ce que vous allez faire\npour remettre de l\'ordre ?-On n\'est pas dans le désordre.Sur le campus, ça se passe bien.Plusieurs centaines de participants\nreprésentant les étudiants,les employés et les profs ont parlé\net ça s\'est bien passé.Tous nos canaux de soutien sont\nà disposition de toute la communauté.-Vous appelez les étudiants\nà s\'adresser à vos canaux de soutiensi quelque chose se passe.-On a créé\nune commission spécifique.On va regarder\nces différentes dimensions.Cette commission\nest dirigée par ma collègue.',
#   'transcript_ts': 'start: 6 end: 9 text: -Martin Vetterli, bonsoir.\nstart: 9 end: 15 text: Le Temps révèle que des étudiants\nde votre établissement\nstart: 15 end: 21 text: sont harcelés car ils pensent\ndifféremment, et parlent de paix.\nstart: 21 end: 28 text: Un étudiant est menacé de mort\nsur les réseaux sociaux:\nstart: 28 end: 31 text: "il faut tuer Nicolas et son gang".\nstart: 31 end: 35 text: Une autre est intimidée:\n"on a vu où tu étais assise".\nstart: 35 end: 38 text: Quelle est votre réaction ?\nstart: 38 end: 40 text: - Je suis très triste\nstart: 40 end: 44 text: qu\'il y a une telle tension\nsur le campus.\nstart: 44 end: 48 text: Ce sont les excès\ndes réseaux sociaux.\nstart: 48 end: 52 text: Si on n\'est pas dans le cadre légal,\nstart: 52 end: 55 text: par rapport aux lois\nsur le racisme et l\'antisémitisme,\nstart: 55 end: 59 text: on donne\nle support à notre communauté.\nstart: 59 end: 66 text: Nos étudiants ont des canaux où ils\npeuvent venir chercher de l\'aide.\nstart: 66 end: 71 text: Et on prendra\nles mesures nécessaires.\nstart: 72 end: 75 text: Des plaintes pourront être portées.\nstart: 75 end: 79 text: -On entend des étudiants juifs\nstart: 79 end: 84 text: qui ont peur de venir sur le campus.\nstart: 84 end: 86 text: Leur sécurité est garantie ?\nstart: 86 end: 90 text: -C\'est notre première priorité.\nstart: 90 end: 93 text: La sécurité de tous sur le campus.\nstart: 93 end: 98 text: On a parlé avec ces gens,\nils se sont exprimés.\nstart: 98 end: 102 text: Ils ont besoin d\'être protégés,\ncomme tout le monde.\nstart: 102 end: 104 text: -Vous reconnaissez\nqu\'il y a une dérive\nstart: 104 end: 108 text: de certains membres\ndes militants propalestiniens ?\nstart: 108 end: 111 text: -Il y a toujours des dérives.\nstart: 111 end: 117 text: Il y a un large spectre\nd\'opinions sur le campus.\nstart: 117 end: 121 text: Notre mission\nest de garder une unité.\nstart: 121 end: 124 text: -Comment on en est arrivé là ?\nstart: 124 end: 129 text: Y a-t-il aussi une responsabilité\nde la part des grandes écoles\nstart: 129 end: 133 text: de laisser entrer ces discussions\npolitiques sur le campus ?\nstart: 133 end: 137 text: L\'université ne doit-elle\npas être totalement neutre ?\nstart: 137 end: 141 text: -L\'université en tant qu\'institution\ndoit rester neutre\nstart: 141 end: 143 text: pour permettre un débat.\nstart: 143 end: 147 text: Mais chacun est un être humain\nqui peut s\'exprimer en son nom.\nstart: 147 end: 149 text: Il ne faut pas\nqu\'il y ait de dérive.\nstart: 150 end: 155 text: Il ne faut pas qu\'il y ait le genre\nd\'excès dont vous avez parlé.\nstart: 156 end: 160 text: -On a atteint\nà ce niveau-là du rouge.\nstart: 160 end: 166 text: Qu\'est-ce que vous allez faire\npour remettre de l\'ordre ?\nstart: 166 end: 169 text: -On n\'est pas dans le désordre.\nstart: 169 end: 172 text: Sur le campus, ça se passe bien.\nstart: 173 end: 178 text: Plusieurs centaines de participants\nreprésentant les étudiants,\nstart: 178 end: 181 text: les employés et les profs ont parlé\net ça s\'est bien passé.\nstart: 181 end: 187 text: Tous nos canaux de soutien sont\nà disposition de toute la communauté.\nstart: 187 end: 192 text: -Vous appelez les étudiants\nà s\'adresser à vos canaux de soutien\nstart: 192 end: 196 text: si quelque chose se passe.\nstart: 196 end: 200 text: -On a créé\nune commission spécifique.\nstart: 200 end: 203 text: On va regarder\nces différentes dimensions.\nstart: 203 end: 209 text: Cette commission\nest dirigée par ma collègue.',
#   'video_start': './video/video_segments/seg-30-f3-v1.m4s',
#   'video_end': './video/video_segments/seg-55-f3-v1.m4s',
#   'video_start_idx': 30,
#   'video_end_idx': 55,
#   'audio_start': './video/subtitle_segments/seg-30-f1-a1.m4s',
#   'audio_end': './video/subtitle_segments/seg-55-f1-a1.m4s',
#   'subtitle_start': './video/subtitle_segments/seg-30-f6.vtt',
#   'subtitle_end': './video/subtitle_segments/seg-55-f6.vtt'}}

# %% [markdown]
# # create clips

# %%
import subprocess
import os

# %% [markdown]
# bash_script_content = '''#!/bin/bash
#
# # Loop from 1 to 107
# for i in {1..107}
# do
#   # Use ffmpeg to create separate video with audio
#   ffmpeg -i "concat:video/init-f3-v1.mp4|video/video_segments/seg-$i-f3-v1.m4s" -i "concat:video/init-f1-a1.mp4|video/audio_segments/seg-$i-f1-a1.m4s" -c copy -map 0:v -map 1:a "video/clips/output_segment${i}_with_audio.mp4" -nostdin
#
#   # Optionally print progress
#   echo "Created output_segment${i}_with_audio.mp4"
# done
# '''
#
# # Write the bash script to a file
# with open('video/video_segments/script.sh', 'w') as file:
#     file.write(bash_script_content)

# %%
# Ensure the script is executable
os.chmod('video/video_segments/script.sh', 0o775)

# Run the bash script using subprocess
result = subprocess.run(['video/video_segments/script.sh'], capture_output=True, text=True)

# Print the output and errors if any
print(result.stdout)
print(result.stderr)
# Out:
# Created output_segment1_with_audio_and_subs.mp4
# Created output_segment2_with_audio_and_subs.mp4
# Created output_segment3_with_audio_and_subs.mp4
# Created output_segment4_with_audio_and_subs.mp4
# Created output_segment5_with_audio_and_subs.mp4
# Created output_segment6_with_audio_and_subs.mp4
# Created output_segment7_with_audio_and_subs.mp4
# Created output_segment8_with_audio_and_subs.mp4
# Created output_segment9_with_audio_and_subs.mp4
# Created output_segment10_with_audio_and_subs.mp4
# Created output_segment11_with_audio_and_subs.mp4
# Created output_segment12_with_audio_and_subs.mp4
# Created output_segment13_with_audio_and_subs.mp4
# Created output_segment14_with_audio_and_subs.mp4
# Created output_segment15_with_audio_and_subs.mp4
# Created output_segment16_with_audio_and_subs.mp4
# Created output_segment17_with_audio_and_subs.mp4
# Created output_segment18_with_audio_and_subs.mp4
# Created output_segment19_with_audio_and_subs.mp4
# Created output_segment20_with_audio_and_subs.mp4
# Created output_segment21_with_audio_and_subs.mp4
# Created output_segment22_with_audio_and_subs.mp4
# Created output_segment23_with_audio_and_subs.mp4
# Created output_segment24_with_audio_and_subs.mp4
# Created output_segment25_with_audio_and_subs.mp4
# Created output_segment26_with_audio_and_subs.mp4
# Created output_segment27_with_audio_and_subs.mp4
# Created output_segment28_with_audio_and_subs.mp4
# Created output_segment29_with_audio_and_subs.mp4
# Created output_segment30_with_audio_and_subs.mp4
# Created output_segment31_with_audio_and_subs.mp4
# Created output_segment32_with_audio_and_subs.mp4
# Created output_segment33_with_audio_and_subs.mp4
# Created output_segment34_with_audio_and_subs.mp4
# Created output_segment35_with_audio_and_subs.mp4
# Created output_segment36_with_audio_and_subs.mp4
# Created output_segment37_with_audio_and_subs.mp4
# Created output_segment38_with_audio_and_subs.mp4
# Created output_segment39_with_audio_and_subs.mp4
# Created output_segment40_with_audio_and_subs.mp4
# Created output_segment41_with_audio_and_subs.mp4
# Created output_segment42_with_audio_and_subs.mp4
# Created output_segment43_with_audio_and_subs.mp4
# Created output_segment44_with_audio_and_subs.mp4
# Created output_segment45_with_audio_and_subs.mp4
# Created output_segment46_with_audio_and_subs.mp4
# Created output_segment47_with_audio_and_subs.mp4
# Created output_segment48_with_audio_and_subs.mp4
# Created output_segment49_with_audio_and_subs.mp4
# Created output_segment50_with_audio_and_subs.mp4
# Created output_segment51_with_audio_and_subs.mp4
# Created output_segment52_with_audio_and_subs.mp4
# Created output_segment53_with_audio_and_subs.mp4
# Created output_segment54_with_audio_and_subs.mp4
# Created output_segment55_with_audio_and_subs.mp4
# Created output_segment56_with_audio_and_subs.mp4
# Created output_segment57_with_audio_and_subs.mp4
# Created output_segment58_with_audio_and_subs.mp4
# Created output_segment59_with_audio_and_subs.mp4
# Created output_segment60_with_audio_and_subs.mp4
# Created output_segment61_with_audio_and_subs.mp4
# Created output_segment62_with_audio_and_subs.mp4
# Created output_segment63_with_audio_and_subs.mp4
# Created output_segment64_with_audio_and_subs.mp4
# Created output_segment65_with_audio_and_subs.mp4
# Created output_segment66_with_audio_and_subs.mp4
# Created output_segment67_with_audio_and_subs.mp4
# Created output_segment68_with_audio_and_subs.mp4
# Created output_segment69_with_audio_and_subs.mp4
# Created output_segment70_with_audio_and_subs.mp4
# Created output_segment71_with_audio_and_subs.mp4
# Created output_segment72_with_audio_and_subs.mp4
# Created output_segment73_with_audio_and_subs.mp4
# Created output_segment74_with_audio_and_subs.mp4
# Created output_segment75_with_audio_and_subs.mp4
# Created output_segment76_with_audio_and_subs.mp4
# Created output_segment77_with_audio_and_subs.mp4
# Created output_segment78_with_audio_and_subs.mp4
# Created output_segment79_with_audio_and_subs.mp4
# Created output_segment80_with_audio_and_subs.mp4
# Created output_segment81_with_audio_and_subs.mp4
# Created output_segment82_with_audio_and_subs.mp4
# Created output_segment83_with_audio_and_subs.mp4
# Created output_segment84_with_audio_and_subs.mp4
# Created output_segment85_with_audio_and_subs.mp4
# Created output_segment86_with_audio_and_subs.mp4
# Created output_segment87_with_audio_and_subs.mp4
# Created output_segment88_with_audio_and_subs.mp4
# Created output_segment89_with_audio_and_subs.mp4
# Created output_segment90_with_audio_and_subs.mp4
# Created output_segment91_with_audio_and_subs.mp4
# Created output_segment92_with_audio_and_subs.mp4
# Created output_segment93_with_audio_and_subs.mp4
# Created output_segment94_with_audio_and_subs.mp4
# Created output_segment95_with_audio_and_subs.mp4
# Created output_segment96_with_audio_and_subs.mp4
# Created output_segment97_with_audio_and_subs.mp4
# Created output_segment98_with_audio_and_subs.mp4
# Created output_segment99_with_audio_and_subs.mp4
# Created output_segment100_with_audio_and_subs.mp4
# Created output_segment101_with_audio_and_subs.mp4
# Created output_segment102_with_audio_and_subs.mp4
# Created output_segment103_with_audio_and_subs.mp4
# Created output_segment104_with_audio_and_subs.mp4
# Created output_segment105_with_audio_and_subs.mp4
# Created output_segment106_with_audio_and_subs.mp4
# Created output_segment107_with_audio_and_subs.mp4
#
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, webvtt, from 'video/subtitle_segments/seg-1-f6.vtt':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Subtitle: webvtt
# Stream mapping:
#   Stream #0:0 -> #0:0 (webvtt (native) -> subrip (srt))
# Output #0, srt, to 'video/subtitle_segments/seg-1-f6.srt':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Subtitle: subrip
#       Metadata:
#         encoder         : Lavc61.3.100 srt
# [out#0/srt @ 0x6000022d8000] video:0KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1133.333333%
# size=       0KiB time=00:00:13.94 bitrate=   0.0kbits/s speed=2.55e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f3-v1.mp4|video/video_segments/seg-1-f3-v1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 1806 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], 1799 kb/s, 25 fps, 25 tbr, 90k tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Elemental H.264
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f1-a1.mp4|video/audio_segments/seg-1-f1-a1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:02.01, start: 0.000000, bitrate: 135 kb/s
#   Stream #1:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 129 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [Parsed_subtitles_0 @ 0x600002b182c0] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x600002b182c0] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x600002b182c0] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x600002b182c0] Using font provider coretext
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (copy)
# [Parsed_subtitles_0 @ 0x600002b0c2c0] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x600002b0c2c0] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x600002b0c2c0] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x600002b0c2c0] Using font provider coretext
# [Parsed_subtitles_0 @ 0x600002b0c2c0] fontselect: (Arial, 400, 0) -> /System/Library/Fonts/Supplemental/Arial.ttf, -1, ArialMT
# [libx264 @ 0x12f007000] using SAR=1/1
# [libx264 @ 0x12f007000] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12f007000] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x12f007000] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video/clips/output_segment1_with_audio_and_burned_subs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 129 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x600002918000] video:11KiB audio:32KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 6.621020%
# frame=   50 fps=0.0 q=-1.0 Lsize=      46KiB time=00:00:01.92 bitrate= 196.6kbits/s speed=23.4x
# [libx264 @ 0x12f007000] frame I:1     Avg QP:16.59  size:  1170
# [libx264 @ 0x12f007000] frame P:13    Avg QP:24.97  size:   394
# [libx264 @ 0x12f007000] frame B:36    Avg QP:29.21  size:   133
# [libx264 @ 0x12f007000] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x12f007000] mb I  I16..4: 53.6% 45.5%  0.8%
# [libx264 @ 0x12f007000] mb P  I16..4:  3.2%  1.1%  0.1%  P16..4:  1.8%  0.2%  0.1%  0.0%  0.0%    skip:93.4%
# [libx264 @ 0x12f007000] mb B  I16..4:  0.6%  0.2%  0.0%  B16..8:  2.4%  0.2%  0.0%  direct: 0.1%  skip:96.4%  L0:64.8% L1:32.0% BI: 3.2%
# [libx264 @ 0x12f007000] 8x8 transform intra:36.2% inter:73.0%
# [libx264 @ 0x12f007000] coded y,uvDC,uvAC intra: 1.3% 5.5% 2.2% inter: 0.1% 0.6% 0.1%
# [libx264 @ 0x12f007000] i16 v,h,dc,p: 94%  5%  0%  1%
# [libx264 @ 0x12f007000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 49%  0% 51%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x12f007000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 26% 26%  1%  2%  3%  3%  2%  2%
# [libx264 @ 0x12f007000] i8c dc,h,v,p: 63%  2% 34%  1%
# [libx264 @ 0x12f007000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12f007000] ref P L0: 71.9%  5.9% 10.6% 11.6%
# [libx264 @ 0x12f007000] ref B L0: 92.9%  4.5%  2.6%
# [libx264 @ 0x12f007000] ref B L1: 97.7%  2.3%
# [libx264 @ 0x12f007000] kb/s:44.25
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, webvtt, from 'video/subtitle_segments/seg-2-f6.vtt':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Subtitle: webvtt
# Stream mapping:
#   Stream #0:0 -> #0:0 (webvtt (native) -> subrip (srt))
# Output #0, srt, to 'video/subtitle_segments/seg-2-f6.srt':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Subtitle: subrip
#       Metadata:
#         encoder         : Lavc61.3.100 srt
# [out#0/srt @ 0x600000d003c0] video:0KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1133.333333%
# size=       0KiB time=00:00:13.94 bitrate=   0.0kbits/s speed=8.61e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f3-v1.mp4|video/video_segments/seg-2-f3-v1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:04.00, start: 2.000000, bitrate: 1062 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], 1059 kb/s, 25 fps, 25 tbr, 90k tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Elemental H.264
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f1-a1.mp4|video/audio_segments/seg-2-f1-a1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:04.01, start: 2.005333, bitrate: 66 kb/s
#   Stream #1:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 63 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [Parsed_subtitles_0 @ 0x6000001fc000] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x6000001fc000] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x6000001fc000] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x6000001fc000] Using font provider coretext
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (copy)
# [Parsed_subtitles_0 @ 0x6000001ec2c0] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x6000001ec2c0] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x6000001ec2c0] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x6000001ec2c0] Using font provider coretext
# [Parsed_subtitles_0 @ 0x6000001ec2c0] fontselect: (Arial, 400, 0) -> /System/Library/Fonts/Supplemental/Arial.ttf, -1, ArialMT
# [libx264 @ 0x13b006070] using SAR=1/1
# [libx264 @ 0x13b006070] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13b006070] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x13b006070] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video/clips/output_segment2_with_audio_and_burned_subs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 63 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x6000003f00c0] video:34KiB audio:31KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 4.223988%
# frame=   50 fps=0.0 q=-1.0 Lsize=      68KiB time=00:00:01.92 bitrate= 291.4kbits/s speed=  17x
# [libx264 @ 0x13b006070] frame I:1     Avg QP:20.58  size:  1992
# [libx264 @ 0x13b006070] frame P:23    Avg QP:21.30  size:   861
# [libx264 @ 0x13b006070] frame B:26    Avg QP:22.78  size:   489
# [libx264 @ 0x13b006070] consecutive B-frames: 28.0%  8.0%  0.0% 64.0%
# [libx264 @ 0x13b006070] mb I  I16..4:  8.1% 90.1%  1.8%
# [libx264 @ 0x13b006070] mb P  I16..4:  8.4%  7.7%  0.2%  P16..4:  6.9%  0.6%  0.4%  0.0%  0.0%    skip:75.9%
# [libx264 @ 0x13b006070] mb B  I16..4:  1.9%  0.4%  0.0%  B16..8: 15.6%  0.8%  0.0%  direct: 0.4%  skip:80.9%  L0:54.3% L1:45.5% BI: 0.2%
# [libx264 @ 0x13b006070] 8x8 transform intra:51.7% inter:85.2%
# [libx264 @ 0x13b006070] coded y,uvDC,uvAC intra: 2.4% 11.8% 3.1% inter: 0.4% 2.0% 0.2%
# [libx264 @ 0x13b006070] i16 v,h,dc,p: 91%  6%  0%  2%
# [libx264 @ 0x13b006070] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 59%  4% 37%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x13b006070] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 31% 22%  1%  1%  2%  2%  1%  1%
# [libx264 @ 0x13b006070] i8c dc,h,v,p: 45%  4% 51%  1%
# [libx264 @ 0x13b006070] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13b006070] ref P L0: 81.9%  5.8%  9.1%  3.2%
# [libx264 @ 0x13b006070] ref B L0: 87.9% 11.6%  0.5%
# [libx264 @ 0x13b006070] ref B L1: 97.2%  2.8%
# [libx264 @ 0x13b006070] kb/s:138.03
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, webvtt, from 'video/subtitle_segments/seg-3-f6.vtt':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Subtitle: webvtt
# Stream mapping:
#   Stream #0:0 -> #0:0 (webvtt (native) -> subrip (srt))
# Output #0, srt, to 'video/subtitle_segments/seg-3-f6.srt':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Subtitle: subrip
#       Metadata:
#         encoder         : Lavc61.3.100 srt
# [out#0/srt @ 0x600002f3c000] video:0KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1133.333333%
# size=       0KiB time=00:00:13.94 bitrate=   0.0kbits/s speed=7.66e+04x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f3-v1.mp4|video/video_segments/seg-3-f3-v1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:06.00, start: 4.000000, bitrate: 744 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], 742 kb/s, 25 fps, 25 tbr, 90k tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Elemental H.264
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f1-a1.mp4|video/audio_segments/seg-3-f1-a1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:06.02, start: 4.010667, bitrate: 44 kb/s
#   Stream #1:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 42 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [Parsed_subtitles_0 @ 0x6000018d0420] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x6000018d0420] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x6000018d0420] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x6000018d0420] Using font provider coretext
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (copy)
# [Parsed_subtitles_0 @ 0x6000018d8a50] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x6000018d8a50] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x6000018d8a50] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x6000018d8a50] Using font provider coretext
# [Parsed_subtitles_0 @ 0x6000018d8a50] fontselect: (Arial, 400, 0) -> /System/Library/Fonts/Supplemental/Arial.ttf, -1, ArialMT
# [libx264 @ 0x14f806670] using SAR=1/1
# [libx264 @ 0x14f806670] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14f806670] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x14f806670] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video/clips/output_segment3_with_audio_and_burned_subs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 42 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x600001adc000] video:140KiB audio:31KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.645071%
# frame=   50 fps=0.0 q=-1.0 Lsize=     174KiB time=00:00:01.92 bitrate= 742.0kbits/s speed=12.2x
# [libx264 @ 0x14f806670] frame I:1     Avg QP:21.00  size:  2434
# [libx264 @ 0x14f806670] frame P:18    Avg QP:21.73  size:  4962
# [libx264 @ 0x14f806670] frame B:31    Avg QP:23.69  size:  1630
# [libx264 @ 0x14f806670] consecutive B-frames: 14.0%  8.0%  6.0% 72.0%
# [libx264 @ 0x14f806670] mb I  I16..4: 13.8% 84.3%  2.0%
# [libx264 @ 0x14f806670] mb P  I16..4: 10.4% 11.4%  2.3%  P16..4: 23.2%  4.8%  2.8%  0.0%  0.0%    skip:45.2%
# [libx264 @ 0x14f806670] mb B  I16..4:  1.3%  0.6%  0.2%  B16..8: 29.1%  2.0%  0.2%  direct: 1.3%  skip:65.4%  L0:46.7% L1:50.7% BI: 2.5%
# [libx264 @ 0x14f806670] 8x8 transform intra:51.8% inter:83.0%
# [libx264 @ 0x14f806670] coded y,uvDC,uvAC intra: 15.2% 38.0% 16.1% inter: 3.5% 11.4% 1.2%
# [libx264 @ 0x14f806670] i16 v,h,dc,p: 76% 15%  3%  6%
# [libx264 @ 0x14f806670] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 49% 11% 36%  1%  0%  1%  1%  1%  1%
# [libx264 @ 0x14f806670] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 40% 25% 21%  2%  2%  2%  3%  3%  2%
# [libx264 @ 0x14f806670] i8c dc,h,v,p: 42% 14% 42%  2%
# [libx264 @ 0x14f806670] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x14f806670] ref P L0: 71.1%  4.6% 17.8%  6.5%
# [libx264 @ 0x14f806670] ref B L0: 88.6% 10.1%  1.3%
# [libx264 @ 0x14f806670] ref B L1: 94.6%  5.4%
# [libx264 @ 0x14f806670] kb/s:569.17
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, webvtt, from 'video/subtitle_segments/seg-4-f6.vtt':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Subtitle: webvtt
# Stream mapping:
#   Stream #0:0 -> #0:0 (webvtt (native) -> subrip (srt))
# Output #0, srt, to 'video/subtitle_segments/seg-4-f6.srt':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Subtitle: subrip
#       Metadata:
#         encoder         : Lavc61.3.100 srt
# [out#0/srt @ 0x600000c10000] video:0KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1133.333333%
# size=       0KiB time=00:00:13.94 bitrate=   0.0kbits/s speed=1.69e+03x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f3-v1.mp4|video/video_segments/seg-4-f3-v1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:08.00, start: 6.000000, bitrate: 502 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], 500 kb/s, 25 fps, 25 tbr, 90k tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Elemental H.264
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f1-a1.mp4|video/audio_segments/seg-4-f1-a1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:08.00, start: 6.016000, bitrate: 33 kb/s
#   Stream #1:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 31 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [Parsed_subtitles_0 @ 0x600001b984d0] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x600001b984d0] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x600001b984d0] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x600001b984d0] Using font provider coretext
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (copy)
# [Parsed_subtitles_0 @ 0x600001b88000] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x600001b88000] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x600001b88000] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x600001b88000] Using font provider coretext
# [Parsed_subtitles_0 @ 0x600001b88000] fontselect: (Arial, 400, 0) -> /System/Library/Fonts/Supplemental/Arial.ttf, -1, ArialMT
# [libx264 @ 0x153006fe0] using SAR=1/1
# [libx264 @ 0x153006fe0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x153006fe0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x153006fe0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video/clips/output_segment4_with_audio_and_burned_subs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 31 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x600001998000] video:249KiB audio:31KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.016537%
# frame=   50 fps=0.0 q=-1.0 Lsize=     283KiB time=00:00:01.92 bitrate=1208.2kbits/s speed=10.1x
# [libx264 @ 0x153006fe0] frame I:1     Avg QP:21.88  size: 23001
# [libx264 @ 0x153006fe0] frame P:13    Avg QP:22.91  size:  9912
# [libx264 @ 0x153006fe0] frame B:36    Avg QP:25.77  size:  2854
# [libx264 @ 0x153006fe0] consecutive B-frames:  2.0%  4.0%  6.0% 88.0%
# [libx264 @ 0x153006fe0] mb I  I16..4: 31.5% 45.4% 23.1%
# [libx264 @ 0x153006fe0] mb P  I16..4:  5.9%  6.8%  4.1%  P16..4: 45.7% 13.6%  5.7%  0.0%  0.0%    skip:18.2%
# [libx264 @ 0x153006fe0] mb B  I16..4:  0.9%  0.6%  0.3%  B16..8: 39.3%  4.6%  0.6%  direct: 1.6%  skip:51.9%  L0:50.3% L1:45.8% BI: 3.9%
# [libx264 @ 0x153006fe0] 8x8 transform intra:40.5% inter:79.1%
# [libx264 @ 0x153006fe0] coded y,uvDC,uvAC intra: 39.2% 79.3% 36.8% inter: 7.2% 21.6% 2.3%
# [libx264 @ 0x153006fe0] i16 v,h,dc,p: 42% 32%  8% 19%
# [libx264 @ 0x153006fe0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 29% 30%  2%  2%  2%  4%  2%  4%
# [libx264 @ 0x153006fe0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 40% 29% 16%  2%  2%  2%  3%  2%  2%
# [libx264 @ 0x153006fe0] i8c dc,h,v,p: 28% 34% 31%  7%
# [libx264 @ 0x153006fe0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x153006fe0] ref P L0: 69.0%  3.6% 20.7%  6.8%
# [libx264 @ 0x153006fe0] ref B L0: 89.4%  8.8%  1.7%
# [libx264 @ 0x153006fe0] ref B L1: 96.5%  3.5%
# [libx264 @ 0x153006fe0] kb/s:1018.46
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, webvtt, from 'video/subtitle_segments/seg-5-f6.vtt':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Subtitle: webvtt
# Stream mapping:
#   Stream #0:0 -> #0:0 (webvtt (native) -> subrip (srt))
# Output #0, srt, to 'video/subtitle_segments/seg-5-f6.srt':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Subtitle: subrip
#       Metadata:
#         encoder         : Lavc61.3.100 srt
# [out#0/srt @ 0x600003cb4000] video:0KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 144.680851%
# size=       0KiB time=00:00:16.42 bitrate=   0.1kbits/s speed=1.03e+05x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f3-v1.mp4|video/video_segments/seg-5-f3-v1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:16.00, start: 8.000000, bitrate: 1035 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], 1033 kb/s, 25 fps, 25 tbr, 90k tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Elemental H.264
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f1-a1.mp4|video/audio_segments/seg-5-f1-a1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:00:16.00, start: 8.000000, bitrate: 65 kb/s
#   Stream #1:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 64 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [Parsed_subtitles_0 @ 0x600000a38210] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x600000a38210] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x600000a38210] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x600000a38210] Using font provider coretext
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (copy)
# [Parsed_subtitles_0 @ 0x600000a28000] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x600000a28000] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x600000a28000] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x600000a28000] Using font provider coretext
# [Parsed_subtitles_0 @ 0x600000a28000] fontselect: (Arial, 400, 0) -> /System/Library/Fonts/Supplemental/Arial.ttf, -1, ArialMT
# [libx264 @ 0x12d9062b0] using SAR=1/1
# [libx264 @ 0x12d9062b0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12d9062b0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x12d9062b0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video/clips/output_segment5_with_audio_and_burned_subs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 64 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# frame=  135 fps=0.0 q=28.0 size=     512KiB time=00:00:05.32 bitrate= 788.5kbits/s speed=10.5x
# [out#0/mp4 @ 0x600000834000] video:943KiB audio:125KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.669558%
# frame=  200 fps=0.0 q=-1.0 Lsize=    1075KiB time=00:00:07.92 bitrate=1112.0kbits/s speed=12.6x
# [libx264 @ 0x12d9062b0] frame I:2     Avg QP:21.29  size: 20960
# [libx264 @ 0x12d9062b0] frame P:73    Avg QP:22.77  size:  8706
# [libx264 @ 0x12d9062b0] frame B:125   Avg QP:27.05  size:  2299
# [libx264 @ 0x12d9062b0] consecutive B-frames: 13.5%  6.0% 10.5% 70.0%
# [libx264 @ 0x12d9062b0] mb I  I16..4: 30.3% 47.7% 21.9%
# [libx264 @ 0x12d9062b0] mb P  I16..4:  4.1%  5.3%  1.5%  P16..4: 35.2% 13.3%  5.6%  0.0%  0.0%    skip:35.0%
# [libx264 @ 0x12d9062b0] mb B  I16..4:  0.3%  0.3%  0.1%  B16..8: 31.7%  4.4%  0.8%  direct: 1.3%  skip:61.1%  L0:47.3% L1:44.4% BI: 8.3%
# [libx264 @ 0x12d9062b0] 8x8 transform intra:48.1% inter:72.7%
# [libx264 @ 0x12d9062b0] coded y,uvDC,uvAC intra: 43.6% 67.8% 23.6% inter: 10.4% 16.0% 1.0%
# [libx264 @ 0x12d9062b0] i16 v,h,dc,p: 18% 48%  6% 28%
# [libx264 @ 0x12d9062b0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 34% 22%  2%  3%  3%  6%  3%  5%
# [libx264 @ 0x12d9062b0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 33% 16%  3%  5%  4%  6%  3%  3%
# [libx264 @ 0x12d9062b0] i8c dc,h,v,p: 39% 36% 18%  7%
# [libx264 @ 0x12d9062b0] Weighted P-Frames: Y:6.8% UV:0.0%
# [libx264 @ 0x12d9062b0] ref P L0: 74.9%  8.3% 13.0%  3.4%  0.4%
# [libx264 @ 0x12d9062b0] ref B L0: 95.7%  3.7%  0.6%
# [libx264 @ 0x12d9062b0] ref B L1: 98.2%  1.8%
# [libx264 @ 0x12d9062b0] kb/s:964.84
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
# ...
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, webvtt, from 'video/subtitle_segments/seg-106-f6.vtt':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Subtitle: webvtt
# Stream mapping:
#   Stream #0:0 -> #0:0 (webvtt (native) -> subrip (srt))
# Output #0, srt, to 'video/subtitle_segments/seg-106-f6.srt':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Subtitle: subrip
#       Metadata:
#         encoder         : Lavc61.3.100 srt
# [out#0/srt @ 0x600001910000] video:0KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 56.983240%
# size=       0KiB time=00:13:46.25 bitrate=   0.0kbits/s speed=4.86e+06x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f3-v1.mp4|video/video_segments/seg-106-f3-v1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:13:44.00, start: 816.000000, bitrate: 19 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], 19 kb/s, 25 fps, 25 tbr, 90k tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Elemental H.264
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f1-a1.mp4|video/audio_segments/seg-106-f1-a1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:13:44.00, start: 816.000000, bitrate: 1 kb/s
#   Stream #1:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 1 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [Parsed_subtitles_0 @ 0x60000230cd10] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x60000230cd10] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x60000230cd10] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x60000230cd10] Using font provider coretext
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (copy)
# [Parsed_subtitles_0 @ 0x600002300000] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x600002300000] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x600002300000] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x600002300000] Using font provider coretext
# [libx264 @ 0x14a6080c0] using SAR=1/1
# [libx264 @ 0x14a6080c0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14a6080c0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x14a6080c0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video/clips/output_segment106_with_audio_and_burned_subs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 1 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# frame=  180 fps=0.0 q=28.0 size=     768KiB time=00:00:07.12 bitrate= 883.7kbits/s speed=14.1x
# [out#0/mp4 @ 0x60000210c3c0] video:978KiB audio:125KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.633582%
# frame=  200 fps=0.0 q=-1.0 Lsize=    1110KiB time=00:00:07.92 bitrate=1147.8kbits/s speed=14.7x
# [libx264 @ 0x14a6080c0] frame I:2     Avg QP:21.21  size: 47855
# [libx264 @ 0x14a6080c0] frame P:90    Avg QP:22.98  size:  7256
# [libx264 @ 0x14a6080c0] frame B:108   Avg QP:26.21  size:  2331
# [libx264 @ 0x14a6080c0] consecutive B-frames: 25.5%  3.0% 13.5% 58.0%
# [libx264 @ 0x14a6080c0] mb I  I16..4: 17.5% 47.3% 35.2%
# [libx264 @ 0x14a6080c0] mb P  I16..4:  2.1%  5.2%  0.6%  P16..4: 40.1% 10.3%  5.2%  0.0%  0.0%    skip:36.6%
# [libx264 @ 0x14a6080c0] mb B  I16..4:  0.4%  0.9%  0.1%  B16..8: 43.7%  4.3%  0.4%  direct: 1.0%  skip:49.2%  L0:50.6% L1:46.2% BI: 3.2%
# [libx264 @ 0x14a6080c0] 8x8 transform intra:61.8% inter:63.0%
# [libx264 @ 0x14a6080c0] coded y,uvDC,uvAC intra: 49.1% 59.0% 10.0% inter: 11.5% 11.4% 0.2%
# [libx264 @ 0x14a6080c0] i16 v,h,dc,p: 45% 16% 10% 28%
# [libx264 @ 0x14a6080c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 13% 25%  3%  6%  7%  5%  6%  4%
# [libx264 @ 0x14a6080c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 22% 14%  4%  6%  7%  6%  5%  5%
# [libx264 @ 0x14a6080c0] i8c dc,h,v,p: 51% 17% 28%  5%
# [libx264 @ 0x14a6080c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x14a6080c0] ref P L0: 79.7%  7.4%  9.8%  3.1%
# [libx264 @ 0x14a6080c0] ref B L0: 93.9%  5.0%  1.1%
# [libx264 @ 0x14a6080c0] ref B L1: 97.7%  2.3%
# [libx264 @ 0x14a6080c0] kb/s:1000.47
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, webvtt, from 'video/subtitle_segments/seg-107-f6.vtt':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Subtitle: webvtt
# Stream mapping:
#   Stream #0:0 -> #0:0 (webvtt (native) -> subrip (srt))
# Output #0, srt, to 'video/subtitle_segments/seg-107-f6.srt':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Subtitle: subrip
#       Metadata:
#         encoder         : Lavc61.3.100 srt
# [out#0/srt @ 0x600000e08000] video:0KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 105.426357%
# size=       0KiB time=00:13:52.50 bitrate=   0.0kbits/s speed=4.29e+06x
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f3-v1.mp4|video/video_segments/seg-107-f3-v1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:13:52.00, start: 824.000000, bitrate: 18 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], 18 kb/s, 25 fps, 25 tbr, 90k tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Elemental H.264
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'concat:video/init-f1-a1.mp4|video/audio_segments/seg-107-f1-a1.m4s':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#   Duration: 00:13:52.00, start: 824.000000, bitrate: 1 kb/s
#   Stream #1:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 1 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# [Parsed_subtitles_0 @ 0x600003d382c0] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x600003d382c0] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x600003d382c0] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x600003d382c0] Using font provider coretext
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (copy)
# [Parsed_subtitles_0 @ 0x600003d342c0] libass API version: 0x1702000
# [Parsed_subtitles_0 @ 0x600003d342c0] libass source: tarball: 0.17.2
# [Parsed_subtitles_0 @ 0x600003d342c0] Shaper: FriBidi 1.0.14 (SIMPLE) HarfBuzz-ng 8.4.0 (COMPLEX)
# [Parsed_subtitles_0 @ 0x600003d342c0] Using font provider coretext
# [libx264 @ 0x131806af0] using SAR=1/1
# [libx264 @ 0x131806af0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x131806af0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x131806af0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video/clips/output_segment107_with_audio_and_burned_subs.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 1
#     compatible_brands: isomavc1
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 1 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# frame=  175 fps=0.0 q=28.0 size=    1024KiB time=00:00:06.92 bitrate=1212.3kbits/s speed=13.7x
# [out#0/mp4 @ 0x600003f38000] video:1037KiB audio:125KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.626454%
# frame=  200 fps=0.0 q=-1.0 Lsize=    1170KiB time=00:00:07.92 bitrate=1210.1kbits/s speed=14.5x
# [libx264 @ 0x131806af0] frame I:3     Avg QP:21.99  size: 33627
# [libx264 @ 0x131806af0] frame P:54    Avg QP:22.97  size: 12413
# [libx264 @ 0x131806af0] frame B:143   Avg QP:27.97  size:  2031
# [libx264 @ 0x131806af0] consecutive B-frames:  4.5%  0.0%  1.5% 94.0%
# [libx264 @ 0x131806af0] mb I  I16..4: 17.4% 46.6% 36.0%
# [libx264 @ 0x131806af0] mb P  I16..4:  1.0%  2.9%  0.9%  P16..4: 46.0% 20.0% 10.6%  0.0%  0.0%    skip:18.6%
# [libx264 @ 0x131806af0] mb B  I16..4:  0.1%  0.1%  0.1%  B16..8: 46.9%  3.7%  0.6%  direct: 0.7%  skip:47.8%  L0:44.5% L1:51.8% BI: 3.7%
# [libx264 @ 0x131806af0] 8x8 transform intra:53.1% inter:62.9%
# [libx264 @ 0x131806af0] coded y,uvDC,uvAC intra: 62.0% 61.2% 16.5% inter: 11.5% 12.9% 0.4%
# [libx264 @ 0x131806af0] i16 v,h,dc,p: 48% 20% 10% 22%
# [libx264 @ 0x131806af0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 17% 23%  3%  5%  7%  5%  6%  5%
# [libx264 @ 0x131806af0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 21% 13%  4%  6%  7%  6%  5%  5%
# [libx264 @ 0x131806af0] i8c dc,h,v,p: 48% 20% 28%  5%
# [libx264 @ 0x131806af0] Weighted P-Frames: Y:1.9% UV:0.0%
# [libx264 @ 0x131806af0] ref P L0: 69.6% 11.8% 15.7%  2.9%  0.0%
# [libx264 @ 0x131806af0] ref B L0: 95.9%  3.5%  0.6%
# [libx264 @ 0x131806af0] ref B L1: 97.0%  3.0%
# [libx264 @ 0x131806af0] kb/s:1061.68

# %%
idx_keep = []
for clip in relevant_clip_topics.values():
    idx_keep.extend([i for i in range(clip["video_start_idx"], clip["video_end_idx"]+1)])

# %%
for clip in glob.glob("video/clips/*.mp4"):
    idx = int(re.findall(r'segment(\d+)', clip)[0])
    if idx not in idx_keep:
        os.remove(clip)

# %% [markdown]
# ### Merge clips by topic

# %%
import ffmpeg

for i, clip in enumerate(relevant_clip_topics.values()):

    # List of video clips to merge
    input_clips = [f"video/clips/output_segment{i}_with_audio_and_burned_subs.mp4" for i in range(clip["video_start_idx"], clip["video_end_idx"]+1)]
    
    # Create a file containing the list of video clips in the format required by FFmpeg
    with open('file_list.txt', 'w') as f:
        for i_clip in input_clips:
            f.write(f"file '{i_clip}'\n")

    # Use FFmpeg to merge the clips
    (
        ffmpeg
        .input('./file_list.txt', format='concat', safe=0)  # 'concat' format for concatenation
        .output(f'video/final_output/output_{i}.mp4', c='copy')  # Output file
        .run()
    )

    print("Merging complete!")
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x15b606370] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from './file_list.txt':
#   Duration: N/A, start: 0.000000, bitrate: 1562 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], 1434 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video/final_output/output_0.mp4':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 1434 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b704a60] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b704990] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b604820] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x15b6061d0] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 2 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b704ad0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x15b704360] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b604080] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x15b6061d0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b704210] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x15b6066b0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b704850] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x15b611300] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b704ff0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x13b704eb0] Auto-inserting h264_mp4toannexb bitstream filter
# [out#0/mp4 @ 0x600003530000] video:19372KiB audio:2250KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.487380%
# size=   21727KiB time=00:02:23.92 bitrate=1236.7kbits/s speed= 917x
# Merging complete!
# Merging complete!
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06370] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from './file_list.txt':
#   Duration: N/A, start: 0.000000, bitrate: 708 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], 581 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to 'video/final_output/output_1.mp4':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 581 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 libx264
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e07540] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e07aa0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06a80] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06960] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06870] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06770] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x119e04080] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06c10] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06bb0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06b30] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e061d0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x119e04c90] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e061d0] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x119e05010] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x119e04950] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x119e04fd0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06990] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x119e04ff0] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x119e04fa0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e069b0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e06840] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x129e063c0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x119e04d00] Auto-inserting h264_mp4toannexb bitstream filter
# [out#0/mp4 @ 0x6000011a4000] video:17475KiB audio:3250KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.747898%
# size=   20880KiB time=00:03:27.92 bitrate= 822.7kbits/s speed=1.33e+03x

# %% [markdown]
# # Identify tactics

# %%
system_prompt = """

In the context of protecting the agenda of those in power, the term "chien de garde" (or "guard dog") in journalism refers to media outlets or journalists who act in the interests of the powerful, rather than serving the public. This concept is the opposite of the traditional watchdog role, as these "guard dogs" may:

- **Promote the interests of the powerful**: They may prioritize stories that align with the agendas of those in power, often neglecting or downplaying issues that could be detrimental to these interests.

- **Suppress critical information**: They may ignore, underreport, or discredit information and perspectives that could challenge or undermine the status quo or the power of influential entities.

- **Propagate propaganda**: They might disseminate biased or misleading information to shape public opinion in favor of the powerful, often blurring the line between journalism and public relations.

- **Maintain the status quo**: By focusing on narratives that reinforce existing power structures and social hierarchies, they contribute to the preservation of these structures.

This concept critiques the potential for media to become complicit in maintaining power dynamics and failing to serve the broader public interest. It highlights the tension between journalistic integrity and the influence of powerful stakeholders on media content and practices.

Media outlets or journalists who act as "chiens de garde" (guard dogs) protecting the agenda of the powerful may use various tactics to shape public perception and influence narratives. Here are some of the common tactics employed:

1. **Passive Voice**

Purpose: To obscure the subject responsible for an action, thereby diminishing accountability.

Example: "Mistakes were made" instead of "The company made mistakes."
   
2. **Guided Questions**

Purpose: To lead the audience to a predetermined conclusion or to frame an issue in a specific way.

Example: "Don't you think that the new policy will benefit the economy?" instead of "What are the potential impacts of the new policy?"

3. **Selective Reporting**

Purpose: To highlight certain information while ignoring other relevant facts, shaping the narrative to favor the powerful.

Example: Focusing extensively on the economic benefits of a new law while ignoring its negative social impacts.

4. **Euphemisms**

Purpose: To downplay or soften the perception of negative actions or outcomes.

Example: Using "collateral damage" to refer to civilian casualties in a military operation.

5. **Framing**

Purpose: To present information in a way that influences interpretation and opinion.

Example: Describing a protest as a "riot" versus a "demonstration" can evoke different responses from the audience.

6. **Omission**

Purpose: To leave out crucial information that might present the powerful in a negative light.

Example: Reporting on a company's financial success without mentioning its environmental violations.

7. **Cherry-Picking Data**

Purpose: To select specific data points that support a particular narrative while ignoring data that contradicts it.

Example: Highlighting a temporary drop in unemployment rates without discussing the overall trend of increasing job insecurity.

8. **Loaded Language**

Purpose: To use emotionally charged words to influence audience perception.

Example: Referring to a policy as "radical" or "extreme" to create a negative impression.

9. **Ad Hominem Attacks**

Purpose: To discredit critics or opposition by attacking their character rather than addressing their arguments.

Example: Labeling a whistleblower as "disgruntled" or "unreliable" instead of addressing the substance of their claims.

10. **False Balance**

Purpose: To present two sides of an issue as equally valid, even when the evidence heavily supports one side.

Example: Giving equal time to climate change scientists and climate change deniers, despite the overwhelming scientific consensus.

11. **Sensationalism**

Purpose: To use shocking or sensational headlines and stories to attract attention, often at the expense of accuracy and depth.

Example: "Government Under Siege by Angry Mobs" instead of "Peaceful Protesters Rally for Change."

12. **Astroturfing**

Purpose: To create the illusion of grassroots support for a cause that is actually orchestrated by powerful interests.

Example: Coordinating fake social media campaigns to simulate public support for a controversial policy.

13. **Repetition**

Purpose: To reinforce a particular message or narrative by repeating it frequently.

Example: Constantly repeating a slogan or catchphrase associated with a policy or leader to embed it in the public consciousness.

14. **Appeal to Authority**

Purpose: To strengthen an argument by citing authoritative figures or institutions that support the powerful's agenda.

Example: "Experts agree that this policy is necessary," without specifying which experts or the basis of their agreement.

15. **False Equivalence**

Purpose: To present two unequal things as being equivalent, often to downplay the negative aspects of one side.

Example: Comparing minor ethical lapses of a critic to major scandals involving those in power.

16. **Scapegoating**

Purpose: To divert blame or criticism by attributing problems to a convenient target, often a minority group or external entity.

Example: Blaming economic woes on immigrants or foreign competitors rather than domestic policy failures.

17. **Straw Man Argument**

Purpose: To misrepresent or oversimplify an opponent's position, making it easier to attack.

Example: "Opponents of this policy want to abandon progress," ignoring the nuanced arguments of critics.

18. **Glittering Generalities**

Purpose: To use vague, emotionally appealing phrases that lack substantive content but create a positive impression.

Example: Promising "a brighter future" without providing specific plans or actions.

19. **Deflection**

Purpose: To avoid addressing uncomfortable questions or criticisms by shifting the focus to a different issue.

Example: When asked about corruption, a politician responds by talking about their achievements in a completely different area.

20. **Manufactured Outrage**

Purpose: To generate emotional responses over trivial or irrelevant issues to distract from more important matters.

Example: Focusing media attention on a celebrity scandal during a significant political crisis.

21. **Control of Information Flow**

Purpose: To limit access to information by controlling who gets to speak, what gets reported, and how it's presented.

Example: Only allowing friendly journalists access to press conferences and events.

22. **Echo Chambers**

Purpose: To reinforce existing beliefs by ensuring that people are exposed only to information that confirms their views.

Example: Media outlets tailoring content to fit the biases and preferences of their audience, creating a feedback loop.

23. **Tokenism**

Purpose: To give the appearance of inclusivity or reform by making superficial changes while maintaining the status quo.

Example: Highlighting a few minority voices or implementing minor policy tweaks while ignoring systemic issues.

24. **Image Management**

Purpose: To carefully craft and control the public image of those in power through PR campaigns, selective appearances, and staged events.

Example: Politicians visiting schools and hospitals for photo ops while their policies may harm those very institutions.

25. **Agenda Setting**

Purpose: To shape the public agenda by prioritizing certain topics over others, thereby influencing what people think about.

Example: Giving extensive coverage to economic growth while underreporting environmental degradation.

26. **Distraction Techniques**

Purpose: To divert attention from important issues by focusing on trivial or sensational topics.

Example: Extensive coverage of celebrity gossip during critical political events.

27. **False Consensus**

Purpose: To create the illusion that the majority of people support a particular viewpoint or policy.

Example: Polling data presented in a misleading way to suggest overwhelming public support.

28. **Minimization**

Purpose: To downplay the severity or significance of an issue or event.

Example: Referring to a major environmental disaster as a "minor spill."

29. **Use of Flawed Studies**

Purpose: To present biased or poorly conducted research as credible to support a specific agenda.

Example: Citing industry-funded studies that show no harm from a product known to be dangerous.

30. **Smokescreening**

Purpose: To obscure the truth by overwhelming the audience with irrelevant information.

Example: Flooding news cycles with minor updates to drown out significant but unfavorable reports.

31. **Appeal to Emotion**

Purpose: To manipulate audience feelings rather than using logical arguments.

Example: Using heart-wrenching stories to garner support for a policy without discussing its broader implications.

32. **Rebranding Negative Concepts**

Purpose: To change the language used to describe a controversial policy to make it more palatable.

Example: Referring to "tax cuts for the wealthy" as "tax relief."

33. **Hasty Generalizations**

Purpose: To make broad claims based on limited evidence to mislead the audience.

Example: Using an isolated incident to justify widespread policy changes.

34. **Marginalization**

Purpose: To sideline or discredit voices that challenge the dominant narrative.

Example: Labeling critics as "fringe" or "extremists" to delegitimize their viewpoints.

35. **Overemphasis on Negatives of Opponents**

Purpose: To focus disproportionately on the flaws or mistakes of those who oppose the agenda of the powerful.

Example: Highlighting every minor gaffe of a political opponent while ignoring substantive policy issues.

36. **Manufactured Statistics**

Purpose: To present misleading or cherry-picked data to support a narrative.

Example: Using selective unemployment statistics that don't account for underemployment or workforce participation rates.

37. **Strategic Ambiguity**

Purpose: To be deliberately vague to avoid accountability or detailed scrutiny.

Example: Announcing a policy with general statements without specifying the concrete measures or implications.

38. **Discrediting Whistleblowers**

Purpose: To undermine the credibility of those who expose misconduct.

Example: Portraying whistleblowers as disgruntled employees or traitors.

39. **False Dilemma**

Purpose: To present a situation as having only two choices, ignoring other viable options.

Example: "Either we implement this policy or face economic ruin," disregarding alternative solutions.

40. **Echoing Talking Points**

Purpose: To repeat specific phrases or ideas consistently across different media outlets to solidify them in public discourse.

Example: Coordinated use of certain buzzwords or slogans in both news articles and political speeches.

41. **Misleading Headlines**

Purpose: To attract attention with sensational or biased headlines that may not accurately reflect the content of the article.

Example: A headline that exaggerates or distorts the findings of a report.

42. **Conflation**

Purpose: To combine two unrelated issues to confuse the audience or obscure the truth.

Example: Linking unrelated policy failures to a particular political ideology to create a false association.

43. **False Balance in Scientific Reporting**

Purpose: To give equal weight to scientific consensus and fringe theories, misleading the public about the level of disagreement.

Example: Presenting climate change deniers' views alongside those of the vast majority of scientists without context.

44. **Strategic Leaks**

Purpose: To release information selectively to control the narrative or distract from other issues.

Example: Releasing favorable news just before a damaging report is due to be published.

45. **Creating Pseudo-Events**

Purpose: To stage events specifically designed to attract media coverage and shape public perception.

Example: Politicians staging visits to disaster areas or community centers to showcase their concern and involvement.

46. **Creating Scapegoats**

Purpose: To divert blame for societal problems onto specific individuals or groups.

Example: Blaming economic downturns on immigrants or minority groups rather than systemic issues.

47. **Amplification of Fear**

Purpose: To use fear to manipulate public opinion and justify certain actions or policies.

Example: Highlighting rare but sensational crimes to justify increased security measures.

48. **Disinformation Campaigns**

Purpose: To deliberately spread false information to confuse or mislead the public.

Example: Spreading fake news or conspiracy theories to discredit opposition or distract from real issues.

49. **Undercover Advertising (Native Advertising)**

Purpose: To present advertisements as genuine news content, blurring the lines between editorial and commercial content.

Example: Sponsored content that looks like a news article but promotes a product or viewpoint.

50. **Use of Surrogates**

Purpose: To have third parties or pundits express views that align with the agenda, providing a veneer of independence.

Example: Using think-tank experts or analysts who have ties to powerful interests to present biased opinions as objective analysis.

51. **Policy Laundering**

Purpose: To introduce controversial policies through less visible channels or secondary legislation to avoid public scrutiny.

Example: Embedding significant policy changes within larger, less controversial bills.

52. **Red Herring**

Purpose: To introduce irrelevant information to distract from the main issue.

Example: Bringing up past scandals or unrelated issues during discussions of current policy failures.

53. **False Attribution**

Purpose: To attribute statements or statistics to credible sources that did not actually provide them.

Example: Claiming that "studies show" a certain fact without referencing specific, credible studies.

54. **Misrepresentation of Opponents’ Views**

Purpose: To distort or mischaracterize the arguments of opponents to make them easier to refute.

Example: Oversimplifying a critic’s nuanced argument to make it seem unreasonable.

55. **Emotional Appeals to Tradition**

Purpose: To argue that certain policies or actions are justified because they are traditional or have always been done that way.

Example: Defending a discriminatory practice by citing historical precedent without addressing current ethical standards.

56. **Pseudo-Expertise**

Purpose: To present individuals with dubious qualifications as experts to lend credibility to a specific narrative.

Example: Featuring "experts" with no relevant background or education to support controversial claims.

57. **Selective Quoting**

Purpose: To quote out of context to misrepresent someone's statement or position.

Example: Using a snippet from a speech that changes its intended meaning.

58. **Deflection with Humor or Satire**

Purpose: To use humor to trivialize serious issues or criticism.

Example: Making jokes about a serious allegation to downplay its significance and avoid addressing it substantively.

59. **Overreliance on Official Sources**

Purpose: To use statements from authorities without questioning or independently verifying them.

Example: Reporting government statements as fact without investigating or seeking alternative viewpoints.

60. **Sensationalizing Successes**

Purpose: To exaggerate the achievements of those in power to build a positive public image.

Example: Extensively covering minor policy successes while ignoring major failures.

61. **Personalization**

Purpose: To focus on individual stories or personalities to distract from systemic issues.

Example: Highlighting a single individual’s success story to imply that systemic barriers do not exist.

62. **Credentialism**

Purpose: To emphasize credentials over the validity of arguments or evidence.

Example: Dismissing valid critiques by pointing out the critic's lack of formal qualifications.

63. **False Clarity**

Purpose: To present complex issues as simple and straightforward to manipulate public understanding.

Example: Reducing a complicated policy debate to a simplistic dichotomy.

64. **Creating Urgency**

Purpose: To invoke a sense of urgency to push through policies without thorough debate or consideration.

Example: Framing a policy decision as needing immediate action to avoid disaster, thereby limiting public discourse.

65. **Using Anecdotal Evidence**

Purpose: To use personal stories or isolated incidents to make broad generalizations.

Example: Using a single positive outcome to argue for a policy’s effectiveness, ignoring broader statistical data.

66. **Normalization of Corruption**

Purpose: To present corrupt practices as standard and unavoidable in order to desensitize the public.

Example: Reporting on corruption as a commonplace and expected part of political life, reducing public outrage.

67. **Demonizing Critics**

Purpose: To portray critics as untrustworthy, malicious, or extremist.

Example: Labeling activists or whistleblowers as anti-progress or enemies of the state.

68. **Creating False Precedents**

Purpose: To cite non-existent or misrepresented precedents to justify current actions.

Example: Claiming that a policy has historical backing when it does not, or misrepresenting past events.

These tactics can subtly manipulate public perception, maintaining the power of influential entities while undermining the role of the media as an independent watchdog.


"""

# %%
def generate_text(prompt):
    response = llm_client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": prompt},
        ],
        max_tokens=4096,  # Adjust this value based on your needs
        n=1,
        stop=None,
        temperature=0,  # Adjust the temperature to control the creativity of the output
    )
    
    return response.choices[0].message.content

# %% [markdown]
# # TO DO: add timestamps of tactics for image caption text generation alignment

# %% [markdown]
# # TO DO: add tag of people speaking (présentatrice, invité)

# %%
tactics = []
for clip in relevant_clip_topics.values():

    # Define the prompt
    prompt = f"""YOU MUST NOW EXTRACT ANY TACTIC YOU FIND IN THE NEWS TRANSCRIPT PROVIDED BELOW. BE VERY SPECIFIC AND ONLY MENTION A TACTIC IF IT IS CLEARLY PRESENT IN THE TRANSCRIPT.
    ALWAYS TAKE INTO ACCOUNT THE PRESENTATOR'S WAY OF ASKING QUESTIONS AS WELL AS THE GUEST's ANSWER IF APPLICABLE (are they oriented?, etc.).
    Base your extraction on the "text" field of the transcript. Consider previous and following lines to extract tactics.
    Output format: Output a list of dict with fields:
        - {{'tactic': extracted tactic,
            'passage': exact retranscription of passage containing tactic,
            'start': start value (int) of passage,
            'end': end value (int) of passage,
            'explanation': why the tactic was extracted
            }}
    
    NEWS TRANSCRIPT: {clip["transcript_ts"]}
    TACTICS:"""

    # Generate the text
    generated_text = generate_text(prompt)
    
    print(clip["transcript_ts"])
    print(generated_text)
    print("-------------")
    tactics.append(generated_text)
# Out:
# start: 6 end: 10 text: Le climat est délétère à l'EPFL
# start: 10 end: 12 text: sur fond de guerre
# entre Israël et le Hamas.
# start: 13 end: 15 text: Les étudiants qui émettent
# un avis contraire
# start: 15 end: 17 text: au mouvement propalestinien
# sont menacés.
# start: 17 end: 27 text: Des jeunes ont peur
# d'aller sur le campus.
# start: 29 end: 32 text: -Si ce groupe de discussion
# sur la guerre au Moyen-Orient
# start: 32 end: 35 text: par des étudiants de l'EPFL
# a été depuis supprimé,
# start: 35 end: 38 text: il en subsiste
# ces captures d'écran.
# start: 41 end: 43 text: Des menaces de mort dirigées
# contre des étudiants
# start: 43 end: 45 text: qui souhaitaient apaiser
# des tensions.
# start: 51 end: 53 text: Ces révélations du journal Le Temps
# start: 53 end: 55 text: décrivent une radicalisation
# sur le campus de l'EPFL.
# start: 55 end: 60 text: Cet étudiant visé ne s'affole pas,
# mais avoue être sur ses gardes.
# start: 62 end: 63 text: -Une limite a été franchie
# start: 63 end: 67 text: parce que c'est un événement
# qui n'a jamais été vu sur le campus.
# start: 67 end: 75 text: On a peur,
# on regarde un peu derrière nous.
# start: 75 end: 78 text: -La direction de l'EPFL
# organisait cet après-midi
# start: 78 end: 80 text: une discussion
# pour éviter toute escalade.
# start: 81 end: 84 text: Si la démarche a été saluée,
# certains en ont profité
# start: 85 end: 88 text: pour remettre en doute
# le témoignage des étudiants menacés.
# start: 88 end: 92 text: -La première réaction dans
# l'auditoire, c'est "ils mentent".
# start: 92 end: 102 text: Ils parlent de menaces de mort,
# donc forcément ils mentent.
# start: 102 end: 105 text: -Du côté
# des manifestants propalestiniens,
# start: 105 end: 108 text: on condamne fermement
# toutes attitudes discriminatoires.
# start: 108 end: 111 text: -Menacer de mort pour des idées
# politiques,
# start: 111 end: 114 text: ce n'est pas acceptable,
# surtout pas dans notre école.
# start: 114 end: 125 text: Ca ne reflète pas
# la majorité des étudiants.
# start: 126 end: 129 text: -Le groupe propalestinien considère
# start: 129 end: 131 text: que la direction porte
# une part de responsabilité
# start: 131 end: 134 text: en limitant la liberté d'expression.
# start: 134 end: 141 text: La direction de l'EPFL doit faire
# la lumière sur ces événements.
# ```json
# [
#     {
#         "tactic": "Sensationalism",
#         "passage": "Le climat est délétère à l'EPFL sur fond de guerre entre Israël et le Hamas.",
#         "start": 6,
#         "end": 12,
#         "explanation": "The use of the word 'délétère' (deleterious) and the dramatic context of a war sets a sensational tone, potentially exaggerating the severity of the situation."
#     },
#     {
#         "tactic": "Loaded Language",
#         "passage": "Les étudiants qui émettent un avis contraire au mouvement propalestinien sont menacés.",
#         "start": 13,
#         "end": 17,
#         "explanation": "The phrase 'sont menacés' (are threatened) uses emotionally charged language to evoke a strong reaction from the audience."
#     },
#     {
#         "tactic": "Appeal to Emotion",
#         "passage": "Des jeunes ont peur d'aller sur le campus.",
#         "start": 17,
#         "end": 27,
#         "explanation": "This statement appeals to the audience's emotions by highlighting the fear of young students, aiming to elicit sympathy and concern."
#     },
#     {
#         "tactic": "Selective Reporting",
#         "passage": "Des menaces de mort dirigées contre des étudiants qui souhaitaient apaiser des tensions.",
#         "start": 41,
#         "end": 45,
#         "explanation": "The focus on death threats without providing broader context or other perspectives selectively highlights the most extreme aspect of the situation."
#     },
#     {
#         "tactic": "Framing",
#         "passage": "Ces révélations du journal Le Temps décrivent une radicalisation sur le campus de l'EPFL.",
#         "start": 51,
#         "end": 55,
#         "explanation": "The use of the term 'radicalisation' frames the situation in a way that suggests extreme and dangerous behavior, influencing the audience's perception."
#     },
#     {
#         "tactic": "Guided Questions",
#         "passage": "-La première réaction dans l'auditoire, c'est 'ils mentent'. Ils parlent de menaces de mort, donc forcément ils mentent.",
#         "start": 88,
#         "end": 102,
#         "explanation": "The presenter uses a guided question to lead the audience to a predetermined conclusion that the students are lying about the death threats."
#     },
#     {
#         "tactic": "False Balance",
#         "passage": "-Du côté des manifestants propalestiniens, on condamne fermement toutes attitudes discriminatoires.",
#         "start": 102,
#         "end": 108,
#         "explanation": "By presenting the condemnation of discriminatory attitudes by pro-Palestinian protesters, the report gives the impression of balanced coverage, even though the overall narrative may be skewed."
#     },
#     {
#         "tactic": "Tokenism",
#         "passage": "Ca ne reflète pas la majorité des étudiants.",
#         "start": 114,
#         "end": 125,
#         "explanation": "This statement is used to give the appearance of inclusivity and balance by suggesting that the extreme actions do not represent the majority, without addressing the systemic issues."
#     }
# ]
# ```
# -------------
# start: 6 end: 9 text: -Martin Vetterli, bonsoir.
# start: 9 end: 15 text: Le Temps révèle que des étudiants
# de votre établissement
# start: 15 end: 21 text: sont harcelés car ils pensent
# différemment, et parlent de paix.
# start: 21 end: 28 text: Un étudiant est menacé de mort
# sur les réseaux sociaux:
# start: 28 end: 31 text: "il faut tuer Nicolas et son gang".
# start: 31 end: 35 text: Une autre est intimidée:
# "on a vu où tu étais assise".
# start: 35 end: 38 text: Quelle est votre réaction ?
# start: 38 end: 40 text: - Je suis très triste
# start: 40 end: 44 text: qu'il y a une telle tension
# sur le campus.
# start: 44 end: 48 text: Ce sont les excès
# des réseaux sociaux.
# start: 48 end: 52 text: Si on n'est pas dans le cadre légal,
# start: 52 end: 55 text: par rapport aux lois
# sur le racisme et l'antisémitisme,
# start: 55 end: 59 text: on donne
# le support à notre communauté.
# start: 59 end: 66 text: Nos étudiants ont des canaux où ils
# peuvent venir chercher de l'aide.
# start: 66 end: 71 text: Et on prendra
# les mesures nécessaires.
# start: 72 end: 75 text: Des plaintes pourront être portées.
# start: 75 end: 79 text: -On entend des étudiants juifs
# start: 79 end: 84 text: qui ont peur de venir sur le campus.
# start: 84 end: 86 text: Leur sécurité est garantie ?
# start: 86 end: 90 text: -C'est notre première priorité.
# start: 90 end: 93 text: La sécurité de tous sur le campus.
# start: 93 end: 98 text: On a parlé avec ces gens,
# ils se sont exprimés.
# start: 98 end: 102 text: Ils ont besoin d'être protégés,
# comme tout le monde.
# start: 102 end: 104 text: -Vous reconnaissez
# qu'il y a une dérive
# start: 104 end: 108 text: de certains membres
# des militants propalestiniens ?
# start: 108 end: 111 text: -Il y a toujours des dérives.
# start: 111 end: 117 text: Il y a un large spectre
# d'opinions sur le campus.
# start: 117 end: 121 text: Notre mission
# est de garder une unité.
# start: 121 end: 124 text: -Comment on en est arrivé là ?
# start: 124 end: 129 text: Y a-t-il aussi une responsabilité
# de la part des grandes écoles
# start: 129 end: 133 text: de laisser entrer ces discussions
# politiques sur le campus ?
# start: 133 end: 137 text: L'université ne doit-elle
# pas être totalement neutre ?
# start: 137 end: 141 text: -L'université en tant qu'institution
# doit rester neutre
# start: 141 end: 143 text: pour permettre un débat.
# start: 143 end: 147 text: Mais chacun est un être humain
# qui peut s'exprimer en son nom.
# start: 147 end: 149 text: Il ne faut pas
# qu'il y ait de dérive.
# start: 150 end: 155 text: Il ne faut pas qu'il y ait le genre
# d'excès dont vous avez parlé.
# start: 156 end: 160 text: -On a atteint
# à ce niveau-là du rouge.
# start: 160 end: 166 text: Qu'est-ce que vous allez faire
# pour remettre de l'ordre ?
# start: 166 end: 169 text: -On n'est pas dans le désordre.
# start: 169 end: 172 text: Sur le campus, ça se passe bien.
# start: 173 end: 178 text: Plusieurs centaines de participants
# représentant les étudiants,
# start: 178 end: 181 text: les employés et les profs ont parlé
# et ça s'est bien passé.
# start: 181 end: 187 text: Tous nos canaux de soutien sont
# à disposition de toute la communauté.
# start: 187 end: 192 text: -Vous appelez les étudiants
# à s'adresser à vos canaux de soutien
# start: 192 end: 196 text: si quelque chose se passe.
# start: 196 end: 200 text: -On a créé
# une commission spécifique.
# start: 200 end: 203 text: On va regarder
# ces différentes dimensions.
# start: 203 end: 209 text: Cette commission
# est dirigée par ma collègue.
# ```json
# [
#     {
#         "tactic": "Loaded Language",
#         "passage": "Le Temps révèle que des étudiants de votre établissement sont harcelés car ils pensent différemment, et parlent de paix.",
#         "start": 9,
#         "end": 21,
#         "explanation": "The phrase 'sont harcelés car ils pensent différemment, et parlent de paix' uses emotionally charged language to frame the situation in a way that evokes sympathy and concern, potentially influencing the audience's perception."
#     },
#     {
#         "tactic": "Guided Questions",
#         "passage": "Leur sécurité est garantie ?",
#         "start": 84,
#         "end": 86,
#         "explanation": "The question 'Leur sécurité est garantie ?' is leading, implying that there is a significant concern about the safety of Jewish students, which may pressure the interviewee to respond in a specific way."
#     },
#     {
#         "tactic": "Guided Questions",
#         "passage": "Vous reconnaissez qu'il y a une dérive de certains membres des militants propalestiniens ?",
#         "start": 102,
#         "end": 108,
#         "explanation": "The question 'Vous reconnaissez qu'il y a une dérive de certains membres des militants propalestiniens ?' is leading, suggesting that the interviewee should acknowledge a specific problem with pro-Palestinian activists, which may not be a neutral or unbiased inquiry."
#     },
#     {
#         "tactic": "Guided Questions",
#         "passage": "Y a-t-il aussi une responsabilité de la part des grandes écoles de laisser entrer ces discussions politiques sur le campus ?",
#         "start": 124,
#         "end": 133,
#         "explanation": "The question 'Y a-t-il aussi une responsabilité de la part des grandes écoles de laisser entrer ces discussions politiques sur le campus ?' is leading, implying that the presence of political discussions on campus is problematic and that the schools might be responsible for it."
#     },
#     {
#         "tactic": "Guided Questions",
#         "passage": "L'université ne doit-elle pas être totalement neutre ?",
#         "start": 133,
#         "end": 137,
#         "explanation": "The question 'L'université ne doit-elle pas être totalement neutre ?' is leading, suggesting that the university should be completely neutral, which may influence the interviewee to agree with this perspective."
#     },
#     {
#         "tactic": "Loaded Language",
#         "passage": "On a atteint à ce niveau-là du rouge. Qu'est-ce que vous allez faire pour remettre de l'ordre ?",
#         "start": 156,
#         "end": 169,
#         "explanation": "The phrase 'On a atteint à ce niveau-là du rouge' uses dramatic language to suggest a critical situation, and 'remettre de l'ordre' implies a need for significant corrective action, which can influence the audience's perception of the severity of the issue."
#     }
# ]
# ```
# -------------

# %%
parsed_res = []
for tactic in tactics:
    parsed_res.append(ast.literal_eval(tactic.replace("```json", "").replace("```", "")))

parsed_res
# Out:
# [[{'tactic': 'Sensationalism',
#    'passage': "Le climat est délétère à l'EPFL sur fond de guerre entre Israël et le Hamas.",
#    'start': 6,
#    'end': 12,
#    'explanation': "The use of the word 'délétère' (deleterious) and the dramatic context of a war sets a sensational tone, potentially exaggerating the severity of the situation."},
#   {'tactic': 'Loaded Language',
#    'passage': 'Les étudiants qui émettent un avis contraire au mouvement propalestinien sont menacés.',
#    'start': 13,
#    'end': 17,
#    'explanation': "The phrase 'sont menacés' (are threatened) uses emotionally charged language to evoke a strong reaction from the audience."},
#   {'tactic': 'Appeal to Emotion',
#    'passage': "Des jeunes ont peur d'aller sur le campus.",
#    'start': 17,
#    'end': 27,
#    'explanation': "This statement appeals to the audience's emotions by highlighting the fear of young students, aiming to elicit sympathy and concern."},
#   {'tactic': 'Selective Reporting',
#    'passage': 'Des menaces de mort dirigées contre des étudiants qui souhaitaient apaiser des tensions.',
#    'start': 41,
#    'end': 45,
#    'explanation': 'The focus on death threats without providing broader context or other perspectives selectively highlights the most extreme aspect of the situation.'},
#   {'tactic': 'Framing',
#    'passage': "Ces révélations du journal Le Temps décrivent une radicalisation sur le campus de l'EPFL.",
#    'start': 51,
#    'end': 55,
#    'explanation': "The use of the term 'radicalisation' frames the situation in a way that suggests extreme and dangerous behavior, influencing the audience's perception."},
#   {'tactic': 'Guided Questions',
#    'passage': "-La première réaction dans l'auditoire, c'est 'ils mentent'. Ils parlent de menaces de mort, donc forcément ils mentent.",
#    'start': 88,
#    'end': 102,
#    'explanation': 'The presenter uses a guided question to lead the audience to a predetermined conclusion that the students are lying about the death threats.'},
#   {'tactic': 'False Balance',
#    'passage': '-Du côté des manifestants propalestiniens, on condamne fermement toutes attitudes discriminatoires.',
#    'start': 102,
#    'end': 108,
#    'explanation': 'By presenting the condemnation of discriminatory attitudes by pro-Palestinian protesters, the report gives the impression of balanced coverage, even though the overall narrative may be skewed.'},
#   {'tactic': 'Tokenism',
#    'passage': 'Ca ne reflète pas la majorité des étudiants.',
#    'start': 114,
#    'end': 125,
#    'explanation': 'This statement is used to give the appearance of inclusivity and balance by suggesting that the extreme actions do not represent the majority, without addressing the systemic issues.'}],
#  [{'tactic': 'Loaded Language',
#    'passage': 'Le Temps révèle que des étudiants de votre établissement sont harcelés car ils pensent différemment, et parlent de paix.',
#    'start': 9,
#    'end': 21,
#    'explanation': "The phrase 'sont harcelés car ils pensent différemment, et parlent de paix' uses emotionally charged language to frame the situation in a way that evokes sympathy and concern, potentially influencing the audience's perception."},
#   {'tactic': 'Guided Questions',
#    'passage': 'Leur sécurité est garantie ?',
#    'start': 84,
#    'end': 86,
#    'explanation': "The question 'Leur sécurité est garantie ?' is leading, implying that there is a significant concern about the safety of Jewish students, which may pressure the interviewee to respond in a specific way."},
#   {'tactic': 'Guided Questions',
#    'passage': "Vous reconnaissez qu'il y a une dérive de certains membres des militants propalestiniens ?",
#    'start': 102,
#    'end': 108,
#    'explanation': "The question 'Vous reconnaissez qu'il y a une dérive de certains membres des militants propalestiniens ?' is leading, suggesting that the interviewee should acknowledge a specific problem with pro-Palestinian activists, which may not be a neutral or unbiased inquiry."},
#   {'tactic': 'Guided Questions',
#    'passage': 'Y a-t-il aussi une responsabilité de la part des grandes écoles de laisser entrer ces discussions politiques sur le campus ?',
#    'start': 124,
#    'end': 133,
#    'explanation': "The question 'Y a-t-il aussi une responsabilité de la part des grandes écoles de laisser entrer ces discussions politiques sur le campus ?' is leading, implying that the presence of political discussions on campus is problematic and that the schools might be responsible for it."},
#   {'tactic': 'Guided Questions',
#    'passage': "L'université ne doit-elle pas être totalement neutre ?",
#    'start': 133,
#    'end': 137,
#    'explanation': "The question 'L'université ne doit-elle pas être totalement neutre ?' is leading, suggesting that the university should be completely neutral, which may influence the interviewee to agree with this perspective."},
#   {'tactic': 'Loaded Language',
#    'passage': "On a atteint à ce niveau-là du rouge. Qu'est-ce que vous allez faire pour remettre de l'ordre ?",
#    'start': 156,
#    'end': 169,
#    'explanation': "The phrase 'On a atteint à ce niveau-là du rouge' uses dramatic language to suggest a critical situation, and 'remettre de l'ordre' implies a need for significant corrective action, which can influence the audience's perception of the severity of the issue."}]]

# %%
parsed_res[0][0]
# Out:
# {'tactic': 'Sensationalism',
#  'passage': "Le climat est délétère à l'EPFL sur fond de guerre entre Israël et le Hamas.",
#  'start': 6,
#  'end': 12,
#  'explanation': "The use of the word 'délétère' (deleterious) and the dramatic context of a war sets a sensational tone, potentially exaggerating the severity of the situation."}

# %% [markdown]
# # Add blank space to video frames for tactics display

# %%
parsed_res
# Out:
# [[{'tactic': 'Sensationalism',
#    'passage': "Le climat est délétère à l'EPFL sur fond de guerre entre Israël et le Hamas.",
#    'start': 6,
#    'end': 12,
#    'explanation': "The use of the word 'délétère' (deleterious) and the dramatic context of a war sets a sensational tone, potentially exaggerating the severity of the situation."},
#   {'tactic': 'Loaded Language',
#    'passage': 'Les étudiants qui émettent un avis contraire au mouvement propalestinien sont menacés.',
#    'start': 13,
#    'end': 17,
#    'explanation': "The phrase 'sont menacés' (are threatened) uses emotionally charged language to evoke a strong reaction from the audience."},
#   {'tactic': 'Appeal to Emotion',
#    'passage': "Des jeunes ont peur d'aller sur le campus.",
#    'start': 17,
#    'end': 27,
#    'explanation': "This statement appeals to the audience's emotions by highlighting the fear of young students, aiming to elicit sympathy and concern."},
#   {'tactic': 'Selective Reporting',
#    'passage': 'Des menaces de mort dirigées contre des étudiants qui souhaitaient apaiser des tensions.',
#    'start': 41,
#    'end': 45,
#    'explanation': 'The focus on death threats without providing broader context or other perspectives selectively highlights the most extreme aspect of the situation.'},
#   {'tactic': 'Framing',
#    'passage': "Ces révélations du journal Le Temps décrivent une radicalisation sur le campus de l'EPFL.",
#    'start': 51,
#    'end': 55,
#    'explanation': "The use of the term 'radicalisation' frames the situation in a way that suggests extreme and dangerous behavior, influencing the audience's perception."},
#   {'tactic': 'Guided Questions',
#    'passage': "-La première réaction dans l'auditoire, c'est 'ils mentent'. Ils parlent de menaces de mort, donc forcément ils mentent.",
#    'start': 88,
#    'end': 102,
#    'explanation': 'The presenter uses a guided question to lead the audience to a predetermined conclusion that the students are lying about the death threats.'},
#   {'tactic': 'False Balance',
#    'passage': '-Du côté des manifestants propalestiniens, on condamne fermement toutes attitudes discriminatoires.',
#    'start': 102,
#    'end': 108,
#    'explanation': 'By presenting the condemnation of discriminatory attitudes by pro-Palestinian protesters, the report gives the impression of balanced coverage, even though the overall narrative may be skewed.'},
#   {'tactic': 'Tokenism',
#    'passage': 'Ca ne reflète pas la majorité des étudiants.',
#    'start': 114,
#    'end': 125,
#    'explanation': 'This statement is used to give the appearance of inclusivity and balance by suggesting that the extreme actions do not represent the majority, without addressing the systemic issues.'}],
#  [{'tactic': 'Loaded Language',
#    'passage': 'Le Temps révèle que des étudiants de votre établissement sont harcelés car ils pensent différemment, et parlent de paix.',
#    'start': 9,
#    'end': 21,
#    'explanation': "The phrase 'sont harcelés car ils pensent différemment, et parlent de paix' uses emotionally charged language to frame the situation in a way that evokes sympathy and concern, potentially influencing the audience's perception."},
#   {'tactic': 'Guided Questions',
#    'passage': 'Leur sécurité est garantie ?',
#    'start': 84,
#    'end': 86,
#    'explanation': "The question 'Leur sécurité est garantie ?' is leading, implying that there is a significant concern about the safety of Jewish students, which may pressure the interviewee to respond in a specific way."},
#   {'tactic': 'Guided Questions',
#    'passage': "Vous reconnaissez qu'il y a une dérive de certains membres des militants propalestiniens ?",
#    'start': 102,
#    'end': 108,
#    'explanation': "The question 'Vous reconnaissez qu'il y a une dérive de certains membres des militants propalestiniens ?' is leading, suggesting that the interviewee should acknowledge a specific problem with pro-Palestinian activists, which may not be a neutral or unbiased inquiry."},
#   {'tactic': 'Guided Questions',
#    'passage': 'Y a-t-il aussi une responsabilité de la part des grandes écoles de laisser entrer ces discussions politiques sur le campus ?',
#    'start': 124,
#    'end': 133,
#    'explanation': "The question 'Y a-t-il aussi une responsabilité de la part des grandes écoles de laisser entrer ces discussions politiques sur le campus ?' is leading, implying that the presence of political discussions on campus is problematic and that the schools might be responsible for it."},
#   {'tactic': 'Guided Questions',
#    'passage': "L'université ne doit-elle pas être totalement neutre ?",
#    'start': 133,
#    'end': 137,
#    'explanation': "The question 'L'université ne doit-elle pas être totalement neutre ?' is leading, suggesting that the university should be completely neutral, which may influence the interviewee to agree with this perspective."},
#   {'tactic': 'Loaded Language',
#    'passage': "On a atteint à ce niveau-là du rouge. Qu'est-ce que vous allez faire pour remettre de l'ordre ?",
#    'start': 156,
#    'end': 169,
#    'explanation': "The phrase 'On a atteint à ce niveau-là du rouge' uses dramatic language to suggest a critical situation, and 'remettre de l'ordre' implies a need for significant corrective action, which can influence the audience's perception of the severity of the issue."}]]

# %%
# !pip install --upgrade decorator==4.4.2

# %%
from moviepy.editor import VideoFileClip
from PIL import Image, ImageDraw
import numpy as np

# Load the original video
video = VideoFileClip("video/final_output/output_0.mp4")

# Function to add blank space to the right of each frame
def add_blank_space(frame):
    # Get frame dimensions
    height, width, _ = frame.shape
    
    # Create a blank white image with the new width (500 pixels more)
    new_width = width + 500
    new_frame = Image.new('RGB', (new_width, height), (255, 255, 255))
    
    # Convert the original frame to a Pillow image
    original_frame = Image.fromarray(frame)
    
    # Paste the original frame into the new frame (aligned to the left)
    new_frame.paste(original_frame, (0, 0))
    
    # Convert back to a NumPy array
    return np.array(new_frame)

# Apply the function to every frame in the video
new_video = video.fl_image(add_blank_space)

# Set the FPS from the input video, or use a default value (e.g., 25)
fps = video.fps if video.fps else 25

new_video = new_video.set_audio(video.audio)

# Write the modified video to a file, using the fps
new_video.write_videofile("insta/in/output_video_with_blank_space.mp4", codec="libx264", fps=fps, audio_codec="aac")
# Out:
# Moviepy - Building video insta/in/output_video_with_blank_space.mp4.
# MoviePy - Writing audio in output_video_with_blank_spaceTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video insta/in/output_video_with_blank_space.mp4
# Moviepy - Done !
# Moviepy - video ready insta/in/output_video_with_blank_space.mp4

# %% [markdown]
# # Overlay text tactics

# %%
from moviepy.editor import VideoFileClip, ImageClip, CompositeVideoClip
from PIL import Image, ImageDraw, ImageFont

def wrap_text(text, font, max_width):
    """
    Wrap text into multiple lines so that it fits within the specified width.
    Parameters:
    - text: str - the text to wrap
    - font: PIL.ImageFont - the font object used to measure text width
    - max_width: int - the maximum width in pixels for each line of text
    
    Returns:
    - wrapped_text: str - the input text with line breaks added
    """
    words = text.split(' ')
    lines = []
    current_line = ""

    for word in words:
        # Check the width of the current line + the next word
        line_width = font.getbbox(current_line + " " + word)[2] if current_line else font.getbbox(word)[2]
        if line_width <= max_width:
            current_line += " " + word if current_line else word
        else:
            lines.append(current_line)
            current_line = word

    if current_line:
        lines.append(current_line)

    return "\n".join(lines)

def generate_text_image(text, size=(500, 100), font_size=24, color='white'):
    """ Generates an image with the given text using PIL, ensuring text wraps within the given width. """
    # Create a font object
    font = ImageFont.truetype("~/Library/Fonts/NotoSans-Regular.ttf", font_size)  # Replace with correct path to font if necessary
    
    # Wrap the text so it fits within the width
    wrapped_text = wrap_text(text, font, size[0])  # size[0] is the width of the image
    
    # Estimate height of the image based on number of lines
    lines = wrapped_text.split('\n')
    text_height = font.getbbox(wrapped_text)[3] * len(lines)  # Estimate height based on font size and line count
    
    # Create the image large enough to fit the text
    img = Image.new('RGB', (size[0], text_height + 20), color='black')  # Add padding
    
    # Draw the text
    d = ImageDraw.Draw(img)
    d.text((10, 10), wrapped_text, fill=color, font=font)
    
    # Save the image temporarily
    img.save("temp_text_image.png")
    
    return "temp_text_image.png"

def add_text_to_video(video_path, text_data, output_path):
    """
    Parameters:
    - video_path: str - path to the input video file
    - text_data: list of tuples [(timestamp1, text1), (timestamp2, text2), ...]
    - output_path: str - path to save the output video file
    """
    # Load the video
    video = VideoFileClip(video_path)
    
    # List to hold clips
    clips = [video]

    # Iterate over text data and add text at the specified timestamps
    for timestamp, text in text_data:
        # Generate text image using PIL
        text_img_path = generate_text_image(text)
        
        # Create an ImageClip
        txt_clip = (ImageClip(text_img_path)
                    .set_duration(5)  # Text display duration (5 seconds in this case)
                    .set_start(timestamp))  # Start time for text display

        # Add text clip to the list of clips
        clips.append(txt_clip.set_position((video.w - 500, 'center')))  # Align text in the blank space

    # Composite the video and text clips together
    final_video = CompositeVideoClip(clips, size=video.size)

    # Add original audio back to the final video
    final_video = final_video.set_audio(video.audio)

    # Write the final video to a file
    final_video.write_videofile(output_path, codec='libx264', audio_codec='aac')

# %%
video_path = "insta/in/output_video_with_blank_space.mp4"
output_path = "insta/out/output_video_with_text.mp4"

text_data = [(x["start"], "/!\ " + x["tactic"]+": "+x["explanation"]) for x in parsed_res[0]]

# %%
add_text_to_video(video_path, text_data, output_path)
# Out:
# Moviepy - Building video insta/out/output_video_with_text.mp4.
# MoviePy - Writing audio in output_video_with_textTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video insta/out/output_video_with_text.mp4
# Moviepy - Done !
# Moviepy - video ready insta/out/output_video_with_text.mp4

# %% [markdown]
# # WITH DIFF FONTS AND SYMBOLS

# %%
from moviepy.editor import VideoFileClip, ImageClip, CompositeVideoClip
from PIL import Image, ImageDraw, ImageFont

def generate_text_image_with_styles(text_parts, font_paths, size=(500, 200), font_size=24, color='white'):
    """
    Generates an image with styled text (bold, italic) and highlights parts of the text.
    - text_parts: list of tuples [(text, style)] - style can be 'bold', 'italic', 'highlight', 'normal'
    - font_paths: dict with 'normal', 'bold', 'italic' paths to font files
    - size: (width, height) of the image
    - font_size: size of the font
    - color: text color (default: white)
    """
    img = Image.new('RGB', size, color='black')
    d = ImageDraw.Draw(img)
    
    # Set initial x, y position
    x, y = 10, 10

    for part, style in text_parts:
        if style == "bold":
            font = ImageFont.truetype(font_paths['bold'], font_size)
        elif style == "italic":
            font = ImageFont.truetype(font_paths['italic'], font_size)
        else:
            font = ImageFont.truetype(font_paths['normal'], font_size)

        if style == "highlight":
            # Draw a rectangle for highlight (slightly bigger than text)
            text_bbox = d.textbbox((x, y), part, font=font)  # Get bounding box for text
            text_width = text_bbox[2] - text_bbox[0]
            text_height = text_bbox[3] - text_bbox[1]
            d.rectangle([(x - 2, y - 2), (x + text_width + 2, y + text_height + 2)], fill="yellow")

        # Draw the text
        d.text((x, y), part, font=font, fill=color)
        
        # Update x position for the next part of the text
        text_bbox = d.textbbox((x, y), part, font=font)
        text_width = text_bbox[2] - text_bbox[0]
        x += text_width + 5  # Add some padding between words
    
    # Save the image temporarily
    img.save("temp_text_image.png")
    return "temp_text_image.png"

def add_text_to_video_with_styles_and_audio(video_path, text_data, output_path):
    """
    Adds styled text (bold, italic, highlighted, emoji) to video and preserves the original audio.
    - video_path: str - path to the input video file
    - text_data: list of tuples [(timestamp1, text1_parts), (timestamp2, text2_parts), ...]
    - output_path: str - path to save the output video file
    """
    # Load the video
    video = VideoFileClip(video_path)
    
    # Font paths (replace these paths with actual paths to your font files)
    font_paths = {
        'normal': 'NotoSans-Regular.ttf',
        'bold': 'NotoSans-Bold.ttf',
        'italic': 'NotoSans-Italic.ttf',
        'emoji': 'NotoColorEmoji-Regular.ttf'
    }
    
    # List to hold clips
    clips = [video]

    # Iterate over text data and add text at the specified timestamps
    for timestamp, text_parts in text_data:
        # Generate text image with styles (bold, italic, highlights, etc.)
        text_img_path = generate_text_image_with_styles(text_parts, font_paths)
        
        # Create an ImageClip
        txt_clip = (ImageClip(text_img_path)
                    .set_duration(5)  # Text display duration (5 seconds in this case)
                    .set_start(timestamp)
                    .set_position((video.w - 500, 'center')))  # Align text in the blank space

        # Add text clip to the list of clips
        clips.append(txt_clip)

    # Composite the video and text clips together
    final_video = CompositeVideoClip(clips, size=video.size)

    # Add original audio back to the final video
    final_video = final_video.set_audio(video.audio)

    # Write the final video to a file
    final_video.write_videofile(output_path, codec='libx264', audio_codec='aac')

# %%
# Define text with parts having different styles
# Use tuple (text, style) where style can be 'bold', 'italic', 'highlight', 'normal'
text_data = [
    (3, [("⚠️", 'normal')]),
    (10, [("Another text here, normal.", 'normal')]),
    (15, [("Final text example.", 'bold')])
]

# %%
video_path = "insta/in/output_video_with_blank_space.mp4"
output_path = "insta/out/output_video_with_text.mp4"

text_data = [(x["start"], [("⚠️ " + x["tactic"]+": "+x["explanation"], "bold")]) for x in parsed_res[0]]

# %%
add_text_to_video_with_styles_and_audio(video_path, text_data, output_path)
# Out:
# Moviepy - Building video insta/out/output_video_with_text.mp4.
# MoviePy - Writing audio in output_video_with_textTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video insta/out/output_video_with_text.mp4
# Moviepy - Done !
# Moviepy - video ready insta/out/output_video_with_text.mp4

# %% [markdown]
# # Insta clip generation

# %%
# !pip install mediapipe==0.10.15

# %%
import cv2
import mediapipe as mp

# %%
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

# For static images:
IMAGE_FILES = ["insta/in/test.png"]
with mp_face_detection.FaceDetection(
    model_selection=1, min_detection_confidence=0.5) as face_detection:
  for idx, file in enumerate(IMAGE_FILES):
    image = cv2.imread(file)
    # Convert the BGR image to RGB and process it with MediaPipe Face Detection.
    results = face_detection.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

    # Draw face detections of each face.
    if not results.detections:
      continue
    annotated_image = image.copy()
    for detection in results.detections:
      print('Nose tip:')
      print(mp_face_detection.get_key_point(
          detection, mp_face_detection.FaceKeyPoint.NOSE_TIP))
      mp_drawing.draw_detection(annotated_image, detection)
    cv2.imwrite('./insta/out/annotated_image' + str(idx) + '.png', annotated_image)

# %%
detection.location_data.relative_bounding_box

# %%
from PIL import Image, ImageDraw, ImageFont

# Load your PNG image
image = Image.open('insta/out/annotated_image0.png')

# Initialize the drawing context with the image as background
draw = ImageDraw.Draw(image)

# Load a font that supports special characters (Arial or DejaVu Sans)
# Use the appropriate path for the font file on your system
#font_path = "~/Library/Fonts/Poppins-ExtraLight.ttf"  # Change to your actual font path
#font_path = "~/Library/Fonts/Supplemental/Arial.ttf"
font_path = "~/Library/Fonts/Symbola.ttf"

font = ImageFont.truetype(font_path, size=20)

# Define the text and position (x, y) coordinates
text = """
⚠️ **Framing**: The way the situation is described (e.g., "climat délétère," "menaces de mort," "radicalisation")
frames the issue in a highly negative light, which can influence the audience's perception of the pro-Palestinian
movement and the overall atmosphere at EPFL.
"""

position = (50, 100)  # (x, y) coordinates
color = (245,35,35)  # White color (R, G, B format)

# Add text to the image
draw.rectangle(((40, 100), (1050, 200)), outline="#f52323", fill="white")
draw.text((50, 100), text, font=ImageFont.truetype(font_path, 20), fill="#f52323")
#draw.text(position, text, font=font, fill=color)

# Save the modified image to a new file
image.save('insta/out/image_with_text_pil.png')

# %% [markdown]
# # TO DO: auto position text based on detected face bounding box
# # position text left/right of face based on rule
# # multiline text with bold/italic fonts
# # remove facial detection points
# # emotion detection

# %% [markdown]
# # Scrap video captions

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
driver = webdriver.Firefox()

# %%
driver.get("https://www.rts.ch/play/tv/19h30/video/19h30?urn=urn:rts:video:14926430")

# %%
soup = BeautifulSoup(driver.page_source)

# %%
clips = soup.find_all("p", {"class": "subdivision__description"})
clip_durations = soup.find_all("div", {"class": "subdivision__duration"})
topic_timestamps = {c.text:d.text for c,d in zip(clips, clip_durations)}
topic_timestamps

# %%
from numpy import cumsum

def time_to_seconds(time_str):
    minutes, seconds = map(int, time_str.split(':'))
    return minutes * 60 + seconds
    
topic_timestamps_s = [time_to_seconds(t) for t in topic_timestamps.values()]
topic_timestamps_s = cumsum(topic_timestamps_s)

for key, new_value in zip(topic_timestamps.keys(), topic_timestamps_s):
    topic_timestamps[key] = int(new_value)

topic_timestamps

# %% [markdown]
# # Legacy

# %%
# !pip install ffmpeg-python

# %%
import os
import requests
import ffmpeg

# Set the base folder where your files are stored
base_folder = 'video'

# Function to download M4S segments
def download_segments(m3u8_url, output_file, base_url):
    segments = []
    with open(os.path.join(base_folder, m3u8_url), 'r') as m3u8_file:
        for line in m3u8_file:
            if line.startswith('#') or not line.strip():
                continue
            segments.append(line.strip())
    
    with open(os.path.join(base_folder, output_file), 'wb') as out_file:
        for segment in segments:
            segment_url = os.path.join(base_url, segment)
            response = requests.get(segment_url)
            out_file.write(response.content)

# %%
# Download the video and audio segments
video_m3u8 = 'index-f3-v1.m3u8'  # Adjust this to the appropriate video stream
audio_m3u8 = 'index-f1-a1.m3u8'  # Adjust this to the appropriate audio stream
base_url = 'https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/'  # Base URL for the segments

download_segments(video_m3u8, 'video.ts', base_url)
download_segments(audio_m3u8, 'audio.ts', base_url)

# Merge the video and audio using ffmpeg
output_file = 'output.mp4'
ffmpeg.input(os.path.join(base_folder, 'video.ts')).output(os.path.join(base_folder, 'audio.ts')).output(output_file).run()

print(f'Merged video and audio into {output_file}')

# %%
import os

# Folder containing the video segments
#folder_path = 'video/video_segments'
folder_path = 'video/audio_segments'

# Check if the folder exists
if not os.path.exists(folder_path):
    print(f"Folder {folder_path} does not exist.")
else:
    # Rename files from "segment_{i}.m4s" to "seg-{i}-f3-v1.m4s"
    for filename in os.listdir(folder_path):
        if filename.startswith('segment_') and filename.endswith('.m4s'):
            # Extract the segment number from the filename
            segment_number = filename.split('_')[1].split('.')[0]
            # Create new filename
            new_filename = f'seg-{segment_number}-f3-v1.m4s'
            # Full paths
            old_file_path = os.path.join(folder_path, filename)
            new_file_path = os.path.join(folder_path, new_filename)
            # Rename the file
            os.rename(old_file_path, new_file_path)
            print(f"Renamed {filename} to {new_filename}")

    print("File renaming completed.")

# %%
import os

# Folder containing the video segments
folder_path = 'video/audio_segments'

# Check if the folder exists
if not os.path.exists(folder_path):
    print(f"Folder {folder_path} does not exist.")
else:
    # Rename files from "seg-{i}-f3-v1.m4s" to "seg-{i}-f3-a1.m4s"
    for filename in os.listdir(folder_path):
        if filename.startswith('seg-') and '-f3-v1.m4s' in filename:
            # Create new filename by replacing 'v1' with 'a1'
            new_filename = filename.replace('-f3-v1.m4s', '-f3-a1.m4s')
            # Full paths
            old_file_path = os.path.join(folder_path, filename)
            new_file_path = os.path.join(folder_path, new_filename)
            # Rename the file
            os.rename(old_file_path, new_file_path)
            print(f"Renamed {filename} to {new_filename}")

    print("File renaming completed.")

# %%
import os
import subprocess

# Define paths to the segments and output file
base_folder = 'video/video_segments'
video_segments = [os.path.join(base_folder, f'seg-{i}-f3-v1.m4s') for i in range(232)]  # Adjust number of segments
audio_segments = [os.path.join('video/audio_segments', f'seg-{i}-f3-a1.m4s') for i in range(232)]  # Adjust number of segments
output_file = 'output.mp4'

# Concatenate video segments into one file
with open(os.path.join(base_folder, 'video_concat.ts'), 'wb') as video_concat:
    for video_segment in video_segments:
        with open(video_segment, 'rb') as vf:
            video_concat.write(vf.read())

# Concatenate audio segments into one file
with open(os.path.join(base_folder, 'audio_concat.ts'), 'wb') as audio_concat:
    for audio_segment in audio_segments:
        with open(audio_segment, 'rb') as af:
            audio_concat.write(af.read())

# Merge video and audio using ffmpeg
subprocess.run([
    'ffmpeg', '-i', os.path.join(base_folder, 'video_concat.ts'),
    '-i', os.path.join(base_folder, 'audio_concat.ts'),
    '-c:v', 'copy', '-c:a', 'copy', output_file
])

print(f'Merged video and audio into {output_file}')

# %% [markdown]
# # Download m4s files

# %%
# URL of the .m4s file
url = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/seg-1-f3-v1.m4s"
#url = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/seg-1-f1-a1.m4s"

# File name where the downloaded file will be saved
output_file = "../data/assets/19h30/video/24_05_2024/seg-1-f3-v1.m4s"
#output_file = "../data/assets/19h30/video/24_05_2024/seg-1-f1-a1.m4s"

# Send a GET request to the URL to download the file
response = requests.get(url, stream=True)

# Check if the request was successful
if response.status_code == 200:
    # Open the output file in write-binary mode
    with open(output_file, "wb") as file:
        # Write the content to the file in chunks to avoid loading the entire file into memory
        for chunk in response.iter_content(chunk_size=1024):
            if chunk:
                file.write(chunk)
    print(f"Downloaded: {output_file}")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")

# %% [markdown]
# # Concatenate files

# %%
import os
import requests
import subprocess

# %% [markdown]
# # DOWNLOAD M4S SEGMENTS

# %%
import os
import requests
from urllib.parse import urljoin

# Function to download .ts or .m4s segments from a .m3u8 file
def download_segments(m3u8_url, output_folder):
    # Extract the base URL from the .m3u8 URL
    base_url = m3u8_url.rsplit('/', 1)[0] + '/'

    response = requests.get(m3u8_url)
    playlist = response.text.splitlines()

    segment_urls = [line for line in playlist if not line.startswith("#")]
    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    segment_files = []
    
    for i, segment_url in enumerate(segment_urls):
        # Handle relative URLs by joining them with the base URL
        if not segment_url.startswith("http"):
            segment_url = urljoin(base_url, segment_url)
        
        segment_file = os.path.join(output_folder, f"segment_{i}.m4s")
        segment_files.append(segment_file)
        
        # Download the segment
        segment_data = requests.get(segment_url).content
        with open(segment_file, "wb") as f:
            f.write(segment_data)
        
        print(f"Downloaded segment {i + 1}/{len(segment_urls)}")
    
    return segment_files

# %%
# VIDEO
video_m3u8_url = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/index-f3-v1.m3u8"  # Adjust this to your actual .m3u8 URL
output_folder = "../data/assets/19h30/video/24_05_2024/video_segments"

download_segments(video_m3u8_url, output_folder)

# %%
# AUDIO
video_m3u8_url = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/index-f1-a1.m3u8"  # Adjust this to your actual .m3u8 URL
output_folder = "../data/assets/19h30/video/24_05_2024/audio_segments"

download_segments(video_m3u8_url, output_folder)

# %% [markdown]
# # CONCATENATE SEGMENTS

# %%
import os
import subprocess

# Path to the directory containing video segments
video_segments_folder = "../data/assets/19h30/video/24_05_2024/video_segments"
audio_segments_folder = "../data/assets/19h30/video/24_05_2024/audio_segments"  # Update if audio is in a separate folder
output_video_file = "output_video.mp4"
final_output_file = "final_output.mp4"

# Step 1: Create a file listing all the video segments to concatenate
def create_segment_list_file(segment_folder, segment_prefix, output_file):
    segment_files = sorted([os.path.join(segment_folder, f) for f in os.listdir(segment_folder) if f.startswith(segment_prefix) and f.endswith('.m4s')])
    
    with open(output_file, "w") as f:
        for segment_file in segment_files:
            f.write(f"file '{segment_file}'\n")
    
    return output_file

# Step 2: Concatenate video segments into a single file
def concatenate_video_segments(segment_list_file, output_file):
    ffmpeg_concat_command = f"ffmpeg -f concat -safe 0 -i {segment_list_file} -c copy {output_file}"
    subprocess.run(ffmpeg_concat_command, shell=True)
    print(f"Video segments concatenated into: {output_file}")

# Step 3: Combine the concatenated video file with audio (if available)
def combine_video_audio(video_file, audio_file, output_file):
    ffmpeg_combine_command = f"ffmpeg -i {video_file} -i {audio_file} -c copy {output_file}"
    subprocess.run(ffmpeg_combine_command, shell=True)
    print(f"Video and audio combined into: {output_file}")

# %%
# Create the file listing the video segments
video_list_file = "../data/assets/19h30/video/24_05_2024/video_segment_list.txt"
create_segment_list_file(video_segments_folder, "segment_", video_list_file)

# %%
# reorder segments
import os
import re

# Folder containing the .m4s files
video_segments_folder = "../data/assets/19h30/video/24_05_2024/video_segments"
output_list_file = "../data/assets/19h30/video/24_05_2024/video_segment_list.txt"

# Function to extract the numeric index from the filename
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(0)) if match else -1  # Return -1 if no number is found (unlikely in your case)

# Step 1: List and sort the .m4s files by their numeric index
segment_files = sorted([f for f in os.listdir(video_segments_folder) if f.endswith(".m4s")], key=extract_number)

# Step 2: Create a list file for FFmpeg with the correctly ordered .m4s files
with open(output_list_file, "w") as f:
    for segment_file in segment_files:
        segment_path = os.path.join(video_segments_folder, segment_file)
        f.write(f"file '{segment_path}'\n")

print(f"Created {output_list_file} with numerically ordered segments.")

# %%
output_list_file = "video_segment_list.txt"
output_list_file

# %%
output_video_file

# %%
# Concatenate the video segments
concatenate_video_segments(output_list_file, output_video_file)

# %%
# Combine video with audio if audio segments are available
# You may replace the audio file if it's a different format or path
audio_file = "path_to_audio_file.m4s"  # Adjust this to the actual audio file or segment
combine_video_audio(output_video_file, audio_file, final_output_file)

# %%
# Function to concatenate the downloaded .ts files
def concatenate_segments(segment_files, output_file):
    with open("file_list.txt", "w") as file_list:
        for segment in segment_files:
            file_list.write(f"file '{segment}'\n")
    
    # Use ffmpeg to concatenate the files
    ffmpeg_command = f"ffmpeg -f concat -safe 0 -i file_list.txt -c copy {output_file}"
    subprocess.run(ffmpeg_command, shell=True)

# %%
# Paths to your video and audio .m3u8 URLs
video_m3u8_url = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/seg-1-f3-v1.m4s"  # Replace with your URL
audio_m3u8_url = "https://rts-vod-amd.akamaized.net/ww/14926430/2fd70dc2-e142-3071-bc7a-a4d0ecdd7765/seg-1-f1-a1.m4s"  # Replace with your URL

# %%
# Output folders for video and audio segments
video_output_folder = "video_segments"
audio_output_folder = "audio_segments"

# Download video and audio segments
video_segment_files = download_segments(video_m3u8_url, video_output_folder)
audio_segment_files = download_segments(audio_m3u8_url, audio_output_folder)

# %%
# Concatenate video and audio files into one final file each
concatenated_video = "concatenated_video.ts"
concatenated_audio = "concatenated_audio.ts"

concatenate_segments(video_segment_files, concatenated_video)
concatenate_segments(audio_segment_files, concatenated_audio)

# Step 3: Combine video and audio into a single MP4 file using ffmpeg
final_output = "output.mp4"
ffmpeg_command = f"ffmpeg -i {concatenated_video} -i {concatenated_audio} -c copy {final_output}"
subprocess.run(ffmpeg_command, shell=True)

print(f"Video saved as {final_output}")

# %%
import os

# Path to the directory containing the .m4s files
video_segments_folder = "../data/assets/19h30/video/24_05_2024/video_segments"
output_file = "all.m4s"

# Remove output file if it exists
if os.path.exists(output_file):
    os.remove(output_file)

# Open the output file in binary append mode
with open(output_file, "ab") as outfile:
    # Sort and concatenate all .m4s files
    for segment_file in sorted(os.listdir(video_segments_folder)):
        if segment_file.endswith(".m4s"):
            segment_path = os.path.join(video_segments_folder, segment_file)
            with open(segment_path, "rb") as infile:
                outfile.write(infile.read())
            print(f"Appended {segment_file}")

print(f"Concatenation complete. Output is in {output_file}")

# %% [markdown]
# # Automate m4s scraping

# %%
import json
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.devtools.v111 import devtools
from selenium.webdriver.common.devtools.v111.network import Network

# %%
# Initialize the Chrome driver
driver = webdriver.Firefox()

# %%
# Enable Network domain
driver.execute(devtools.DevTools.send(Network.enable()))

# Navigate to the page
url = 'https://www.rts.ch/play/tv/19h30/video/19h30?urn=urn:rts:video:15072997'
driver.get(url)

# Wait for some time to let the page load completely
driver.implicitly_wait(5)

# Retrieve network logs
logs = driver.execute(devtools.DevTools.send(Network.getResponseBody))

# Extract network logs and save them as a HAR file
har_entries = []

for log in logs:
    log_data = json.loads(log['message'])['message']
    if log_data['method'] == 'Network.requestWillBeSent':
        har_entries.append(log_data)

# Save HAR data to a file
har_data = {
    "log": {
        "version": "1.2",
        "creator": {
            "name": "Selenium",
            "version": "3.141.0"
        },
        "entries": har_entries
    }
}

# %%
with open('network.har', 'w') as har_file:
    json.dump(har_data, har_file, indent=4)

# Close the browser
driver.quit()

print("HAR file saved as network.har")

# %%
from pydub import AudioSegment

# %%
# Load the .m4s file
audio = AudioSegment.from_file("../data/assets/segment.m4s", format="m4s")

# %%
# Export to .mp4
audio.export("../data/assets/output.mp4", format="mp4")
