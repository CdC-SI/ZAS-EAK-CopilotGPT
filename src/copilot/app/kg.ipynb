# %%
from indexing.scraper import scraper
from indexing.pipelines.admin import AdminParser

from bs4 import BeautifulSoup
from bs4.element import Tag

# %%
sitemap_url = "https://eak.admin.ch/eak/de/home.sitemap.xml"
sitemap = await scraper.fetch(sitemap_url)
sitemap

# %%
parser = AdminParser()
url_list = parser.parse_urls(sitemap)
url_list

# %%
# select language
#url_list = [url.replace("/de/", "/fr/") for url in url_list]
url_list

# %%
# get content
content = scraper.scrap_urls(url_list)
content

# %% [markdown]
# ### Parser

# %% [markdown]
# - https://eak.admin.ch/eak/fr/home/sitemap.html has hierarchical structure of content -> use for KG

# %%
url = "https://eak.admin.ch/eak/fr/home/sitemap.html"

# %%
content = scraper.scrap_urls([url])

# %%
soup = BeautifulSoup(content[0].data)

# %%
soup
# Out:
# <!DOCTYPE HTML>
# <!--[if lt IE 7 ]> <html lang="fr" class="no-js ie6 oldie"> <![endif]--><!--[if IE 7 ]> <html lang="fr" class="no-js ie7 oldie"> <![endif]--><!--[if IE 8 ]> <html lang="fr" class="no-js ie8 oldie"> <![endif]--><!--[if IE 9 ]> <html lang="fr" class="no-js ie9"> <![endif]--><!--[if gt IE 9 ]><!--><html class="no-js no-ie" lang="fr"> <!--<![endif]-->
# <head>
# <title>Aperçu général  | Caisse fédérale de compensation CFC</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/etc/designs/core/frontend/guidelines/img/ico/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="/etc/designs/core/frontend/guidelines/img/ico/browserconfig.xml" name="msapplication-config"/>
# <meta content="vm-z81rKpUUGFccp6aHx1gWH13-HvNLJmYNct9dKlKU" name="google-site-verification"/>
# <meta content="fr" name="language"/>
# <meta content="Caisse fédérale de compensation CFC" name="author"/>
# <!-- current page in other languages -->
# <link href="/eak/de/home/sitemap.html" hreflang="de" lang="de" rel="alternate" type="text/html"/>
# <link href="/eak/it/home/sitemap.html" hreflang="it" lang="it" rel="alternate" type="text/html"/>
# <link href="/eak/fr/home/sitemap.html" hreflang="fr" lang="fr" rel="alternate" type="text/html"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://eak.admin.ch/eak/fr/home/sitemap.html" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="Aperçu général" property="og:title"/>
# <!--style type="text/css" id="antiClickjack">body{display:none !important;}</style-->
# <script type="text/javascript">
#
# 		var styleElement = document.createElement('STYLE');
# 		styleElement.setAttribute('id', 'antiClickjack');
# 		styleElement.setAttribute('type', 'text/css');
# 		styleElement.innerHTML = 'body {display:none !important;}';
# 		document.getElementsByTagName('HEAD')[0].appendChild(styleElement);
#
# 		if (self === top) {
# 			var antiClickjack = document.getElementById("antiClickjack");
# 			antiClickjack.parentNode.removeChild(antiClickjack);
# 		} else {
# 			top.location = self.location;
# 		}
# 	</script>
# <script src="/etc.clientlibs/clientlibs/granite/jquery.min.js"></script>
# <script src="/etc.clientlibs/clientlibs/granite/utils.min.js"></script>
# <script>
# 		Granite.I18n.init({
# 			locale: "fr",
# 			urlPrefix: "/libs/cq/i18n/dict."
# 		});
# 	</script>
# <link href="/etc/designs/core/frontend/guidelines.min.css" rel="stylesheet" type="text/css"/>
# <link href="/etc/designs/core/frontend/modules.min.css" rel="stylesheet" type="text/css"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/favicon.ico" rel="shortcut icon"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/etc/designs/core/frontend/guidelines/img/ico/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <script src="/dam/eak/gtag.js"></script>
# <script src="https://cdnjs.cloudflare.com/polyfill/v2/polyfill.js?version=4.8.0"></script>
# <!--[if lt IE 9]>
# 		<script src="https://cdnjs.cloudflare.com/polyfill/v2/polyfill.js?version=4.8.0"></script>
# 	<![endif]-->
# </head>
# <body class="mod mod-layout skin-layout-template-sitemap" data-glossary="/eak/fr/home.glossaryjs.json">
# <div class="mod mod-contentpage">
# <ul class="access-keys" role="navigation">
# <li><a accesskey="0" href="/eak/fr/home.html">Homepage</a></li>
# <li><a accesskey="1" href="#main-navigation">Main navigation</a></li>
# <li><a accesskey="2" href="#content">Content area</a></li>
# <li><a accesskey="3" href="#site-map">Sitemap</a></li>
# <li><a accesskey="4" href="#search-field">Search</a></li>
# </ul>
# </div>
# <!-- begin: container -->
# <div class="container container-main">
# <header role="banner" style="background-size: cover; background-image:">
# <div class="clearfix">
# <nav class="navbar treecrumb pull-left">
# <h2 class="sr-only">Centrale de compensation</h2>
# <ul class="nav navbar-nav">
# <li class="dropdown">
# <a aria-label="Le Conseil fédéral" class="dropdown-toggle" data-toggle="dropdown" href="#" id="federalAdministration-dropdown"><span class="icon icon--right"></span> Le Conseil fédéral</a>
# <ul aria-labelledby="federalAdministration-dropdown" class="dropdown-menu" role="menu">
# <li class="dropdown-header">
# <a aria-label="Le conseil fédéral admin.ch" href="https://www.admin.ch/gov/fr/accueil.html" target="_blank" title="">Le conseil fédéral admin.ch</a>
# <ul>
# <li>
# <a aria-label="ChF: Chancellerie fédérale" href="https://www.bk.admin.ch/bk/fr/home.html" target="_blank" title=""> ChF: Chancellerie fédérale</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="DFAE: Département fédéral des affaires étrangères" href="http://www.eda.admin.ch/eda/fr/home.html" target="_blank" title=""> DFAE: Département fédéral des affaires étrangères</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="DFI: Département fédéral de l'intérieur" href="https://www.edi.admin.ch/edi/fr/home.html" target="_blank" title=""> DFI: Département fédéral de l'intérieur</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="DFJP: Département fédéral de justice et police" href="https://www.ejpd.admin.ch/content/ejpd/fr/home.html" target="_blank" title=""> DFJP: Département fédéral de justice et police</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="DDPS: Département fédéral de la défense, de la protection de la population et des sports" href="https://www.vbs.admin.ch/fr" target="_blank" title=""> DDPS: Département fédéral de la défense, de la protection de la population et des sports</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="DFF: Département fédéral des finances" href="https://www.efd.admin.ch/fr" target="_blank" title=""> DFF: Département fédéral des finances</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="DEFR: Département fédéral de l'économie, de la formation et de la recherche" href="https://www.wbf.admin.ch/wbf/fr/home.html" target="_blank" title=""> DEFR: Département fédéral de l'économie, de la formation et de la recherche</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="DETEC: Département fédéral de l'environnement, des transports, de l'énergie et de la communication" href="https://www.uvek.admin.ch/uvek/fr/home.html" target="_blank" title=""> DETEC: Département fédéral de l'environnement, des transports, de l'énergie et de la communication</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-label="DFF" class="dropdown-toggle" data-toggle="dropdown" href="#" id="departement-dropdown"><span class="icon icon--right"></span> DFF</a>
# <ul aria-labelledby="departement-dropdown" class="dropdown-menu" role="menu">
# <li class="dropdown-header">
# <a aria-label="DFF: Département fédéral des finances" href="https://www.efd.admin.ch/fr" target="_blank" title="">DFF: Département fédéral des finances</a>
# <ul>
# <li>
# <a aria-label="SG-DFF: Secrétariat général" href="https://www.efd.admin.ch/fr/secretariat-general-dff" target="_blank" title=""> SG-DFF: Secrétariat général</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="SFI: Secrétariat d'Etat et aux questions financières internationales" href="https://www.sif.admin.ch/sif/fr/home.html" target="_blank" title=""> SFI: Secrétariat d'Etat et aux questions financières internationales</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="AFF: Administration fédérale des finances" href="https://www.efv.admin.ch/efv/fr/home.html" target="_blank" title=""> AFF: Administration fédérale des finances</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="OFPER: Office fédéral du personnel" href="https://www.epa.admin.ch/epa/fr/home.html" target="_blank" title=""> OFPER: Office fédéral du personnel</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="AFC: Administration fédérale des contributions" href="https://www.estv.admin.ch/estv/fr/home.html" target="_blank" title=""> AFC: Administration fédérale des contributions</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="OFDF: Office fédéral de la douane et de la sécurité des frontières " href="https://www.bazg.admin.ch/bazg/fr/home.html" target="_blank" title=""> OFDF: Office fédéral de la douane et de la sécurité des frontières </a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="OFIT: Office fédéral de l'informatique et de la télécommunication" href="https://www.bit.admin.ch/bit/fr/home.html" target="_blank" title=""> OFIT: Office fédéral de l'informatique et de la télécommunication</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="OFCL: Office fédéral des constructions et de la logistique" href="https://www.bbl.admin.ch/bbl/fr/home.html" target="_blank" title=""> OFCL: Office fédéral des constructions et de la logistique</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="Délégué fédéral à la cybersécurité / Centre national pour la cybersécurité NCSC" href="https://www.ncsc.admin.ch/ncsc/fr/home.html" target="_blank" title=""> Délégué fédéral à la cybersécurité / Centre national pour la cybersécurité NCSC</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="Déléguée fédérale au plurilinguisme" href="https://www.plurilingua.admin.ch/fr" target="_blank" title=""> Déléguée fédérale au plurilinguisme</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="FINMA: Autorité fédérale de surveillance des marchés financiers" href="https://www.finma.ch/fr" target="_blank" title=""> FINMA: Autorité fédérale de surveillance des marchés financiers</a>
# </li>
# </ul>
# <ul>
# <li>
# <a aria-label="CDF: Contrôle fédéral des finances" href="http://www.efk.admin.ch/index.php?lang=fr" target="_blank" title=""> CDF: Contrôle fédéral des finances</a>
# </li>
# </ul>
# <ul>
# <li>
#
#
#
#
# 																	 PUBLICA: Caisse fédérale de pensions
#
#
# 														</li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-label="CFC" class="dropdown-toggle" href="#" id="federalOffice-dropdown"><span class="icon icon--right"></span> CFC</a>
# </li>
# </ul>
# </nav>
# <!-- begin: metanav -->
# <section class="nav-services clearfix">
# <h2>Aperçu général</h2>
# <h2 class="sr-only">Sélection de la langue</h2>
# <nav class="nav-lang">
# <ul>
# <li>
# <a aria-label="allemand" href="/eak/de/home/sitemap.html" lang="de" title="allemand">DE</a>
# </li>
# <li>
# <a aria-label="français selected" class="active" lang="fr" title="français selected">FR</a>
# </li>
# <li>
# <a aria-label="italien" href="/eak/it/home/sitemap.html" lang="it" title="italien">IT</a>
# </li>
# </ul>
# </nav>
# <h2 class="sr-only">Service navigation</h2>
# <nav class="nav-service">
# <ul>
# <li><a aria-label="Page d'accueil" data-skipextcss="true" href="/eak/fr/home.html" target="_self" title="Page d'accueil">Page d'accueil</a></li>
# <li><a aria-label="Plan du site" data-skipextcss="true" href="/eak/fr/home/sitemap.html" target="_self" title="Plan du site">Plan du site</a></li>
# <li><a aria-label="connect.eak Login" href="https://www.akisnet.ch/ak026?spcd=2/default.aspx" target="_self" title="">connect.eak Login</a></li>
# <li><a aria-label="Contact" data-skipextcss="true" href="/eak/fr/home/EAK/kontakt.html" target="_self" title="Contact">Contact</a></li>
# </ul>
# </nav>
# </section>
# <!-- end: metanav -->
# </div>
# <div class="mod mod-logo">
# <a aria-label="Page d'accueil" class="brand hidden-xs" href="/eak/fr/home.html" id="logo" title="Page d'accueil">
# <img alt="Logo Confédération suisse" src="/eak/fr/_jcr_content/logo/image.imagespooler.png/1674124776626/logo.png"/>
# <h2 id="logo-desktop-departement">Caisse fédérale de compensation CFC
#                     </h2>
# </a>
# </div>
# <div class="mod mod-searchfield">
# <!-- begin: sitesearch desktop-->
# <div class="mod mod-searchfield global-search global-search-standard">
# <form action="/eak/fr/home/suche.html" class="form-horizontal form-search pull-right">
# <h2 class="sr-only">Recherche</h2>
# <label class="sr-only" for="search-field">Recherche</label>
# <input class="form-control search-field" id="search-field" name="query" placeholder="Recherche" type="text"/>
# <button class="icon icon--search icon--before" role="button" tabindex="0">
# <span class="sr-only">Recherche</span>
# </button>
# <button class="icon icon--close icon--after search-reset" role="button" tabindex="0"><span class="sr-only">Réinitialiser la recherche</span></button>
# <div class="search-results">
# <div class="search-results-list"></div>
# </div>
# </form>
# </div>
# <!-- end: sitesearch desktop-->
# </div>
# </header>
# <div class="mod mod-mainnavigation">
# <!-- begin: mainnav -->
# <div class="nav-main yamm navbar" id="main-navigation">
# <h2 class="sr-only">
# 			Navigation
# 		</h2>
# <!-- mobile mainnav buttonbar -->
# <section class="nav-mobile">
# <div class="table-row">
# <div class="nav-mobile-header">
# <div class="table-row">
# <span class="nav-mobile-logo">
# <img alt="Caisse fédérale de compensation CFC" onerror="this.onerror=null; this.src='/etc/designs/core/frontend/guidelines/img/swiss.png'" src="/etc/designs/core/frontend/guidelines/img/swiss.svg"/>
# </span>
# <h2>
# <a aria-label="Page d'accueil" href="/eak/fr/home.html" title="Page d'accueil">CFC</a>
# </h2>
# </div>
# </div>
# <div class="table-cell dropdown">
# <a class="nav-mobile-menu dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="icon icon--menu"></span>
# </a>
# <div class="drilldown dropdown-menu" role="menu">
# <div class="drilldown-container">
# <nav class="nav-page-list">
# <ul aria-controls="submenu">
# <li>
# <a href="/eak/fr/home/Firmen.html">Entreprises</a>
# </li>
# </ul>
# <ul aria-controls="submenu">
# <li>
# <a href="/eak/fr/home/dokumentation.html">Particuliers</a>
# </li>
# </ul>
# <ul aria-controls="submenu">
# <li>
# <a href="/eak/fr/home/formulare.html">Formulaires / Annonces</a>
# </li>
# </ul>
# <ul aria-controls="submenu">
# <li>
# <a href="/eak/fr/home/EAK.html">La CFC</a>
# </li>
# </ul>
# <button aria-label="Fermer" class="yamm-close-bottom">
# <span aria-hidden="true" class="icon icon--top"></span>
# </button>
# </nav>
# </div>
# </div>
# </div>
# <div class="table-cell dropdown">
# <a class="nav-mobile-menu dropdown-toggle" data-toggle="dropdown" href="#">
# <span class="icon icon--search"></span>
# </a>
# <div class="dropdown-menu" role="menu">
# <div class="mod mod-searchfield">
# <div class="mod mod-searchfield global-search global-search-mobile">
# <form action="/eak/fr/home/suche.html" class="form mod-searchfield-mobile" role="form">
# <h2 class="sr-only">Recherche</h2>
# <label class="sr-only" for="search-field-phone">
#                     Recherche
#                 </label>
# <input class="search-input form-control" id="search-field-phone" name="query" placeholder="Recherche" type="text"/>
# <button class="icon icon--search icon--before" role="button" tabindex="0">
# <span class="sr-only">Recherche</span>
# </button>
# <button class="icon icon--close icon--after search-reset" role="button" tabindex="0"><span class="sr-only">Réinitialiser la recherche</span></button>
# <div class="search-results">
# <div class="search-results-list"></div>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <ul aria-controls="submenu" class="nav navbar-nav">
# <li class="dropdown yamm-fw">
# <a aria-label="Entreprises" class="dropdown-toggle" data-toggle="dropdown" data-url="/eak/fr/home/Firmen/_jcr_content/par.html" href="/eak/fr/home/Firmen.html">Entreprises</a>
# <ul aria-controls="submenu" class="dropdown-menu" role="menu">
# <li>
# <div class="yamm-content container-fluid">
# <div class="row">
# <div class="col-sm-12">
# <button class="yamm-close btn btn-link icon icon--after icon--close pull-right">Fermer</button>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 main-column">
# </div>
# </div>
# <br/><br/><br/>
# <button aria-label="Fermer" class="yamm-close-bottom"><span class="icon icon--top"></span></button>
# </div>
# </li>
# </ul>
# </li>
# <li class="dropdown yamm-fw">
# <a aria-label="Particuliers" class="dropdown-toggle" data-toggle="dropdown" data-url="/eak/fr/home/dokumentation/_jcr_content/par.html" href="/eak/fr/home/dokumentation.html">Particuliers</a>
# <ul aria-controls="submenu" class="dropdown-menu" role="menu">
# <li>
# <div class="yamm-content container-fluid">
# <div class="row">
# <div class="col-sm-12">
# <button class="yamm-close btn btn-link icon icon--after icon--close pull-right">Fermer</button>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 main-column">
# </div>
# </div>
# <br/><br/><br/>
# <button aria-label="Fermer" class="yamm-close-bottom"><span class="icon icon--top"></span></button>
# </div>
# </li>
# </ul>
# </li>
# <li class="dropdown yamm-fw">
# <a aria-label="Formulaires / Annonces" class="dropdown-toggle" data-toggle="dropdown" data-url="/eak/fr/home/formulare/_jcr_content/par.html" href="/eak/fr/home/formulare.html">Formulaires / Annonces</a>
# <ul aria-controls="submenu" class="dropdown-menu" role="menu">
# <li>
# <div class="yamm-content container-fluid">
# <div class="row">
# <div class="col-sm-12">
# <button class="yamm-close btn btn-link icon icon--after icon--close pull-right">Fermer</button>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 main-column">
# </div>
# </div>
# <br/><br/><br/>
# <button aria-label="Fermer" class="yamm-close-bottom"><span class="icon icon--top"></span></button>
# </div>
# </li>
# </ul>
# </li>
# <li class="dropdown yamm-fw">
# <a aria-label="La CFC" class="dropdown-toggle" data-toggle="dropdown" data-url="/eak/fr/home/EAK/_jcr_content/par.html" href="/eak/fr/home/EAK.html">La CFC</a>
# <ul aria-controls="submenu" class="dropdown-menu" role="menu">
# <li>
# <div class="yamm-content container-fluid">
# <div class="row">
# <div class="col-sm-12">
# <button class="yamm-close btn btn-link icon icon--after icon--close pull-right">Fermer</button>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 main-column">
# </div>
# </div>
# <br/><br/><br/>
# <button aria-label="Fermer" class="yamm-close-bottom"><span class="icon icon--top"></span></button>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <!-- begin: main -->
# <div class="container-fluid hidden-xs">
# <div class="row">
# <div class="col-sm-12">
# <div class="mod mod-breadcrumb">
# <h2 class="sr-only" id="br1">Breadcrumb</h2>
# <ol aria-labelledby="br1" class="breadcrumb" role="menu">
# <li><a aria-label="Page d'accueil" href="/eak/fr/home.html" title="Page d'accueil">Page d'accueil</a><span class="icon icon--greater"></span></li>
# <li class="active" role="presentation">Aperçu général</li>
# </ol>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12" id="content">
# <div class="visible-xs visible-sm">
# <p><a class="icon icon--before icon--root" href="#context-sidebar">Navigation</a></p>
# </div>
# <div class="contentHead">
# <div class="mod mod-backtooverview">
# </div>
# <a class="icon icon--before icon--print pull-right" href="javascript:$.printPreview.printPreview()" onclick="" title="Imprimer cette page"></a>
# <div class="mod mod-contentpage">
# <h1 class="text-inline">Aperçu général</h1>
# </div>
# </div>
# <div class="mod mod-sitemap">
# <div class="row">
# <div class="col-md-3 col-sm-6">
# <h3>
# <a aria-label="Entreprises" href="/eak/fr/home/Firmen.html" title="Entreprises">Entreprises</a></h3>
# <ul aria-controls="submenu" class="list-unstyled">
# <li><a aria-label="Affiliation" href="/eak/fr/home/Firmen/Anschluss.html" title="Affiliation">Affiliation</a>
# <ul>
# <li><a aria-label="Obligation de s’affilier" href="/eak/fr/home/Firmen/Anschluss/anschlusspflicht.html" title="Obligation de s’affilier">Obligation de s’affilier</a></li>
# <li><a aria-label="Succursales" href="/eak/fr/home/Firmen/Anschluss/zweigniederlassungen.html" title="Succursales">Succursales</a></li>
# <li><a aria-label="Procédure d’affiliation" href="/eak/fr/home/Firmen/Anschluss/anschlussverfahren.html" title="Procédure d’affiliation">Procédure d’affiliation</a></li>
# <li><a aria-label="Contrôle des employeurs" href="/eak/fr/home/Firmen/Anschluss/arbeitgeberkontrolle.html" title="Contrôle des employeurs">Contrôle des employeurs</a></li>
# </ul>
# </li>
# <li><a aria-label="Personnel" href="/eak/fr/home/Firmen/Personal.html" title="Personnel">Personnel</a>
# <ul>
# <li><a aria-label="Annonce de salariés" href="/eak/fr/home/Firmen/Personal/anmeldung-von-arbeitnehmern.html" title="Annonce de salariés">Annonce de salariés</a></li>
# <li><a aria-label="Départ de salariés" href="/eak/fr/home/Firmen/Personal/abmeldung-von-arbeitnehmern.html" title="Départ de salariés">Départ de salariés</a></li>
# <li><a aria-label="Certificat d’assurance" href="/eak/fr/home/Firmen/Personal/versicherungsausweis.html" title="Certificat d’assurance">Certificat d’assurance</a></li>
# </ul>
# </li>
# <li><a aria-label="Mandats externes " href="/eak/fr/home/Firmen/externe_auftraege.html" title="Mandats externes ">Mandats externes </a>
# <ul>
# <li><a aria-label="Appréciation par la caisse de compensation" href="/eak/fr/home/Firmen/externe_auftraege/beurteilung_durch_die_ausgleichskasse.html" title="Appréciation par la caisse de compensation">Appréciation par la caisse de compensation</a></li>
# <li><a aria-label="Statut dans le domaine de l‘AVS/AI/APG au regard du droit des assurances sociales" href="/eak/fr/home/Firmen/externe_auftraege/sozialversicherungsrechtliche_stellung_in_AHV-IV-EO.html" title="Statut dans le domaine de l‘AVS/AI/APG au regard du droit des assurances sociales">Statut dans le domaine de l‘AVS/AI/APG au regard du droit des assurances sociales</a></li>
# </ul>
# </li>
# <li><a aria-label="Travailler à l’étranger" href="/eak/fr/home/Firmen/arbeiten_im_ausland.html" title="Travailler à l’étranger">Travailler à l’étranger</a>
# <ul>
# <li><a aria-label="Détachement, voyage d’affaires" href="/eak/fr/home/Firmen/arbeiten_im_ausland/auslandeinsaetze_entsendungen.html" title="Détachement, voyage d’affaires">Détachement, voyage d’affaires</a></li>
# <li><a aria-label="Fonctionnaires, personnes exerçant une fonction publique" href="/eak/fr/home/Firmen/arbeiten_im_ausland/beamte-personen-im-oeffentlichen-dienst.html" title="Fonctionnaires, personnes exerçant une fonction publique">Fonctionnaires, personnes exerçant une fonction publique</a></li>
# <li><a aria-label="Travailler dans plusieurs Etats, pluriactivité" href="/eak/fr/home/Firmen/arbeiten_im_ausland/arbeiten_in_mehreren_staaten.html" title="Travailler dans plusieurs Etats, pluriactivité">Travailler dans plusieurs Etats, pluriactivité</a></li>
# <li><a aria-label="ALPS" href="/eak/fr/home/Firmen/arbeiten_im_ausland/alps.html" title="ALPS">ALPS</a></li>
# <li><a aria-label="Certificat A1, Certificate of Coverage (CoC)" href="/eak/fr/home/Firmen/arbeiten_im_ausland/bescheinigung-a1-coc.html" title="Certificat A1, Certificate of Coverage (CoC)">Certificat A1, Certificate of Coverage (CoC)</a></li>
# </ul>
# </li>
# <li><a aria-label="Cotisations et salaires" href="/eak/fr/home/Firmen/beitraege_und_loehne.html" title="Cotisations et salaires">Cotisations et salaires</a>
# <ul>
# <li><a aria-label="Acomptes de cotisations" href="/eak/fr/home/Firmen/beitraege_und_loehne/akontobeitraege.html" title="Acomptes de cotisations">Acomptes de cotisations</a></li>
# <li><a aria-label="Décompte des salaires et Déclaration de salaires" href="/eak/fr/home/Firmen/beitraege_und_loehne/lohndeklaration_und_lohnmeldung.html" title="Décompte des salaires et Déclaration de salaires">Décompte des salaires et Déclaration de salaires</a></li>
# <li><a aria-label="Décompte annuel" href="/eak/fr/home/Firmen/beitraege_und_loehne/jahresabrechnung.html" title="Décompte annuel">Décompte annuel</a></li>
# <li><a aria-label="Avenants de salaire et remboursements" href="/eak/fr/home/Firmen/beitraege_und_loehne/lohnnachtraege_und_rueckerstattungen.html" title="Avenants de salaire et remboursements">Avenants de salaire et remboursements</a></li>
# <li><a aria-label="Taxe sur le CO2" href="/eak/fr/home/Firmen/beitraege_und_loehne/co2-abgabe.html" title="Taxe sur le CO2">Taxe sur le CO2</a></li>
# <li><a aria-label="eBill" href="/eak/fr/home/Firmen/beitraege_und_loehne/e-rechnung.html" title="eBill">eBill</a></li>
# </ul>
# </li>
# <li><a aria-label="Allocations familiales" href="/eak/fr/home/Firmen/familienzulagen.html" title="Allocations familiales">Allocations familiales</a>
# <ul>
# <li><a aria-label="Bases" href="/eak/fr/home/Firmen/familienzulagen/grundlagen.html" title="Bases">Bases</a></li>
# <li><a aria-label="Obligation d'informer" href="/eak/fr/home/Firmen/familienzulagen/meldepflicht.html" title="Obligation d'informer">Obligation d'informer</a>
# <ul>
# <li><a aria-label="Fiche informative" href="/eak/fr/home/Firmen/familienzulagen/meldepflicht/familienzulagen.html" title="Fiche informative">Fiche informative</a></li>
# <li><a aria-label="Devoir d’informer et de collaborer" href="/eak/fr/home/Firmen/familienzulagen/meldepflicht/melde--und-mitwirkungspflicht-gegenueber-der-familienausgleichsk.html" title="Devoir d’informer et de collaborer">Devoir d’informer et de collaborer</a></li>
# </ul>
# </li>
# <li><a aria-label="Procédure" href="/eak/fr/home/Firmen/familienzulagen/vorgehen.html" title="Procédure">Procédure</a>
# <ul>
# <li><a aria-label="Plan de production 2024" href="/eak/fr/home/Firmen/familienzulagen/vorgehen/produktionsplan-2024.html" title="Plan de production 2024">Plan de production 2024</a></li>
# </ul>
# </li>
# <li><a aria-label="Enfants résidant à l’étranger" href="/eak/fr/home/Firmen/familienzulagen/kinder-im-ausland.html" title="Enfants résidant à l’étranger">Enfants résidant à l’étranger</a></li>
# <li><a aria-label="Dispositions cantonales" href="/eak/fr/home/Firmen/familienzulagen/kantonalebestimmungen.html" title="Dispositions cantonales">Dispositions cantonales</a></li>
# <li><a aria-label="Gestion des dossiers" href="/eak/fr/home/Firmen/familienzulagen/dossierfuehrung.html" title="Gestion des dossiers">Gestion des dossiers</a></li>
# <li><a aria-label="«home made» CAF" href="/eak/fr/home/Firmen/familienzulagen/home-made-fak.html" title="«home made» CAF">«home made» CAF</a>
# <ul>
# <li><a aria-label="Enfants domiciliés en Suisse pour les employeurs «home made»" href="/eak/fr/home/Firmen/familienzulagen/home-made-fak/kinder-in-der-schweiz.html" title="Enfants domiciliés en Suisse pour les employeurs «home made»">Enfants domiciliés en Suisse pour les employeurs «home made»</a></li>
# <li><a aria-label="Enfants domiciliés à l’étranger pour les employeurs «home made» " href="/eak/fr/home/Firmen/familienzulagen/home-made-fak/kinder-im-ausland.html" title="Enfants domiciliés à l’étranger pour les employeurs «home made» ">Enfants domiciliés à l’étranger pour les employeurs «home made» </a></li>
# <li><a aria-label="Allocations de formation pour les employeurs «home made»" href="/eak/fr/home/Firmen/familienzulagen/home-made-fak/ausbildung.html" title="Allocations de formation pour les employeurs «home made»">Allocations de formation pour les employeurs «home made»</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a aria-label="Allocations pour perte de gain" href="/eak/fr/home/Firmen/erwerbsersatz.html" title="Allocations pour perte de gain">Allocations pour perte de gain</a>
# <ul>
# <li><a aria-label="Allocation de paternité, resp. allocation à l’autre parent" href="/eak/fr/home/Firmen/erwerbsersatz/vaterschaftsentschaedigung-ab-01-01-2021-fuer-firmen.html" title="Allocation de paternité, resp. allocation à l’autre parent">Allocation de paternité, resp. allocation à l’autre parent</a></li>
# <li><a aria-label="Allocation d‘adoption" href="/eak/fr/home/Firmen/erwerbsersatz/adoptionsentschaedigung.html" title="Allocation d‘adoption">Allocation d‘adoption</a></li>
# <li><a aria-label="Allocation de prise en charge" href="/eak/fr/home/Firmen/erwerbsersatz/betreuungsentschadigung.html" title="Allocation de prise en charge">Allocation de prise en charge</a></li>
# <li><a aria-label="Allocation de maternité" href="/eak/fr/home/Firmen/erwerbsersatz/mutterschaft.html" title="Allocation de maternité">Allocation de maternité</a></li>
# <li><a aria-label="APG (service militaire, jeunesse et sport)" href="/eak/fr/home/Firmen/erwerbsersatz/militaer_jugend_und_sport.html" title="APG (service militaire, jeunesse et sport)">APG (service militaire, jeunesse et sport)</a></li>
# </ul>
# </li>
# <li><a aria-label="connect.eak" href="/eak/fr/home/Firmen/connect-eak.html" title="connect.eak">connect.eak</a>
# <ul>
# <li><a aria-label="Délégations" href="/eak/fr/home/Firmen/connect-eak/delegationsfunktion.html" title="Délégations">Délégations</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="col-md-3 col-sm-6">
# <h3>
# <a aria-label="Particuliers" href="/eak/fr/home/dokumentation.html" title="Particuliers">Particuliers</a></h3>
# <ul aria-controls="submenu" class="list-unstyled">
# <li><a aria-label="Mon compte AVS" href="/eak/fr/home/dokumentation/mein_ahv-konto.html" title="Mon compte AVS">Mon compte AVS</a>
# <ul>
# <li><a aria-label="Extrait de compte" href="/eak/fr/home/dokumentation/mein_ahv-konto/kontoauszug.html" title="Extrait de compte">Extrait de compte</a></li>
# <li><a aria-label="Certificat d’assurance" href="/eak/fr/home/dokumentation/mein_ahv-konto/versicherungsausweis.html" title="Certificat d’assurance">Certificat d’assurance</a></li>
# </ul>
# </li>
# <li><a aria-label="État civil" href="/eak/fr/home/dokumentation/zivilstand.html" title="État civil">État civil</a>
# <ul>
# <li><a aria-label="Célibataire, concubinage" href="/eak/fr/home/dokumentation/zivilstand/ledig_konkubinat.html" title="Célibataire, concubinage">Célibataire, concubinage</a></li>
# <li><a aria-label="Mariage, partenariat enregistré" href="/eak/fr/home/dokumentation/zivilstand/heirat_eingetragene_partnerschaft.html" title="Mariage, partenariat enregistré">Mariage, partenariat enregistré</a></li>
# <li><a aria-label="Divorce, séparation" href="/eak/fr/home/dokumentation/zivilstand/trennung_scheidung.html" title="Divorce, séparation">Divorce, séparation</a></li>
# <li><a aria-label="Veuvage" href="/eak/fr/home/dokumentation/zivilstand/verwitwung.html" title="Veuvage">Veuvage</a></li>
# </ul>
# </li>
# <li><a aria-label="Enfants" href="/eak/fr/home/dokumentation/kinder.html" title="Enfants">Enfants</a>
# <ul>
# <li><a aria-label="Allocations familiales" href="/eak/fr/home/dokumentation/kinder/familienzulagen.html" title="Allocations familiales">Allocations familiales</a></li>
# <li><a aria-label="Rente pour l’enfant" href="/eak/fr/home/dokumentation/kinder/kinderrente.html" title="Rente pour l’enfant">Rente pour l’enfant</a></li>
# <li><a aria-label="Formation" href="/eak/fr/home/dokumentation/kinder/ausbildung.html" title="Formation">Formation</a></li>
# </ul>
# </li>
# <li><a aria-label="Travail" href="/eak/fr/home/dokumentation/arbeit.html" title="Travail">Travail</a>
# <ul>
# <li><a aria-label="Emploi" href="/eak/fr/home/dokumentation/arbeit/anstellung.html" title="Emploi">Emploi</a></li>
# <li><a aria-label="Emploi à temps partiel" href="/eak/fr/home/dokumentation/arbeit/teilzeitbeschaeftigung.html" title="Emploi à temps partiel">Emploi à temps partiel</a></li>
# <li><a aria-label="Indépendants" href="/eak/fr/home/dokumentation/arbeit/selbstaendigerwerbende.html" title="Indépendants">Indépendants</a></li>
# </ul>
# </li>
# <li><a aria-label="Interruption de travail, aucune activité lucrative" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit.html" title="Interruption de travail, aucune activité lucrative">Interruption de travail, aucune activité lucrative</a>
# <ul>
# <li><a aria-label="Allocation de prise en charge" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit/betreuungsentschaedigung.html" title="Allocation de prise en charge">Allocation de prise en charge</a></li>
# <li><a aria-label="Allocation d‘adoption" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit/adoptionsentschaedigung.html" title="Allocation d‘adoption">Allocation d‘adoption</a></li>
# <li><a aria-label="Personnes sans activité lucrative" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit/keine_erwerbstaetigkeit.html" title="Personnes sans activité lucrative">Personnes sans activité lucrative</a></li>
# <li><a aria-label="Congé non payé" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit/unbezahlter_urlaub.html" title="Congé non payé">Congé non payé</a></li>
# <li><a aria-label="Invalidité" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit/invaliditaet.html" title="Invalidité">Invalidité</a></li>
# <li><a aria-label="Maladie, accident" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit/krankheit_unfall.html" title="Maladie, accident">Maladie, accident</a></li>
# <li><a aria-label="Allocation de maternité" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit/mutterschaft.html" title="Allocation de maternité">Allocation de maternité</a></li>
# <li><a aria-label="Allocation de paternité, resp. allocation à l’autre parent" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit/vaterschaftsurlaub-ab-01-01-2021.html" title="Allocation de paternité, resp. allocation à l’autre parent">Allocation de paternité, resp. allocation à l’autre parent</a></li>
# <li><a aria-label="APG (service militaire, jeunesse et sport)" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit/militaer_jugend_und_sport.html" title="APG (service militaire, jeunesse et sport)">APG (service militaire, jeunesse et sport)</a></li>
# </ul>
# </li>
# <li><a aria-label="Départ à la retraite" href="/eak/fr/home/dokumentation/pensionierung.html" title="Départ à la retraite">Départ à la retraite</a>
# <ul>
# <li><a aria-label="Calcul anticipé de la rente" href="/eak/fr/home/dokumentation/pensionierung/rentenvorausberechnung.html" title="Calcul anticipé de la rente">Calcul anticipé de la rente</a></li>
# <li><a aria-label="Rente de vieillesse" href="/eak/fr/home/dokumentation/pensionierung/altersrente.html" title="Rente de vieillesse">Rente de vieillesse</a></li>
# <li><a aria-label="Nouveau calcul de la rente de vieillesse après l’âge de référence" href="/eak/fr/home/dokumentation/pensionierung/neuberechnung-der-altersrente-nach-dem-referenzalter.html" title="Nouveau calcul de la rente de vieillesse après l’âge de référence">Nouveau calcul de la rente de vieillesse après l’âge de référence</a></li>
# <li><a aria-label="Flexibilisation de la retraite" href="/eak/fr/home/dokumentation/pensionierung/vorbezug_aufschub.html" title="Flexibilisation de la retraite">Flexibilisation de la retraite</a>
# <ul>
# <li><a aria-label="Anticipation" href="/eak/fr/home/dokumentation/pensionierung/vorbezug_aufschub/vorbezug.html" title="Anticipation">Anticipation</a></li>
# <li><a aria-label="Ajournement" href="/eak/fr/home/dokumentation/pensionierung/vorbezug_aufschub/aufschub.html" title="Ajournement">Ajournement</a></li>
# </ul>
# </li>
# <li><a aria-label="Allocations pour impotent" href="/eak/fr/home/dokumentation/pensionierung/hilflosenentschaedigung.html" title="Allocations pour impotent">Allocations pour impotent</a></li>
# <li><a aria-label="Obligation de cotiser" href="/eak/fr/home/dokumentation/pensionierung/beitragspflicht.html" title="Obligation de cotiser">Obligation de cotiser</a></li>
# <li><a aria-label="Versements des rentes" href="/eak/fr/home/dokumentation/pensionierung/rentenauszahlung.html" title="Versements des rentes">Versements des rentes</a></li>
# <li><a aria-label="Réforme AVS 21" href="/eak/fr/home/dokumentation/pensionierung/reform-ahv21.html" title="Réforme AVS 21">Réforme AVS 21</a>
# <ul>
# <li><a aria-label="Âge de référence 65 ans" href="/eak/fr/home/dokumentation/pensionierung/reform-ahv21/referenzalter.html" title="Âge de référence 65 ans">Âge de référence 65 ans</a></li>
# <li><a aria-label="Mesures de compensation" href="/eak/fr/home/dokumentation/pensionierung/reform-ahv21/ausgleichsmassnahmen.html" title="Mesures de compensation">Mesures de compensation</a></li>
# <li><a aria-label="Supplément de rente" href="/eak/fr/home/dokumentation/pensionierung/reform-ahv21/rentenzuschlag.html" title="Supplément de rente">Supplément de rente</a></li>
# <li><a aria-label="Taux de réduction" href="/eak/fr/home/dokumentation/pensionierung/reform-ahv21/kuerzungssaetze-bei-vorbezug.html" title="Taux de réduction">Taux de réduction</a></li>
# <li><a aria-label="Retraite flexible	" href="/eak/fr/home/dokumentation/pensionierung/reform-ahv21/flexibler-rentenbezug-ab-63-jahren.html" title="Retraite flexible	">Retraite flexible	</a></li>
# <li><a aria-label="Travail après 65 ans " href="/eak/fr/home/dokumentation/pensionierung/reform-ahv21/arbeiten-nach-65.html" title="Travail après 65 ans ">Travail après 65 ans </a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a aria-label="À l’étranger" href="/eak/fr/home/dokumentation/im_ausland.html" title="À l’étranger">À l’étranger</a>
# <ul>
# <li><a aria-label="Activités à l’étranger, détachements" href="/eak/fr/home/dokumentation/im_ausland/auslandeinsaetze-entsendungen.html" title="Activités à l’étranger, détachements">Activités à l’étranger, détachements</a></li>
# <li><a aria-label="Activité lucrative dans plusieurs pays" href="/eak/fr/home/dokumentation/im_ausland/erwerbstaetigkeit-in-mehreren-staaten.html" title="Activité lucrative dans plusieurs pays">Activité lucrative dans plusieurs pays</a></li>
# <li><a aria-label="Personnes sans activité lucrative à l’étranger" href="/eak/fr/home/dokumentation/im_ausland/nichterwerbstaetige-im-ausland.html" title="Personnes sans activité lucrative à l’étranger">Personnes sans activité lucrative à l’étranger</a></li>
# <li><a aria-label="Assurance facultative" href="/eak/fr/home/dokumentation/im_ausland/freiwillige-versicherung.html" title="Assurance facultative">Assurance facultative</a></li>
# </ul>
# </li>
# <li><a aria-label="Attestation fiscale" href="/eak/fr/home/dokumentation/steuerausweis.html" title="Attestation fiscale">Attestation fiscale</a></li>
# </ul>
# </div>
# <div class="col-md-3 col-sm-6">
# <h3>
# <a aria-label="Formulaires / Annonces" href="/eak/fr/home/formulare.html" title="Formulaires / Annonces">Formulaires / Annonces</a></h3>
# </div>
# <div class="col-md-3 col-sm-6">
# <h3>
# <a aria-label="La CFC" href="/eak/fr/home/EAK.html" title="La CFC">La CFC</a></h3>
# <ul aria-controls="submenu" class="list-unstyled">
# <li><a aria-label="Nos produits" href="/eak/fr/home/EAK/unsere-leistungen.html" title="Nos produits">Nos produits</a>
# <ul>
# <li><a aria-label="Assurance-vieillesse et survivants (AVS)" href="/eak/fr/home/EAK/unsere-leistungen/ahv.html" title="Assurance-vieillesse et survivants (AVS)">Assurance-vieillesse et survivants (AVS)</a></li>
# <li><a aria-label="Assurance-invalidité (AI)" href="/eak/fr/home/EAK/unsere-leistungen/iv.html" title="Assurance-invalidité (AI)">Assurance-invalidité (AI)</a></li>
# <li><a aria-label="Les allocations pour perte de gain (APG)" href="/eak/fr/home/EAK/unsere-leistungen/eo.html" title="Les allocations pour perte de gain (APG)">Les allocations pour perte de gain (APG)</a></li>
# <li><a aria-label="Indemnités parentales" href="/eak/fr/home/EAK/unsere-leistungen/mutterschaftsentschaedigung.html" title="Indemnités parentales">Indemnités parentales</a></li>
# <li><a aria-label="Allocations familiales (AF)" href="/eak/fr/home/EAK/unsere-leistungen/familienausgleichskasse.html" title="Allocations familiales (AF)">Allocations familiales (AF)</a></li>
# </ul>
# </li>
# <li><a aria-label="Portrait" href="/eak/fr/home/EAK/portrait.html" title="Portrait">Portrait</a>
# <ul>
# <li><a aria-label="Nos principes" href="/eak/fr/home/EAK/portrait/vision--leitbild.html" title="Nos principes">Nos principes</a></li>
# <li><a aria-label="Assurances qualité" href="/eak/fr/home/EAK/portrait/qualitaetssicherung.html" title="Assurances qualité">Assurances qualité</a></li>
# <li><a aria-label="A proximité du client" href="/eak/fr/home/EAK/portrait/kundennaehe.html" title="A proximité du client">A proximité du client</a></li>
# </ul>
# </li>
# <li><a aria-label="Organisation" href="/eak/fr/home/EAK/organisation.html" title="Organisation">Organisation</a>
# <ul>
# <li><a aria-label="Organigramme" href="/eak/fr/home/EAK/organisation/organigramm.html" title="Organigramme">Organigramme</a></li>
# <li><a aria-label="La gérante de la CFC " href="/eak/fr/home/EAK/organisation/kassenleitung.html" title="La gérante de la CFC ">La gérante de la CFC </a></li>
# <li><a aria-label="Le comité de la caisse" href="/eak/fr/home/EAK/organisation/geschaeftsleitung.html" title="Le comité de la caisse">Le comité de la caisse</a></li>
# <li><a aria-label="Centrale de compensation (CdC)" href="/eak/fr/home/EAK/organisation/zentraleausgleichsstelleZAS.html" title="Centrale de compensation (CdC)">Centrale de compensation (CdC)</a></li>
# </ul>
# </li>
# <li><a aria-label="Publications" href="/eak/fr/home/EAK/publikationen.html" title="Publications">Publications</a>
# <ul>
# <li><a aria-label="Rapports annuels" href="/eak/fr/home/EAK/publikationen/jahresberichte.html" title="Rapports annuels">Rapports annuels</a>
# <ul>
# <li><a aria-label="Rapport annuel 2023" href="/eak/fr/home/EAK/publikationen/jahresberichte/jahresbericht-2023.html" title="Rapport annuel 2023">Rapport annuel 2023</a>
# <ul>
# <li><a aria-label="Avant-propos" href="/eak/fr/home/EAK/publikationen/jahresberichte/jahresbericht-2023/vorwort.html" title="Avant-propos">Avant-propos</a></li>
# <li><a aria-label="Aperçu" href="/eak/fr/home/EAK/publikationen/jahresberichte/jahresbericht-2023/uberblick.html" title="Aperçu">Aperçu</a></li>
# <li><a aria-label="Cotisations" href="/eak/fr/home/EAK/publikationen/jahresberichte/jahresbericht-2023/beitraege.html" title="Cotisations">Cotisations</a></li>
# <li><a aria-label="Prestations" href="/eak/fr/home/EAK/publikationen/jahresberichte/jahresbericht-2023/leistungen.html" title="Prestations">Prestations</a></li>
# <li><a aria-label="Allocations familiales" href="/eak/fr/home/EAK/publikationen/jahresberichte/jahresbericht-2023/familienausgleichskasse-eak.html" title="Allocations familiales">Allocations familiales</a></li>
# <li><a aria-label="Finances" href="/eak/fr/home/EAK/publikationen/jahresberichte/jahresbericht-2023/finanzen.html" title="Finances">Finances</a></li>
# <li><a aria-label="Services d’état-major" href="/eak/fr/home/EAK/publikationen/jahresberichte/jahresbericht-2023/stabsdienste.html" title="Services d’état-major">Services d’état-major</a></li>
# <li><a aria-label="Impressum" href="/eak/fr/home/EAK/publikationen/jahresberichte/jahresbericht-2023/impressum.html" title="Impressum">Impressum</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a aria-label="Archives des actualités " href="/eak/fr/home/EAK/publikationen/mitteilungs-archiv.html" title="Archives des actualités ">Archives des actualités </a></li>
# <li><a aria-label="Nouveautés pour 2024" href="/eak/fr/home/EAK/publikationen/neuerungen-2024.html" title="Nouveautés pour 2024">Nouveautés pour 2024</a></li>
# </ul>
# </li>
# <li><a aria-label="Cours et conseils" href="/eak/fr/home/EAK/kurse-und-beratung.html" title="Cours et conseils">Cours et conseils</a>
# <ul>
# <li><a aria-label="Offre de cours" href="/eak/fr/home/EAK/kurse-und-beratung/kursangebot.html" title="Offre de cours">Offre de cours</a></li>
# <li><a aria-label="Formulaire d'inscription" href="/eak/fr/home/EAK/kurse-und-beratung/kursanmeldung.html" title="Formulaire d'inscription">Formulaire d'inscription</a></li>
# </ul>
# </li>
# <li><a aria-label="Places vacantes" href="/eak/fr/home/EAK/offene-stellen0.html" title="Places vacantes">Places vacantes</a></li>
# <li><a aria-label="Contact" href="/eak/fr/home/EAK/kontakt.html" title="Contact">Contact</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="mod mod-backtooverview">
# </div>
# <div class="clearfix">
# <p class="pull-right">
# <small>
# <a class="icon icon--before icon--power hidden-print" href="#">
# 					Début de la page
# 				</a>
# </small>
# </p>
# </div>
# </div>
# </div>
# </div>
# <!-- end: main -->
# <span class="visible-print">https://eak.admin.ch/content/eak/fr/home/sitemap.html</span>
# <footer role="contentinfo">
# <h2 class="sr-only">Footer</h2>
# <a name="context-sidebar"></a>
# <div class="container-fluid footer-service">
# <h3>Caisse fédérale de compensation CFC</h3>
# <nav>
# <ul>
# <li><a aria-label="Page d'accueil" href="/eak/fr/home.html" target="_self" title="Page d'accueil">Page d'accueil</a></li>
# <li><a aria-label="Plan du site" href="/eak/fr/home/sitemap.html" target="_self" title="Plan du site">Plan du site</a></li>
# <li><a aria-label="connect.eak Login" class="icon icon--after icon--external" href="https://www.akisnet.ch/ak026?spcd=2/default.aspx" target="_self" title="">connect.eak Login</a></li>
# <li><a aria-label="Contact" href="/eak/fr/home/EAK/kontakt.html" target="_self" title="Contact">Contact</a></li>
# </ul>
# </nav>
# </div>
# <div class="site-map">
# <h2 class="sr-only">Footer</h2>
# <a class="site-map-toggle collapsed" data-target="#site-map" data-toggle="collapse" href="#site-map">Sitemap</a>
# <div class="container-fluid" id="site-map">
# <div class="col-sm-6 col-md-3">
# <div class="mod mod-linklist">
# <h2>Entreprises</h2>
# <ul class="list-unstyled">
# <li>
# <a aria-label="Affiliation" data-skipextcss="true" href="/eak/fr/home/Firmen/Anschluss.html" title="Affiliation">Affiliation</a>
# </li>
# <li>
# <a aria-label="Personnel" data-skipextcss="true" href="/eak/fr/home/Firmen/Personal.html" title="Personnel">Personnel</a>
# </li>
# <li>
# <a aria-label="Mandats externes " data-skipextcss="true" href="/eak/fr/home/Firmen/externe_auftraege.html" title="Mandats externes ">Mandats externes </a>
# </li>
# <li>
# <a aria-label="Travailler à l’étranger" data-skipextcss="true" href="/eak/fr/home/Firmen/arbeiten_im_ausland.html" title="Travailler à l’étranger">Travailler à l’étranger</a>
# </li>
# <li>
# <a aria-label="Cotisations et salaires" data-skipextcss="true" href="/eak/fr/home/Firmen/beitraege_und_loehne.html" title="Cotisations et salaires">Cotisations et salaires</a>
# </li>
# <li>
# <a aria-label="Allocations familiales" data-skipextcss="true" href="/eak/fr/home/Firmen/familienzulagen.html" title="Allocations familiales">Allocations familiales</a>
# </li>
# <li>
# <a aria-label="Allocations pour perte de gain" data-skipextcss="true" href="/eak/fr/home/Firmen/erwerbsersatz.html" title="Allocations pour perte de gain">Allocations pour perte de gain</a>
# </li>
# <li>
# <a aria-label="connect.eak" data-skipextcss="true" href="/eak/fr/home/Firmen/connect-eak.html" title="connect.eak">connect.eak</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-sm-6 col-md-3">
# <div class="mod mod-linklist">
# <h2>Particuliers</h2>
# <ul class="list-unstyled">
# <li>
# <a aria-label="Mon compte AVS" data-skipextcss="true" href="/eak/fr/home/dokumentation/mein_ahv-konto.html" title="Mon compte AVS">Mon compte AVS</a>
# </li>
# <li>
# <a aria-label="État civil" data-skipextcss="true" href="/eak/fr/home/dokumentation/zivilstand.html" title="État civil">État civil</a>
# </li>
# <li>
# <a aria-label="Enfants" data-skipextcss="true" href="/eak/fr/home/dokumentation/kinder.html" title="Enfants">Enfants</a>
# </li>
# <li>
# <a aria-label="Travail" data-skipextcss="true" href="/eak/fr/home/dokumentation/arbeit.html" title="Travail">Travail</a>
# </li>
# <li>
# <a aria-label="Interruption de travail, aucune activité lucrative" data-skipextcss="true" href="/eak/fr/home/dokumentation/arbeitsunterbruch_keine_erwerbstaetigkeit.html" title="Interruption de travail, aucune activité lucrative">Interruption de travail, aucune activité lucrative</a>
# </li>
# <li>
# <a aria-label="Départ à la retraite" data-skipextcss="true" href="/eak/fr/home/dokumentation/pensionierung.html" title="Départ à la retraite">Départ à la retraite</a>
# </li>
# <li>
# <a aria-label="À l’étranger" data-skipextcss="true" href="/eak/fr/home/dokumentation/im_ausland.html" title="À l’étranger">À l’étranger</a>
# </li>
# <li>
# <a aria-label="Attestation fiscale" data-skipextcss="true" href="/eak/fr/home/dokumentation/steuerausweis.html" title="Attestation fiscale">Attestation fiscale</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-sm-6 col-md-3">
# <div class="mod mod-linklist">
# <h2>La CFC</h2>
# <ul class="list-unstyled">
# <li>
# <a aria-label="Nos produits" data-skipextcss="true" href="/eak/fr/home/EAK/unsere-leistungen.html" title="Nos produits">Nos produits</a>
# </li>
# <li>
# <a aria-label="Portrait" data-skipextcss="true" href="/eak/fr/home/EAK/portrait.html" title="Portrait">Portrait</a>
# </li>
# <li>
# <a aria-label="Organisation" data-skipextcss="true" href="/eak/fr/home/EAK/organisation.html" title="Organisation">Organisation</a>
# </li>
# <li>
# <a aria-label="Publications" data-skipextcss="true" href="/eak/fr/home/EAK/publikationen.html" title="Publications">Publications</a>
# </li>
# <li>
# <a aria-label="Cours et conseils" data-skipextcss="true" href="/eak/fr/home/EAK/kurse-und-beratung.html" title="Cours et conseils">Cours et conseils</a>
# </li>
# <li>
# <a aria-label="Places vacantes" data-skipextcss="true" href="/eak/fr/home/EAK/offene-stellen0.html" title="Places vacantes">Places vacantes</a>
# </li>
# <li>
# <a aria-label="Contact" data-skipextcss="true" href="/eak/fr/home/EAK/kontakt.html" title="Contact">Contact</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-sm-6 col-md-3">
# <div class="mod mod-linklist">
# </div>
# </div>
# <div class="col-sm-6 col-md-3">
# <div class="mod mod-linklist">
# </div>
# </div>
# <div class="col-sm-6 col-md-3">
# <div class="mod mod-linklist">
# </div>
# </div>
# <div class="col-sm-6 col-md-3">
# <div class="mod mod-linklist">
# </div>
# </div>
# <div class="col-sm-6 col-md-3">
# <div class="mod mod-linklist">
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid">
# <div class="mod mod-cobranding">
# <div class="mod mod-cobranding">
# <div class="row">
# <div class="col-xs-4 col-sm-3 col-md-2">
# <div class="thumbnail-wrapper">
# <a class="thumbnail" data-skipextcss="true" href="/eak/fr/home/EAK/portrait/qualitaetssicherung.html" target="_self">
# <figure><img alt="ISO 9001" src="/eak/fr/_jcr_content/cobranding/logos/12_1712295720710/image.imagespooler.png/1712568149715/2000.200/ISO-9001.png"/><figcaption>
# <span></span>
# </figcaption></figure></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- begin: logo phone -->
# <div class="mod mod-logo">
# <hr class="footer-line visible-xs"/>
# <img alt="Logo Confédération suisse" class="visible-xs" src="/eak/fr/_jcr_content/logo/image.imagespooler.png/1674124776626/logo.png"/>
# </div>
# <!-- end: logo phone -->
# </div>
# <div class="footer-address">
# <span class="hidden-xs">Caisse fédérale de compensation CFC</span>
# <nav class="pull-right">
# <ul>
# <li><a aria-label="Informations juridiques" href="https://www.admin.ch/gov/fr/accueil/conditions-utilisation.html" target="_blank" title="">Informations juridiques</a></li>
# </ul>
# </nav>
# </div>
# </footer>
# <div class="modal" id="nav_modal_rnd">
# <!-- modal -->
# </div>
# </div>
# <!-- end: container -->
# <script src="/etc.clientlibs/clientlibs/granite/jquery/granite/csrf.min.js"></script>
# <script src="/etc/clientlibs/granite/jquery/granite/csrf.min.js"></script>
# <script src="/etc/designs/core/frontend/modules.js" type="text/javascript"></script>
# <!-- ... -->
# <!-- Matomo -->
# <script type="text/javascript">
#   var _paq = window._paq || [];
#   /* tracker methods like "setCustomDimension" should be called before "trackPageView" */
#   _paq.push(['trackPageView']);
#   _paq.push(['enableLinkTracking']);
#   (function() {
#     var u="https://analytics.bit.admin.ch/";
#     _paq.push(['setTrackerUrl', u+'matomo.php']);
#     _paq.push(['setSiteId', '82']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.type='text/javascript'; g.async=true; g.defer=true; g.src=u+'matomo.js'; s.parentNode.insertBefore(g,s);
#   })();
# </script>
# <!-- End Matomo Code -->
# </body>
# </html>

# %% [markdown]
# ### Not necessary (?)

# %%
sitemap = soup.find_all("div", {"class":"mod mod-sitemap"})[0]

# %%
h3_tags = sitemap.find_all("h3")
h3_tags
# Out:
# [<h3>
#  <a aria-label="Entreprises" href="/eak/fr/home/Firmen.html" title="Entreprises">Entreprises</a></h3>,
#  <h3>
#  <a aria-label="Particuliers" href="/eak/fr/home/dokumentation.html" title="Particuliers">Particuliers</a></h3>,
#  <h3>
#  <a aria-label="Formulaires / Annonces" href="/eak/fr/home/formulare.html" title="Formulaires / Annonces">Formulaires / Annonces</a></h3>,
#  <h3>
#  <a aria-label="La CFC" href="/eak/fr/home/EAK.html" title="La CFC">La CFC</a></h3>]

# %%
# Initialize a list to hold the sections
sections = []

# Loop through each h3 tag
for i, h3 in enumerate(h3_tags):
    # Get the next siblings of the current h3 until the next h3
    content = []
    for sibling in h3.next_siblings:
        if sibling.name == "h3":
            break
        if isinstance(sibling, Tag):
            content.append(sibling)
    
    # Add the h3 and its associated content to the sections list
    sections.append({
        'heading': h3.get_text(strip=True),
        'content': content[0].find_all("a") if content else []
    })

# %% [markdown]
# ### Create nested dict for neo4j

# %%
from bs4 import BeautifulSoup
from collections import defaultdict

def build_hierarchy(element, use_href=False):
    """Recursively build a dictionary hierarchy from the HTML structure."""
    hierarchy = defaultdict(dict)
    for tag in element.find_all('li', recursive=False):
        a_tag = tag.find('a', recursive=False)
        if a_tag:
            if use_href:
                key = "https://eak.admin.ch" + a_tag.get('href')
            else:
                key = a_tag.get_text(strip=True)
            
            # Find nested UL (if any) and build its hierarchy
            nested_ul = tag.find('ul', recursive=False)
            if nested_ul:
                hierarchy[key] = build_hierarchy(nested_ul, use_href)
            else:
                hierarchy[key] = {}
    return hierarchy

# %%
# Initialize a dictionary to hold the complete structure
structure = {}

# Option to use href as keys
use_href = False  # Set this to False to use text instead of href

# Find all h3 tags and build the hierarchy under each
for h3 in soup.find_all('h3'):
    first_a = h3.find('a')
    if first_a:
        if use_href:
            h3_heading = "https://eak.admin.ch" + first_a.get('href')
        else:
            h3_heading = first_a.get_text(strip=True)
        
        next_ul = h3.find_next_sibling('ul')
        if next_ul:
            structure[h3_heading] = build_hierarchy(next_ul, use_href)
        else:
            structure[h3_heading] = {}

# Display the hierarchical structure
import pprint
pprint.pprint(structure)
# Out:
# {'Entreprises': defaultdict(<class 'dict'>,
#                             {'Affiliation': defaultdict(<class 'dict'>,
#                                                         {'Contrôle des employeurs': {},
#                                                          'Obligation de s’affilier': {},
#                                                          'Procédure d’affiliation': {},
#                                                          'Succursales': {}}),
#                              'Allocations familiales': defaultdict(<class 'dict'>,
#                                                                    {'Bases': {},
#                                                                     'Dispositions cantonales': {},
#                                                                     'Enfants résidant à l’étranger': {},
#                                                                     'Gestion des dossiers': {},
#                                                                     "Obligation d'informer": defaultdict(<class 'dict'>,
#                                                                                                          {'Devoir d’informer et de collaborer': {},
#                                                                                                           'Fiche informative': {}}),
#                                                                     'Procédure': defaultdict(<class 'dict'>,
#                                                                                              {'Plan de production 2024': {}}),
#                                                                     '«home made» CAF': defaultdict(<class 'dict'>,
#                                                                                                    {'Allocations de formation pour les employeurs «home made»': {},
#                                                                                                     'Enfants domiciliés en Suisse pour les employeurs «home made»': {},
#                                                                                                     'Enfants domiciliés à l’étranger pour les employeurs «home made»': {}})}),
#                              'Allocations pour perte de gain': defaultdict(<class 'dict'>,
#                                                                            {'APG (service militaire, jeunesse et sport)': {},
#                                                                             'Allocation de maternité': {},
#                                                                             'Allocation de paternité, resp. allocation à l’autre parent': {},
#                                                                             'Allocation de prise en charge': {},
#                                                                             'Allocation d‘adoption': {}}),
#                              'Cotisations et salaires': defaultdict(<class 'dict'>,
#                                                                     {'Acomptes de cotisations': {},
#                                                                      'Avenants de salaire et remboursements': {},
#                                                                      'Décompte annuel': {},
#                                                                      'Décompte des salaires et Déclaration de salaires': {},
#                                                                      'Taxe sur le CO2': {},
#                                                                      'eBill': {}}),
#                              'Mandats externes': defaultdict(<class 'dict'>,
#                                                              {'Appréciation par la caisse de compensation': {},
#                                                               'Statut dans le domaine de l‘AVS/AI/APG au regard du droit des assurances sociales': {}}),
#                              'Personnel': defaultdict(<class 'dict'>,
#                                                       {'Annonce de salariés': {},
#                                                        'Certificat d’assurance': {},
#                                                        'Départ de salariés': {}}),
#                              'Travailler à l’étranger': defaultdict(<class 'dict'>,
#                                                                     {'ALPS': {},
#                                                                      'Certificat A1, Certificate of Coverage (CoC)': {},
#                                                                      'Détachement, voyage d’affaires': {},
#                                                                      'Fonctionnaires, personnes exerçant une fonction publique': {},
#                                                                      'Travailler dans plusieurs Etats, pluriactivité': {}}),
#                              'connect.eak': defaultdict(<class 'dict'>,
#                                                         {'Délégations': {}})}),
#  'Formulaires / Annonces': {},
#  'La CFC': defaultdict(<class 'dict'>,
#                        {'Contact': {},
#                         'Cours et conseils': defaultdict(<class 'dict'>,
#                                                          {"Formulaire d'inscription": {},
#                                                           'Offre de cours': {}}),
#                         'Nos produits': defaultdict(<class 'dict'>,
#                                                     {'Allocations familiales (AF)': {},
#                                                      'Assurance-invalidité (AI)': {},
#                                                      'Assurance-vieillesse et survivants (AVS)': {},
#                                                      'Indemnités parentales': {},
#                                                      'Les allocations pour perte de gain (APG)': {}}),
#                         'Organisation': defaultdict(<class 'dict'>,
#                                                     {'Centrale de compensation (CdC)': {},
#                                                      'La gérante de la CFC': {},
#                                                      'Le comité de la caisse': {},
#                                                      'Organigramme': {}}),
#                         'Places vacantes': {},
#                         'Portrait': defaultdict(<class 'dict'>,
#                                                 {'A proximité du client': {},
#                                                  'Assurances qualité': {},
#                                                  'Nos principes': {}}),
#                         'Publications': defaultdict(<class 'dict'>,
#                                                     {'Archives des actualités': {},
#                                                      'Nouveautés pour 2024': {},
#                                                      'Rapports annuels': defaultdict(<class 'dict'>,
#                                                                                      {'Rapport annuel 2023': defaultdict(<class 'dict'>,
#                                                                                                                          {'Allocations familiales': {},
#                                                                                                                           'Aperçu': {},
#                                                                                                                           'Avant-propos': {},
#                                                                                                                           'Cotisations': {},
#                                                                                                                           'Finances': {},
#                                                                                                                           'Impressum': {},
#                                                                                                                           'Prestations': {},
#                                                                                                                           'Services d’état-major': {}})})})}),
#  'Particuliers': defaultdict(<class 'dict'>,
#                              {'Attestation fiscale': {},
#                               'Départ à la retraite': defaultdict(<class 'dict'>,
#                                                                   {'Allocations pour impotent': {},
#                                                                    'Calcul anticipé de la rente': {},
#                                                                    'Flexibilisation de la retraite': defaultdict(<class 'dict'>,
#                                                                                                                  {'Ajournement': {},
#                                                                                                                   'Anticipation': {}}),
#                                                                    'Nouveau calcul de la rente de vieillesse après l’âge de référence': {},
#                                                                    'Obligation de cotiser': {},
#                                                                    'Rente de vieillesse': {},
#                                                                    'Réforme AVS 21': defaultdict(<class 'dict'>,
#                                                                                                  {'Mesures de compensation': {},
#                                                                                                   'Retraite flexible': {},
#                                                                                                   'Supplément de rente': {},
#                                                                                                   'Taux de réduction': {},
#                                                                                                   'Travail après 65 ans': {},
#                                                                                                   'Âge de référence 65 ans': {}}),
#                                                                    'Versements des rentes': {}}),
#                               'Enfants': defaultdict(<class 'dict'>,
#                                                      {'Allocations familiales': {},
#                                                       'Formation': {},
#                                                       'Rente pour l’enfant': {}}),
#                               'Interruption de travail, aucune activité lucrative': defaultdict(<class 'dict'>,
#                                                                                                 {'APG (service militaire, jeunesse et sport)': {},
#                                                                                                  'Allocation de maternité': {},
#                                                                                                  'Allocation de paternité, resp. allocation à l’autre parent': {},
#                                                                                                  'Allocation de prise en charge': {},
#                                                                                                  'Allocation d‘adoption': {},
#                                                                                                  'Congé non payé': {},
#                                                                                                  'Invalidité': {},
#                                                                                                  'Maladie, accident': {},
#                                                                                                  'Personnes sans activité lucrative': {}}),
#                               'Mon compte AVS': defaultdict(<class 'dict'>,
#                                                             {'Certificat d’assurance': {},
#                                                              'Extrait de compte': {}}),
#                               'Travail': defaultdict(<class 'dict'>,
#                                                      {'Emploi': {},
#                                                       'Emploi à temps partiel': {},
#                                                       'Indépendants': {}}),
#                               'À l’étranger': defaultdict(<class 'dict'>,
#                                                           {'Activité lucrative dans plusieurs pays': {},
#                                                            'Activités à l’étranger, détachements': {},
#                                                            'Assurance facultative': {},
#                                                            'Personnes sans activité lucrative à l’étranger': {}}),
#                               'État civil': defaultdict(<class 'dict'>,
#                                                         {'Célibataire, concubinage': {},
#                                                          'Divorce, séparation': {},
#                                                          'Mariage, partenariat enregistré': {},
#                                                          'Veuvage': {}})})}

# %% [markdown]
# - !!! Formulaires/Annonces pas récupérés
#     - eg. formulaires d'allocations familiales

# %% [markdown]
# # Postprocessing

# %% [markdown]
# - for each subtopic
#     - can subtopic be linked to any other subtopic?

# %% [markdown]
# # Neo4j

# %%
from neo4j import GraphDatabase

# %%
# Example connection to Neo4j
driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "neo4j_password"))

# %%
def create_nodes_and_relationships(tx, parent, children):
    for child in children:
        tx.run("MERGE (p:Category {name: $parent}) "
               "MERGE (c:Category {name: $child}) "
               "MERGE (p)-[:CONTAINS]->(c)", parent=parent, child=child)
        # Recursively create relationships for the next level
        create_nodes_and_relationships(tx, child, children[child])

# Start a session and create the graph
with driver.session() as session:
    for parent, children in structure.items():
        session.write_transaction(create_nodes_and_relationships, parent, children)
# Out:
# /var/folders/7_/85hx44gd4sb_6w_n8wqmfj3c0000gn/T/ipykernel_69992/2839144241.py:12: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_nodes_and_relationships, parent, children)

# %% [markdown]
# ### Convert to docs

# %%
# convert to docs
docs = parser.convert_to_documents(content)
docs
